# %%
import pandas as pd
import numpy as np

# %%
movie_data = "graph1-highest_rated.csv"

movie_df = pd.read_csv(movie_data)
movie_df = movie_df.sort_values("avg_vote", ascending=False)
movie_df
# Out:
#          country                    original_title  year   genre    votes  \
# 14407     Turkey                    Hababam Sinifi  1975  Comedy    36269
# 3782         USA          The Shawshank Redemption  1994   Drama  2278845
# 14409      India                       Little Baby  2019  Family     2095
# 14408      India                       Maya Bazaar  1957  Comedy     3813
# 635          USA                     The Godfather  1972   Crime  1572674
# ...          ...                               ...   ...     ...      ...
# 8456     Germany                    Kartoffelsalat  2015  Comedy     6512
# 20009         UK                The Butterfly Ball  1977   Music     2951
# 20010  Indonesia  Hanum & Rangga: Faith & The City  2018   Drama     3490
# 9662      Turkey    Cumali Ceber: Allah Seni Alsin  2017  Comedy    37592
# 20011      India                           Sadak 2  2020  Action    53162
#
#        avg_vote
# 14407       9.3
# 3782        9.3
# 14409       9.2
# 14408       9.2
# 635         9.2
# ...         ...
# 8456        1.3
# 20009       1.3
# 20010       1.2
# 9662        1.0
# 20011       1.0
#
# [20012 rows x 6 columns]

# %%
movie_df.to_dict('records')
# Out:
# [{'country': 'Turkey',
#   'original_title': 'Hababam Sinifi',
#   'year': 1975,
#   'genre': 'Comedy',
#   'votes': 36269,
#   'avg_vote': 9.3},
#  {'country': 'USA',
#   'original_title': 'The Shawshank Redemption',
#   'year': 1994,
#   'genre': 'Drama',
#   'votes': 2278845,
#   'avg_vote': 9.3},
#  {'country': 'India',
#   'original_title': 'Little Baby',
#   'year': 2019,
#   'genre': 'Family',
#   'votes': 2095,
#   'avg_vote': 9.2},
#  {'country': 'India',
#   'original_title': 'Maya Bazaar',
#   'year': 1957,
#   'genre': 'Comedy',
#   'votes': 3813,
#   'avg_vote': 9.2},
#  {'country': 'USA',
#   'original_title': 'The Godfather',
#   'year': 1972,
#   'genre': 'Crime',
#   'votes': 1572674,
#   'avg_vote': 9.2},
#  {'country': 'Bulgaria',
#   'original_title': 'Vchera',
#   'year': 1988,
#   'genre': 'Drama',
#   'votes': 3095,
#   'avg_vote': 9.1},
#  {'country': 'Kosovo',
#   'original_title': 'Zana',
#   'year': 2019,
#   'genre': 'Drama',
#   'votes': 4114,
#   'avg_vote': 9.1},
#  {'country': 'Bangladesh',
#   'original_title': 'Aynabaji',
#   'year': 2016,
#   'genre': 'Crime',
#   'votes': 19876,
#   'avg_vote': 9.1},
#  {'country': 'Bangladesh',
#   'original_title': 'Aguner Poroshmoni',
#   'year': 1994,
#   'genre': 'Drama',
#   'votes': 2618,
#   'avg_vote': 9.1},
#  {'country': 'India',
#   'original_title': 'Natsamrat',
#   'year': 2016,
#   'genre': 'Drama',
#   'votes': 4880,
#   'avg_vote': 9.1},
#  {'country': 'USA',
#   'original_title': 'The Dark Knight',
#   'year': 2008,
#   'genre': 'Action',
#   'votes': 2241615,
#   'avg_vote': 9.0},
#  {'country': 'India',
#   'original_title': 'Peranbu',
#   'year': 2018,
#   'genre': 'Drama',
#   'votes': 11752,
#   'avg_vote': 9.0},
#  {'country': 'India',
#   'original_title': 'C/o Kancharapalem',
#   'year': 2018,
#   'genre': 'Drama',
#   'votes': 3937,
#   'avg_vote': 9.0},
#  {'country': 'Sri Lanka',
#   'original_title': 'Aloko Udapadi',
#   'year': 2017,
#   'genre': 'Drama',
#   'votes': 6618,
#   'avg_vote': 9.0},
#  {'country': 'Yugoslavia',
#   'original_title': 'Maratonci trce pocasni krug',
#   'year': 1982,
#   'genre': 'Comedy',
#   'votes': 14088,
#   'avg_vote': 9.0},
#  {'country': 'Turkey',
#   'original_title': 'Tosun Pasa',
#   'year': 1976,
#   'genre': 'Comedy',
#   'votes': 20968,
#   'avg_vote': 9.0},
#  {'country': 'Turkey',
#   'original_title': 'Hababam Sinifi Sinifta Kaldi',
#   'year': 1976,
#   'genre': 'Comedy',
#   'votes': 21178,
#   'avg_vote': 9.0},
#  {'country': 'Georgia',
#   'original_title': 'Ekvtime: Man of God',
#   'year': 2018,
#   'genre': 'Biography',
#   'votes': 2644,
#   'avg_vote': 9.0},
#  {'country': 'Bangladesh',
#   'original_title': 'Oggatonama',
#   'year': 2016,
#   'genre': 'Drama',
#   'votes': 3642,
#   'avg_vote': 9.0},
#  {'country': 'USA',
#   'original_title': 'The Godfather: Part II',
#   'year': 1974,
#   'genre': 'Crime',
#   'votes': 1098714,
#   'avg_vote': 9.0},
#  {'country': 'India',
#   'original_title': 'Sandesham',
#   'year': 1991,
#   'genre': 'Comedy',
#   'votes': 3346,
#   'avg_vote': 9.0},
#  {'country': 'India',
#   'original_title': 'Aha Naa Pellanta',
#   'year': 1987,
#   'genre': 'Comedy',
#   'votes': 2487,
#   'avg_vote': 8.9},
#  {'country': 'Turkey',
#   'original_title': 'Süt Kardesler',
#   'year': 1976,
#   'genre': 'Comedy',
#   'votes': 17971,
#   'avg_vote': 8.9},
#  {'country': 'Yugoslavia',
#   'original_title': 'Ko to tamo peva',
#   'year': 1980,
#   'genre': 'Adventure',
#   'votes': 13665,
#   'avg_vote': 8.9},
#  {'country': 'Romania',
#   'original_title': 'Morometii',
#   'year': 1987,
#   'genre': 'Drama',
#   'votes': 3609,
#   'avg_vote': 8.9},
#  {'country': 'New Zealand',
#   'original_title': 'The Lord of the Rings: The Return of the King',
#   'year': 2003,
#   'genre': 'Action',
#   'votes': 1604280,
#   'avg_vote': 8.9},
#  {'country': 'India',
#   'original_title': 'Heerak Rajar Deshe',
#   'year': 1980,
#   'genre': 'Comedy',
#   'votes': 2192,
#   'avg_vote': 8.9},
#  {'country': 'Yugoslavia',
#   'original_title': 'Balkanski spijun',
#   'year': 1984,
#   'genre': 'Comedy',
#   'votes': 10194,
#   'avg_vote': 8.9},
#  {'country': 'USA',
#   'original_title': "Schindler's List",
#   'year': 1993,
#   'genre': 'Biography',
#   'votes': 1183248,
#   'avg_vote': 8.9},
#  {'country': 'USA',
#   'original_title': 'Pulp Fiction',
#   'year': 1994,
#   'genre': 'Crime',
#   'votes': 1780147,
#   'avg_vote': 8.9},
#  {'country': 'USA',
#   'original_title': '12 Angry Men',
#   'year': 1957,
#   'genre': 'Crime',
#   'votes': 668473,
#   'avg_vote': 8.9},
#  {'country': 'India',
#   'original_title': 'Kireedam',
#   'year': 1989,
#   'genre': 'Action',
#   'votes': 5359,
#   'avg_vote': 8.9},
#  {'country': 'Turkey',
#   'original_title': 'Saban Oglu Saban',
#   'year': 1977,
#   'genre': 'Comedy',
#   'votes': 15764,
#   'avg_vote': 8.8},
#  {'country': 'India',
#   'original_title': 'Upendra',
#   'year': 1999,
#   'genre': 'Drama',
#   'votes': 2363,
#   'avg_vote': 8.8},
#  {'country': 'India',
#   'original_title': 'Dil Bechara',
#   'year': 2020,
#   'genre': 'Comedy',
#   'votes': 101686,
#   'avg_vote': 8.8},
#  {'country': 'India',
#   'original_title': 'Om',
#   'year': 1995,
#   'genre': 'Action',
#   'votes': 2545,
#   'avg_vote': 8.8},
#  {'country': 'India',
#   'original_title': 'Sagara Sangamam',
#   'year': 1983,
#   'genre': 'Musical',
#   'votes': 2681,
#   'avg_vote': 8.8},
#  {'country': 'India',
#   'original_title': 'Nadodikkattu',
#   'year': 1987,
#   'genre': 'Comedy',
#   'votes': 3921,
#   'avg_vote': 8.8},
#  {'country': 'Japan',
#   'original_title': 'Ningen no jôken',
#   'year': 1961,
#   'genre': 'Drama',
#   'votes': 4841,
#   'avg_vote': 8.8},
#  {'country': 'India',
#   'original_title': 'Thevar Magan',
#   'year': 1992,
#   'genre': 'Drama',
#   'votes': 4867,
#   'avg_vote': 8.8},
#  {'country': 'Greece',
#   'original_title': 'Tis kakomoiras',
#   'year': 1963,
#   'genre': 'Comedy',
#   'votes': 2086,
#   'avg_vote': 8.8},
#  {'country': 'Turkey',
#   'original_title': 'Hababam Sinifi Uyaniyor',
#   'year': 1977,
#   'genre': 'Comedy',
#   'votes': 17762,
#   'avg_vote': 8.8},
#  {'country': 'USA',
#   'original_title': 'Forrest Gump',
#   'year': 1994,
#   'genre': 'Drama',
#   'votes': 1755490,
#   'avg_vote': 8.8},
#  {'country': 'UK',
#   'original_title': 'The Phantom of the Opera at the Royal Albert Hall',
#   'year': 2011,
#   'genre': 'Drama',
#   'votes': 7775,
#   'avg_vote': 8.8},
#  {'country': 'USA',
#   'original_title': 'Inception',
#   'year': 2010,
#   'genre': 'Action',
#   'votes': 2002816,
#   'avg_vote': 8.8},
#  {'country': 'UK',
#   'original_title': 'Les Misérables in Concert: The 25th Anniversary',
#   'year': 2010,
#   'genre': 'Drama',
#   'votes': 5215,
#   'avg_vote': 8.8},
#  {'country': 'USA',
#   'original_title': 'Fight Club',
#   'year': 1999,
#   'genre': 'Drama',
#   'votes': 1807440,
#   'avg_vote': 8.8},
#  {'country': 'Italy',
#   'original_title': 'Il buono, il brutto, il cattivo',
#   'year': 1966,
#   'genre': 'Western',
#   'votes': 672499,
#   'avg_vote': 8.8},
#  {'country': 'Turkey',
#   'original_title': 'Dag II',
#   'year': 2016,
#   'genre': 'Action',
#   'votes': 103949,
#   'avg_vote': 8.8},
#  {'country': 'New Zealand',
#   'original_title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'year': 2001,
#   'genre': 'Action',
#   'votes': 1619920,
#   'avg_vote': 8.8},
#  {'country': 'USA',
#   'original_title': 'Wheels',
#   'year': 2014,
#   'genre': 'Drama',
#   'votes': 17814,
#   'avg_vote': 8.8},
#  {'country': 'USA',
#   'original_title': 'Graves End',
#   'year': 2005,
#   'genre': 'Thriller',
#   'votes': 6494,
#   'avg_vote': 8.8},
#  {'country': 'USA',
#   'original_title': 'Kill Bill: The Whole Bloody Affair',
#   'year': 2011,
#   'genre': 'Action',
#   'votes': 5332,
#   'avg_vote': 8.8},
#  {'country': 'USA',
#   'original_title': "One Flew Over the Cuckoo's Nest",
#   'year': 1975,
#   'genre': 'Drama',
#   'votes': 891071,
#   'avg_vote': 8.7},
#  {'country': 'Japan',
#   'original_title': 'Seppuku',
#   'year': 1962,
#   'genre': 'Action',
#   'votes': 37310,
#   'avg_vote': 8.7},
#  {'country': 'USA',
#   'original_title': 'Goodfellas',
#   'year': 1990,
#   'genre': 'Biography',
#   'votes': 991505,
#   'avg_vote': 8.7},
#  {'country': 'New Zealand',
#   'original_title': 'The Lord of the Rings: The Two Towers',
#   'year': 2002,
#   'genre': 'Action',
#   'votes': 1449778,
#   'avg_vote': 8.7},
#  {'country': 'India',
#   'original_title': 'Godhi Banna Sadharana Mykattu',
#   'year': 2016,
#   'genre': 'Drama',
#   'votes': 2448,
#   'avg_vote': 8.7},
#  {'country': 'India',
#   'original_title': 'Nuvvu Naaku Nachchav',
#   'year': 2001,
#   'genre': 'Musical',
#   'votes': 3560,
#   'avg_vote': 8.7},
#  {'country': 'Hungary',
#   'original_title': 'Az ötödik pecsét',
#   'year': 1976,
#   'genre': 'Drama',
#   'votes': 3671,
#   'avg_vote': 8.7},
#  {'country': 'Indonesia',
#   'original_title': 'A Man Called Ahok',
#   'year': 2018,
#   'genre': 'Biography',
#   'votes': 4235,
#   'avg_vote': 8.7},
#  {'country': 'India',
#   'original_title': 'Devasuram',
#   'year': 1993,
#   'genre': 'Action',
#   'votes': 4503,
#   'avg_vote': 8.7},
#  {'country': 'Hungary',
#   'original_title': 'A tanú',
#   'year': 1969,
#   'genre': 'Drama',
#   'votes': 6041,
#   'avg_vote': 8.7},
#  {'country': 'India',
#   'original_title': 'Oru Vadakkan Veeragatha',
#   'year': 1989,
#   'genre': 'Drama',
#   'votes': 4112,
#   'avg_vote': 8.7},
#  {'country': 'Federal Republic of Yugoslavia',
#   'original_title': 'Lajanje na zvezde',
#   'year': 1998,
#   'genre': 'Comedy',
#   'votes': 6481,
#   'avg_vote': 8.7},
#  {'country': 'Turkey',
#   'original_title': 'Hababam Sinifi Tatilde',
#   'year': 1977,
#   'genre': 'Adventure',
#   'votes': 16100,
#   'avg_vote': 8.7},
#  {'country': 'USA',
#   'original_title': 'The Matrix',
#   'year': 1999,
#   'genre': 'Action',
#   'votes': 1632315,
#   'avg_vote': 8.7},
#  {'country': 'UK',
#   'original_title': 'National Theatre Live: Frankenstein',
#   'year': 2011,
#   'genre': 'Drama',
#   'votes': 3062,
#   'avg_vote': 8.7},
#  {'country': 'Federal Republic of Yugoslavia',
#   'original_title': 'Lepa sela lepo gore',
#   'year': 1996,
#   'genre': 'Comedy',
#   'votes': 14304,
#   'avg_vote': 8.7},
#  {'country': 'India',
#   'original_title': 'Manichitrathazhu',
#   'year': 1993,
#   'genre': 'Comedy',
#   'votes': 7990,
#   'avg_vote': 8.7},
#  {'country': 'India',
#   'original_title': 'Ratsasan',
#   'year': 2018,
#   'genre': 'Action',
#   'votes': 19367,
#   'avg_vote': 8.7},
#  {'country': 'USA',
#   'original_title': 'Star Wars: Episode V - The Empire Strikes Back',
#   'year': 1980,
#   'genre': 'Action',
#   'votes': 1132073,
#   'avg_vote': 8.7},
#  {'country': 'USA',
#   'original_title': 'Hamilton',
#   'year': 2020,
#   'genre': 'Biography',
#   'votes': 37551,
#   'avg_vote': 8.7},
#  {'country': 'India',
#   'original_title': 'Anbe Sivam',
#   'year': 2003,
#   'genre': 'Adventure',
#   'votes': 15469,
#   'avg_vote': 8.7},
#  {'country': 'Turkey',
#   'original_title': 'Kibar Feyzo',
#   'year': 1978,
#   'genre': 'Comedy',
#   'votes': 14240,
#   'avg_vote': 8.7},
#  {'country': 'Turkey',
#   'original_title': 'Canim Kardesim',
#   'year': 1973,
#   'genre': 'Drama',
#   'votes': 8348,
#   'avg_vote': 8.7},
#  {'country': 'Turkey',
#   'original_title': 'Neseli Günler',
#   'year': 1978,
#   'genre': 'Comedy',
#   'votes': 9534,
#   'avg_vote': 8.7},
#  {'country': 'Turkey',
#   'original_title': 'Zügürt Aga',
#   'year': 1985,
#   'genre': 'Comedy',
#   'votes': 13367,
#   'avg_vote': 8.7},
#  {'country': 'USA',
#   'original_title': 'The Silence of the Lambs',
#   'year': 1991,
#   'genre': 'Crime',
#   'votes': 1234134,
#   'avg_vote': 8.6},
#  {'country': 'USA',
#   'original_title': 'Interstellar',
#   'year': 2014,
#   'genre': 'Adventure',
#   'votes': 1449256,
#   'avg_vote': 8.6},
#  {'country': 'USA',
#   'original_title': 'Star Wars',
#   'year': 1977,
#   'genre': 'Action',
#   'votes': 1204107,
#   'avg_vote': 8.6},
#  {'country': 'India',
#   'original_title': '96',
#   'year': 2018,
#   'genre': 'Drama',
#   'votes': 16525,
#   'avg_vote': 8.6},
#  {'country': 'India',
#   'original_title': 'Vikram Vedha',
#   'year': 2017,
#   'genre': 'Action',
#   'votes': 24441,
#   'avg_vote': 8.6},
#  {'country': 'India',
#   'original_title': 'Kumbalangi Nights',
#   'year': 2019,
#   'genre': 'Comedy',
#   'votes': 7560,
#   'avg_vote': 8.6},
#  {'country': 'Japan',
#   'original_title': 'Sen to Chihiro no kamikakushi',
#   'year': 2001,
#   'genre': 'Animation',
#   'votes': 626693,
#   'avg_vote': 8.6},
#  {'country': 'Italy',
#   'original_title': 'La vita è bella',
#   'year': 1997,
#   'genre': 'Comedy',
#   'votes': 605648,
#   'avg_vote': 8.6},
#  {'country': 'USA',
#   'original_title': "It's a Wonderful Life",
#   'year': 1946,
#   'genre': 'Drama',
#   'votes': 388310,
#   'avg_vote': 8.6},
#  {'country': 'South Korea',
#   'original_title': 'Gisaengchung',
#   'year': 2019,
#   'genre': 'Comedy',
#   'votes': 470931,
#   'avg_vote': 8.6},
#  {'country': 'Japan',
#   'original_title': 'Shichinin no samurai',
#   'year': 1954,
#   'genre': 'Action',
#   'votes': 307958,
#   'avg_vote': 8.6},
#  {'country': 'USA',
#   'original_title': 'Se7en',
#   'year': 1995,
#   'genre': 'Crime',
#   'votes': 1402015,
#   'avg_vote': 8.6},
#  {'country': 'India',
#   'original_title': 'Moondram Pirai',
#   'year': 1982,
#   'genre': 'Drama',
#   'votes': 2257,
#   'avg_vote': 8.6},
#  {'country': 'India',
#   'original_title': 'Pather Panchali',
#   'year': 1955,
#   'genre': 'Drama',
#   'votes': 22206,
#   'avg_vote': 8.6},
#  {'country': 'Turkey',
#   'original_title': 'Selvi Boylum Al Yazmalim',
#   'year': 1977,
#   'genre': 'Drama',
#   'votes': 14422,
#   'avg_vote': 8.6},
#  {'country': 'Bangladesh',
#   'original_title': 'Matir moina',
#   'year': 2002,
#   'genre': 'Drama',
#   'votes': 3724,
#   'avg_vote': 8.6},
#  {'country': 'USA',
#   'original_title': 'The Green Mile',
#   'year': 1999,
#   'genre': 'Crime',
#   'votes': 1112336,
#   'avg_vote': 8.6},
#  {'country': 'Brazil',
#   'original_title': 'Cidade de Deus',
#   'year': 2002,
#   'genre': 'Crime',
#   'votes': 685856,
#   'avg_vote': 8.6},
#  {'country': 'USA',
#   'original_title': 'Saving Private Ryan',
#   'year': 1998,
#   'genre': 'Drama',
#   'votes': 1203825,
#   'avg_vote': 8.6},
#  {'country': 'India',
#   'original_title': 'Nayakan',
#   'year': 1987,
#   'genre': 'Crime',
#   'votes': 15166,
#   'avg_vote': 8.6},
#  {'country': 'Brazil',
#   'original_title': 'O Auto da Compadecida',
#   'year': 2000,
#   'genre': 'Comedy',
#   'votes': 11127,
#   'avg_vote': 8.6},
#  {'country': 'India',
#   'original_title': 'In Harihar Nagar',
#   'year': 1990,
#   'genre': 'Comedy',
#   'votes': 3026,
#   'avg_vote': 8.6},
#  {'country': 'India',
#   'original_title': 'Pushpaka Vimana',
#   'year': 1987,
#   'genre': 'Comedy',
#   'votes': 3158,
#   'avg_vote': 8.6},
#  {'country': 'Turkey',
#   'original_title': 'Çöpçüler Krali',
#   'year': 1977,
#   'genre': 'Comedy',
#   'votes': 17931,
#   'avg_vote': 8.6},
#  {'country': 'India',
#   'original_title': 'Gol Maal',
#   'year': 1979,
#   'genre': 'Comedy',
#   'votes': 17381,
#   'avg_vote': 8.6},
#  {'country': 'India',
#   'original_title': 'Kilukkam',
#   'year': 1991,
#   'genre': 'Comedy',
#   'votes': 3161,
#   'avg_vote': 8.6},
#  {'country': 'India',
#   'original_title': 'Thoovanathumbikal',
#   'year': 1987,
#   'genre': 'Drama',
#   'votes': 3367,
#   'avg_vote': 8.6},
#  {'country': 'Soviet Union',
#   'original_title': "Operatsiya 'Y' i drugie priklyucheniya Shurika",
#   'year': 1965,
#   'genre': 'Comedy',
#   'votes': 11627,
#   'avg_vote': 8.6},
#  {'country': 'Soviet Union',
#   'original_title': 'Jariskatsis mama',
#   'year': 1964,
#   'genre': 'Drama',
#   'votes': 3811,
#   'avg_vote': 8.6},
#  {'country': 'India',
#   'original_title': 'Spadikam',
#   'year': 1995,
#   'genre': 'Action',
#   'votes': 4429,
#   'avg_vote': 8.6},
#  {'country': 'Bangladesh',
#   'original_title': 'Monpura',
#   'year': 2009,
#   'genre': 'Crime',
#   'votes': 5526,
#   'avg_vote': 8.6},
#  {'country': 'India',
#   'original_title': 'Thillu Mullu',
#   'year': 1981,
#   'genre': 'Comedy',
#   'votes': 2768,
#   'avg_vote': 8.6},
#  {'country': 'India',
#   'original_title': 'Chithram',
#   'year': 1988,
#   'genre': 'Comedy',
#   'votes': 4261,
#   'avg_vote': 8.6},
#  {'country': 'Greece',
#   'original_title': 'Istoria mias kalpikis liras',
#   'year': 1955,
#   'genre': 'Comedy',
#   'votes': 2422,
#   'avg_vote': 8.6},
#  {'country': 'India',
#   'original_title': 'Aaranya Kaandam',
#   'year': 2010,
#   'genre': 'Action',
#   'votes': 3443,
#   'avg_vote': 8.6},
#  {'country': 'Yugoslavia',
#   'original_title': "Varljivo leto '68",
#   'year': 1984,
#   'genre': 'Comedy',
#   'votes': 4714,
#   'avg_vote': 8.6},
#  {'country': 'India',
#   'original_title': 'Godfather',
#   'year': 1991,
#   'genre': 'Comedy',
#   'votes': 2839,
#   'avg_vote': 8.6},
#  {'country': 'India',
#   'original_title': 'Apur Sansar',
#   'year': 1959,
#   'genre': 'Drama',
#   'votes': 11428,
#   'avg_vote': 8.5},
#  {'country': 'USA',
#   'original_title': 'The Lion King',
#   'year': 1994,
#   'genre': 'Animation',
#   'votes': 917248,
#   'avg_vote': 8.5},
#  {'country': 'USA',
#   'original_title': 'Psycho',
#   'year': 1960,
#   'genre': 'Horror',
#   'votes': 586765,
#   'avg_vote': 8.5},
#  {'country': 'USA',
#   'original_title': 'The Departed',
#   'year': 2006,
#   'genre': 'Crime',
#   'votes': 1159703,
#   'avg_vote': 8.5},
#  {'country': 'Italy',
#   'original_title': "C'era una volta il West",
#   'year': 1968,
#   'genre': 'Western',
#   'votes': 295220,
#   'avg_vote': 8.5},
#  {'country': 'USA',
#   'original_title': 'Whiplash',
#   'year': 2014,
#   'genre': 'Drama',
#   'votes': 690732,
#   'avg_vote': 8.5},
#  {'country': 'USA',
#   'original_title': 'City Lights',
#   'year': 1931,
#   'genre': 'Comedy',
#   'votes': 162668,
#   'avg_vote': 8.5},
#  {'country': 'Soviet Union',
#   'original_title': 'Dzhentlmeny udachi',
#   'year': 1971,
#   'genre': 'Comedy',
#   'votes': 10209,
#   'avg_vote': 8.5},
#  {'country': 'UK',
#   'original_title': 'The Prestige',
#   'year': 2006,
#   'genre': 'Drama',
#   'votes': 1155723,
#   'avg_vote': 8.5},
#  {'country': 'USA',
#   'original_title': 'The Usual Suspects',
#   'year': 1995,
#   'genre': 'Crime',
#   'votes': 968947,
#   'avg_vote': 8.5},
#  {'country': 'Turkey',
#   'original_title': 'Ayla: The Daughter of War',
#   'year': 2017,
#   'genre': 'Biography',
#   'votes': 32247,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Mahanati',
#   'year': 2018,
#   'genre': 'Biography',
#   'votes': 9054,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Jersey',
#   'year': 2019,
#   'genre': 'Drama',
#   'votes': 6688,
#   'avg_vote': 8.5},
#  {'country': 'France',
#   'original_title': 'Léon',
#   'year': 1994,
#   'genre': 'Action',
#   'votes': 1007598,
#   'avg_vote': 8.5},
#  {'country': 'USA',
#   'original_title': 'Casablanca',
#   'year': 1942,
#   'genre': 'Drama',
#   'votes': 509953,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Visaaranai',
#   'year': 2015,
#   'genre': 'Crime',
#   'votes': 6711,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Agent Sai Srinivasa Athreya',
#   'year': 2019,
#   'genre': 'Action',
#   'votes': 5585,
#   'avg_vote': 8.5},
#  {'country': 'USA',
#   'original_title': 'Gladiator',
#   'year': 2000,
#   'genre': 'Action',
#   'votes': 1308193,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Pudhu Pettai',
#   'year': 2006,
#   'genre': 'Action',
#   'votes': 4161,
#   'avg_vote': 8.5},
#  {'country': 'UK',
#   'original_title': 'The Pianist',
#   'year': 2002,
#   'genre': 'Biography',
#   'votes': 707942,
#   'avg_vote': 8.5},
#  {'country': 'France',
#   'original_title': 'Intouchables',
#   'year': 2011,
#   'genre': 'Biography',
#   'votes': 736691,
#   'avg_vote': 8.5},
#  {'country': 'Turkey',
#   'original_title': 'Cep Herkülü: Naim Süleymanoglu',
#   'year': 2019,
#   'genre': 'Biography',
#   'votes': 5682,
#   'avg_vote': 8.5},
#  {'country': 'USA',
#   'original_title': 'Terminator 2: Judgment Day',
#   'year': 1991,
#   'genre': 'Action',
#   'votes': 974970,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Angrej',
#   'year': 2015,
#   'genre': 'Romance',
#   'votes': 2838,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Kaithi',
#   'year': 2019,
#   'genre': 'Action',
#   'votes': 8400,
#   'avg_vote': 8.5},
#  {'country': 'Japan',
#   'original_title': 'Hotaru no haka',
#   'year': 1988,
#   'genre': 'Animation',
#   'votes': 225438,
#   'avg_vote': 8.5},
#  {'country': 'USA',
#   'original_title': 'Back to the Future',
#   'year': 1985,
#   'genre': 'Adventure',
#   'votes': 1027330,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Vada Chennai',
#   'year': 2018,
#   'genre': 'Action',
#   'votes': 9563,
#   'avg_vote': 8.5},
#  {'country': 'USA',
#   'original_title': 'Modern Times',
#   'year': 1936,
#   'genre': 'Comedy',
#   'votes': 211250,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Asuran',
#   'year': 2019,
#   'genre': 'Action',
#   'votes': 8648,
#   'avg_vote': 8.5},
#  {'country': 'Italy',
#   'original_title': 'Nuovo Cinema Paradiso',
#   'year': 1988,
#   'genre': 'Drama',
#   'votes': 223050,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Kuruthipunal',
#   'year': 1995,
#   'genre': 'Action',
#   'votes': 3558,
#   'avg_vote': 8.5},
#  {'country': 'USA',
#   'original_title': 'Joker',
#   'year': 2019,
#   'genre': 'Crime',
#   'votes': 855097,
#   'avg_vote': 8.5},
#  {'country': 'USA',
#   'original_title': 'American History X',
#   'year': 1998,
#   'genre': 'Drama',
#   'votes': 1014218,
#   'avg_vote': 8.5},
#  {'country': 'Sweden',
#   'original_title': 'Scener ur ett äktenskap',
#   'year': 1974,
#   'genre': 'Drama',
#   'votes': 3744,
#   'avg_vote': 8.5},
#  {'country': 'France',
#   'original_title': 'Le trou',
#   'year': 1960,
#   'genre': 'Crime',
#   'votes': 14787,
#   'avg_vote': 8.5},
#  {'country': 'Japan',
#   'original_title': 'Ningen no jôken',
#   'year': 1959,
#   'genre': 'Drama',
#   'votes': 6233,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Pyaasa',
#   'year': 1957,
#   'genre': 'Drama',
#   'votes': 5313,
#   'avg_vote': 8.5},
#  {'country': 'Japan',
#   'original_title': 'Ningen no jôken',
#   'year': 1959,
#   'genre': 'Drama',
#   'votes': 4957,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Iruvar',
#   'year': 1997,
#   'genre': 'Biography',
#   'votes': 4557,
#   'avg_vote': 8.5},
#  {'country': 'Iran',
#   'original_title': 'Madar',
#   'year': 1990,
#   'genre': 'Drama',
#   'votes': 3987,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Michael Madana Kama Rajan',
#   'year': 1990,
#   'genre': 'Comedy',
#   'votes': 3575,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Mouna Ragam',
#   'year': 1986,
#   'genre': 'Drama',
#   'votes': 3164,
#   'avg_vote': 8.5},
#  {'country': 'Yugoslavia',
#   'original_title': 'Nacionalna klasa',
#   'year': 1979,
#   'genre': 'Comedy',
#   'votes': 3116,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Mahanadhi',
#   'year': 1994,
#   'genre': 'Crime',
#   'votes': 3021,
#   'avg_vote': 8.5},
#  {'country': 'Federal Republic of Yugoslavia',
#   'original_title': 'Noz',
#   'year': 1999,
#   'genre': 'Drama',
#   'votes': 2871,
#   'avg_vote': 8.5},
#  {'country': 'Bangladesh',
#   'original_title': 'Srabon Megher Din',
#   'year': 2000,
#   'genre': 'Drama',
#   'votes': 2080,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Ramji Rav Speaking',
#   'year': 1989,
#   'genre': 'Comedy',
#   'votes': 2672,
#   'avg_vote': 8.5},
#  {'country': 'Hungary',
#   'original_title': 'A tizedes meg a többiek',
#   'year': 1965,
#   'genre': 'Comedy',
#   'votes': 2114,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Black Friday',
#   'year': 2004,
#   'genre': 'Action',
#   'votes': 18180,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Belaseshe',
#   'year': 2015,
#   'genre': 'Drama',
#   'votes': 2149,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Aa Naluguru',
#   'year': 2004,
#   'genre': 'Drama',
#   'votes': 2541,
#   'avg_vote': 8.5},
#  {'country': 'Turkey',
#   'original_title': 'Gülen Gözler',
#   'year': 1977,
#   'genre': 'Comedy',
#   'votes': 6131,
#   'avg_vote': 8.5},
#  {'country': 'Estonia',
#   'original_title': 'Tõde ja õigus',
#   'year': 2019,
#   'genre': 'Drama',
#   'votes': 2644,
#   'avg_vote': 8.5},
#  {'country': 'Turkey',
#   'original_title': 'Muhsin Bey',
#   'year': 1987,
#   'genre': 'Comedy',
#   'votes': 9560,
#   'avg_vote': 8.5},
#  {'country': 'Romania',
#   'original_title': 'Filantropica',
#   'year': 2002,
#   'genre': 'Comedy',
#   'votes': 12252,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Anand',
#   'year': 1971,
#   'genre': 'Drama',
#   'votes': 28121,
#   'avg_vote': 8.5},
#  {'country': 'Japan',
#   'original_title': 'Suna no onna',
#   'year': 1964,
#   'genre': 'Drama',
#   'votes': 16739,
#   'avg_vote': 8.5},
#  {'country': 'Iran',
#   'original_title': 'Marmoulak',
#   'year': 2004,
#   'genre': 'Comedy',
#   'votes': 13756,
#   'avg_vote': 8.5},
#  {'country': 'Italy',
#   'original_title': 'La meglio gioventù',
#   'year': 2003,
#   'genre': 'Drama',
#   'votes': 20184,
#   'avg_vote': 8.5},
#  {'country': 'Soviet Union',
#   'original_title': 'Brilliantovaya ruka',
#   'year': 1969,
#   'genre': 'Adventure',
#   'votes': 12923,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Aruvi',
#   'year': 2016,
#   'genre': 'Drama',
#   'votes': 10269,
#   'avg_vote': 8.5},
#  {'country': 'Norway',
#   'original_title': 'Flåklypa Grand Prix',
#   'year': 1975,
#   'genre': 'Animation',
#   'votes': 12267,
#   'avg_vote': 8.5},
#  {'country': 'India',
#   'original_title': 'Thalapathi',
#   'year': 1991,
#   'genre': 'Action',
#   'votes': 9485,
#   'avg_vote': 8.5},
#  {'country': 'USA',
#   'original_title': 'Raiders of the Lost Ark',
#   'year': 1981,
#   'genre': 'Action',
#   'votes': 865510,
#   'avg_vote': 8.4},
#  {'country': 'Japan',
#   'original_title': 'Mononoke-hime',
#   'year': 1997,
#   'genre': 'Animation',
#   'votes': 331045,
#   'avg_vote': 8.4},
#  {'country': 'USA',
#   'original_title': 'Paths of Glory',
#   'year': 1957,
#   'genre': 'Drama',
#   'votes': 172671,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Qismat',
#   'year': 2018,
#   'genre': 'Drama',
#   'votes': 2086,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Kirik Party',
#   'year': 2016,
#   'genre': 'Comedy',
#   'votes': 4269,
#   'avg_vote': 8.4},
#  {'country': 'USA',
#   'original_title': 'Django Unchained',
#   'year': 2012,
#   'genre': 'Drama',
#   'votes': 1317856,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Super Deluxe',
#   'year': 2019,
#   'genre': 'Action',
#   'votes': 8238,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Kaakkaa Muttai',
#   'year': 2014,
#   'genre': 'Comedy',
#   'votes': 5225,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Papanasam',
#   'year': 2015,
#   'genre': 'Drama',
#   'votes': 5438,
#   'avg_vote': 8.4},
#  {'country': 'USA',
#   'original_title': 'Sunset Blvd.',
#   'year': 1950,
#   'genre': 'Drama',
#   'votes': 195789,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Kattradhu Thamizh',
#   'year': 2007,
#   'genre': 'Drama',
#   'votes': 2300,
#   'avg_vote': 8.4},
#  {'country': 'USA',
#   'original_title': 'Witness for the Prosecution',
#   'year': 1957,
#   'genre': 'Crime',
#   'votes': 104524,
#   'avg_vote': 8.4},
#  {'country': 'Japan',
#   'original_title': 'Kimi no na wa.',
#   'year': 2016,
#   'genre': 'Animation',
#   'votes': 178480,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Rangasthalam',
#   'year': 2018,
#   'genre': 'Action',
#   'votes': 17902,
#   'avg_vote': 8.4},
#  {'country': 'USA',
#   'original_title': 'Spider-Man: Into the Spider-Verse',
#   'year': 2018,
#   'genre': 'Animation',
#   'votes': 335892,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Dangal',
#   'year': 2016,
#   'genre': 'Action',
#   'votes': 147907,
#   'avg_vote': 8.4},
#  {'country': 'Japan',
#   'original_title': 'Sanshô dayû',
#   'year': 1954,
#   'genre': 'Drama',
#   'votes': 14034,
#   'avg_vote': 8.4},
#  {'country': 'USA',
#   'original_title': 'Once Upon a Time in America',
#   'year': 1984,
#   'genre': 'Crime',
#   'votes': 302317,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Ulidavaru Kandanthe',
#   'year': 2014,
#   'genre': 'Crime',
#   'votes': 6577,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Aparajito',
#   'year': 1956,
#   'genre': 'Drama',
#   'votes': 11088,
#   'avg_vote': 8.4},
#  {'country': 'Serbia',
#   'original_title': 'Kad porastem bicu Kengur',
#   'year': 2004,
#   'genre': 'Comedy',
#   'votes': 9343,
#   'avg_vote': 8.4},
#  {'country': 'Libya',
#   'original_title': 'Lion of the Desert',
#   'year': 1980,
#   'genre': 'Biography',
#   'votes': 13734,
#   'avg_vote': 8.4},
#  {'country': 'Hungary',
#   'original_title': 'Sátántangó',
#   'year': 1994,
#   'genre': 'Drama',
#   'votes': 9024,
#   'avg_vote': 8.4},
#  {'country': 'Indonesia',
#   'original_title': 'Yowis Ben',
#   'year': 2018,
#   'genre': 'Comedy',
#   'votes': 3080,
#   'avg_vote': 8.4},
#  {'country': 'Romania',
#   'original_title': 'Nea Marin miliardar',
#   'year': 1979,
#   'genre': 'Comedy',
#   'votes': 3309,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Yoddha',
#   'year': 1992,
#   'genre': 'Action',
#   'votes': 3508,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Masoom',
#   'year': 1983,
#   'genre': 'Drama',
#   'votes': 3542,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Kaalapani',
#   'year': 1996,
#   'genre': 'Action',
#   'votes': 3566,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Pathemari',
#   'year': 2015,
#   'genre': 'Drama',
#   'votes': 3676,
#   'avg_vote': 8.4},
#  {'country': 'Soviet Union',
#   'original_title': "V boy idut odni 'stariki'",
#   'year': 1974,
#   'genre': 'Comedy',
#   'votes': 4475,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Pithamagan',
#   'year': 2003,
#   'genre': 'Action',
#   'votes': 4743,
#   'avg_vote': 8.4},
#  {'country': 'Federal Republic of Yugoslavia',
#   'original_title': "Mrtav 'ladan",
#   'year': 2002,
#   'genre': 'Comedy',
#   'votes': 8362,
#   'avg_vote': 8.4},
#  {'country': 'Federal Republic of Yugoslavia',
#   'original_title': 'Mi nismo andjeli',
#   'year': 1992,
#   'genre': 'Comedy',
#   'votes': 7963,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Nil Battey Sannata',
#   'year': 2015,
#   'genre': 'Drama',
#   'votes': 5293,
#   'avg_vote': 8.4},
#  {'country': 'Turkey',
#   'original_title': 'Bizim Aile',
#   'year': 1975,
#   'genre': 'Comedy',
#   'votes': 5603,
#   'avg_vote': 8.4},
#  {'country': 'Serbia',
#   'original_title': 'Profesionalac',
#   'year': 2003,
#   'genre': 'Comedy',
#   'votes': 5947,
#   'avg_vote': 8.4},
#  {'country': 'Turkey',
#   'original_title': 'Uçurtmayi Vurmasinlar',
#   'year': 1989,
#   'genre': 'Crime',
#   'votes': 5980,
#   'avg_vote': 8.4},
#  {'country': 'Turkey',
#   'original_title': 'Zübük',
#   'year': 1980,
#   'genre': 'Comedy',
#   'votes': 6930,
#   'avg_vote': 8.4},
#  {'country': 'Romania',
#   'original_title': 'Mihai Viteazul',
#   'year': 1971,
#   'genre': 'Action',
#   'votes': 6035,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Sadma',
#   'year': 1983,
#   'genre': 'Romance',
#   'votes': 2852,
#   'avg_vote': 8.4},
#  {'country': 'Japan',
#   'original_title': 'Jôi-uchi: Hairyô tsuma shimatsu',
#   'year': 1967,
#   'genre': 'Drama',
#   'votes': 10317,
#   'avg_vote': 8.4},
#  {'country': 'Soviet Union',
#   'original_title': 'Kavkazskaya plennitsa, ili Novye priklyucheniya Shurika',
#   'year': 1967,
#   'genre': 'Adventure',
#   'votes': 10532,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Aditya 369',
#   'year': 1991,
#   'genre': 'Family',
#   'votes': 2223,
#   'avg_vote': 8.4},
#  {'country': 'UK',
#   'original_title': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   'year': 1964,
#   'genre': 'Comedy',
#   'votes': 441115,
#   'avg_vote': 8.4},
#  {'country': 'Soviet Union',
#   'original_title': 'Monanieba',
#   'year': 1984,
#   'genre': 'Drama',
#   'votes': 3827,
#   'avg_vote': 8.4},
#  {'country': 'Hungary',
#   'original_title': 'Macskafogó',
#   'year': 1986,
#   'genre': 'Animation',
#   'votes': 9240,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Thani Oruvan',
#   'year': 2015,
#   'genre': 'Action',
#   'votes': 15768,
#   'avg_vote': 8.4},
#  {'country': 'Japan',
#   'original_title': 'Tengoku to jigoku',
#   'year': 1963,
#   'genre': 'Crime',
#   'votes': 31231,
#   'avg_vote': 8.4},
#  {'country': 'Japan',
#   'original_title': 'Akahige',
#   'year': 1965,
#   'genre': 'Drama',
#   'votes': 16152,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Bharatham',
#   'year': 1991,
#   'genre': 'Musical',
#   'votes': 2204,
#   'avg_vote': 8.4},
#  {'country': 'Soviet Union',
#   'original_title': 'Ivan Vasilevich menyaet professiyu',
#   'year': 1973,
#   'genre': 'Adventure',
#   'votes': 14659,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Guru',
#   'year': 1997,
#   'genre': 'Drama',
#   'votes': 2537,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Vatsalyam',
#   'year': 1993,
#   'genre': 'Drama',
#   'votes': 2248,
#   'avg_vote': 8.4},
#  {'country': 'Soviet Union',
#   'original_title': 'Ostrov Sokrovishch',
#   'year': 1989,
#   'genre': 'Animation',
#   'votes': 2383,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Jaane Bhi Do Yaaro',
#   'year': 1983,
#   'genre': 'Comedy',
#   'votes': 12834,
#   'avg_vote': 8.4},
#  {'country': 'Bulgaria',
#   'original_title': 'Kozijat rog',
#   'year': 1972,
#   'genre': 'Drama',
#   'votes': 2401,
#   'avg_vote': 8.4},
#  {'country': 'France',
#   'original_title': 'Les enfants du paradis',
#   'year': 1945,
#   'genre': 'Drama',
#   'votes': 17829,
#   'avg_vote': 8.4},
#  {'country': 'Mexico',
#   'original_title': 'Macario',
#   'year': 1960,
#   'genre': 'Drama',
#   'votes': 2522,
#   'avg_vote': 8.4},
#  {'country': 'Turkey',
#   'original_title': 'Kapicilar Krali',
#   'year': 1976,
#   'genre': 'Comedy',
#   'votes': 10831,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Joker',
#   'year': 2016,
#   'genre': 'Comedy',
#   'votes': 2867,
#   'avg_vote': 8.4},
#  {'country': 'South Korea',
#   'original_title': 'Oldeuboi',
#   'year': 2003,
#   'genre': 'Action',
#   'votes': 501082,
#   'avg_vote': 8.4},
#  {'country': 'UK',
#   'original_title': 'The Dark Knight Rises',
#   'year': 2012,
#   'genre': 'Action',
#   'votes': 1480582,
#   'avg_vote': 8.4},
#  {'country': 'USA',
#   'original_title': 'WALL·E',
#   'year': 2008,
#   'genre': 'Animation',
#   'votes': 974734,
#   'avg_vote': 8.4},
#  {'country': 'USA',
#   'original_title': 'Rear Window',
#   'year': 1954,
#   'genre': 'Mystery',
#   'votes': 432390,
#   'avg_vote': 8.4},
#  {'country': 'Lebanon',
#   'original_title': 'Capharnaüm',
#   'year': 2018,
#   'genre': 'Drama',
#   'votes': 53506,
#   'avg_vote': 8.4},
#  {'country': 'USA',
#   'original_title': 'The Great Dictator',
#   'year': 1940,
#   'genre': 'Comedy',
#   'votes': 197381,
#   'avg_vote': 8.4},
#  {'country': 'USA',
#   'original_title': 'Coco',
#   'year': 2017,
#   'genre': 'Animation',
#   'votes': 352455,
#   'avg_vote': 8.4},
#  {'country': 'UK',
#   'original_title': 'The Shining',
#   'year': 1980,
#   'genre': 'Drama',
#   'votes': 869480,
#   'avg_vote': 8.4},
#  {'country': 'USA',
#   'original_title': 'Avengers: Endgame',
#   'year': 2019,
#   'genre': 'Action',
#   'votes': 754786,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Taare Zameen Par',
#   'year': 2007,
#   'genre': 'Drama',
#   'votes': 161867,
#   'avg_vote': 8.4},
#  {'country': 'Pakistan',
#   'original_title': 'Khuda Kay Liye',
#   'year': 2007,
#   'genre': 'Drama',
#   'votes': 9036,
#   'avg_vote': 8.4},
#  {'country': 'USA',
#   'original_title': 'Avengers: Infinity War',
#   'year': 2018,
#   'genre': 'Action',
#   'votes': 796486,
#   'avg_vote': 8.4},
#  {'country': 'UK',
#   'original_title': 'Alien',
#   'year': 1979,
#   'genre': 'Horror',
#   'votes': 768874,
#   'avg_vote': 8.4},
#  {'country': 'USA',
#   'original_title': 'Memento',
#   'year': 2000,
#   'genre': 'Mystery',
#   'votes': 1098879,
#   'avg_vote': 8.4},
#  {'country': 'Germany',
#   'original_title': 'Das Leben der Anderen',
#   'year': 2006,
#   'genre': 'Drama',
#   'votes': 349642,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': '3 Idiots',
#   'year': 2009,
#   'genre': 'Comedy',
#   'votes': 332217,
#   'avg_vote': 8.4},
#  {'country': 'USA',
#   'original_title': 'Apocalypse Now',
#   'year': 1979,
#   'genre': 'Drama',
#   'votes': 591251,
#   'avg_vote': 8.4},
#  {'country': 'India',
#   'original_title': 'Apoorva Sagodharargal',
#   'year': 1989,
#   'genre': 'Action',
#   'votes': 3218,
#   'avg_vote': 8.3},
#  {'country': 'Italy',
#   'original_title': 'Rocco e i suoi fratelli',
#   'year': 1960,
#   'genre': 'Crime',
#   'votes': 15986,
#   'avg_vote': 8.3},
#  {'country': 'Japan',
#   'original_title': 'Banshun',
#   'year': 1949,
#   'genre': 'Drama',
#   'votes': 13888,
#   'avg_vote': 8.3},
#  {'country': 'Mexico',
#   'original_title': 'Los olvidados',
#   'year': 1950,
#   'genre': 'Crime',
#   'votes': 17864,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Drishyam',
#   'year': 2013,
#   'genre': 'Crime',
#   'votes': 29766,
#   'avg_vote': 8.3},
#  {'country': 'Iran',
#   'original_title': 'Nema-ye Nazdik',
#   'year': 1990,
#   'genre': 'Biography',
#   'votes': 15063,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Tumbbad',
#   'year': 2018,
#   'genre': 'Drama',
#   'votes': 24345,
#   'avg_vote': 8.3},
#  {'country': 'UK',
#   'original_title': 'Lawrence of Arabia',
#   'year': 1962,
#   'genre': 'Adventure',
#   'votes': 261504,
#   'avg_vote': 8.3},
#  {'country': 'Soviet Union',
#   'original_title': 'Dersu Uzala',
#   'year': 1975,
#   'genre': 'Adventure',
#   'votes': 22988,
#   'avg_vote': 8.3},
#  {'country': 'UK',
#   'original_title': 'Full Metal Jacket',
#   'year': 1987,
#   'genre': 'Drama',
#   'votes': 658175,
#   'avg_vote': 8.3},
#  {'country': 'China',
#   'original_title': 'Huo zhe',
#   'year': 1994,
#   'genre': 'Drama',
#   'votes': 15563,
#   'avg_vote': 8.3},
#  {'country': 'Sweden',
#   'original_title': 'Höstsonaten',
#   'year': 1978,
#   'genre': 'Drama',
#   'votes': 24472,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': 'Double Indemnity',
#   'year': 1944,
#   'genre': 'Crime',
#   'votes': 139564,
#   'avg_vote': 8.3},
#  {'country': 'France',
#   'original_title': "Un condamné à mort s'est échappé ou Le vent souffle où il veut",
#   'year': 1956,
#   'genre': 'Drama',
#   'votes': 18362,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': "Singin' in the Rain",
#   'year': 1952,
#   'genre': 'Comedy',
#   'votes': 213152,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Lucia',
#   'year': 2013,
#   'genre': 'Drama',
#   'votes': 11317,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Sairat',
#   'year': 2016,
#   'genre': 'Drama',
#   'votes': 11018,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Chupke Chupke',
#   'year': 1975,
#   'genre': 'Comedy',
#   'votes': 11306,
#   'avg_vote': 8.3},
#  {'country': 'Turkey',
#   'original_title': 'Masumiyet',
#   'year': 1997,
#   'genre': 'Drama',
#   'votes': 14756,
#   'avg_vote': 8.3},
#  {'country': 'Denmark',
#   'original_title': 'Ordet',
#   'year': 1955,
#   'genre': 'Drama',
#   'votes': 13608,
#   'avg_vote': 8.3},
#  {'country': 'Italy',
#   'original_title': 'Ladri di biciclette',
#   'year': 1948,
#   'genre': 'Drama',
#   'votes': 141507,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Uri: The Surgical Strike',
#   'year': 2019,
#   'genre': 'Action',
#   'votes': 41318,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Dhuruvangal Pathinaaru',
#   'year': 2016,
#   'genre': 'Action',
#   'votes': 11410,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': '1917',
#   'year': 2019,
#   'genre': 'Drama',
#   'votes': 362897,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': 'Toy Story 3',
#   'year': 2010,
#   'genre': 'Animation',
#   'votes': 739717,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': 'Amadeus',
#   'year': 1984,
#   'genre': 'Biography',
#   'votes': 361028,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': 'The Sting',
#   'year': 1973,
#   'genre': 'Comedy',
#   'votes': 236285,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'RangiTaranga',
#   'year': 2015,
#   'genre': 'Mystery',
#   'votes': 12176,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': 'Citizen Kane',
#   'year': 1941,
#   'genre': 'Drama',
#   'votes': 389322,
#   'avg_vote': 8.3},
#  {'country': 'Turkey',
#   'original_title': 'Yedinci Kogustaki Mucize',
#   'year': 2019,
#   'genre': 'Drama',
#   'votes': 28714,
#   'avg_vote': 8.3},
#  {'country': 'Japan',
#   'original_title': 'Ugetsu monogatari',
#   'year': 1953,
#   'genre': 'Drama',
#   'votes': 20036,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Bangalore Days',
#   'year': 2014,
#   'genre': 'Comedy',
#   'votes': 15520,
#   'avg_vote': 8.3},
#  {'country': 'West Germany',
#   'original_title': 'Das Boot',
#   'year': 1981,
#   'genre': 'Adventure',
#   'votes': 226427,
#   'avg_vote': 8.3},
#  {'country': 'Iran',
#   'original_title': 'Jodaeiye Nader az Simin',
#   'year': 2011,
#   'genre': 'Drama',
#   'votes': 214165,
#   'avg_vote': 8.3},
#  {'country': 'UK',
#   'original_title': 'Snatch',
#   'year': 2000,
#   'genre': 'Comedy',
#   'votes': 766589,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': 'The Kid',
#   'year': 1921,
#   'genre': 'Comedy',
#   'votes': 109038,
#   'avg_vote': 8.3},
#  {'country': 'Turkey',
#   'original_title': 'Sürü',
#   'year': 1978,
#   'genre': 'Drama',
#   'votes': 4205,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': 'Taxi Driver',
#   'year': 1976,
#   'genre': 'Crime',
#   'votes': 703264,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': 'Requiem for a Dream',
#   'year': 2000,
#   'genre': 'Drama',
#   'votes': 748291,
#   'avg_vote': 8.3},
#  {'country': 'UK',
#   'original_title': 'A Clockwork Orange',
#   'year': 1971,
#   'genre': 'Crime',
#   'votes': 740301,
#   'avg_vote': 8.3},
#  {'country': 'Iran',
#   'original_title': 'Bacheha-Ye aseman',
#   'year': 1997,
#   'genre': 'Drama',
#   'votes': 62309,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': 'Aliens',
#   'year': 1986,
#   'genre': 'Action',
#   'votes': 639500,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Drushyam',
#   'year': 2014,
#   'genre': 'Crime',
#   'votes': 3395,
#   'avg_vote': 8.3},
#  {'country': 'Germany',
#   'original_title': 'Inglourious Basterds',
#   'year': 2009,
#   'genre': 'Adventure',
#   'votes': 1229958,
#   'avg_vote': 8.3},
#  {'country': 'Germany',
#   'original_title': 'M - Eine Stadt sucht einen Mörder',
#   'year': 1931,
#   'genre': 'Crime',
#   'votes': 139271,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': 'Good Will Hunting',
#   'year': 1997,
#   'genre': 'Drama',
#   'votes': 837379,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Khosla Ka Ghosla!',
#   'year': 2006,
#   'genre': 'Comedy',
#   'votes': 21879,
#   'avg_vote': 8.3},
#  {'country': 'Germany',
#   'original_title': 'Metropolis',
#   'year': 1927,
#   'genre': 'Drama',
#   'votes': 156076,
#   'avg_vote': 8.3},
#  {'country': 'Soviet Union',
#   'original_title': 'Letyat zhuravli',
#   'year': 1957,
#   'genre': 'Drama',
#   'votes': 14508,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': 'Reservoir Dogs',
#   'year': 1992,
#   'genre': 'Crime',
#   'votes': 896551,
#   'avg_vote': 8.3},
#  {'country': 'Italy',
#   'original_title': 'Il sorpasso',
#   'year': 1962,
#   'genre': 'Comedy',
#   'votes': 8790,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': 'American Beauty',
#   'year': 1999,
#   'genre': 'Drama',
#   'votes': 1049009,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Charulata',
#   'year': 1964,
#   'genre': 'Drama',
#   'votes': 4928,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': 'Braveheart',
#   'year': 1995,
#   'genre': 'Biography',
#   'votes': 941683,
#   'avg_vote': 8.3},
#  {'country': 'Soviet Union',
#   'original_title': 'Voyna i mir',
#   'year': 1966,
#   'genre': 'Drama',
#   'votes': 6199,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': 'Vertigo',
#   'year': 1958,
#   'genre': 'Mystery',
#   'votes': 352786,
#   'avg_vote': 8.3},
#  {'country': 'Turkey',
#   'original_title': 'Bizim Için Sampiyon',
#   'year': 2018,
#   'genre': 'Biography',
#   'votes': 8818,
#   'avg_vote': 8.3},
#  {'country': 'UK',
#   'original_title': 'Dom za vesanje',
#   'year': 1988,
#   'genre': 'Comedy',
#   'votes': 24543,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': "It's Such a Beautiful Day",
#   'year': 2012,
#   'genre': 'Animation',
#   'votes': 10514,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Maheshinte Prathikaaram',
#   'year': 2016,
#   'genre': 'Comedy',
#   'votes': 6266,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Ee. Ma. Yau',
#   'year': 2018,
#   'genre': 'Comedy',
#   'votes': 2133,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Virumandi',
#   'year': 2004,
#   'genre': 'Action',
#   'votes': 4175,
#   'avg_vote': 8.3},
#  {'country': 'Soviet Union',
#   'original_title': 'Idi i smotri',
#   'year': 1985,
#   'genre': 'Drama',
#   'votes': 54237,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': 'The Apartment',
#   'year': 1960,
#   'genre': 'Comedy',
#   'votes': 158999,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Jigarthanda',
#   'year': 2014,
#   'genre': 'Action',
#   'votes': 9755,
#   'avg_vote': 8.3},
#  {'country': 'Turkey',
#   'original_title': 'Köyden Indim Sehire',
#   'year': 1974,
#   'genre': 'Adventure',
#   'votes': 9347,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Kshanam',
#   'year': 2016,
#   'genre': 'Thriller',
#   'votes': 4345,
#   'avg_vote': 8.3},
#  {'country': 'Canada',
#   'original_title': 'Incendies',
#   'year': 2010,
#   'genre': 'Drama',
#   'votes': 142557,
#   'avg_vote': 8.3},
#  {'country': 'Egypt',
#   'original_title': 'The Blue Elephant 2',
#   'year': 2019,
#   'genre': 'Drama',
#   'votes': 5587,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Gamyam',
#   'year': 2008,
#   'genre': 'Drama',
#   'votes': 2837,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Angoor',
#   'year': 1982,
#   'genre': 'Comedy',
#   'votes': 4665,
#   'avg_vote': 8.3},
#  {'country': 'Serbia',
#   'original_title': 'Hadersfild',
#   'year': 2007,
#   'genre': 'Drama',
#   'votes': 2586,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Premam',
#   'year': 2015,
#   'genre': 'Comedy',
#   'votes': 16224,
#   'avg_vote': 8.3},
#  {'country': 'South Korea',
#   'original_title': 'So-won',
#   'year': 2013,
#   'genre': 'Drama',
#   'votes': 5179,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Chhello Divas',
#   'year': 2015,
#   'genre': 'Comedy',
#   'votes': 2407,
#   'avg_vote': 8.3},
#  {'country': 'Soviet Union',
#   'original_title': 'Sluzhebnyy roman',
#   'year': 1977,
#   'genre': 'Comedy',
#   'votes': 7945,
#   'avg_vote': 8.3},
#  {'country': 'Yugoslavia',
#   'original_title': 'Sabirni centar',
#   'year': 1989,
#   'genre': 'Comedy',
#   'votes': 2563,
#   'avg_vote': 8.3},
#  {'country': 'Turkey',
#   'original_title': 'Babam ve Oglum',
#   'year': 2005,
#   'genre': 'Drama',
#   'votes': 76026,
#   'avg_vote': 8.3},
#  {'country': 'Japan',
#   'original_title': 'Ikiru',
#   'year': 1952,
#   'genre': 'Drama',
#   'votes': 65369,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Prasthanam',
#   'year': 2010,
#   'genre': 'Action',
#   'votes': 2436,
#   'avg_vote': 8.3},
#  {'country': 'Denmark',
#   'original_title': 'Jagten',
#   'year': 2012,
#   'genre': 'Drama',
#   'votes': 269616,
#   'avg_vote': 8.3},
#  {'country': 'France',
#   'original_title': 'Z',
#   'year': 1969,
#   'genre': 'Crime',
#   'votes': 23239,
#   'avg_vote': 8.3},
#  {'country': 'Soviet Union',
#   'original_title': 'Gamlet',
#   'year': 1964,
#   'genre': 'Drama',
#   'votes': 2429,
#   'avg_vote': 8.3},
#  {'country': 'Soviet Union',
#   'original_title': 'Zolotoy telyonok',
#   'year': 1968,
#   'genre': 'Comedy',
#   'votes': 2381,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': 'Scarface',
#   'year': 1983,
#   'genre': 'Crime',
#   'votes': 721343,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Amaram',
#   'year': 1991,
#   'genre': 'Drama',
#   'votes': 2280,
#   'avg_vote': 8.3},
#  {'country': 'Soviet Union',
#   'original_title': 'Voskhozhdenie',
#   'year': 1977,
#   'genre': 'Drama',
#   'votes': 6102,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Alai Payuthey',
#   'year': 2000,
#   'genre': 'Drama',
#   'votes': 4933,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Mudhalvan',
#   'year': 1999,
#   'genre': 'Action',
#   'votes': 6088,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Pranchiyettan and the Saint',
#   'year': 2010,
#   'genre': 'Comedy',
#   'votes': 4584,
#   'avg_vote': 8.3},
#  {'country': 'India',
#   'original_title': 'Carry on Jatta',
#   'year': 2012,
#   'genre': 'Comedy',
#   'votes': 2927,
#   'avg_vote': 8.3},
#  {'country': 'UK',
#   'original_title': '2001: A Space Odyssey',
#   'year': 1968,
#   'genre': 'Adventure',
#   'votes': 587866,
#   'avg_vote': 8.3},
#  {'country': 'Soviet Union',
#   'original_title': '12 stulev',
#   'year': 1971,
#   'genre': 'Adventure',
#   'votes': 5654,
#   'avg_vote': 8.3},
#  {'country': 'USA',
#   'original_title': 'North by Northwest',
#   'year': 1959,
#   'genre': 'Adventure',
#   'votes': 291628,
#   'avg_vote': 8.3},
#  {'country': 'France',
#   'original_title': "Le fabuleux destin d'Amélie Poulain",
#   'year': 2001,
#   'genre': 'Comedy',
#   'votes': 690480,
#   'avg_vote': 8.3},
#  {'country': 'Hungary',
#   'original_title': 'Vuk',
#   'year': 1981,
#   'genre': 'Animation',
#   'votes': 5195,
#   'avg_vote': 8.3},
#  {'country': 'India',
# ...
#   'year': 1939,
#   'genre': 'Crime',
#   'votes': 12461,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Dog Day Afternoon',
#   'year': 1975,
#   'genre': 'Biography',
#   'votes': 230684,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'The Little Foxes',
#   'year': 1941,
#   'genre': 'Drama',
#   'votes': 10092,
#   'avg_vote': 8.0},
#  {'country': 'Hong Kong',
#   'original_title': 'Sai yau gei: Sin leui kei yun',
#   'year': 1995,
#   'genre': 'Action',
#   'votes': 6102,
#   'avg_vote': 8.0},
#  {'country': 'France',
#   'original_title': 'Mulholland Dr.',
#   'year': 2001,
#   'genre': 'Drama',
#   'votes': 312966,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Ugly',
#   'year': 2013,
#   'genre': 'Crime',
#   'votes': 19577,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Manjhi: The Mountain Man',
#   'year': 2015,
#   'genre': 'Adventure',
#   'votes': 17434,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Bawarchi',
#   'year': 1972,
#   'genre': 'Comedy',
#   'votes': 3534,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Big Fish',
#   'year': 2003,
#   'genre': 'Adventure',
#   'votes': 408409,
#   'avg_vote': 8.0},
#  {'country': 'UK',
#   'original_title': 'Gandhi',
#   'year': 1982,
#   'genre': 'Biography',
#   'votes': 215222,
#   'avg_vote': 8.0},
#  {'country': 'Russia',
#   'original_title': 'Brat',
#   'year': 1997,
#   'genre': 'Crime',
#   'votes': 16484,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'The Graduate',
#   'year': 1967,
#   'genre': 'Comedy',
#   'votes': 249910,
#   'avg_vote': 8.0},
#  {'country': 'France',
#   'original_title': 'Papillon',
#   'year': 1973,
#   'genre': 'Biography',
#   'votes': 119445,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'The Best Years of Our Lives',
#   'year': 1946,
#   'genre': 'Drama',
#   'votes': 56280,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Togo',
#   'year': 2019,
#   'genre': 'Adventure',
#   'votes': 30833,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Out of the Past',
#   'year': 1947,
#   'genre': 'Crime',
#   'votes': 31759,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Laura',
#   'year': 1944,
#   'genre': 'Drama',
#   'votes': 41682,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'My Name Is Khan',
#   'year': 2010,
#   'genre': 'Drama',
#   'votes': 96685,
#   'avg_vote': 8.0},
#  {'country': 'Greece',
#   'original_title': 'O thiasos',
#   'year': 1975,
#   'genre': 'Drama',
#   'votes': 3351,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Fail Safe',
#   'year': 1964,
#   'genre': 'Drama',
#   'votes': 19263,
#   'avg_vote': 8.0},
#  {'country': 'Spain',
#   'original_title': 'Mar adentro',
#   'year': 2004,
#   'genre': 'Biography',
#   'votes': 76333,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': "Rosemary's Baby",
#   'year': 1968,
#   'genre': 'Drama',
#   'votes': 187646,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Roman Holiday',
#   'year': 1953,
#   'genre': 'Comedy',
#   'votes': 124684,
#   'avg_vote': 8.0},
#  {'country': 'UK',
#   'original_title': 'The Terminator',
#   'year': 1984,
#   'genre': 'Action',
#   'votes': 784356,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'The Grapes of Wrath',
#   'year': 1940,
#   'genre': 'Drama',
#   'votes': 84612,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Aaram Thamburan',
#   'year': 1997,
#   'genre': 'Action',
#   'votes': 2954,
#   'avg_vote': 8.0},
#  {'country': 'Sweden',
#   'original_title': 'Utvandrarna',
#   'year': 1971,
#   'genre': 'Drama',
#   'votes': 5494,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Jalsaghar',
#   'year': 1958,
#   'genre': 'Drama',
#   'votes': 4967,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'The Killing',
#   'year': 1956,
#   'genre': 'Crime',
#   'votes': 79652,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'The Hustler',
#   'year': 1961,
#   'genre': 'Drama',
#   'votes': 73998,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Arsenic and Old Lace',
#   'year': 1944,
#   'genre': 'Comedy',
#   'votes': 64192,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'All Quiet on the Western Front',
#   'year': 1930,
#   'genre': 'Drama',
#   'votes': 56356,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Stalag 17',
#   'year': 1953,
#   'genre': 'Comedy',
#   'votes': 50292,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Cat on a Hot Tin Roof',
#   'year': 1958,
#   'genre': 'Drama',
#   'votes': 43979,
#   'avg_vote': 8.0},
#  {'country': 'Japan',
#   'original_title': 'Akibiyori',
#   'year': 1960,
#   'genre': 'Comedy',
#   'votes': 4439,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'The Thin Man',
#   'year': 1934,
#   'genre': 'Comedy',
#   'votes': 25805,
#   'avg_vote': 8.0},
#  {'country': 'Italy',
#   'original_title': 'La dolce vita',
#   'year': 1960,
#   'genre': 'Comedy',
#   'votes': 64595,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'La La Land',
#   'year': 2016,
#   'genre': 'Comedy',
#   'votes': 488112,
#   'avg_vote': 8.0},
#  {'country': 'France',
#   'original_title': 'Les diaboliques',
#   'year': 1955,
#   'genre': 'Crime',
#   'votes': 60336,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'The Bourne Ultimatum',
#   'year': 2007,
#   'genre': 'Action',
#   'votes': 597616,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Virus',
#   'year': 2019,
#   'genre': 'Drama',
#   'votes': 3659,
#   'avg_vote': 8.0},
#  {'country': 'Spain',
#   'original_title': 'Cría cuervos',
#   'year': 1976,
#   'genre': 'Drama',
#   'votes': 8865,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Iraivi',
#   'year': 2016,
#   'genre': 'Crime',
#   'votes': 2794,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Blade Runner 2049',
#   'year': 2017,
#   'genre': 'Action',
#   'votes': 440890,
#   'avg_vote': 8.0},
#  {'country': 'France',
#   'original_title': 'JFK',
#   'year': 1991,
#   'genre': 'Drama',
#   'votes': 138655,
#   'avg_vote': 8.0},
#  {'country': 'Soviet Union',
#   'original_title': 'Bronenosets Potemkin',
#   'year': 1925,
#   'genre': 'Drama',
#   'votes': 51775,
#   'avg_vote': 8.0},
#  {'country': 'UK',
#   'original_title': 'The Martian',
#   'year': 2015,
#   'genre': 'Adventure',
#   'votes': 740757,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Special Chabbis',
#   'year': 2013,
#   'genre': 'Crime',
#   'votes': 49678,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Uyare',
#   'year': 2019,
#   'genre': 'Drama',
#   'votes': 2256,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Angamaly Diaries',
#   'year': 2017,
#   'genre': 'Action',
#   'votes': 4512,
#   'avg_vote': 8.0},
#  {'country': 'France',
#   'original_title': 'Au revoir les enfants',
#   'year': 1987,
#   'genre': 'Drama',
#   'votes': 30449,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Bound by Honor',
#   'year': 1993,
#   'genre': 'Crime',
#   'votes': 28313,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'The Incredibles',
#   'year': 2004,
#   'genre': 'Animation',
#   'votes': 642759,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Kaamyaab',
#   'year': 2018,
#   'genre': 'Drama',
#   'votes': 3120,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Airlift',
#   'year': 2016,
#   'genre': 'Drama',
#   'votes': 51927,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Vaastav: The Reality',
#   'year': 1999,
#   'genre': 'Action',
#   'votes': 12360,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'The Exorcist',
#   'year': 1973,
#   'genre': 'Horror',
#   'votes': 354234,
#   'avg_vote': 8.0},
#  {'country': 'UK',
#   'original_title': 'Casino Royale',
#   'year': 2006,
#   'genre': 'Action',
#   'votes': 569968,
#   'avg_vote': 8.0},
#  {'country': 'UK',
#   'original_title': "The King's Speech",
#   'year': 2010,
#   'genre': 'Biography',
#   'votes': 628323,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Dances with Wolves',
#   'year': 1990,
#   'genre': 'Adventure',
#   'votes': 235155,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Mishima: A Life in Four Chapters',
#   'year': 1985,
#   'genre': 'Biography',
#   'votes': 8630,
#   'avg_vote': 8.0},
#  {'country': 'South Korea',
#   'original_title': 'Bin-jip',
#   'year': 2004,
#   'genre': 'Crime',
#   'votes': 48839,
#   'avg_vote': 8.0},
#  {'country': 'Switzerland',
#   'original_title': 'Jean de Florette',
#   'year': 1986,
#   'genre': 'Comedy',
#   'votes': 23572,
#   'avg_vote': 8.0},
#  {'country': 'Hong Kong',
#   'original_title': 'Mou gaan dou',
#   'year': 2002,
#   'genre': 'Action',
#   'votes': 116388,
#   'avg_vote': 8.0},
#  {'country': 'Japan',
#   'original_title': 'Pâfekuto burû',
#   'year': 1997,
#   'genre': 'Animation',
#   'votes': 54174,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Kal ho naa ho',
#   'year': 2003,
#   'genre': 'Comedy',
#   'votes': 62020,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Mildred Pierce',
#   'year': 1945,
#   'genre': 'Crime',
#   'votes': 22055,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Rope',
#   'year': 1948,
#   'genre': 'Crime',
#   'votes': 125949,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Brochevarevarura',
#   'year': 2019,
#   'genre': 'Comedy',
#   'votes': 2230,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Jaws',
#   'year': 1975,
#   'genre': 'Adventure',
#   'votes': 535807,
#   'avg_vote': 8.0},
#  {'country': 'Republic of North Macedonia',
#   'original_title': 'Pred dozhdot',
#   'year': 1994,
#   'genre': 'Drama',
#   'votes': 13590,
#   'avg_vote': 8.0},
#  {'country': 'Japan',
#   'original_title': 'Chikamatsu monogatari',
#   'year': 1954,
#   'genre': 'Drama',
#   'votes': 3618,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Anjaam Pathiraa',
#   'year': 2020,
#   'genre': 'Crime',
#   'votes': 3535,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'The Help',
#   'year': 2011,
#   'genre': 'Drama',
#   'votes': 419566,
#   'avg_vote': 8.0},
#  {'country': 'Turkey',
#   'original_title': 'Vizontele',
#   'year': 2001,
#   'genre': 'Comedy',
#   'votes': 32299,
#   'avg_vote': 8.0},
#  {'country': 'West Germany',
#   'original_title': 'Der Himmel über Berlin',
#   'year': 1987,
#   'genre': 'Drama',
#   'votes': 62968,
#   'avg_vote': 8.0},
#  {'country': 'Japan',
#   'original_title': 'Warui yatsu hodo yoku nemuru',
#   'year': 1960,
#   'genre': 'Crime',
#   'votes': 10624,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Monsters, Inc.',
#   'year': 2001,
#   'genre': 'Animation',
#   'votes': 794964,
#   'avg_vote': 8.0},
#  {'country': 'Germany',
#   'original_title': 'Das Testament des Dr. Mabuse',
#   'year': 1933,
#   'genre': 'Crime',
#   'votes': 11162,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Manam',
#   'year': 2014,
#   'genre': 'Comedy',
#   'votes': 9715,
#   'avg_vote': 8.0},
#  {'country': 'France',
#   'original_title': 'Le deuxième souffle',
#   'year': 1966,
#   'genre': 'Crime',
#   'votes': 5302,
#   'avg_vote': 8.0},
#  {'country': 'Turkey',
#   'original_title': 'Devrim Arabalari',
#   'year': 2008,
#   'genre': 'Drama',
#   'votes': 10617,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Pinjar: Beyond Boundaries...',
#   'year': 2003,
#   'genre': 'Drama',
#   'votes': 2502,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Fiddler on the Roof',
#   'year': 1971,
#   'genre': 'Drama',
#   'votes': 38350,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Ratatouille',
#   'year': 2007,
#   'genre': 'Animation',
#   'votes': 624762,
#   'avg_vote': 8.0},
#  {'country': 'South Korea',
#   'original_title': 'Bom Yeoareum Gaeul Gyeoul Geurigo Bom',
#   'year': 2003,
#   'genre': 'Drama',
#   'votes': 75616,
#   'avg_vote': 8.0},
#  {'country': 'UK',
#   'original_title': 'The Imitation Game',
#   'year': 2014,
#   'genre': 'Biography',
#   'votes': 668033,
#   'avg_vote': 8.0},
#  {'country': 'France',
#   'original_title': 'Vivre sa vie: Film en douze tableaux',
#   'year': 1962,
#   'genre': 'Drama',
#   'votes': 26759,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'A Streetcar Named Desire',
#   'year': 1951,
#   'genre': 'Drama',
#   'votes': 97240,
#   'avg_vote': 8.0},
#  {'country': 'Mexico',
#   'original_title': 'La ley de Herodes',
#   'year': 1999,
#   'genre': 'Comedy',
#   'votes': 4646,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Vaaranam Aayiram',
#   'year': 2008,
#   'genre': 'Drama',
#   'votes': 8356,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Opening Night',
#   'year': 1977,
#   'genre': 'Drama',
#   'votes': 8816,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'In a Lonely Place',
#   'year': 1950,
#   'genre': 'Drama',
#   'votes': 25368,
#   'avg_vote': 8.0},
#  {'country': 'Brazil',
#   'original_title': 'Bingo: O Rei das Manhãs',
#   'year': 2017,
#   'genre': 'Biography',
#   'votes': 3944,
#   'avg_vote': 8.0},
#  {'country': 'Iran',
#   'original_title': 'Darbareye Elly',
#   'year': 2009,
#   'genre': 'Drama',
#   'votes': 43558,
#   'avg_vote': 8.0},
#  {'country': 'France',
#   'original_title': 'Jeux interdits',
#   'year': 1952,
#   'genre': 'Comedy',
#   'votes': 10904,
#   'avg_vote': 8.0},
#  {'country': 'Switzerland',
#   'original_title': 'Manon des sources',
#   'year': 1986,
#   'genre': 'Comedy',
#   'votes': 20347,
#   'avg_vote': 8.0},
#  {'country': 'Italy',
#   'original_title': 'La strada',
#   'year': 1954,
#   'genre': 'Drama',
#   'votes': 56965,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'The Revenant',
#   'year': 2015,
#   'genre': 'Action',
#   'votes': 684961,
#   'avg_vote': 8.0},
#  {'country': 'Japan',
#   'original_title': 'Kagemusha',
#   'year': 1980,
#   'genre': 'Drama',
#   'votes': 31273,
#   'avg_vote': 8.0},
#  {'country': 'West Germany',
#   'original_title': 'Alice in den Städten',
#   'year': 1974,
#   'genre': 'Drama',
#   'votes': 9677,
#   'avg_vote': 8.0},
#  {'country': 'India',
#   'original_title': 'Dev.D',
#   'year': 2009,
#   'genre': 'Drama',
#   'votes': 28198,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Aladdin',
#   'year': 1992,
#   'genre': 'Animation',
#   'votes': 363761,
#   'avg_vote': 8.0},
#  {'country': 'Italy',
#   'original_title': 'Roma città aperta',
#   'year': 1945,
#   'genre': 'Drama',
#   'votes': 22689,
#   'avg_vote': 8.0},
#  {'country': 'UK',
#   'original_title': 'Secrets & Lies',
#   'year': 1996,
#   'genre': 'Comedy',
#   'votes': 36481,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Beauty and the Beast',
#   'year': 1991,
#   'genre': 'Animation',
#   'votes': 410499,
#   'avg_vote': 8.0},
#  {'country': 'Japan',
#   'original_title': 'Kôkaku Kidôtai',
#   'year': 1995,
#   'genre': 'Animation',
#   'votes': 125549,
#   'avg_vote': 8.0},
#  {'country': 'UK',
#   'original_title': 'Kind Hearts and Coronets',
#   'year': 1949,
#   'genre': 'Comedy',
#   'votes': 33789,
#   'avg_vote': 8.0},
#  {'country': 'Japan',
#   'original_title': 'Tenkû no shiro Rapyuta',
#   'year': 1986,
#   'genre': 'Animation',
#   'votes': 145338,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Rain Man',
#   'year': 1988,
#   'genre': 'Drama',
#   'votes': 465105,
#   'avg_vote': 8.0},
#  {'country': 'Turkey',
#   'original_title': 'Dedemin Insanlari',
#   'year': 2011,
#   'genre': 'Comedy',
#   'votes': 9092,
#   'avg_vote': 8.0},
#  {'country': 'Germany',
#   'original_title': "Knockin' on Heaven's Door",
#   'year': 1997,
#   'genre': 'Action',
#   'votes': 27031,
#   'avg_vote': 8.0},
#  {'country': 'USA',
#   'original_title': 'Short Term 12',
#   'year': 2013,
#   'genre': 'Drama',
#   'votes': 79731,
#   'avg_vote': 8.0},
#  {'country': 'South Korea',
#   'original_title': 'Yeopgijeogin geunyeo',
#   'year': 2001,
#   'genre': 'Comedy',
#   'votes': 44669,
#   'avg_vote': 8.0},
#  {'country': 'France',
#   'original_title': 'Madame de...',
#   'year': 1953,
#   'genre': 'Drama',
#   'votes': 8632,
#   'avg_vote': 8.0},
#  {'country': 'Italy',
#   'original_title': 'Per un pugno di dollari',
#   'year': 1964,
#   'genre': 'Action',
#   'votes': 192338,
#   'avg_vote': 8.0},
#  {'country': 'UK',
#   'original_title': 'Bohemian Rhapsody',
#   'year': 2018,
#   'genre': 'Biography',
#   'votes': 433549,
#   'avg_vote': 8.0},
#  {'country': 'Italy',
#   'original_title': '8½',
#   'year': 1963,
#   'genre': 'Drama',
#   'votes': 106454,
#   'avg_vote': 8.0},
#  ...]

# %%
profit_data = "graph2-profit.csv"

profit_df = pd.read_csv(profit_data)
profit_df.head()
# Out:
#   country                              original_title  year   genre  avg_vote  \
# 0     USA                           Avengers: Endgame  2019  Action       8.4
# 1     USA                                      Avatar  2009  Action       7.8
# 2     USA                                     Titanic  1997   Drama       7.8
# 3     USA  Star Wars: Episode VII - The Force Awakens  2015  Action       7.9
# 4     USA                      Avengers: Infinity War  2018  Action       8.4
#
#    worlwide_gross_income
# 0           2.797801e+09
# 1           2.790439e+09
# 2           2.195170e+09
# 3           2.068224e+09
# 4           2.048360e+09

# %%
profit_df.to_dict('records')
# Out:
# [{'country': 'USA',
#   'original_title': 'Avengers: Endgame',
#   'year': 2019,
#   'genre': 'Action',
#   'avg_vote': 8.4,
#   'worlwide_gross_income': 2797800564.0},
#  {'country': 'USA',
#   'original_title': 'Avatar',
#   'year': 2009,
#   'genre': 'Action',
#   'avg_vote': 7.8,
#   'worlwide_gross_income': 2790439092.0},
#  {'country': 'USA',
#   'original_title': 'Titanic',
#   'year': 1997,
#   'genre': 'Drama',
#   'avg_vote': 7.8,
#   'worlwide_gross_income': 2195169869.0},
#  {'country': 'USA',
#   'original_title': 'Star Wars: Episode VII - The Force Awakens',
#   'year': 2015,
#   'genre': 'Action',
#   'avg_vote': 7.9,
#   'worlwide_gross_income': 2068224036.0},
#  {'country': 'USA',
#   'original_title': 'Avengers: Infinity War',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 8.4,
#   'worlwide_gross_income': 2048359754.0},
#  {'country': 'USA',
#   'original_title': 'Jurassic World',
#   'year': 2015,
#   'genre': 'Action',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 1670401444.0},
#  {'country': 'USA',
#   'original_title': 'The Lion King',
#   'year': 2019,
#   'genre': 'Animation',
#   'avg_vote': 6.9,
#   'worlwide_gross_income': 1656963790.0},
#  {'country': 'USA',
#   'original_title': 'The Avengers',
#   'year': 2012,
#   'genre': 'Action',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 1518814206.0},
#  {'country': 'USA',
#   'original_title': 'Fast & Furious 7',
#   'year': 2015,
#   'genre': 'Action',
#   'avg_vote': 7.1,
#   'worlwide_gross_income': 1515048151.0},
#  {'country': 'USA',
#   'original_title': 'Frozen II',
#   'year': 2019,
#   'genre': 'Animation',
#   'avg_vote': 6.9,
#   'worlwide_gross_income': 1450026933.0},
#  {'country': 'USA',
#   'original_title': 'Avengers: Age of Ultron',
#   'year': 2015,
#   'genre': 'Action',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 1402808753.0},
#  {'country': 'USA',
#   'original_title': 'Black Panther',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 1347280838.0},
#  {'country': 'UK',
#   'original_title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'year': 2011,
#   'genre': 'Adventure',
#   'avg_vote': 8.1,
#   'worlwide_gross_income': 1342166497.0},
#  {'country': 'USA',
#   'original_title': 'Star Wars: Episode VIII - The Last Jedi',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 1332540187.0},
#  {'country': 'USA',
#   'original_title': 'Jurassic World: Fallen Kingdom',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 6.2,
#   'worlwide_gross_income': 1331958159.0},
#  {'country': 'India',
#   'original_title': 'The Villain',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 5.5,
#   'worlwide_gross_income': 1300000000.0},
#  {'country': 'USA',
#   'original_title': 'Frozen',
#   'year': 2013,
#   'genre': 'Animation',
#   'avg_vote': 7.4,
#   'worlwide_gross_income': 1280803353.0},
#  {'country': 'USA',
#   'original_title': 'Beauty and the Beast',
#   'year': 2017,
#   'genre': 'Family',
#   'avg_vote': 7.1,
#   'worlwide_gross_income': 1264064380.0},
#  {'country': 'USA',
#   'original_title': 'Incredibles 2',
#   'year': 2018,
#   'genre': 'Animation',
#   'avg_vote': 7.6,
#   'worlwide_gross_income': 1242805359.0},
#  {'country': 'China',
#   'original_title': 'The Fate of the Furious',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 6.7,
#   'worlwide_gross_income': 1236005118.0},
#  {'country': 'USA',
#   'original_title': 'Iron Man Three',
#   'year': 2013,
#   'genre': 'Action',
#   'avg_vote': 7.2,
#   'worlwide_gross_income': 1214811252.0},
#  {'country': 'USA',
#   'original_title': 'Minions',
#   'year': 2015,
#   'genre': 'Animation',
#   'avg_vote': 6.4,
#   'worlwide_gross_income': 1159443129.0},
#  {'country': 'USA',
#   'original_title': 'Captain America: Civil War',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 7.8,
#   'worlwide_gross_income': 1153332120.0},
#  {'country': 'USA',
#   'original_title': 'Aquaman',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 6.9,
#   'worlwide_gross_income': 1148485886.0},
#  {'country': 'New Zealand',
#   'original_title': 'The Lord of the Rings: The Return of the King',
#   'year': 2003,
#   'genre': 'Action',
#   'avg_vote': 8.9,
#   'worlwide_gross_income': 1142271098.0},
#  {'country': 'USA',
#   'original_title': 'Spider-Man: Far from Home',
#   'year': 2019,
#   'genre': 'Action',
#   'avg_vote': 7.5,
#   'worlwide_gross_income': 1131927996.0},
#  {'country': 'USA',
#   'original_title': 'Captain Marvel',
#   'year': 2019,
#   'genre': 'Action',
#   'avg_vote': 6.9,
#   'worlwide_gross_income': 1128276090.0},
#  {'country': 'USA',
#   'original_title': 'Transformers: Dark of the Moon',
#   'year': 2011,
#   'genre': 'Action',
#   'avg_vote': 6.2,
#   'worlwide_gross_income': 1123794079.0},
#  {'country': 'UK',
#   'original_title': 'Skyfall',
#   'year': 2012,
#   'genre': 'Action',
#   'avg_vote': 7.7,
#   'worlwide_gross_income': 1108561013.0},
#  {'country': 'USA',
#   'original_title': 'Transformers: Age of Extinction',
#   'year': 2014,
#   'genre': 'Action',
#   'avg_vote': 5.6,
#   'worlwide_gross_income': 1104054072.0},
#  {'country': 'UK',
#   'original_title': 'The Dark Knight Rises',
#   'year': 2012,
#   'genre': 'Action',
#   'avg_vote': 8.4,
#   'worlwide_gross_income': 1081133191.0},
#  {'country': 'USA',
#   'original_title': 'Joker',
#   'year': 2019,
#   'genre': 'Crime',
#   'avg_vote': 8.5,
#   'worlwide_gross_income': 1074251311.0},
#  {'country': 'USA',
#   'original_title': 'Star Wars: Episode IX - The Rise of Skywalker',
#   'year': 2019,
#   'genre': 'Action',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 1074144248.0},
#  {'country': 'USA',
#   'original_title': 'Toy Story 4',
#   'year': 2019,
#   'genre': 'Animation',
#   'avg_vote': 7.8,
#   'worlwide_gross_income': 1073394593.0},
#  {'country': 'USA',
#   'original_title': 'Toy Story 3',
#   'year': 2010,
#   'genre': 'Animation',
#   'avg_vote': 8.3,
#   'worlwide_gross_income': 1066969703.0},
#  {'country': 'USA',
#   'original_title': "Pirates of the Caribbean: Dead Man's Chest",
#   'year': 2006,
#   'genre': 'Action',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 1066179725.0},
#  {'country': 'USA',
#   'original_title': 'Rogue One',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 7.8,
#   'worlwide_gross_income': 1056057720.0},
#  {'country': 'UK',
#   'original_title': 'Aladdin',
#   'year': 2019,
#   'genre': 'Adventure',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 1050693953.0},
#  {'country': 'USA',
#   'original_title': 'Pirates of the Caribbean: On Stranger Tides',
#   'year': 2011,
#   'genre': 'Action',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 1045713802.0},
#  {'country': 'USA',
#   'original_title': 'Despicable Me 3',
#   'year': 2017,
#   'genre': 'Animation',
#   'avg_vote': 6.3,
#   'worlwide_gross_income': 1034799409.0},
#  {'country': 'USA',
#   'original_title': 'Jurassic Park',
#   'year': 1993,
#   'genre': 'Action',
#   'avg_vote': 8.1,
#   'worlwide_gross_income': 1033758854.0},
#  {'country': 'USA',
#   'original_title': 'Finding Dory',
#   'year': 2016,
#   'genre': 'Animation',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 1028570889.0},
#  {'country': 'USA',
#   'original_title': 'Star Wars: Episode I - The Phantom Menace',
#   'year': 1999,
#   'genre': 'Action',
#   'avg_vote': 6.5,
#   'worlwide_gross_income': 1027082707.0},
#  {'country': 'USA',
#   'original_title': 'Alice in Wonderland',
#   'year': 2010,
#   'genre': 'Adventure',
#   'avg_vote': 6.4,
#   'worlwide_gross_income': 1025467110.0},
#  {'country': 'USA',
#   'original_title': 'Zootopia',
#   'year': 2016,
#   'genre': 'Animation',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 1023789075.0},
#  {'country': 'New Zealand',
#   'original_title': 'The Hobbit: An Unexpected Journey',
#   'year': 2012,
#   'genre': 'Adventure',
#   'avg_vote': 7.8,
#   'worlwide_gross_income': 1017003568.0},
#  {'country': 'USA',
#   'original_title': 'The Dark Knight',
#   'year': 2008,
#   'genre': 'Action',
#   'avg_vote': 9.0,
#   'worlwide_gross_income': 1005455211.0},
#  {'country': 'UK',
#   'original_title': "Harry Potter and the Sorcerer's Stone",
#   'year': 2001,
#   'genre': 'Adventure',
#   'avg_vote': 7.6,
#   'worlwide_gross_income': 1001985848.0},
#  {'country': 'UK',
#   'original_title': 'Harry Potter and the Deathly Hallows: Part 1',
#   'year': 2010,
#   'genre': 'Adventure',
#   'avg_vote': 7.7,
#   'worlwide_gross_income': 976952911.0},
#  {'country': 'USA',
#   'original_title': 'Despicable Me 2',
#   'year': 2013,
#   'genre': 'Animation',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 970766005.0},
#  {'country': 'USA',
#   'original_title': 'The Lion King',
#   'year': 1994,
#   'genre': 'Animation',
#   'avg_vote': 8.5,
#   'worlwide_gross_income': 968511805.0},
#  {'country': 'UK',
#   'original_title': 'The Jungle Book',
#   'year': 2016,
#   'genre': 'Adventure',
#   'avg_vote': 7.4,
#   'worlwide_gross_income': 966552003.0},
#  {'country': 'USA',
#   'original_title': 'Jumanji: Welcome to the Jungle',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 6.9,
#   'worlwide_gross_income': 962102237.0},
#  {'country': 'USA',
#   'original_title': "Pirates of the Caribbean: At World's End",
#   'year': 2007,
#   'genre': 'Action',
#   'avg_vote': 7.1,
#   'worlwide_gross_income': 960996492.0},
#  {'country': 'New Zealand',
#   'original_title': 'The Hobbit: The Desolation of Smaug',
#   'year': 2013,
#   'genre': 'Adventure',
#   'avg_vote': 7.8,
#   'worlwide_gross_income': 958366855.0},
#  {'country': 'New Zealand',
#   'original_title': 'The Hobbit: The Battle of the Five Armies',
#   'year': 2014,
#   'genre': 'Adventure',
#   'avg_vote': 7.4,
#   'worlwide_gross_income': 956019788.0},
#  {'country': 'New Zealand',
#   'original_title': 'The Lord of the Rings: The Two Towers',
#   'year': 2002,
#   'genre': 'Action',
#   'avg_vote': 8.7,
#   'worlwide_gross_income': 951227416.0},
#  {'country': 'UK',
#   'original_title': 'Harry Potter and the Order of the Phoenix',
#   'year': 2007,
#   'genre': 'Action',
#   'avg_vote': 7.5,
#   'worlwide_gross_income': 942133343.0},
#  {'country': 'USA',
#   'original_title': 'Finding Nemo',
#   'year': 2003,
#   'genre': 'Animation',
#   'avg_vote': 8.1,
#   'worlwide_gross_income': 940350086.0},
#  {'country': 'UK',
#   'original_title': 'Harry Potter and the Half-Blood Prince',
#   'year': 2009,
#   'genre': 'Action',
#   'avg_vote': 7.6,
#   'worlwide_gross_income': 934408366.0},
#  {'country': 'USA',
#   'original_title': 'Shrek 2',
#   'year': 2004,
#   'genre': 'Animation',
#   'avg_vote': 7.2,
#   'worlwide_gross_income': 928760770.0},
#  {'country': 'UK',
#   'original_title': 'Bohemian Rhapsody',
#   'year': 2018,
#   'genre': 'Biography',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 906884690.0},
#  {'country': 'UK',
#   'original_title': 'Harry Potter and the Goblet of Fire',
#   'year': 2005,
#   'genre': 'Adventure',
#   'avg_vote': 7.7,
#   'worlwide_gross_income': 896381256.0},
#  {'country': 'USA',
#   'original_title': 'Spider-Man 3',
#   'year': 2007,
#   'genre': 'Action',
#   'avg_vote': 6.2,
#   'worlwide_gross_income': 894983373.0},
#  {'country': 'New Zealand',
#   'original_title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'year': 2001,
#   'genre': 'Action',
#   'avg_vote': 8.8,
#   'worlwide_gross_income': 887934303.0},
#  {'country': 'USA',
#   'original_title': 'Ice Age: Dawn of the Dinosaurs',
#   'year': 2009,
#   'genre': 'Animation',
#   'avg_vote': 6.9,
#   'worlwide_gross_income': 886686817.0},
#  {'country': 'UK',
#   'original_title': 'Spectre',
#   'year': 2015,
#   'genre': 'Action',
#   'avg_vote': 6.8,
#   'worlwide_gross_income': 880674609.0},
#  {'country': 'USA',
#   'original_title': 'Spider-Man: Homecoming',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 7.4,
#   'worlwide_gross_income': 880166924.0},
#  {'country': 'UK',
#   'original_title': 'Harry Potter and the Chamber of Secrets',
#   'year': 2002,
#   'genre': 'Adventure',
#   'avg_vote': 7.4,
#   'worlwide_gross_income': 879569371.0},
#  {'country': 'USA',
#   'original_title': 'Ice Age: Continental Drift',
#   'year': 2012,
#   'genre': 'Animation',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 877244782.0},
#  {'country': 'USA',
#   'original_title': 'The Secret Life of Pets',
#   'year': 2016,
#   'genre': 'Animation',
#   'avg_vote': 6.5,
#   'worlwide_gross_income': 875457937.0},
#  {'country': 'USA',
#   'original_title': 'Batman v Superman: Dawn of Justice',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 6.4,
#   'worlwide_gross_income': 873637528.0},
#  {'country': 'China',
#   'original_title': 'Zhan lang II',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 6.0,
#   'worlwide_gross_income': 870325439.0},
#  {'country': 'USA',
#   'original_title': 'Inception',
#   'year': 2010,
#   'genre': 'Action',
#   'avg_vote': 8.8,
#   'worlwide_gross_income': 869784991.0},
#  {'country': 'USA',
#   'original_title': 'Star Wars: Episode III - Revenge of the Sith',
#   'year': 2005,
#   'genre': 'Action',
#   'avg_vote': 7.5,
#   'worlwide_gross_income': 868390560.0},
#  {'country': 'USA',
#   'original_title': 'The Hunger Games: Catching Fire',
#   'year': 2013,
#   'genre': 'Action',
#   'avg_vote': 7.5,
#   'worlwide_gross_income': 865011746.0},
#  {'country': 'USA',
#   'original_title': 'Guardians of the Galaxy Vol. 2',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 7.6,
#   'worlwide_gross_income': 863756051.0},
#  {'country': 'USA',
#   'original_title': 'Inside Out',
#   'year': 2015,
#   'genre': 'Animation',
#   'avg_vote': 8.1,
#   'worlwide_gross_income': 858071350.0},
#  {'country': 'China',
#   'original_title': 'Venom',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 6.7,
#   'worlwide_gross_income': 856085151.0},
#  {'country': 'USA',
#   'original_title': 'Thor: Ragnarok',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 7.9,
#   'worlwide_gross_income': 853979142.0},
#  {'country': 'USA',
#   'original_title': 'Transformers: Revenge of the Fallen',
#   'year': 2009,
#   'genre': 'Action',
#   'avg_vote': 6.0,
#   'worlwide_gross_income': 836303693.0},
#  {'country': 'USA',
#   'original_title': 'The Twilight Saga: Breaking Dawn - Part 2',
#   'year': 2012,
#   'genre': 'Adventure',
#   'avg_vote': 5.5,
#   'worlwide_gross_income': 829746820.0},
#  {'country': 'USA',
#   'original_title': 'Spider-Man',
#   'year': 2002,
#   'genre': 'Action',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 825025036.0},
#  {'country': 'USA',
#   'original_title': 'Wonder Woman',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 7.4,
#   'worlwide_gross_income': 821847012.0},
#  {'country': 'USA',
#   'original_title': 'Independence Day',
#   'year': 1996,
#   'genre': 'Action',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 817400891.0},
#  {'country': 'UK',
#   'original_title': 'Fantastic Beasts and Where to Find Them',
#   'year': 2016,
#   'genre': 'Adventure',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 814038508.0},
#  {'country': 'USA',
#   'original_title': 'Shrek the Third',
#   'year': 2007,
#   'genre': 'Animation',
#   'avg_vote': 6.1,
#   'worlwide_gross_income': 813367380.0},
#  {'country': 'USA',
#   'original_title': 'Coco',
#   'year': 2017,
#   'genre': 'Animation',
#   'avg_vote': 8.4,
#   'worlwide_gross_income': 807083670.0},
#  {'country': 'USA',
#   'original_title': 'Jumanji: The Next Level',
#   'year': 2019,
#   'genre': 'Action',
#   'avg_vote': 6.7,
#   'worlwide_gross_income': 796575993.0},
#  {'country': 'UK',
#   'original_title': 'Harry Potter and the Prisoner of Azkaban',
#   'year': 2004,
#   'genre': 'Adventure',
#   'avg_vote': 7.9,
#   'worlwide_gross_income': 796158319.0},
#  {'country': 'USA',
#   'original_title': 'Pirates of the Caribbean: Dead Men Tell No Tales',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 794878815.0},
#  {'country': 'USA',
#   'original_title': 'E.T. the Extra-Terrestrial',
#   'year': 1982,
#   'genre': 'Family',
#   'avg_vote': 7.8,
#   'worlwide_gross_income': 793482178.0},
#  {'country': 'USA',
#   'original_title': '2012',
#   'year': 2009,
#   'genre': 'Action',
#   'avg_vote': 5.8,
#   'worlwide_gross_income': 791217826.0},
#  {'country': 'USA',
#   'original_title': 'Mission: Impossible - Fallout',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 7.7,
#   'worlwide_gross_income': 791120426.0},
#  {'country': 'USA',
#   'original_title': 'Indiana Jones and the Kingdom of the Crystal Skull',
#   'year': 2008,
#   'genre': 'Action',
#   'avg_vote': 6.1,
#   'worlwide_gross_income': 790653942.0},
#  {'country': 'USA',
#   'original_title': 'Spider-Man 2',
#   'year': 2004,
#   'genre': 'Action',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 788976453.0},
#  {'country': 'USA',
#   'original_title': 'Furious 6',
#   'year': 2013,
#   'genre': 'Action',
#   'avg_vote': 7.1,
#   'worlwide_gross_income': 788680968.0},
#  {'country': 'USA',
#   'original_title': 'Deadpool 2',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 7.7,
#   'worlwide_gross_income': 785794179.0},
#  {'country': 'USA',
#   'original_title': 'Deadpool',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 782612155.0},
#  {'country': 'USA',
#   'original_title': 'Star Wars',
#   'year': 1977,
#   'genre': 'Action',
#   'avg_vote': 8.6,
#   'worlwide_gross_income': 775768912.0},
#  {'country': 'USA',
#   'original_title': 'Guardians of the Galaxy',
#   'year': 2014,
#   'genre': 'Action',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 772791156.0},
#  {'country': 'USA',
#   'original_title': 'The Da Vinci Code',
#   'year': 2006,
#   'genre': 'Mystery',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 760006945.0},
#  {'country': 'USA',
#   'original_title': 'Fast & Furious Presents: Hobbs & Shaw',
#   'year': 2019,
#   'genre': 'Action',
#   'avg_vote': 6.4,
#   'worlwide_gross_income': 759056935.0},
#  {'country': 'USA',
#   'original_title': 'Maleficent',
#   'year': 2014,
#   'genre': 'Action',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 758411648.0},
#  {'country': 'USA',
#   'original_title': 'The Amazing Spider-Man',
#   'year': 2012,
#   'genre': 'Action',
#   'avg_vote': 6.9,
#   'worlwide_gross_income': 757930663.0},
#  {'country': 'USA',
#   'original_title': 'The Hunger Games: Mockingjay - Part 1',
#   'year': 2014,
#   'genre': 'Action',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 755356711.0},
#  {'country': 'USA',
#   'original_title': 'Shrek Forever After',
#   'year': 2010,
#   'genre': 'Animation',
#   'avg_vote': 6.3,
#   'worlwide_gross_income': 752600867.0},
#  {'country': 'India',
#   'original_title': 'Chandramukhi',
#   'year': 2005,
#   'genre': 'Action',
#   'avg_vote': 7.1,
#   'worlwide_gross_income': 750000000.0},
#  {'country': 'USA',
#   'original_title': "Madagascar 3: Europe's Most Wanted",
#   'year': 2012,
#   'genre': 'Animation',
#   'avg_vote': 6.8,
#   'worlwide_gross_income': 746921274.0},
#  {'country': 'USA',
#   'original_title': 'Suicide Squad',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 6.0,
#   'worlwide_gross_income': 746846894.0},
#  {'country': 'USA',
#   'original_title': 'X-Men: Days of Future Past',
#   'year': 2014,
#   'genre': 'Action',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 746045700.0},
#  {'country': 'UK',
#   'original_title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   'year': 2005,
#   'genre': 'Adventure',
#   'avg_vote': 6.9,
#   'worlwide_gross_income': 745013115.0},
#  {'country': 'USA',
#   'original_title': 'Monsters University',
#   'year': 2013,
#   'genre': 'Animation',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 743559607.0},
#  {'country': 'USA',
#   'original_title': 'The Matrix Reloaded',
#   'year': 2003,
#   'genre': 'Action',
#   'avg_vote': 7.2,
#   'worlwide_gross_income': 741847890.0},
#  {'country': 'India',
#   'original_title': 'Temper',
#   'year': 2015,
#   'genre': 'Action',
#   'avg_vote': 7.4,
#   'worlwide_gross_income': 740300000.0},
#  {'country': 'India',
#   'original_title': 'Naan Sigappu Manithan',
#   'year': 2014,
#   'genre': 'Action',
#   'avg_vote': 6.5,
#   'worlwide_gross_income': 740000000.0},
#  {'country': 'USA',
#   'original_title': 'Up',
#   'year': 2009,
#   'genre': 'Animation',
#   'avg_vote': 8.2,
#   'worlwide_gross_income': 735099082.0},
#  {'country': 'China',
#   'original_title': 'Ne Zha zhi mo tong jiang shi',
#   'year': 2019,
#   'genre': 'Animation',
#   'avg_vote': 7.5,
#   'worlwide_gross_income': 726063471.0},
#  {'country': 'UK',
#   'original_title': 'Gravity',
#   'year': 2013,
#   'genre': 'Drama',
#   'avg_vote': 7.7,
#   'worlwide_gross_income': 723192705.0},
#  {'country': 'USA',
#   'original_title': 'Captain America: The Winter Soldier',
#   'year': 2014,
#   'genre': 'Action',
#   'avg_vote': 7.7,
#   'worlwide_gross_income': 714421503.0},
#  {'country': 'USA',
#   'original_title': 'The Twilight Saga: Breaking Dawn - Part 1',
#   'year': 2011,
#   'genre': 'Adventure',
#   'avg_vote': 4.9,
#   'worlwide_gross_income': 712205856.0},
#  {'country': 'USA',
#   'original_title': 'The Twilight Saga: New Moon',
#   'year': 2009,
#   'genre': 'Adventure',
#   'avg_vote': 4.7,
#   'worlwide_gross_income': 711025481.0},
#  {'country': 'USA',
#   'original_title': 'Dawn of the Planet of the Apes',
#   'year': 2014,
#   'genre': 'Action',
#   'avg_vote': 7.6,
#   'worlwide_gross_income': 710644566.0},
#  {'country': 'USA',
#   'original_title': 'Transformers',
#   'year': 2007,
#   'genre': 'Action',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 709709780.0},
#  {'country': 'USA',
#   'original_title': 'The Amazing Spider-Man 2',
#   'year': 2014,
#   'genre': 'Action',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 708982323.0},
#  {'country': 'Canada',
#   'original_title': 'It',
#   'year': 2017,
#   'genre': 'Horror',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 701796444.0},
#  {'country': 'China',
#   'original_title': 'Liu lang di qiu',
#   'year': 2019,
#   'genre': 'Action',
#   'avg_vote': 6.0,
#   'worlwide_gross_income': 699856699.0},
#  {'country': 'USA',
#   'original_title': 'The Twilight Saga: Eclipse',
#   'year': 2010,
#   'genre': 'Adventure',
#   'avg_vote': 5.0,
#   'worlwide_gross_income': 698491347.0},
#  {'country': 'USA',
#   'original_title': 'Interstellar',
#   'year': 2014,
#   'genre': 'Adventure',
#   'avg_vote': 8.6,
#   'worlwide_gross_income': 696742056.0},
#  {'country': 'USA',
#   'original_title': 'Mission: Impossible - Ghost Protocol',
#   'year': 2011,
#   'genre': 'Action',
#   'avg_vote': 7.4,
#   'worlwide_gross_income': 694713380.0},
#  {'country': 'USA',
#   'original_title': 'The Hunger Games',
#   'year': 2012,
#   'genre': 'Action',
#   'avg_vote': 7.2,
#   'worlwide_gross_income': 694394724.0},
#  {'country': 'USA',
#   'original_title': 'Mission: Impossible - Rogue Nation',
#   'year': 2015,
#   'genre': 'Action',
#   'avg_vote': 7.4,
#   'worlwide_gross_income': 682716636.0},
#  {'country': 'USA',
#   'original_title': 'Justice League',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 6.3,
#   'worlwide_gross_income': 681871991.0},
#  {'country': 'USA',
#   'original_title': 'Forrest Gump',
#   'year': 1994,
#   'genre': 'Drama',
#   'avg_vote': 8.8,
#   'worlwide_gross_income': 678229452.0},
#  {'country': 'USA',
#   'original_title': 'Doctor Strange',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 7.5,
#   'worlwide_gross_income': 677718395.0},
#  {'country': 'USA',
#   'original_title': 'The Sixth Sense',
#   'year': 1999,
#   'genre': 'Drama',
#   'avg_vote': 8.1,
#   'worlwide_gross_income': 672806292.0},
#  {'country': 'USA',
#   'original_title': 'Man of Steel',
#   'year': 2013,
#   'genre': 'Action',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 668045518.0},
#  {'country': 'USA',
#   'original_title': 'Ice Age: The Meltdown',
#   'year': 2006,
#   'genre': 'Animation',
#   'avg_vote': 6.8,
#   'worlwide_gross_income': 667094506.0},
#  {'country': 'USA',
#   'original_title': 'Kung Fu Panda 2',
#   'year': 2011,
#   'genre': 'Animation',
#   'avg_vote': 7.2,
#   'worlwide_gross_income': 665692281.0},
#  {'country': 'India',
#   'original_title': 'Gopala Gopala',
#   'year': 2015,
#   'genre': 'Comedy',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 660100000.0},
#  {'country': 'USA',
#   'original_title': 'The Hunger Games: Mockingjay - Part 2',
#   'year': 2015,
#   'genre': 'Action',
#   'avg_vote': 6.5,
#   'worlwide_gross_income': 658344137.0},
#  {'country': 'USA',
#   'original_title': 'Big Hero 6',
#   'year': 2014,
#   'genre': 'Animation',
#   'avg_vote': 7.8,
#   'worlwide_gross_income': 657868146.0},
#  {'country': 'UK',
#   'original_title': 'Fantastic Beasts: The Crimes of Grindelwald',
#   'year': 2018,
#   'genre': 'Adventure',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 654855901.0},
#  {'country': 'USA',
#   'original_title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'genre': 'Action',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 654264015.0},
#  {'country': 'USA',
#   'original_title': 'Star Wars: Episode II - Attack of the Clones',
#   'year': 2002,
#   'genre': 'Action',
#   'avg_vote': 6.5,
#   'worlwide_gross_income': 653779970.0},
#  {'country': 'USA',
#   'original_title': 'Thor: The Dark World',
#   'year': 2013,
#   'genre': 'Action',
#   'avg_vote': 6.9,
#   'worlwide_gross_income': 644783140.0},
#  {'country': 'USA',
#   'original_title': 'Moana',
#   'year': 2016,
#   'genre': 'Animation',
#   'avg_vote': 7.6,
#   'worlwide_gross_income': 643347400.0},
#  {'country': 'Japan',
#   'original_title': 'Sing',
#   'year': 2016,
#   'genre': 'Animation',
#   'avg_vote': 7.1,
#   'worlwide_gross_income': 634154922.0},
#  {'country': 'USA',
#   'original_title': 'Kung Fu Panda',
#   'year': 2008,
#   'genre': 'Animation',
#   'avg_vote': 7.5,
#   'worlwide_gross_income': 631746197.0},
#  {'country': 'USA',
#   'original_title': 'The Incredibles',
#   'year': 2004,
#   'genre': 'Animation',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 631606713.0},
#  {'country': 'UK',
#   'original_title': 'The Martian',
#   'year': 2015,
#   'genre': 'Adventure',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 630161890.0},
#  {'country': 'USA',
#   'original_title': 'Hancock',
#   'year': 2008,
#   'genre': 'Action',
#   'avg_vote': 6.4,
#   'worlwide_gross_income': 629443428.0},
#  {'country': 'USA',
#   'original_title': 'Fast Five',
#   'year': 2011,
#   'genre': 'Action',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 626137675.0},
#  {'country': 'USA',
#   'original_title': 'Men in Black 3',
#   'year': 2012,
#   'genre': 'Action',
#   'avg_vote': 6.8,
#   'worlwide_gross_income': 624026776.0},
#  {'country': 'USA',
#   'original_title': 'Iron Man 2',
#   'year': 2010,
#   'genre': 'Action',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 623933331.0},
#  {'country': 'USA',
#   'original_title': 'Ratatouille',
#   'year': 2007,
#   'genre': 'Animation',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 623726085.0},
#  {'country': 'USA',
#   'original_title': 'Ant-Man and the Wasp',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 7.1,
#   'worlwide_gross_income': 622674139.0},
#  {'country': 'USA',
#   'original_title': 'How to Train Your Dragon 2',
#   'year': 2014,
#   'genre': 'Animation',
#   'avg_vote': 7.8,
#   'worlwide_gross_income': 621537519.0},
#  {'country': 'USA',
#   'original_title': 'Logan',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 8.1,
#   'worlwide_gross_income': 619021436.0},
#  {'country': 'USA',
#   'original_title': 'The Lost World: Jurassic Park',
#   'year': 1997,
#   'genre': 'Action',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 618638999.0},
#  {'country': 'UK',
#   'original_title': 'Casino Royale',
#   'year': 2006,
#   'genre': 'Action',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 616501619.0},
#  {'country': 'USA',
#   'original_title': 'The Passion of the Christ',
#   'year': 2004,
#   'genre': 'Drama',
#   'avg_vote': 7.2,
#   'worlwide_gross_income': 612054428.0},
#  {'country': 'USA',
#   'original_title': 'Mamma Mia!',
#   'year': 2008,
#   'genre': 'Comedy',
#   'avg_vote': 6.4,
#   'worlwide_gross_income': 609910134.0},
#  {'country': 'USA',
#   'original_title': 'Life of Pi',
#   'year': 2012,
#   'genre': 'Adventure',
#   'avg_vote': 7.9,
#   'worlwide_gross_income': 609016565.0},
#  {'country': 'USA',
#   'original_title': 'Transformers: The Last Knight',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 5.2,
#   'worlwide_gross_income': 605425157.0},
#  {'country': 'USA',
#   'original_title': 'Madagascar: Escape 2 Africa',
#   'year': 2008,
#   'genre': 'Animation',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 603900354.0},
#  {'country': 'USA',
#   'original_title': 'War of the Worlds',
#   'year': 2005,
#   'genre': 'Adventure',
#   'avg_vote': 6.5,
#   'worlwide_gross_income': 603873119.0},
#  {'country': 'India',
#   'original_title': 'Premam',
#   'year': 2015,
#   'genre': 'Comedy',
#   'avg_vote': 8.3,
#   'worlwide_gross_income': 600000000.0},
#  {'country': 'USA',
#   'original_title': 'Tangled',
#   'year': 2010,
#   'genre': 'Animation',
#   'avg_vote': 7.7,
#   'worlwide_gross_income': 592461732.0},
#  {'country': 'UK',
#   'original_title': 'Quantum of Solace',
#   'year': 2008,
#   'genre': 'Action',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 589580482.0},
#  {'country': 'USA',
#   'original_title': 'Men in Black',
#   'year': 1997,
#   'genre': 'Action',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 589390539.0},
#  {'country': 'USA',
#   'original_title': 'The Croods',
#   'year': 2013,
#   'genre': 'Animation',
#   'avg_vote': 7.2,
#   'worlwide_gross_income': 587204668.0},
#  {'country': 'USA',
#   'original_title': 'The Hangover Part II',
#   'year': 2011,
#   'genre': 'Comedy',
#   'avg_vote': 6.4,
#   'worlwide_gross_income': 586764305.0},
#  {'country': 'USA',
#   'original_title': 'Iron Man',
#   'year': 2008,
#   'genre': 'Action',
#   'avg_vote': 7.9,
#   'worlwide_gross_income': 585796247.0},
#  {'country': 'USA',
#   'original_title': 'I Am Legend',
#   'year': 2007,
#   'genre': 'Action',
#   'avg_vote': 7.2,
#   'worlwide_gross_income': 585410052.0},
#  {'country': 'USA',
#   'original_title': 'Ready Player One',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 7.5,
#   'worlwide_gross_income': 582893671.0},
#  {'country': 'China',
#   'original_title': 'Hong hai xing dong',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 6.7,
#   'worlwide_gross_income': 579330426.0},
#  {'country': 'USA',
#   'original_title': 'Monsters, Inc.',
#   'year': 2001,
#   'genre': 'Animation',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 578981070.0},
#  {'country': 'USA',
#   'original_title': 'Night at the Museum',
#   'year': 2006,
#   'genre': 'Adventure',
#   'avg_vote': 6.4,
#   'worlwide_gross_income': 574480841.0},
#  {'country': 'USA',
#   'original_title': 'Fifty Shades of Grey',
#   'year': 2015,
#   'genre': 'Drama',
#   'avg_vote': 4.1,
#   'worlwide_gross_income': 569651467.0},
#  {'country': 'USA',
#   'original_title': 'Kong: Skull Island',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 566652812.0},
#  {'country': 'USA',
#   'original_title': 'The Smurfs',
#   'year': 2011,
#   'genre': 'Animation',
#   'avg_vote': 5.4,
#   'worlwide_gross_income': 563749323.0},
#  {'country': 'New Zealand',
#   'original_title': 'King Kong',
#   'year': 2005,
#   'genre': 'Action',
#   'avg_vote': 7.2,
#   'worlwide_gross_income': 562363449.0},
#  {'country': 'USA',
#   'original_title': 'Cars 2',
#   'year': 2011,
#   'genre': 'Animation',
#   'avg_vote': 6.1,
#   'worlwide_gross_income': 559852396.0},
#  {'country': 'USA',
#   'original_title': 'Puss in Boots',
#   'year': 2011,
#   'genre': 'Animation',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 554987477.0},
#  {'country': 'China',
#   'original_title': 'Mei ren yu',
#   'year': 2016,
#   'genre': 'Comedy',
#   'avg_vote': 6.2,
#   'worlwide_gross_income': 553810228.0},
#  {'country': 'USA',
#   'original_title': 'Armageddon',
#   'year': 1998,
#   'genre': 'Action',
#   'avg_vote': 6.7,
#   'worlwide_gross_income': 553709788.0},
#  {'country': 'USA',
#   'original_title': 'The Day After Tomorrow',
#   'year': 2004,
#   'genre': 'Action',
#   'avg_vote': 6.4,
#   'worlwide_gross_income': 552639571.0},
#  {'country': 'India',
#   'original_title': 'Naanum Rowdydhaan',
#   'year': 2015,
#   'genre': 'Action',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 550000000.0},
#  {'country': 'USA',
#   'original_title': 'Ted',
#   'year': 2012,
#   'genre': 'Comedy',
#   'avg_vote': 6.9,
#   'worlwide_gross_income': 549368315.0},
#  {'country': 'USA',
#   'original_title': 'Star Wars: Episode V - The Empire Strikes Back',
#   'year': 1980,
#   'genre': 'Action',
#   'avg_vote': 8.7,
#   'worlwide_gross_income': 549265501.0},
#  {'country': 'USA',
#   'original_title': 'American Sniper',
#   'year': 2014,
#   'genre': 'Action',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 547426372.0},
#  {'country': 'USA',
#   'original_title': 'Mission: Impossible II',
#   'year': 2000,
#   'genre': 'Action',
#   'avg_vote': 6.1,
#   'worlwide_gross_income': 546388108.0},
#  {'country': 'China',
#   'original_title': 'Tang ren jie tan an 2',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 6.0,
#   'worlwide_gross_income': 544185156.0},
#  {'country': 'USA',
#   'original_title': 'X-Men: Apocalypse',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 6.9,
#   'worlwide_gross_income': 543934105.0},
#  {'country': 'USA',
#   'original_title': 'Sherlock Holmes: A Game of Shadows',
#   'year': 2011,
#   'genre': 'Action',
#   'avg_vote': 7.5,
#   'worlwide_gross_income': 543848418.0},
#  {'country': 'USA',
#   'original_title': 'Despicable Me',
#   'year': 2010,
#   'genre': 'Animation',
#   'avg_vote': 7.6,
#   'worlwide_gross_income': 543113985.0},
#  {'country': 'USA',
#   'original_title': 'Cinderella',
#   'year': 2015,
#   'genre': 'Drama',
#   'avg_vote': 6.9,
#   'worlwide_gross_income': 542351353.0},
#  {'country': 'USA',
#   'original_title': 'Madagascar',
#   'year': 2005,
#   'genre': 'Animation',
#   'avg_vote': 6.9,
#   'worlwide_gross_income': 542063846.0},
#  {'country': 'USA',
#   'original_title': 'World War Z',
#   'year': 2013,
#   'genre': 'Action',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 540007876.0},
#  {'country': 'USA',
#   'original_title': 'Brave',
#   'year': 2012,
#   'genre': 'Animation',
#   'avg_vote': 7.1,
#   'worlwide_gross_income': 538983207.0},
#  {'country': 'USA',
#   'original_title': 'The Simpsons Movie',
#   'year': 2007,
#   'genre': 'Animation',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 536414270.0},
#  {'country': 'USA',
#   'original_title': 'The Revenant',
#   'year': 2015,
#   'genre': 'Action',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 532950503.0},
#  {'country': 'India',
#   'original_title': 'Shatamanam Bhavati',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 530500000.0},
#  {'country': 'USA',
#   'original_title': 'The Meg',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 5.6,
#   'worlwide_gross_income': 530259473.0},
#  {'country': 'USA',
#   'original_title': 'Ralph Breaks the Internet',
#   'year': 2018,
#   'genre': 'Animation',
#   'avg_vote': 7.1,
#   'worlwide_gross_income': 529323962.0},
#  {'country': 'USA',
#   'original_title': 'Hotel Transylvania 3: Summer Vacation',
#   'year': 2018,
#   'genre': 'Animation',
#   'avg_vote': 6.3,
#   'worlwide_gross_income': 528583774.0},
#  {'country': 'USA',
#   'original_title': 'The Boss Baby',
#   'year': 2017,
#   'genre': 'Animation',
#   'avg_vote': 6.3,
#   'worlwide_gross_income': 527965936.0},
#  {'country': 'UK',
#   'original_title': 'Dunkirk',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 7.9,
#   'worlwide_gross_income': 526949403.0},
#  {'country': 'USA',
#   'original_title': 'Godzilla',
#   'year': 2014,
#   'genre': 'Action',
#   'avg_vote': 6.4,
#   'worlwide_gross_income': 524976069.0},
#  {'country': 'USA',
#   'original_title': 'Sherlock Holmes',
#   'year': 2009,
#   'genre': 'Action',
#   'avg_vote': 7.6,
#   'worlwide_gross_income': 524028679.0},
#  {'country': 'USA',
#   'original_title': 'Meet the Fockers',
#   'year': 2004,
#   'genre': 'Comedy',
#   'avg_vote': 6.3,
#   'worlwide_gross_income': 522657936.0},
#  {'country': 'USA',
#   'original_title': 'How to Train Your Dragon: The Hidden World',
#   'year': 2019,
#   'genre': 'Animation',
#   'avg_vote': 7.5,
#   'worlwide_gross_income': 521800153.0},
#  {'country': 'USA',
#   'original_title': 'WALL·E',
#   'year': 2008,
#   'genre': 'Animation',
#   'avg_vote': 8.4,
#   'worlwide_gross_income': 521311860.0},
#  {'country': 'China',
#   'original_title': 'Kung Fu Panda 3',
#   'year': 2016,
#   'genre': 'Animation',
#   'avg_vote': 7.1,
#   'worlwide_gross_income': 521170825.0},
#  {'country': 'USA',
#   'original_title': 'Terminator 2: Judgment Day',
#   'year': 1991,
#   'genre': 'Action',
#   'avg_vote': 8.5,
#   'worlwide_gross_income': 520884847.0},
#  {'country': 'USA',
#   'original_title': 'Ant-Man',
#   'year': 2015,
#   'genre': 'Action',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 519311965.0},
#  {'country': 'France',
#   'original_title': 'The Grinch',
#   'year': 2018,
#   'genre': 'Animation',
#   'avg_vote': 6.3,
#   'worlwide_gross_income': 511595957.0},
#  {'country': 'India',
#   'original_title': 'Saamy',
#   'year': 2003,
#   'genre': 'Action',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 510000000.0},
#  {'country': 'USA',
#   'original_title': 'Ghost',
#   'year': 1990,
#   'genre': 'Drama',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 505870681.0},
#  {'country': 'USA',
#   'original_title': 'Aladdin',
#   'year': 1992,
#   'genre': 'Animation',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 504050219.0},
#  {'country': 'India',
#   'original_title': 'Bhale Bhale Magadivoy',
#   'year': 2015,
#   'genre': 'Comedy',
#   'avg_vote': 7.8,
#   'worlwide_gross_income': 500500000.0},
#  {'country': 'India',
#   'original_title': 'Mudhalvan',
#   'year': 1999,
#   'genre': 'Action',
#   'avg_vote': 8.3,
#   'worlwide_gross_income': 500000000.0},
#  {'country': 'India',
#   'original_title': 'Unnaipol Oruvan',
#   'year': 2009,
#   'genre': 'Crime',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 500000000.0},
#  {'country': 'India',
#   'original_title': 'Pandiya Naadu',
#   'year': 2013,
#   'genre': 'Action',
#   'avg_vote': 7.2,
#   'worlwide_gross_income': 500000000.0},
#  {'country': 'USA',
#   'original_title': 'Rio 2',
#   'year': 2014,
#   'genre': 'Animation',
#   'avg_vote': 6.3,
#   'worlwide_gross_income': 498781117.0},
#  {'country': 'USA',
#   'original_title': 'Troy',
#   'year': 2004,
#   'genre': 'Drama',
#   'avg_vote': 7.2,
#   'worlwide_gross_income': 497409852.0},
#  {'country': 'USA',
#   'original_title': 'Toy Story 2',
#   'year': 1999,
#   'genre': 'Animation',
#   'avg_vote': 7.9,
#   'worlwide_gross_income': 497374776.0},
#  {'country': 'USA',
#   'original_title': 'How to Train Your Dragon',
#   'year': 2010,
#   'genre': 'Animation',
#   'avg_vote': 8.1,
#   'worlwide_gross_income': 494878759.0},
#  {'country': 'USA',
#   'original_title': 'Twister',
#   'year': 1996,
#   'genre': 'Action',
#   'avg_vote': 6.4,
#   'worlwide_gross_income': 494471524.0},
#  {'country': 'USA',
#   'original_title': 'Oz the Great and Powerful',
#   'year': 2013,
#   'genre': 'Adventure',
#   'avg_vote': 6.3,
#   'worlwide_gross_income': 493311825.0},
#  {'country': 'USA',
#   'original_title': 'Clash of the Titans',
#   'year': 2010,
#   'genre': 'Action',
#   'avg_vote': 5.8,
#   'worlwide_gross_income': 493214993.0},
#  {'country': 'USA',
#   'original_title': 'Maleficent: Mistress of Evil',
#   'year': 2019,
#   'genre': 'Adventure',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 491730089.0},
#  {'country': 'USA',
#   'original_title': 'War for the Planet of the Apes',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 7.4,
#   'worlwide_gross_income': 490719763.0},
#  {'country': 'USA',
#   'original_title': 'Shrek',
#   'year': 2001,
#   'genre': 'Animation',
#   'avg_vote': 7.8,
#   'worlwide_gross_income': 487769799.0},
#  {'country': 'USA',
#   'original_title': 'Mr. & Mrs. Smith',
#   'year': 2005,
#   'genre': 'Action',
#   'avg_vote': 6.5,
#   'worlwide_gross_income': 487287646.0},
#  {'country': 'USA',
#   'original_title': 'Angels & Demons',
#   'year': 2009,
#   'genre': 'Action',
#   'avg_vote': 6.7,
#   'worlwide_gross_income': 485930816.0},
#  {'country': 'USA',
#   'original_title': 'Teenage Mutant Ninja Turtles',
#   'year': 2014,
#   'genre': 'Action',
#   'avg_vote': 5.8,
#   'worlwide_gross_income': 485004754.0},
#  {'country': 'USA',
#   'original_title': 'Bruce Almighty',
#   'year': 2003,
#   'genre': 'Comedy',
#   'avg_vote': 6.8,
#   'worlwide_gross_income': 484592874.0},
#  {'country': 'USA',
#   'original_title': 'Rio',
#   'year': 2011,
#   'genre': 'Animation',
#   'avg_vote': 6.9,
#   'worlwide_gross_income': 483866518.0},
#  {'country': 'USA',
#   'original_title': 'Saving Private Ryan',
#   'year': 1998,
#   'genre': 'Drama',
#   'avg_vote': 8.6,
#   'worlwide_gross_income': 482349603.0},
#  {'country': 'USA',
#   'original_title': 'Rise of the Planet of the Apes',
#   'year': 2011,
#   'genre': 'Action',
#   'avg_vote': 7.6,
#   'worlwide_gross_income': 481800873.0},
#  {'country': 'USA',
#   'original_title': 'Home Alone',
#   'year': 1990,
#   'genre': 'Comedy',
#   'avg_vote': 7.6,
#   'worlwide_gross_income': 477063114.0},
#  {'country': 'USA',
#   'original_title': 'Star Wars: Episode VI - Return of the Jedi',
#   'year': 1983,
#   'genre': 'Action',
#   'avg_vote': 8.3,
#   'worlwide_gross_income': 475347111.0},
#  {'country': 'UK',
#   'original_title': 'Charlie and the Chocolate Factory',
#   'year': 2005,
#   'genre': 'Adventure',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 474968763.0},
#  {'country': 'USA',
#   'original_title': 'Hotel Transylvania 2',
#   'year': 2015,
#   'genre': 'Animation',
#   'avg_vote': 6.7,
#   'worlwide_gross_income': 474800000.0},
#  {'country': 'USA',
#   'original_title': 'Indiana Jones and the Last Crusade',
#   'year': 1989,
#   'genre': 'Action',
#   'avg_vote': 8.2,
#   'worlwide_gross_income': 474310887.0},
#  {'country': 'USA',
#   'original_title': 'San Andreas',
#   'year': 2015,
#   'genre': 'Action',
#   'avg_vote': 6.1,
#   'worlwide_gross_income': 473990832.0},
#  {'country': 'Canada',
#   'original_title': 'It Chapter Two',
#   'year': 2019,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'worlwide_gross_income': 473093228.0},
#  {'country': 'USA',
#   'original_title': 'Jaws',
#   'year': 1975,
#   'genre': 'Adventure',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 471961371.0},
#  {'country': 'USA',
#   'original_title': 'Wreck-It Ralph',
#   'year': 2012,
#   'genre': 'Animation',
#   'avg_vote': 7.7,
#   'worlwide_gross_income': 471222889.0},
#  {'country': 'USA',
#   'original_title': 'The Hangover',
#   'year': 2009,
#   'genre': 'Comedy',
#   'avg_vote': 7.7,
#   'worlwide_gross_income': 469310836.0},
#  {'country': 'USA',
#   'original_title': 'The Lego Movie',
#   'year': 2014,
#   'genre': 'Animation',
#   'avg_vote': 7.7,
#   'worlwide_gross_income': 468060692.0},
#  {'country': 'China',
#   'original_title': 'Bumblebee',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 6.8,
#   'worlwide_gross_income': 467989645.0},
#  {'country': 'USA',
#   'original_title': 'Star Trek Into Darkness',
#   'year': 2013,
#   'genre': 'Action',
#   'avg_vote': 7.7,
#   'worlwide_gross_income': 467365246.0},
#  {'country': 'USA',
#   'original_title': 'The Matrix',
#   'year': 1999,
#   'genre': 'Action',
#   'avg_vote': 8.7,
#   'worlwide_gross_income': 465718588.0},
#  {'country': 'USA',
#   'original_title': 'Gladiator',
#   'year': 2000,
#   'genre': 'Action',
#   'avg_vote': 8.5,
#   'worlwide_gross_income': 465361176.0},
#  {'country': 'USA',
#   'original_title': 'Pretty Woman',
#   'year': 1990,
#   'genre': 'Comedy',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 463407097.0},
#  {'country': 'USA',
#   'original_title': 'Cars',
#   'year': 2006,
#   'genre': 'Animation',
#   'avg_vote': 7.1,
#   'worlwide_gross_income': 461991867.0},
#  {'country': 'Canada',
#   'original_title': 'X-Men: The Last Stand',
#   'year': 2006,
#   'genre': 'Action',
#   'avg_vote': 6.7,
#   'worlwide_gross_income': 460435291.0},
#  {'country': 'USA',
#   'original_title': 'National Treasure: Book of Secrets',
#   'year': 2007,
#   'genre': 'Action',
#   'avg_vote': 6.5,
#   'worlwide_gross_income': 459242249.0},
#  {'country': 'France',
#   'original_title': 'Lucy',
#   'year': 2014,
#   'genre': 'Action',
#   'avg_vote': 6.4,
#   'worlwide_gross_income': 458863600.0},
#  {'country': 'USA',
#   'original_title': 'Mission: Impossible',
#   'year': 1996,
#   'genre': 'Action',
#   'avg_vote': 7.1,
#   'worlwide_gross_income': 457731198.0},
#  {'country': 'USA',
#   'original_title': '300',
#   'year': 2006,
#   'genre': 'Action',
#   'avg_vote': 7.6,
#   'worlwide_gross_income': 456068181.0},
#  {'country': 'USA',
#   'original_title': 'The Last Samurai',
#   'year': 2003,
#   'genre': 'Action',
#   'avg_vote': 7.7,
#   'worlwide_gross_income': 454627263.0},
#  {'country': 'China',
#   'original_title': 'Wo bu shi yao shen',
#   'year': 2018,
#   'genre': 'Comedy',
#   'avg_vote': 7.9,
#   'worlwide_gross_income': 451183391.0},
#  {'country': 'USA',
#   'original_title': "Ocean's Eleven",
#   'year': 2001,
#   'genre': 'Crime',
#   'avg_vote': 7.7,
#   'worlwide_gross_income': 450717150.0},
#  {'country': 'China',
#   'original_title': 'Wo He Wo De Zu Guo',
#   'year': 2019,
#   'genre': 'Drama',
#   'avg_vote': 6.4,
#   'worlwide_gross_income': 450064993.0},
#  {'country': 'USA',
#   'original_title': 'Thor',
#   'year': 2011,
#   'genre': 'Action',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 449326618.0},
#  {'country': 'USA',
#   'original_title': 'Pearl Harbor',
#   'year': 2001,
#   'genre': 'Action',
#   'avg_vote': 6.2,
#   'worlwide_gross_income': 449220945.0},
#  {'country': 'USA',
#   'original_title': 'Tarzan',
#   'year': 1999,
#   'genre': 'Animation',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 448191819.0},
#  {'country': 'USA',
#   'original_title': 'La La Land',
#   'year': 2016,
#   'genre': 'Comedy',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 446486384.0},
#  {'country': 'USA',
#   'original_title': 'Men in Black II',
#   'year': 2002,
#   'genre': 'Action',
#   'avg_vote': 6.2,
#   'worlwide_gross_income': 445135288.0},
#  {'country': 'USA',
#   'original_title': 'The Bourne Ultimatum',
#   'year': 2007,
#   'genre': 'Action',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 444100035.0},
#  {'country': 'USA',
#   'original_title': 'The Mummy Returns',
#   'year': 2001,
#   'genre': 'Action',
#   'avg_vote': 6.3,
#   'worlwide_gross_income': 443280904.0},
#  {'country': 'USA',
#   'original_title': 'Alvin and the Chipmunks: The Squeakquel',
#   'year': 2009,
#   'genre': 'Animation',
#   'avg_vote': 4.5,
#   'worlwide_gross_income': 443140005.0},
#  {'country': 'UK',
#   'original_title': 'Les Misérables',
#   'year': 2012,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'worlwide_gross_income': 441809770.0},
#  {'country': 'USA',
#   'original_title': 'The Exorcist',
#   'year': 1973,
#   'genre': 'Horror',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 441306145.0},
#  {'country': 'USA',
#   'original_title': 'Mrs. Doubtfire',
#   'year': 1993,
#   'genre': 'Comedy',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 441286195.0},
#  {'country': 'USA',
#   'original_title': 'Terminator Genisys',
#   'year': 2015,
#   'genre': 'Action',
#   'avg_vote': 6.3,
#   'worlwide_gross_income': 440603537.0},
#  {'country': 'USA',
#   'original_title': 'Beauty and the Beast',
#   'year': 1991,
#   'genre': 'Animation',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 440118382.0},
#  {'country': 'India',
#   'original_title': 'Padayappa',
#   'year': 1999,
#   'genre': 'Action',
#   'avg_vote': 8.1,
#   'worlwide_gross_income': 440000000.0},
#  {'country': 'China',
#   'original_title': 'Warcraft',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 6.8,
#   'worlwide_gross_income': 439048914.0},
#  {'country': 'USA',
#   'original_title': 'A Star Is Born',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 7.7,
#   'worlwide_gross_income': 436188866.0},
#  {'country': 'USA',
#   'original_title': 'The Greatest Showman',
#   'year': 2017,
#   'genre': 'Biography',
#   'avg_vote': 7.6,
#   'worlwide_gross_income': 435086403.0},
#  {'country': 'USA',
#   'original_title': 'Terminator 3: Rise of the Machines',
#   'year': 2003,
#   'genre': 'Action',
#   'avg_vote': 6.3,
#   'worlwide_gross_income': 433371112.0},
#  {'country': 'USA',
#   'original_title': 'Pokémon: Detective Pikachu',
#   'year': 2019,
#   'genre': 'Action',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 433005346.0},
#  {'country': 'UK',
#   'original_title': 'Die Another Day',
#   'year': 2002,
#   'genre': 'Action',
#   'avg_vote': 6.1,
#   'worlwide_gross_income': 431971116.0},
#  {'country': 'USA',
#   'original_title': 'The Secret Life of Pets 2',
#   'year': 2019,
#   'genre': 'Animation',
#   'avg_vote': 6.5,
#   'worlwide_gross_income': 430051293.0},
#  {'country': 'USA',
#   'original_title': 'Cast Away',
#   'year': 2000,
#   'genre': 'Adventure',
#   'avg_vote': 7.8,
#   'worlwide_gross_income': 429632142.0},
#  {'country': 'USA',
#   'original_title': 'Rampage',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 6.1,
#   'worlwide_gross_income': 428028233.0},
#  {'country': 'UK',
#   'original_title': "The King's Speech",
#   'year': 2010,
#   'genre': 'Biography',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 427374317.0},
#  {'country': 'USA',
#   'original_title': 'The Matrix Revolutions',
#   'year': 2003,
#   'genre': 'Action',
#   'avg_vote': 6.8,
#   'worlwide_gross_income': 427344064.0},
#  {'country': 'France',
#   'original_title': 'Intouchables',
#   'year': 2011,
#   'genre': 'Biography',
#   'avg_vote': 8.5,
#   'worlwide_gross_income': 426588510.0},
#  {'country': 'USA',
#   'original_title': 'Django Unchained',
#   'year': 2012,
#   'genre': 'Drama',
#   'avg_vote': 8.4,
#   'worlwide_gross_income': 425368238.0},
#  {'country': 'USA',
#   'original_title': 'Bad Boys for Life',
#   'year': 2020,
#   'genre': 'Action',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 424617855.0},
#  {'country': 'USA',
#   'original_title': 'Dances with Wolves',
#   'year': 1990,
#   'genre': 'Adventure',
#   'avg_vote': 8.0,
#   'worlwide_gross_income': 424208848.0},
#  {'country': 'USA',
# ...
#   'year': 1991,
#   'genre': 'Comedy',
#   'avg_vote': 6.9,
#   'worlwide_gross_income': 191502426.0},
#  {'country': 'USA',
#   'original_title': 'The Longest Yard',
#   'year': 2005,
#   'genre': 'Comedy',
#   'avg_vote': 6.4,
#   'worlwide_gross_income': 191466556.0},
#  {'country': 'USA',
#   'original_title': 'Cheaper by the Dozen',
#   'year': 2003,
#   'genre': 'Comedy',
#   'avg_vote': 5.9,
#   'worlwide_gross_income': 190538630.0},
#  {'country': 'USA',
#   'original_title': 'The Equalizer 2',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 6.7,
#   'worlwide_gross_income': 190400157.0},
#  {'country': 'USA',
#   'original_title': 'Hollow Man',
#   'year': 2000,
#   'genre': 'Action',
#   'avg_vote': 5.8,
#   'worlwide_gross_income': 190213455.0},
#  {'country': 'USA',
#   'original_title': 'Outbreak',
#   'year': 1995,
#   'genre': 'Action',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 189859560.0},
#  {'country': 'USA',
#   'original_title': 'The Santa Clause',
#   'year': 1994,
#   'genre': 'Comedy',
#   'avg_vote': 6.5,
#   'worlwide_gross_income': 189833357.0},
#  {'country': 'China',
#   'original_title': 'So duk 2: Tin dei duei kuet',
#   'year': 2019,
#   'genre': 'Action',
#   'avg_vote': 6.0,
#   'worlwide_gross_income': 189396380.0},
#  {'country': 'USA',
#   'original_title': 'The X Files',
#   'year': 1998,
#   'genre': 'Drama',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 189176423.0},
#  {'country': 'China',
#   'original_title': 'Xin hua lu fang',
#   'year': 2014,
#   'genre': 'Comedy',
#   'avg_vote': 6.4,
#   'worlwide_gross_income': 189017596.0},
#  {'country': 'USA',
#   'original_title': 'Rambo III',
#   'year': 1988,
#   'genre': 'Action',
#   'avg_vote': 5.8,
#   'worlwide_gross_income': 189015611.0},
#  {'country': 'USA',
#   'original_title': 'The Secret Life of Walter Mitty',
#   'year': 2013,
#   'genre': 'Comedy',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 188133322.0},
#  {'country': 'China',
#   'original_title': 'Mou seung',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 6.9,
#   'worlwide_gross_income': 188116796.0},
#  {'country': 'USA',
#   'original_title': 'Jaws 2',
#   'year': 1978,
#   'genre': 'Adventure',
#   'avg_vote': 5.8,
#   'worlwide_gross_income': 187884007.0},
#  {'country': 'USA',
#   'original_title': '12 Years a Slave',
#   'year': 2013,
#   'genre': 'Biography',
#   'avg_vote': 8.1,
#   'worlwide_gross_income': 187733202.0},
#  {'country': 'USA',
#   'original_title': 'Heat',
#   'year': 1995,
#   'genre': 'Crime',
#   'avg_vote': 8.2,
#   'worlwide_gross_income': 187436818.0},
#  {'country': 'USA',
#   'original_title': "Mr. Popper's Penguins",
#   'year': 2011,
#   'genre': 'Comedy',
#   'avg_vote': 6.0,
#   'worlwide_gross_income': 187361754.0},
#  {'country': 'USA',
#   'original_title': 'The Grudge',
#   'year': 2004,
#   'genre': 'Horror',
#   'avg_vote': 5.9,
#   'worlwide_gross_income': 187281115.0},
#  {'country': 'USA',
#   'original_title': 'I Now Pronounce You Chuck & Larry',
#   'year': 2007,
#   'genre': 'Comedy',
#   'avg_vote': 5.9,
#   'worlwide_gross_income': 187134117.0},
#  {'country': 'USA',
#   'original_title': 'The Horse Whisperer',
#   'year': 1998,
#   'genre': 'Drama',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 186883563.0},
#  {'country': 'USA',
#   'original_title': 'Walk the Line',
#   'year': 2005,
#   'genre': 'Biography',
#   'avg_vote': 7.8,
#   'worlwide_gross_income': 186797986.0},
#  {'country': 'China',
#   'original_title': 'Jian bing xia',
#   'year': 2015,
#   'genre': 'Comedy',
#   'avg_vote': 5.6,
#   'worlwide_gross_income': 186699768.0},
#  {'country': 'USA',
#   'original_title': 'The Jungle Book 2',
#   'year': 2003,
#   'genre': 'Animation',
#   'avg_vote': 5.4,
#   'worlwide_gross_income': 186303759.0},
#  {'country': 'USA',
#   'original_title': 'The Final Destination',
#   'year': 2009,
#   'genre': 'Horror',
#   'avg_vote': 5.2,
#   'worlwide_gross_income': 186167139.0},
#  {'country': 'USA',
#   'original_title': 'Atlantis: The Lost Empire',
#   'year': 2001,
#   'genre': 'Animation',
#   'avg_vote': 6.9,
#   'worlwide_gross_income': 186053725.0},
#  {'country': 'USA',
#   'original_title': 'Inside Man',
#   'year': 2006,
#   'genre': 'Crime',
#   'avg_vote': 7.6,
#   'worlwide_gross_income': 186003591.0},
#  {'country': 'USA',
#   'original_title': 'The Waterboy',
#   'year': 1998,
#   'genre': 'Comedy',
#   'avg_vote': 6.1,
#   'worlwide_gross_income': 185991646.0},
#  {'country': 'UK',
#   'original_title': 'Hugo',
#   'year': 2011,
#   'genre': 'Drama',
#   'avg_vote': 7.5,
#   'worlwide_gross_income': 185770160.0},
#  {'country': 'USA',
#   'original_title': 'Pitch Perfect 3',
#   'year': 2017,
#   'genre': 'Comedy',
#   'avg_vote': 5.8,
#   'worlwide_gross_income': 185400345.0},
#  {'country': 'USA',
#   'original_title': 'Watchmen',
#   'year': 2009,
#   'genre': 'Action',
#   'avg_vote': 7.6,
#   'worlwide_gross_income': 185382813.0},
#  {'country': 'USA',
#   'original_title': 'The Birdcage',
#   'year': 1996,
#   'genre': 'Comedy',
#   'avg_vote': 7.1,
#   'worlwide_gross_income': 185260553.0},
#  {'country': 'Australia',
#   'original_title': 'Moulin Rouge!',
#   'year': 2001,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'worlwide_gross_income': 184935030.0},
#  {'country': 'USA',
#   'original_title': 'Snow White and the Seven Dwarfs',
#   'year': 1937,
#   'genre': 'Animation',
#   'avg_vote': 7.6,
#   'worlwide_gross_income': 184925486.0},
#  {'country': 'USA',
#   'original_title': 'Hop',
#   'year': 2011,
#   'genre': 'Animation',
#   'avg_vote': 5.4,
#   'worlwide_gross_income': 183953723.0},
#  {'country': 'USA',
#   'original_title': 'Bad Moms',
#   'year': 2016,
#   'genre': 'Comedy',
#   'avg_vote': 6.2,
#   'worlwide_gross_income': 183936074.0},
#  {'country': 'USA',
#   'original_title': 'Jupiter Ascending',
#   'year': 2015,
#   'genre': 'Action',
#   'avg_vote': 5.3,
#   'worlwide_gross_income': 183887723.0},
#  {'country': 'USA',
#   'original_title': 'Knowing',
#   'year': 2009,
#   'genre': 'Action',
#   'avg_vote': 6.2,
#   'worlwide_gross_income': 183658498.0},
#  {'country': 'USA',
#   'original_title': '102 Dalmatians',
#   'year': 2000,
#   'genre': 'Adventure',
#   'avg_vote': 4.9,
#   'worlwide_gross_income': 183611771.0},
#  {'country': 'Japan',
#   'original_title': 'Stand by Me Doraemon',
#   'year': 2014,
#   'genre': 'Animation',
#   'avg_vote': 7.4,
#   'worlwide_gross_income': 183442714.0},
#  {'country': 'USA',
#   'original_title': 'Storks',
#   'year': 2016,
#   'genre': 'Animation',
#   'avg_vote': 6.8,
#   'worlwide_gross_income': 183388953.0},
#  {'country': 'USA',
#   'original_title': 'Paul Blart: Mall Cop',
#   'year': 2009,
#   'genre': 'Action',
#   'avg_vote': 5.2,
#   'worlwide_gross_income': 183348429.0},
#  {'country': 'USA',
#   'original_title': "Wayne's World",
#   'year': 1992,
#   'genre': 'Comedy',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 183097323.0},
#  {'country': 'USA',
#   'original_title': 'Maverick',
#   'year': 1994,
#   'genre': 'Action',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 183031272.0},
#  {'country': 'USA',
#   'original_title': 'Mirror Mirror',
#   'year': 2012,
#   'genre': 'Adventure',
#   'avg_vote': 5.6,
#   'worlwide_gross_income': 183018522.0},
#  {'country': 'France',
#   'original_title': 'The Man in the Iron Mask',
#   'year': 1998,
#   'genre': 'Action',
#   'avg_vote': 6.5,
#   'worlwide_gross_income': 182968902.0},
#  {'country': 'USA',
#   'original_title': 'Cape Fear',
#   'year': 1991,
#   'genre': 'Crime',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 182291969.0},
#  {'country': 'USA',
#   'original_title': 'The Haunted Mansion',
#   'year': 2003,
#   'genre': 'Comedy',
#   'avg_vote': 5.0,
#   'worlwide_gross_income': 182290266.0},
#  {'country': 'China',
#   'original_title': 'Xi you ji: Da nao tian gong',
#   'year': 2014,
#   'genre': 'Action',
#   'avg_vote': 4.9,
#   'worlwide_gross_income': 182206924.0},
#  {'country': 'USA',
#   'original_title': 'While You Were Sleeping',
#   'year': 1995,
#   'genre': 'Comedy',
#   'avg_vote': 6.7,
#   'worlwide_gross_income': 182057016.0},
#  {'country': 'USA',
#   'original_title': 'The Bridges of Madison County',
#   'year': 1995,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'worlwide_gross_income': 182016617.0},
#  {'country': 'China',
#   'original_title': 'Du cheng feng yun III',
#   'year': 2016,
#   'genre': 'Comedy',
#   'avg_vote': 2.3,
#   'worlwide_gross_income': 181732879.0},
#  {'country': 'USA',
#   'original_title': 'Poseidon',
#   'year': 2006,
#   'genre': 'Action',
#   'avg_vote': 5.7,
#   'worlwide_gross_income': 181674817.0},
#  {'country': 'USA',
#   'original_title': 'The First Wives Club',
#   'year': 1996,
#   'genre': 'Comedy',
#   'avg_vote': 6.4,
#   'worlwide_gross_income': 181489203.0},
#  {'country': 'USA',
#   'original_title': 'Scooby-Doo 2: Monsters Unleashed',
#   'year': 2004,
#   'genre': 'Adventure',
#   'avg_vote': 5.1,
#   'worlwide_gross_income': 181216833.0},
#  {'country': 'USA',
#   'original_title': 'Hot Shots!',
#   'year': 1991,
#   'genre': 'Action',
#   'avg_vote': 6.8,
#   'worlwide_gross_income': 181096164.0},
#  {'country': 'USA',
#   'original_title': 'Road to Perdition',
#   'year': 2002,
#   'genre': 'Crime',
#   'avg_vote': 7.7,
#   'worlwide_gross_income': 181001478.0},
#  {'country': 'USA',
#   'original_title': 'Kill Bill: Vol. 1',
#   'year': 2003,
#   'genre': 'Action',
#   'avg_vote': 8.1,
#   'worlwide_gross_income': 180899045.0},
#  {'country': 'India',
#   'original_title': 'Khaleja',
#   'year': 2010,
#   'genre': 'Action',
#   'avg_vote': 7.5,
#   'worlwide_gross_income': 180800000.0},
#  {'country': 'USA',
#   'original_title': 'The Scorpion King',
#   'year': 2002,
#   'genre': 'Action',
#   'avg_vote': 5.5,
#   'worlwide_gross_income': 180630907.0},
#  {'country': 'USA',
#   'original_title': 'Sweet Home Alabama',
#   'year': 2002,
#   'genre': 'Comedy',
#   'avg_vote': 6.2,
#   'worlwide_gross_income': 180622424.0},
#  {'country': 'USA',
#   'original_title': "Daddy's Home 2",
#   'year': 2017,
#   'genre': 'Comedy',
#   'avg_vote': 6.0,
#   'worlwide_gross_income': 180613180.0},
#  {'country': 'USA',
#   'original_title': 'Deja Vu',
#   'year': 2006,
#   'genre': 'Action',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 180557550.0},
#  {'country': 'Australia',
#   'original_title': 'Hacksaw Ridge',
#   'year': 2016,
#   'genre': 'Biography',
#   'avg_vote': 8.1,
#   'worlwide_gross_income': 180450918.0},
#  {'country': 'China',
#   'original_title': 'Abominable',
#   'year': 2019,
#   'genre': 'Animation',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 179990300.0},
#  {'country': 'USA',
#   'original_title': 'Dangerous Minds',
#   'year': 1995,
#   'genre': 'Biography',
#   'avg_vote': 6.5,
#   'worlwide_gross_income': 179519401.0},
#  {'country': 'USA',
#   'original_title': 'The Dictator',
#   'year': 2012,
#   'genre': 'Comedy',
#   'avg_vote': 6.4,
#   'worlwide_gross_income': 179379533.0},
#  {'country': 'USA',
#   'original_title': 'The League of Extraordinary Gentlemen',
#   'year': 2003,
#   'genre': 'Action',
#   'avg_vote': 5.8,
#   'worlwide_gross_income': 179265204.0},
#  {'country': 'USA',
#   'original_title': 'Allegiant',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 5.7,
#   'worlwide_gross_income': 179246868.0},
#  {'country': 'USA',
#   'original_title': 'Daredevil',
#   'year': 2003,
#   'genre': 'Action',
#   'avg_vote': 5.3,
#   'worlwide_gross_income': 179179718.0},
#  {'country': 'USA',
#   'original_title': 'City Slickers',
#   'year': 1991,
#   'genre': 'Comedy',
#   'avg_vote': 6.8,
#   'worlwide_gross_income': 179033791.0},
#  {'country': 'Germany',
#   'original_title': "He's Just Not That Into You",
#   'year': 2009,
#   'genre': 'Comedy',
#   'avg_vote': 6.4,
#   'worlwide_gross_income': 178866158.0},
#  {'country': 'USA',
#   'original_title': 'Eagle Eye',
#   'year': 2008,
#   'genre': 'Action',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 178767383.0},
#  {'country': 'USA',
#   'original_title': 'Along Came Polly',
#   'year': 2004,
#   'genre': 'Comedy',
#   'avg_vote': 6.0,
#   'worlwide_gross_income': 178311729.0},
#  {'country': 'UK',
#   'original_title': 'Flushed Away',
#   'year': 2006,
#   'genre': 'Animation',
#   'avg_vote': 6.6,
#   'worlwide_gross_income': 178281554.0},
#  {'country': 'USA',
#   'original_title': 'Scary Movie 4',
#   'year': 2006,
#   'genre': 'Comedy',
#   'avg_vote': 5.1,
#   'worlwide_gross_income': 178262620.0},
#  {'country': 'USA',
#   'original_title': "Dante's Peak",
#   'year': 1997,
#   'genre': 'Action',
#   'avg_vote': 5.9,
#   'worlwide_gross_income': 178127760.0},
#  {'country': 'USA',
#   'original_title': 'Brokeback Mountain',
#   'year': 2005,
#   'genre': 'Drama',
#   'avg_vote': 7.7,
#   'worlwide_gross_income': 178062759.0},
#  {'country': 'USA',
#   'original_title': 'Patriot Games',
#   'year': 1992,
#   'genre': 'Action',
#   'avg_vote': 6.9,
#   'worlwide_gross_income': 178051587.0},
#  {'country': 'USA',
#   'original_title': 'Flubber',
#   'year': 1997,
#   'genre': 'Comedy',
#   'avg_vote': 5.3,
#   'worlwide_gross_income': 177977226.0},
#  {'country': 'UK',
#   'original_title': 'Baywatch',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 5.5,
#   'worlwide_gross_income': 177856751.0},
#  {'country': 'USA',
#   'original_title': 'Double Jeopardy',
#   'year': 1999,
#   'genre': 'Crime',
#   'avg_vote': 6.5,
#   'worlwide_gross_income': 177841558.0},
#  {'country': 'USA',
#   'original_title': 'War Horse',
#   'year': 2011,
#   'genre': 'Action',
#   'avg_vote': 7.2,
#   'worlwide_gross_income': 177584879.0},
#  {'country': 'USA',
#   'original_title': 'Paranormal Activity 2',
#   'year': 2010,
#   'genre': 'Horror',
#   'avg_vote': 5.6,
#   'worlwide_gross_income': 177512032.0},
#  {'country': 'USA',
#   'original_title': 'How to Lose a Guy in 10 Days',
#   'year': 2003,
#   'genre': 'Comedy',
#   'avg_vote': 6.4,
#   'worlwide_gross_income': 177502387.0},
#  {'country': 'USA',
#   'original_title': 'AVP: Alien vs. Predator',
#   'year': 2004,
#   'genre': 'Action',
#   'avg_vote': 5.6,
#   'worlwide_gross_income': 177427090.0},
#  {'country': 'China',
#   'original_title': 'Ying xiong',
#   'year': 2002,
#   'genre': 'Action',
#   'avg_vote': 7.9,
#   'worlwide_gross_income': 177395557.0},
#  {'country': 'USA',
#   'original_title': 'The 40 Year Old Virgin',
#   'year': 2005,
#   'genre': 'Comedy',
#   'avg_vote': 7.1,
#   'worlwide_gross_income': 177378645.0},
#  {'country': 'USA',
#   'original_title': 'The Butler',
#   'year': 2013,
#   'genre': 'Biography',
#   'avg_vote': 7.2,
#   'worlwide_gross_income': 177313795.0},
#  {'country': 'USA',
#   'original_title': 'The Haunting',
#   'year': 1999,
#   'genre': 'Fantasy',
#   'avg_vote': 5.0,
#   'worlwide_gross_income': 177311151.0},
#  {'country': 'USA',
#   'original_title': 'The Descendants',
#   'year': 2011,
#   'genre': 'Comedy',
#   'avg_vote': 7.3,
#   'worlwide_gross_income': 177243185.0},
#  {'country': 'USA',
#   'original_title': 'The A-Team',
#   'year': 2010,
#   'genre': 'Action',
#   'avg_vote': 6.7,
#   'worlwide_gross_income': 177238796.0},
#  {'country': 'USA',
#   'original_title': 'Tootsie',
#   'year': 1982,
#   'genre': 'Comedy',
#   'avg_vote': 7.4,
#   'worlwide_gross_income': 177200000.0},
#  {'country': 'USA',
#   'original_title': 'In the Line of Fire',
#   'year': 1993,
#   'genre': 'Action',
#   'avg_vote': 7.2,
#   'worlwide_gross_income': 176997168.0},
#  {'country': 'USA',
#   'original_title': 'Analyze This',
#   'year': 1999,
#   'genre': 'Comedy',
#   'avg_vote': 6.7,
#   'worlwide_gross_income': 176885658.0},
#  {'country': 'USA',
#   'original_title': "The Hitman's Bodyguard",
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 6.9,
#   'worlwide_gross_income': 176600207.0},
#  {'country': 'USA',
#   'original_title': 'Looper',
#   'year': 2012,
#   'genre': 'Action',
#   'avg_vote': 7.4,
#   'worlwide_gross_income': 176506819.0},
#  {'country': 'France',
#   'original_title': "Qu'est-ce qu'on a fait au Bon Dieu?",
#   'year': 2014,
#   'genre': 'Comedy',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 176404493.0},
#  {'country': 'Hong Kong',
#   'original_title': 'Yip Man 4',
#   'year': 2019,
#   'genre': 'Action',
#   'avg_vote': 7.1,
#   'worlwide_gross_income': 176345966.0},
#  {'country': 'USA',
#   'original_title': 'Dr. Dolittle 2',
#   'year': 2001,
#   'genre': 'Comedy',
#   'avg_vote': 4.7,
#   'worlwide_gross_income': 176104344.0},
#  {'country': 'USA',
#   'original_title': 'The Italian Job',
#   'year': 2003,
#   'genre': 'Action',
#   'avg_vote': 7.0,
#   'worlwide_gross_income': 176070171.0},
#  {'country': 'USA',
#   'original_title': 'The Bucket List',
#   'year': 2007,
#   'genre': 'Comedy',
#   'avg_vote': 7.4,
#   'worlwide_gross_income': 175372502.0},
#  {'country': 'USA',
#   'original_title': 'Sleeping with the Enemy',
#   'year': 1991,
#   'genre': 'Drama',
#   'avg_vote': 6.3,
#   'worlwide_gross_income': 174999005.0},
#  ...]

# %%
production_csv = "production.csv"

production_df = pd.read_csv(production_csv)
production_df = production_df.rename(columns={"0":"count"})
production_df
# Out:
#                     production_company  count
# 0            Metro-Goldwyn-Mayer (MGM)   1284
# 1                         Warner Bros.   1153
# 2                    Columbia Pictures    914
# 3                   Paramount Pictures    903
# 4                Twentieth Century Fox    865
# ...                                ...    ...
# 32044         Lucky Pierre Enterprises      1
# 32045                      Lucky Punch      1
# 32046                       Lucky Star      1
# 32047                     Lucky Studio      1
# 32048  "DIA" Productions GmbH & Co. KG      1
#
# [32049 rows x 2 columns]

# %%
production_df.to_dict('records')
# Out:
# [{'production_company': 'Metro-Goldwyn-Mayer (MGM)', 'count': 1284},
#  {'production_company': 'Warner Bros.', 'count': 1153},
#  {'production_company': 'Columbia Pictures', 'count': 914},
#  {'production_company': 'Paramount Pictures', 'count': 903},
#  {'production_company': 'Twentieth Century Fox', 'count': 865},
#  {'production_company': 'Universal Pictures', 'count': 732},
#  {'production_company': 'RKO Radio Pictures', 'count': 535},
#  {'production_company': 'Mosfilm', 'count': 279},
#  {'production_company': 'Universal International Pictures (UI)', 'count': 272},
#  {'production_company': 'Canal+', 'count': 231},
#  {'production_company': 'Republic Pictures (I)', 'count': 208},
#  {'production_company': 'New Line Cinema', 'count': 205},
#  {'production_company': 'CJ Entertainment', 'count': 175},
#  {'production_company': 'Shaw Brothers', 'count': 169},
#  {'production_company': 'Toho Company', 'count': 158},
#  {'production_company': 'First National Pictures', 'count': 155},
#  {'production_company': 'Shochiku', 'count': 144},
#  {'production_company': 'Golden Harvest Company', 'count': 140},
#  {'production_company': 'Touchstone Pictures', 'count': 140},
#  {'production_company': 'Lenfilm Studio', 'count': 137},
#  {'production_company': 'Walt Disney Pictures', 'count': 134},
#  {'production_company': 'Filmové studio Barrandov', 'count': 134},
#  {'production_company': 'Walt Disney Productions', 'count': 129},
#  {'production_company': 'NH Studioz', 'count': 123},
#  {'production_company': 'Nikkatsu', 'count': 120},
#  {'production_company': 'Gaumont', 'count': 119},
#  {'production_company': 'Fox Film Corporation', 'count': 117},
#  {'production_company': 'Finos Film', 'count': 117},
#  {'production_company': 'Toei Company', 'count': 116},
#  {'production_company': 'Monogram Pictures', 'count': 114},
#  {'production_company': 'The Rank Organisation', 'count': 111},
#  {'production_company': 'ARTE', 'count': 109},
#  {'production_company': 'TriStar Pictures', 'count': 101},
#  {'production_company': 'Millennium Films', 'count': 96},
#  {'production_company': 'Miramax', 'count': 93},
#  {'production_company': 'Svensk Filmindustri (SF)', 'count': 91},
#  {'production_company': 'SVF Entertainment', 'count': 90},
#  {'production_company': 'DreamWorks', 'count': 88},
#  {'production_company': 'BBC Films', 'count': 88},
#  {'production_company': 'Canal+ España', 'count': 86},
#  {'production_company': 'Avala Film', 'count': 86},
#  {'production_company': 'Constantin Film', 'count': 86},
#  {'production_company': 'Daiei Studios', 'count': 86},
#  {'production_company': 'Hammer Films', 'count': 85},
#  {'production_company': 'Sam Katzman Productions', 'count': 84},
#  {'production_company': 'Nordisk Film', 'count': 83},
#  {'production_company': 'Lionsgate', 'count': 81},
#  {'production_company': 'American International Pictures (AIP)', 'count': 78},
#  {'production_company': 'Kinostudiya imeni M. Gorkogo', 'count': 77},
#  {'production_company': 'Bandai Visual Company', 'count': 74},
#  {'production_company': 'Orion Pictures', 'count': 73},
#  {'production_company': 'Fox Searchlight Pictures', 'count': 73},
#  {'production_company': 'EuropaCorp', 'count': 71},
#  {'production_company': 'Dimension Films', 'count': 71},
#  {'production_company': 'Fuji Television Network', 'count': 70},
#  {'production_company': 'Allied Artists Pictures', 'count': 70},
#  {'production_company': 'Italian International Film', 'count': 68},
#  {'production_company': 'Gainsborough Pictures', 'count': 68},
#  {'production_company': 'The Samuel Goldwyn Company', 'count': 68},
#  {'production_company': 'Screen Gems', 'count': 68},
#  {'production_company': 'Summit Entertainment', 'count': 67},
#  {'production_company': 'Film i Väst', 'count': 66},
#  {'production_company': 'Globo Filmes', 'count': 66},
#  {'production_company': 'Channel Four Films', 'count': 65},
#  {'production_company': 'Ealing Studios', 'count': 65},
#  {'production_company': 'Fox 2000 Pictures', 'count': 64},
#  {'production_company': 'The Asylum', 'count': 64},
#  {'production_company': 'Castle Rock Entertainment', 'count': 64},
#  {'production_company': 'London Film Productions', 'count': 63},
#  {'production_company': 'Cattleya', 'count': 63},
#  {'production_company': 'Concorde-New Horizons', 'count': 62},
#  {'production_company': 'ABS-CBN Film Productions', 'count': 62},
#  {'production_company': 'Filmauro', 'count': 62},
#  {'production_company': 'Fandango', 'count': 61},
#  {'production_company': 'New World Pictures', 'count': 60},
#  {'production_company': 'China Star Entertainment', 'count': 60},
#  {'production_company': 'Cecchi Gori Group Tiger Cinematografica',
#   'count': 59},
#  {'production_company': 'Ceská Televize', 'count': 59},
#  {'production_company': 'Associated British Picture Corporation (ABPC)',
#   'count': 58},
#  {'production_company': 'Greek Film Center', 'count': 57},
#  {'production_company': 'Edward Small Productions', 'count': 57},
#  {'production_company': 'Harry Sherman Productions', 'count': 57},
#  {'production_company': 'Boyana Film', 'count': 57},
#  {'production_company': 'PM Entertainment Group', 'count': 56},
#  {'production_company': 'British Broadcasting Corporation (BBC)', 'count': 55},
#  {'production_company': 'Arte France Cinéma', 'count': 55},
#  {'production_company': 'Hollywood Pictures', 'count': 54},
#  {'production_company': 'Dania Film', 'count': 54},
#  {'production_company': 'Agat Films & Cie', 'count': 54},
#  {'production_company': 'Focus Features', 'count': 53},
#  {'production_company': 'Universum Film (UFA)', 'count': 53},
#  {'production_company': 'Yash Raj Films', 'count': 53},
#  {'production_company': 'Hal Roach Studios', 'count': 52},
#  {'production_company': 'Det Danske Filminstitut', 'count': 52},
#  {'production_company': 'CTB Film Company', 'count': 52},
#  {'production_company': 'Arzu Film', 'count': 52},
#  {'production_company': 'Zentropa Entertainments', 'count': 52},
#  {'production_company': 'Deutsche Film (DEFA)', 'count': 51},
#  {'production_company': 'Cinetel Films', 'count': 51},
#  {'production_company': 'Central Cinema Company Film (CCC)', 'count': 50},
#  {'production_company': 'Australian Film Finance Corporation (AFFC)',
#   'count': 50},
#  {'production_company': 'Georgian-Film', 'count': 49},
#  {'production_company': 'Karagiannis-Karatzopoulos', 'count': 49},
#  {'production_company': 'United Artists', 'count': 49},
#  {'production_company': 'Gaumont International', 'count': 49},
#  {'production_company': 'Cosmopolitan Productions', 'count': 47},
#  {'production_company': 'Asmik Ace Entertainment', 'count': 46},
#  {'production_company': 'Mandarin Films', 'count': 45},
#  {'production_company': 'Walter Wanger Productions', 'count': 44},
#  {'production_company': 'Suomen Filmiteollisuus', 'count': 44},
#  {'production_company': 'Instituto Nacional de Cine y Artes Audiovisuales (INCAA)',
#   'count': 44},
#  {'production_company': 'Titanus', 'count': 43},
#  {'production_company': 'Pine-Thomas Productions', 'count': 43},
#  {'production_company': 'Erler Film', 'count': 42},
#  {'production_company': 'British Screen Productions', 'count': 42},
#  {'production_company': 'Morgan Creek Entertainment', 'count': 41},
#  {'production_company': 'Bayerischer Rundfunk (BR)', 'count': 41},
#  {'production_company': 'Media Asia Films', 'count': 41},
#  {'production_company': 'Farabi Cinema Foundation', 'count': 41},
#  {'production_company': 'Bavaria Film', 'count': 40},
#  {'production_company': 'Medusa Film', 'count': 40},
#  {'production_company': 'Eros International', 'count': 40},
#  {'production_company': 'Hal Wallis Productions', 'count': 40},
#  {'production_company': 'Aniplex', 'count': 40},
#  {'production_company': 'Golan-Globus Productions', 'count': 39},
#  {'production_company': 'Les Films Pelléas', 'count': 39},
#  {'production_company': 'Two Cities Films', 'count': 38},
#  {'production_company': 'Centar Film', 'count': 38},
#  {'production_company': 'Dharma Productions', 'count': 37},
#  {'production_company': 'Blumhouse Productions', 'count': 37},
#  {'production_company': 'Toei Animation', 'count': 37},
#  {'production_company': 'Agencja Produkcji Filmowej', 'count': 37},
#  {'production_company': 'Dino de Laurentiis Cinematografica', 'count': 37},
#  {'production_company': 'Gaumont British Picture Corporation', 'count': 37},
#  {'production_company': 'Netflix', 'count': 37},
#  {'production_company': 'Amuse', 'count': 37},
#  {'production_company': 'Hrvatska Radiotelevizija (HRT)', 'count': 37},
#  {'production_company': "Centre National du Cinéma et de l'Image Animée",
#   'count': 36},
#  {'production_company': 'Compagnia Cinematografica Champion', 'count': 36},
#  {'production_company': 'The Weinstein Company', 'count': 36},
#  {'production_company': 'Dentsu', 'count': 36},
#  {'production_company': 'China Film Group Corporation (CFGC)', 'count': 36},
#  {'production_company': 'Cannon Group', 'count': 36},
#  {'production_company': 'Concorde Pictures', 'count': 35},
#  {'production_company': 'Gemini Films', 'count': 35},
#  {'production_company': 'Les Films 13', 'count': 35},
#  {'production_company': 'Revolution Studios', 'count': 35},
#  {'production_company': 'Nimbus Film Productions', 'count': 34},
#  {'production_company': 'Hemdale', 'count': 34},
#  {'production_company': 'X-Filme Creative Pool', 'count': 34},
#  {'production_company': 'Central Partnership', 'count': 34},
#  {'production_company': 'Motion Picture Corporation of America (MPCA)',
#   'count': 34},
#  {'production_company': 'BKM Film', 'count': 34},
#  {'production_company': 'Regency Enterprises', 'count': 34},
#  {'production_company': 'Embrafilme', 'count': 34},
#  {'production_company': 'Why Not Productions', 'count': 34},
#  {'production_company': 'Lions Gate Films', 'count': 33},
#  {'production_company': 'Dino De Laurentiis Company', 'count': 33},
#  {'production_company': 'Solar Films', 'count': 33},
#  {'production_company': 'Canadian Film Development Corporation (CFDC)',
#   'count': 33},
#  {'production_company': 'Cartel Pictures', 'count': 33},
#  {'production_company': 'Hunnia Filmstúdió', 'count': 32},
#  {'production_company': 'Rialto Film', 'count': 32},
#  {'production_company': 'Sree Lakshmi Prasanna Pictures', 'count': 32},
#  {'production_company': 'Nord-Ouest Films', 'count': 32},
#  {'production_company': 'Lisa-Film', 'count': 32},
#  {'production_company': 'Arts Council of England', 'count': 32},
#  {'production_company': 'Azerbaijanfilm', 'count': 32},
#  {'production_company': 'StudioCanal', 'count': 32},
#  {'production_company': 'Aries Cinematográfica Argentina', 'count': 31},
#  {'production_company': 'Producers Releasing Corporation (PRC)', 'count': 31},
#  {'production_company': 'EMI Films', 'count': 31},
#  {'production_company': 'Columbia Pictures Corporation', 'count': 31},
#  {'production_company': 'Madragoa Filmes', 'count': 31},
#  {'production_company': 'Nippon Television Network (NTV)', 'count': 31},
#  {'production_company': 'Full Moon Entertainment', 'count': 31},
#  {'production_company': 'Documento Film', 'count': 31},
#  {'production_company': 'British Film Institute (BFI)', 'count': 31},
#  {'production_company': 'Lux Film', 'count': 31},
#  {'production_company': 'Incorporated Television Company (ITC)', 'count': 31},
#  {'production_company': 'The Mirisch Corporation', 'count': 30},
#  {'production_company': 'Argentina Sono Film S.A.C.I.', 'count': 30},
#  {'production_company': 'Colorado Film Production', 'count': 30},
#  {'production_company': "Centre du Cinéma et de l'Audiovisuel de la Fédération Wallonie-Bruxelles",
#   'count': 30},
#  {'production_company': 'Ugur Film', 'count': 30},
#  {'production_company': 'Euro International Film (EIA)', 'count': 30},
#  {'production_company': 'Antena 3 Televisión', 'count': 30},
#  {'production_company': 'ASA Film', 'count': 30},
#  {'production_company': 'MK2 Productions', 'count': 29},
#  {'production_company': 'Film Workshop', 'count': 29},
#  {'production_company': 'Les Films du Losange', 'count': 29},
#  {'production_company': 'DreamWorks Animation', 'count': 29},
#  {'production_company': 'Walt Disney Animation Studios', 'count': 29},
#  {'production_company': 'LGM Productions', 'count': 29},
#  {'production_company': 'Alcon Entertainment', 'count': 29},
#  {'production_company': 'Empire Pictures', 'count': 29},
#  {'production_company': 'Daiei', 'count': 29},
#  {'production_company': 'Star Cinema', 'count': 29},
#  {'production_company': 'Pan Européenne', 'count': 28},
#  {'production_company': 'Carolco Pictures', 'count': 28},
#  {'production_company': 'Sara Films', 'count': 28},
#  {'production_company': 'Posa Films', 'count': 28},
#  {'production_company': 'Troma Entertainment', 'count': 28},
#  {'production_company': 'Saga Studio', 'count': 28},
#  {'production_company': 'Norsk Film', 'count': 28},
#  {'production_company': 'Polygram Filmed Entertainment', 'count': 28},
#  {'production_company': 'Asahi Shimbun', 'count': 28},
#  {'production_company': 'Beijing Film Studio', 'count': 28},
#  {'production_company': 'BRON Studios', 'count': 28},
#  {'production_company': 'Larry Darmour Productions', 'count': 28},
#  {'production_company': 'Cinémaginaire Inc.', 'count': 28},
#  {'production_company': 'Films A2', 'count': 28},
#  {'production_company': 'Les Films Ariane', 'count': 28},
#  {'production_company': 'Haut et Court', 'count': 27},
#  {'production_company': 'Art Theatre Guild (ATG)', 'count': 27},
#  {'production_company': 'Duea Film', 'count': 27},
#  {'production_company': 'Lakeshore Entertainment', 'count': 27},
#  {'production_company': 'Vertigo', 'count': 27},
#  {'production_company': 'Alta Vista Productions', 'count': 27},
#  {'production_company': 'Flora Film', 'count': 27},
#  {'production_company': 'Jadran Film', 'count': 27},
#  {'production_company': 'ARP Sélection', 'count': 27},
#  {'production_company': 'Filmirage', 'count': 26},
#  {'production_company': 'Wallis-Hazen', 'count': 26},
#  {'production_company': 'Romulus Films', 'count': 26},
#  {'production_company': 'Produzioni Europee Associate (PEA)', 'count': 26},
#  {'production_company': 'Les Films du Worso', 'count': 26},
#  {'production_company': 'Art Pictures Studio', 'count': 26},
#  {'production_company': 'Sri Venkateswara Creations', 'count': 26},
#  {'production_company': 'Beijing Enlight Pictures', 'count': 26},
#  {'production_company': 'Rectangle Productions', 'count': 26},
#  {'production_company': 'Fox STAR Studios', 'count': 26},
#  {'production_company': 'Toei Tokyo', 'count': 26},
#  {'production_company': 'Sandrews', 'count': 25},
#  {'production_company': 'Rizzoli Film', 'count': 25},
#  {'production_company': '4 1/2 Film', 'count': 25},
#  {'production_company': 'Merchant Ivory Productions', 'count': 25},
#  {'production_company': 'Paul Malvern Productions', 'count': 25},
#  {'production_company': 'Giorgos Karagiannis & Co.', 'count': 25},
#  {'production_company': '21st Century Film Corporation', 'count': 25},
#  {'production_company': 'Dean Film', 'count': 25},
#  {'production_company': 'Imagine Entertainment', 'count': 25},
#  {'production_company': 'Antena 3 Films', 'count': 25},
#  {'production_company': 'Film Polski', 'count': 25},
#  {'production_company': 'Alliance Atlantis Communications', 'count': 25},
#  {'production_company': 'Bona Film Group', 'count': 25},
#  {'production_company': 'Alexandre Films', 'count': 25},
#  {'production_company': 'P.P. Film Polski', 'count': 25},
#  {'production_company': 'Film4', 'count': 25},
#  {'production_company': 'Maipo Film', 'count': 25},
#  {'production_company': 'Akün Film', 'count': 25},
#  {'production_company': 'Angel Digital Private Limited', 'count': 25},
#  {'production_company': 'Viva Films', 'count': 25},
#  {'production_company': 'Les Films du Kiosque', 'count': 24},
#  {'production_company': 'Danmarks Radio (DR)', 'count': 24},
#  {'production_company': 'National Film Development Corporation of India (NFDC)',
#   'count': 24},
#  {'production_company': 'Merry Film', 'count': 24},
#  {'production_company': 'Eyeworks Film & TV Drama', 'count': 24},
#  {'production_company': 'Centurion', 'count': 24},
#  {'production_company': 'Geetha Arts', 'count': 24},
#  {'production_company': 'Union Générale Cinématographique (UGC)', 'count': 24},
#  {'production_company': 'Metro-Goldwyn-Mayer British Studios', 'count': 24},
#  {'production_company': 'Sahamongkol Film International', 'count': 24},
#  {'production_company': 'Stanley Kramer Productions', 'count': 24},
#  {'production_company': 'Embassy Pictures', 'count': 24},
#  {'production_company': 'Trimark Pictures', 'count': 24},
#  {'production_company': 'Franco London Films', 'count': 24},
#  {'production_company': 'Hedayat Film', 'count': 24},
#  {'production_company': 'Terra Studio', 'count': 23},
#  {'production_company': 'American Playhouse', 'count': 23},
#  {'production_company': 'Impress Telefilm', 'count': 23},
#  {'production_company': 'Cannon Films', 'count': 23},
#  {'production_company': 'North Bank Entertainment', 'count': 23},
#  {'production_company': 'Indigo Film', 'count': 23},
#  {'production_company': 'Fidélité Films', 'count': 23},
#  {'production_company': 'Fidélité Productions', 'count': 23},
#  {'production_company': 'Conspiração Filmes', 'count': 23},
#  {'production_company': 'Asahi Broadcasting Corporation (ABC)', 'count': 23},
#  {'production_company': 'Benedict Bogeaus Production', 'count': 23},
#  {'production_company': 'Amuse Soft Entertainment', 'count': 23},
#  {'production_company': 'Erman Film', 'count': 23},
#  {'production_company': 'Atresmedia Cine', 'count': 23},
#  {'production_company': 'Produzioni Atlas Consorziate (P.A.C.)', 'count': 23},
#  {'production_company': 'Kings Road Entertainment', 'count': 23},
#  {'production_company': 'UTV Motion Pictures', 'count': 23},
#  {'production_company': 'Bazelevs Production', 'count': 23},
#  {'production_company': 'Les Films Alain Sarde', 'count': 23},
#  {'production_company': 'Renn Productions', 'count': 22},
#  {'production_company': 'Les films du 24', 'count': 22},
#  {'production_company': 'Zespól Filmowy "Kadr"', 'count': 22},
#  {'production_company': 'Screen Australia', 'count': 22},
#  {'production_company': 'CBS Films', 'count': 22},
#  {'production_company': 'Sol Lesser Productions', 'count': 22},
#  {'production_company': 'Filmituotanto Spede Pasanen', 'count': 22},
#  {'production_company': 'Shin Ei Animation', 'count': 22},
#  {'production_company': 'De Laurentiis Entertainment Group (DEG)',
#   'count': 22},
#  {'production_company': 'Max Films Productions', 'count': 22},
#  {'production_company': 'Motlys', 'count': 22},
#  {'production_company': 'Adel Productions', 'count': 22},
#  {'production_company': 'D & B Films Co. Ltd.', 'count': 22},
#  {'production_company': 'Clesi Cinematografica', 'count': 22},
#  {'production_company': 'Sigmund Neufeld Productions', 'count': 22},
#  {'production_company': 'Quad Productions', 'count': 22},
#  {'production_company': 'Bianca Film', 'count': 22},
#  {'production_company': 'J. Arthur Rank Organisation', 'count': 22},
#  {'production_company': 'Croatia Film', 'count': 22},
#  {'production_company': 'Tallinnfilm', 'count': 21},
#  {'production_company': 'Falcon Pictures', 'count': 21},
#  {'production_company': 'Regal Films', 'count': 21},
#  {'production_company': 'Cine Bazar', 'count': 21},
#  {'production_company': 'Associated Producers (API)', 'count': 21},
#  {'production_company': 'Bioskop Film', 'count': 21},
#  {'production_company': 'Emmett/Furla/Oasis Films (EFO Films)', 'count': 21},
#  {'production_company': 'Besiktas Kültür Merkezi (BKM)', 'count': 21},
#  {'production_company': 'Vertigo Films', 'count': 21},
#  {'production_company': 'Alicéléo', 'count': 21},
#  {'production_company': 'Bo Ho Film Company Ltd.', 'count': 21},
#  {'production_company': 'Cinema City', 'count': 21},
#  {'production_company': 'Pathé', 'count': 21},
#  {'production_company': 'Trésor Films', 'count': 21},
#  {'production_company': 'Altavista Films', 'count': 21},
#  {'production_company': 'Central Motion Pictures', 'count': 21},
#  {'production_company': 'Avsar Film', 'count': 21},
#  {'production_company': 'Dovzhenko Film Studios', 'count': 21},
#  {'production_company': 'CiBy 2000', 'count': 21},
#  {'production_company': 'Cineville', 'count': 20},
#  {'production_company': 'Cecchi Gori Group Fin.Ma.Vi.', 'count': 20},
#  {'production_company': 'Castelao Producciones', 'count': 20},
#  {'production_company': 'Fida Cinematografica', 'count': 20},
#  {'production_company': 'Eisei Gekijo', 'count': 20},
#  {'production_company': 'Amicus Productions', 'count': 20},
#  {'production_company': 'Enjoy Movies', 'count': 20},
#  {'production_company': 'Lira Films', 'count': 20},
#  {'production_company': 'ODU Movies', 'count': 20},
#  {'production_company': 'Lolafilms', 'count': 20},
#  {'production_company': 'Allegro Films', 'count': 20},
#  {'production_company': 'Cinema Center Films', 'count': 20},
#  {'production_company': 'Robert E. Kent Productions', 'count': 20},
#  {'production_company': '3B Productions', 'count': 20},
#  {'production_company': 'Légende Films', 'count': 20},
#  {'production_company': 'Suresh Productions', 'count': 20},
#  {'production_company': 'King Brothers Productions', 'count': 20},
#  {'production_company': 'After Dark Films', 'count': 20},
#  {'production_company': 'Cité Films', 'count': 20},
#  {'production_company': 'Rapi Films', 'count': 20},
#  {'production_company': 'Rajshri Productions', 'count': 20},
#  {'production_company': 'Filmways Pictures', 'count': 20},
#  {'production_company': 'Filmlance International AB', 'count': 20},
#  {'production_company': 'Gold Circle Films', 'count': 20},
#  {'production_company': 'Peter Rogers Productions', 'count': 20},
#  {'production_company': 'Aashirvad Cinemas', 'count': 19},
#  {'production_company': 'Elías Querejeta Producciones Cinematográficas S.L.',
#   'count': 19},
#  {'production_company': 'Alfama Films', 'count': 19},
#  {'production_company': 'Rapid Film', 'count': 19},
#  {'production_company': 'Fennada-Filmi', 'count': 19},
#  {'production_company': 'Bac Films', 'count': 19},
#  {'production_company': 'Dub', 'count': 19},
#  {'production_company': 'TMS Entertainment', 'count': 19},
#  {'production_company': 'Relativity Media', 'count': 19},
#  {'production_company': 'Go Films', 'count': 19},
#  {'production_company': 'Arena Films', 'count': 19},
#  {'production_company': 'Filmkameratene A/S', 'count': 19},
#  {'production_company': 'Recorded Picture Company (RPC)', 'count': 19},
#  {'production_company': 'BiBi Film', 'count': 19},
#  {'production_company': 'Mukta Arts', 'count': 19},
#  {'production_company': 'Instituto Cubano del Arte e Industrias Cinematográficos (ICAIC)',
#   'count': 19},
#  {'production_company': 'Matila Röhr Productions (MRP)', 'count': 19},
#  {'production_company': 'Everest Entertainment', 'count': 19},
#  {'production_company': 'Franchise Pictures', 'count': 19},
#  {'production_company': 'Cyfuno Ventures', 'count': 19},
#  {'production_company': 'GAGA', 'count': 19},
#  {'production_company': 'Les Films Corona', 'count': 19},
#  {'production_company': 'Pierre Grise Productions', 'count': 19},
#  {'production_company': 'Pandora Filmproduktion', 'count': 19},
#  {'production_company': 'CJ E&M Film Financing & Investment Entertainment & Comics',
#   'count': 19},
#  {'production_company': 'Eskwad', 'count': 19},
#  {'production_company': 'Voltage Pictures', 'count': 18},
#  {'production_company': 'Emperor Film Production', 'count': 18},
#  {'production_company': 'American Zoetrope', 'count': 18},
#  {'production_company': 'Capitol Films', 'count': 18},
#  {'production_company': 'Raajkamal Films International', 'count': 18},
#  {'production_company': 'Argos Films', 'count': 18},
#  {'production_company': 'Selznick International Pictures', 'count': 18},
#  {'production_company': 'Teamfilm AS', 'count': 18},
#  {'production_company': 'Instituto Mexicano de Cinematografía (IMCINE)',
#   'count': 18},
#  {'production_company': 'HandMade Films', 'count': 18},
#  {'production_company': 'BD Cine', 'count': 18},
#  {'production_company': 'Twentieth Century-Fox Productions', 'count': 18},
#  {'production_company': 'Odessa Film Studios', 'count': 18},
#  {'production_company': 'Helsinki-Filmi', 'count': 18},
#  {'production_company': 'Les Films Christian Fechner', 'count': 18},
#  {'production_company': 'Universe Entertainment', 'count': 18},
#  {'production_company': 'Mafilm', 'count': 18},
#  {'production_company': 'Shooting Star Filmcompany BV', 'count': 18},
#  {'production_company': 'Castel Film Romania', 'count': 18},
#  {'production_company': 'Faso Film', 'count': 18},
#  {'production_company': 'Fulvia Film', 'count': 18},
#  {'production_company': 'Ex Nihilo', 'count': 18},
#  {'production_company': 'PolyGram Filmed Entertainment', 'count': 18},
#  {'production_company': 'Mascot Pictures', 'count': 18},
#  {'production_company': 'Divina-Film', 'count': 18},
#  {'production_company': 'Clover Productions', 'count': 18},
#  {'production_company': 'Rodeo Drive', 'count': 18},
#  {'production_company': 'Wildside', 'count': 18},
#  {'production_company': '20th Century Pictures', 'count': 18},
#  {'production_company': 'Dor Film Produktionsgesellschaft', 'count': 18},
#  {'production_company': 'Sidus', 'count': 18},
#  {'production_company': 'Compagnie Industrielle et Commerciale Cinématographique (CICC)',
#   'count': 18},
#  {'production_company': 'Europa Film', 'count': 18},
#  {'production_company': 'Filmsonor', 'count': 18},
#  {'production_company': 'Bórd Scannán na hÉireann', 'count': 17},
#  {'production_company': 'Mary Pickford Company', 'count': 17},
#  {'production_company': 'C.A.P.A.C.', 'count': 17},
#  {'production_company': 'Rhombus Media', 'count': 17},
#  {'production_company': 'Jack Rollins & Charles H. Joffe Productions',
#   'count': 17},
#  {'production_company': '40 Acres & A Mule Filmworks', 'count': 17},
#  {'production_company': 'Villealfa Filmproductions', 'count': 17},
#  {'production_company': 'Alliance Communications Corporation', 'count': 17},
#  {'production_company': 'Rialto Film Preben-Philipsen', 'count': 17},
#  {'production_company': 'Rogue Pictures', 'count': 17},
#  {'production_company': 'Lotus Production', 'count': 17},
#  {'production_company': 'Alta Films', 'count': 17},
#  {'production_company': 'British International Pictures (BIP)', 'count': 17},
#  {'production_company': 'IDTV Film', 'count': 17},
#  {'production_company': 'A.V.M. Productions', 'count': 17},
#  {'production_company': 'Artisan Entertainment', 'count': 17},
#  {'production_company': 'Medusa Distribuzione', 'count': 17},
#  {'production_company': 'Les Films du Carrosse', 'count': 17},
#  {'production_company': 'C.G. Silver Film', 'count': 17},
#  {'production_company': 'Annapurna Pictures', 'count': 17},
#  {'production_company': 'Indiana Production', 'count': 17},
#  {'production_company': 'Kadokawa Haruki Jimusho', 'count': 17},
#  {'production_company': 'Memfis Film', 'count': 17},
#  {'production_company': 'Django Film', 'count': 17},
#  {'production_company': 'Tokyo Broadcasting System (TBS)', 'count': 17},
#  {'production_company': 'Palomar', 'count': 17},
#  {'production_company': 'Eurociné', 'count': 17},
#  {'production_company': 'Duplass Brothers Productions', 'count': 17},
#  {'production_company': 'Distant Horizon', 'count': 17},
#  {'production_company': 'Regner Grasten Film', 'count': 17},
#  {'production_company': 'Filminor', 'count': 17},
#  {'production_company': 'R.K. Films Ltd.', 'count': 17},
#  {'production_company': 'First Look International', 'count': 17},
#  {'production_company': 'Epithète Films', 'count': 17},
#  {'production_company': 'Perlberg-Seaton Productions', 'count': 17},
#  {'production_company': 'StarVision Plus', 'count': 17},
#  {'production_company': 'Eon Productions', 'count': 17},
#  {'production_company': 'Bel-Air Productions', 'count': 17},
#  {'production_company': 'Budapest Filmstúdió', 'count': 17},
#  {'production_company': 'In Film Praha', 'count': 17},
#  {'production_company': 'Edko Films', 'count': 16},
#  {'production_company': 'Boje Buck Produktion', 'count': 16},
#  {'production_company': 'Percept Picture Company', 'count': 16},
#  {'production_company': 'AGS Entertainment', 'count': 16},
#  {'production_company': 'Vides Cinematografica', 'count': 16},
#  {'production_company': 'ASA Film Produktion ApS', 'count': 16},
#  {'production_company': 'Morena Films', 'count': 16},
#  {'production_company': 'Rat Pack Filmproduktion', 'count': 16},
#  {'production_company': 'China Film Co-Production Corporation', 'count': 16},
#  {'production_company': 'British National Films', 'count': 16},
#  {'production_company': 'RKO Pathé Pictures', 'count': 16},
#  {'production_company': 'Viacom18 Motion Pictures', 'count': 16},
#  {'production_company': 'Fine Line Features', 'count': 16},
#  {'production_company': 'TS Productions', 'count': 16},
#  {'production_company': 'Société Nouvelle de Cinématographie (SNC)',
#   'count': 16},
#  {'production_company': 'Overseas FilmGroup', 'count': 16},
#  {'production_company': 'Cinematográfica Calderón S.A.', 'count': 16},
#  {'production_company': 'SVT Drama', 'count': 16},
#  {'production_company': 'Arrowstorm Entertainment', 'count': 16},
#  {'production_company': 'Nordisk Film Production', 'count': 16},
#  {'production_company': 'William Castle Productions', 'count': 16},
#  {'production_company': 'Balaji Motion Pictures', 'count': 16},
#  {'production_company': 'Diler & Associados', 'count': 16},
#  {'production_company': 'A Private View', 'count': 16},
#  {'production_company': 'Afoi Roussopoulloi', 'count': 16},
#  {'production_company': 'Union Film', 'count': 16},
#  {'production_company': 'Cineriz', 'count': 16},
#  {'production_company': 'B.O.B. and Partners', 'count': 16},
#  {'production_company': 'Warwick Film Productions', 'count': 16},
#  {'production_company': 'Topkapi Films', 'count': 16},
#  {'production_company': 'Société des Etablissements L. Gaumont', 'count': 16},
#  {'production_company': 'Anonymous Content', 'count': 16},
#  {'production_company': 'Rysher Entertainment', 'count': 16},
#  {'production_company': 'Marimark Productions', 'count': 16},
#  {'production_company': 'Caravan Pictures', 'count': 16},
#  {'production_company': 'Allfilm', 'count': 16},
#  {'production_company': 'Goskino', 'count': 16},
#  {'production_company': 'D.W. Griffith Productions', 'count': 16},
#  {'production_company': 'Association Coopérative des Productions Audio-Visuelles (ACPAV)',
#   'count': 16},
#  {'production_company': 'Lorimar Film Entertainment', 'count': 16},
#  {'production_company': 'Clasa Films Mundiales', 'count': 16},
#  {'production_company': 'Asatsu-DK', 'count': 16},
#  {'production_company': 'Media Pro Pictures', 'count': 16},
#  {'production_company': 'Avex Entertainment', 'count': 16},
#  {'production_company': 'Lemming Film', 'count': 16},
#  {'production_company': 'Glass Eye Pix', 'count': 15},
#  {'production_company': 'Stage 6 Films', 'count': 15},
#  {'production_company': 'Fair Film', 'count': 15},
#  {'production_company': 'First Floor Features', 'count': 15},
#  {'production_company': 'Akson Studio', 'count': 15},
#  {'production_company': 'El Deseo', 'count': 15},
#  {'production_company': 'Atlantic Entertainment Group', 'count': 15},
#  {'production_company': 'Trans World Entertainment (TWE)', 'count': 15},
#  {'production_company': 'Comptoir Français du Film Production (CFFP)',
#   'count': 15},
#  {'production_company': 'Jerry Wald Productions', 'count': 15},
#  {'production_company': 'Omega Entertainment', 'count': 15},
#  {'production_company': 'Annapurna Studios', 'count': 15},
#  {'production_company': 'Sunrise', 'count': 15},
#  {'production_company': 'Bos Bros. Film & TV Productions', 'count': 15},
#  {'production_company': 'Allegro Film', 'count': 15},
#  {'production_company': 'The Malpaso Company', 'count': 15},
#  {'production_company': 'Graal', 'count': 15},
#  {'production_company': 'Kinorama', 'count': 15},
#  {'production_company': 'Alter Films', 'count': 15},
#  {'production_company': 'Galatea Film', 'count': 15},
#  {'production_company': 'Amazon Studios', 'count': 15},
#  {'production_company': 'Deutsche Film- und Fernsehakademie Berlin (DFFB)',
#   'count': 15},
#  {'production_company': 'Amblin Entertainment', 'count': 15},
#  {'production_company': 'American World Pictures (AWP)', 'count': 15},
#  {'production_company': 'Devon Film', 'count': 15},
#  {'production_company': 'Aleph Media', 'count': 15},
#  {'production_company': 'Production I.G.', 'count': 15},
#  {'production_company': 'Coop99 Filmproduktion', 'count': 15},
#  {'production_company': 'Goldcrest Films International', 'count': 15},
#  {'production_company': 'Mystique Films Inc.', 'count': 15},
#  {'production_company': 'FilmFour', 'count': 15},
#  {'production_company': 'Ceskoslovenský Státní Film', 'count': 15},
#  {'production_company': 'Sigma Film Productions', 'count': 15},
#  {'production_company': 'Bing Crosby Productions', 'count': 15},
#  {'production_company': 'Vega Film', 'count': 15},
#  {'production_company': 'Icon Entertainment International', 'count': 15},
#  {'production_company': 'Huayi Brothers Media', 'count': 15},
#  {'production_company': 'Independent Artists', 'count': 15},
#  {'production_company': 'BOB Film Sweden AB', 'count': 15},
#  {'production_company': 'BNT', 'count': 15},
#  {'production_company': 'George H. Brown Productions', 'count': 15},
#  {'production_company': 'Cinemaundici', 'count': 15},
#  {'production_company': 'Cinemaster S.r.l.', 'count': 15},
#  {'production_company': 'Seasonal Film Corporation', 'count': 15},
#  {'production_company': 'IRS Media', 'count': 15},
#  {'production_company': 'Senator Film Produktion', 'count': 15},
#  {'production_company': 'Bryan Foy Productions', 'count': 15},
#  {'production_company': 'Cinema Service', 'count': 15},
#  {'production_company': 'Saner Film', 'count': 15},
#  {'production_company': 'Aubrey Schenck Productions', 'count': 15},
#  {'production_company': 'Batjac Productions', 'count': 15},
#  {'production_company': 'Chukyo TV Broadcasting Company (CTV)', 'count': 15},
#  {'production_company': 'Nouvelles Éditions de Films (NEF)', 'count': 14},
#  {'production_company': 'Roger Corman Productions', 'count': 14},
#  {'production_company': 'Nat Holt Productions', 'count': 14},
#  {'production_company': 'Epic Productions', 'count': 14},
#  {'production_company': 'Brooksfilms', 'count': 14},
#  {'production_company': 'TAFF Pictures', 'count': 14},
#  {'production_company': 'Angel Films', 'count': 14},
#  {'production_company': 'Reteitalia', 'count': 14},
#  {'production_company': 'Reliance Entertainment', 'count': 14},
#  {'production_company': 'Jeonwonsa Film', 'count': 14},
#  {'production_company': 'Anima Estudios', 'count': 14},
#  {'production_company': 'LD Entertainment', 'count': 14},
#  {'production_company': 'Proton Cinema', 'count': 14},
#  {'production_company': 'MGN Filmes', 'count': 14},
#  {'production_company': 'ICE3', 'count': 14},
#  {'production_company': 'Romania Film', 'count': 14},
#  {'production_company': 'Press On Features', 'count': 14},
#  {'production_company': 'Universal 1440 Entertainment', 'count': 14},
#  {'production_company': 'M&M Productions', 'count': 14},
#  {'production_company': 'Crown International Pictures', 'count': 14},
#  {'production_company': 'American Independent Productions', 'count': 14},
#  {'production_company': 'Canana Films', 'count': 14},
#  {'production_company': 'Gullane', 'count': 14},
#  {'production_company': 'Elzévir Films', 'count': 14},
#  {'production_company': 'Impala', 'count': 14},
#  {'production_company': 'Royal Oaks Entertainment Inc.', 'count': 14},
#  {'production_company': 'The Cannon Group', 'count': 14},
#  {'production_company': 'Per Holst Filmproduktion', 'count': 14},
#  {'production_company': 'Eléfilm', 'count': 14},
#  {'production_company': 'American Broadcasting Company (ABC)', 'count': 14},
#  {'production_company': 'Automatik Entertainment', 'count': 14},
#  {'production_company': 'Woodfall Film Productions', 'count': 14},
#  {'production_company': 'Franz Seitz Filmproduktion', 'count': 14},
#  {'production_company': 'Versus Production', 'count': 14},
#  {'production_company': 'Téléma', 'count': 14},
#  {'production_company': 'UFA Fiction', 'count': 14},
#  {'production_company': 'Hollywood Media Bridge', 'count': 14},
#  {'production_company': 'France 3 Cinéma', 'count': 14},
#  {'production_company': 'Les Films Manuel Munz', 'count': 14},
#  {'production_company': 'A.C. Lyles Productions', 'count': 14},
#  {'production_company': 'MarVista Entertainment', 'count': 14},
#  {'production_company': 'Seven Arts Productions', 'count': 14},
#  {'production_company': 'Joseph M. Schenck Productions', 'count': 14},
#  {'production_company': 'Head Gear Films', 'count': 14},
#  {'production_company': 'Megafilm', 'count': 14},
#  {'production_company': 'Studio Green', 'count': 14},
#  {'production_company': 'Euterpe', 'count': 14},
#  {'production_company': 'HBO Films', 'count': 14},
#  {'production_company': 'Herbert Wilcox Productions', 'count': 14},
#  {'production_company': "Win's Movie Productions Ltd.", 'count': 14},
#  {'production_company': 'Flach Film', 'count': 14},
#  {'production_company': 'Madras Talkies', 'count': 14},
#  {'production_company': 'British Lion Film Corporation', 'count': 14},
#  {'production_company': 'Excelsa Film', 'count': 14},
#  {'production_company': 'Filmpool Nord', 'count': 14},
#  {'production_company': 'Rapid Heart Pictures', 'count': 14},
#  {'production_company': 'Artista Filmi Oy', 'count': 14},
#  {'production_company': 'Katsu Production', 'count': 13},
#  {'production_company': 'Penta Film', 'count': 13},
#  {'production_company': 'Diaphana Films', 'count': 13},
#  {'production_company': 'Boxoffice International Pictures (BIP)', 'count': 13},
#  {'production_company': 'José Frade Producciones Cinematográficas S.A.',
#   'count': 13},
#  {'production_company': 'Warner Bros./Seven Arts', 'count': 13},
#  {'production_company': 'Carnaby International', 'count': 13},
#  {'production_company': 'Kadokawa', 'count': 13},
#  {'production_company': 'First Artists', 'count': 13},
#  {'production_company': 'A.M.A. Film', 'count': 13},
#  {'production_company': 'Panorama Studios', 'count': 13},
#  {'production_company': 'CL Productions', 'count': 13},
#  {'production_company': 'Nelvana', 'count': 13},
#  {'production_company': 'King Records', 'count': 13},
#  {'production_company': 'Killer Films', 'count': 13},
#  {'production_company': 'Pannónia Filmstúdió', 'count': 13},
#  {'production_company': 'Castafiore Films', 'count': 13},
#  {'production_company': 'New Century Production', 'count': 13},
#  {'production_company': 'Pixar Animation Studios', 'count': 13},
#  {'production_company': 'Plato Film Production', 'count': 13},
#  {'production_company': 'Bryna Productions', 'count': 13},
#  {'production_company': 'Kim Ki-Duk Film', 'count': 13},
#  {'production_company': 'Cabin Fever Entertainment', 'count': 13},
#  {'production_company': 'Karé Productions', 'count': 13},
#  {'production_company': 'Circe Films', 'count': 13},
#  {'production_company': 'Andrew L. Stone Productions', 'count': 13},
#  {'production_company': 'Swirl Films', 'count': 13},
#  {'production_company': 'Barefoot Films', 'count': 13},
#  {'production_company': 'Icelandic Film', 'count': 13},
#  {'production_company': 'Feifer Worldwide', 'count': 13},
#  {'production_company': 'T-Series', 'count': 13},
#  {'production_company': 'Rigas Kinostudija', 'count': 13},
#  {'production_company': 'Clemi Cinematografica', 'count': 13},
#  {'production_company': 'Working Title Films', 'count': 13},
#  {'production_company': 'CineRidge Entertainment', 'count': 13},
#  {'production_company': 'Republic Pictures Corporation (I)', 'count': 13},
#  {'production_company': 'Coop Vidéo de Montréal', 'count': 13},
#  {'production_company': 'Beyond Films', 'count': 13},
#  {'production_company': 'Motel Films', 'count': 13},
#  {'production_company': 'Move Movie', 'count': 13},
#  {'production_company': 'Enrique Cerezo Producciones Cinematográficas S.A.',
#   'count': 13},
#  {'production_company': 'Entertainment One', 'count': 13},
#  {'production_company': 'Davis Entertainment', 'count': 13},
#  {'production_company': 'Cineplex Odeon Films', 'count': 13},
#  {'production_company': 'Backup Media', 'count': 13},
#  {'production_company': 'Aoi Promotion', 'count': 13},
#  {'production_company': 'Alameda Films', 'count': 13},
#  {'production_company': 'Arco Film', 'count': 13},
#  {'production_company': 'Melvin Simon Productions', 'count': 13},
#  {'production_company': 'France 2 Cinéma', 'count': 13},
#  {'production_company': 'Fabula', 'count': 13},
#  {'production_company': 'Soyuzmultfilm', 'count': 13},
#  {'production_company': 'Artfilm', 'count': 13},
#  {'production_company': 'BFI Film Fund', 'count': 13},
#  {'production_company': 'B.R.C. Produzione S.r.l.', 'count': 13},
#  {'production_company': 'Serendipity Point Films', 'count': 13},
#  {'production_company': 'Cocinor', 'count': 13},
#  {'production_company': 'Rai Cinema', 'count': 13},
#  {'production_company': 'VEB DEFA-Studio für Spielfilme', 'count': 13},
#  {'production_company': 'Christal Films', 'count': 13},
#  {'production_company': 'Pyramide Productions', 'count': 13},
#  {'production_company': 'Kitty Films', 'count': 13},
#  {'production_company': 'Creativos Asociados de Radio y Televisión (CARTEL)',
#   'count': 13},
#  {'production_company': 'Anagram', 'count': 13},
#  {'production_company': 'Curiosa Films', 'count': 13},
#  {'production_company': 'Destination Films', 'count': 13},
#  {'production_company': 'Projektions-AG Union (PAGU)', 'count': 13},
#  {'production_company': 'Lo Wei Motion Picture Company', 'count': 13},
#  {'production_company': 'J&M Entertainment', 'count': 13},
#  {'production_company': 'Fildebroc', 'count': 13},
#  {'production_company': 'Edward R. Pressman Film', 'count': 13},
#  {'production_company': 'Pupkin Film', 'count': 13},
#  {'production_company': 'Bold Films', 'count': 13},
#  {'production_company': 'Black Fawn Films', 'count': 13},
#  {'production_company': 'Komplizen Film', 'count': 13},
#  {'production_company': 'Tips Films Pvt. Ltd.', 'count': 13},
#  {'production_company': 'R&C Produzioni', 'count': 13},
#  {'production_company': 'Fine Arts Film Company', 'count': 13},
#  {'production_company': 'AMLF', 'count': 13},
#  {'production_company': 'Greenway Entertainment', 'count': 13},
#  {'production_company': 'Collective Development', 'count': 12},
#  {'production_company': 'Goldfinch', 'count': 12},
#  {'production_company': 'Marvel Studios', 'count': 12},
#  {'production_company': 'Arcola Pictures', 'count': 12},
#  {'production_company': 'Excel Entertainment', 'count': 12},
#  {'production_company': 'Les Films Marcel Pagnol', 'count': 12},
#  {'production_company': '2.4.7. Films', 'count': 12},
#  {'production_company': 'Sputnik', 'count': 12},
#  {'production_company': 'Sonet Film AB', 'count': 12},
#  {'production_company': 'The Kushner-Locke Company', 'count': 12},
#  {'production_company': 'Colour Yellow Productions', 'count': 12},
#  {'production_company': 'Sony Pictures Classics', 'count': 12},
#  {'production_company': 'Famous Players-Lasky Corporation', 'count': 12},
#  {'production_company': 'The Film', 'count': 12},
#  {'production_company': 'Madhouse', 'count': 12},
#  {'production_company': 'Kanun parvaresh fekri', 'count': 12},
#  {'production_company': 'micro_scope', 'count': 12},
#  {'production_company': 'TVN', 'count': 12},
#  {'production_company': 'Norstar Entertainment', 'count': 12},
#  {'production_company': 'MD Pictures', 'count': 12},
#  {'production_company': 'Canadian Film or Video Production Tax Credit (CPTC)',
#   'count': 12},
#  {'production_company': 'Five Star Production Co. Ltd.', 'count': 12},
#  {'production_company': 'Kazakhfilm Studios', 'count': 12},
#  {'production_company': 'Ognon Pictures', 'count': 12},
#  {'production_company': 'North American Pictures', 'count': 12},
#  {'production_company': 'Tigon British Film Productions', 'count': 12},
#  {'production_company': 'DENTSU Music And Entertainment', 'count': 12},
#  {'production_company': 'Four Leaf Productions', 'count': 12},
#  {'production_company': 'Albina Productions S.a.r.l.', 'count': 12},
#  {'production_company': 'Kadokawa Pictures', 'count': 12},
#  {'production_company': 'Les Productions La Fête Inc.', 'count': 12},
#  {'production_company': 'Casa de Filme Cinci', 'count': 12},
#  {'production_company': 'Werner Herzog Filmproduktion', 'count': 12},
#  {'production_company': 'K.G. Productions', 'count': 12},
#  {'production_company': 'Les Films des Tournelles', 'count': 12},
#  {'production_company': 'Studioul Cinematografic Bucuresti', 'count': 12},
#  {'production_company': 'Sidney Kimmel Entertainment', 'count': 12},
#  {'production_company': 'National Film Board of Canada (NFB)', 'count': 12},
#  {'production_company': 'Event Film Distribution', 'count': 12},
#  {'production_company': 'Same Player', 'count': 12},
#  {'production_company': '3 Arts Entertainment', 'count': 12},
#  {'production_company': 'Patriot Pictures', 'count': 12},
#  {'production_company': 'Universal Film Manufacturing Company', 'count': 12},
#  {'production_company': 'IFD Films and Arts', 'count': 12},
#  {'production_company': 'La Petite Reine', 'count': 12},
#  {'production_company': 'Minds Eye Entertainment', 'count': 12},
#  {'production_company': 'V. Creations', 'count': 12},
#  {'production_company': 'Focus Films', 'count': 12},
#  {'production_company': 'Worldview Entertainment', 'count': 12},
#  {'production_company': 'Red Giant Movies', 'count': 12},
#  {'production_company': 'Filmstudio Bucuresti', 'count': 12},
#  {'production_company': 'Intercapital', 'count': 12},
#  {'production_company': 'Muhtesem Film', 'count': 12},
#  {'production_company': 'Black Bear Pictures', 'count': 12},
#  {'production_company': 'Cerito Films', 'count': 12},
#  {'production_company': 'Vestron Pictures', 'count': 12},
#  {'production_company': 'Promark Entertainment Group', 'count': 12},
#  {'production_company': 'Ecce Films', 'count': 12},
#  {'production_company': 'NL Film', 'count': 12},
#  {'production_company': 'Chapter 2', 'count': 12},
#  {'production_company': 'Ivan Tors Productions', 'count': 12},
#  {'production_company': 'Bocaboca Producciones', 'count': 12},
#  {'production_company': 'Eagle Films', 'count': 12},
#  {'production_company': 'WWE Studios', 'count': 12},
#  {'production_company': 'Novotny & Novotny Filmproduktion GmbH', 'count': 12},
#  {'production_company': 'Hybrid', 'count': 12},
#  {'production_company': 'Paramount Vantage', 'count': 12},
#  {'production_company': 'Estudios Churubusco Azteca S.A.', 'count': 12},
#  {'production_company': 'Hopalong Cassidy Productions Inc.', 'count': 12},
#  {'production_company': 'Ultra Film', 'count': 12},
#  {'production_company': 'Chang Hong Channel Film & Video', 'count': 12},
#  {'production_company': 'Scorpio Film Releasing', 'count': 12},
#  {'production_company': 'Largo Entertainment', 'count': 12},
#  {'production_company': 'Eskay Movies', 'count': 12},
#  {'production_company': 'Baa-Ram-Ewe', 'count': 12},
#  {'production_company': 'Avenue Pictures', 'count': 12},
#  {'production_company': 'Cem Film', 'count': 12},
#  {'production_company': 'Snowfort Pictures', 'count': 11},
#  {'production_company': 'Egoli Tossell Film', 'count': 11},
#  {'production_company': 'Saregama India', 'count': 11},
#  {'production_company': 'Alfa Film', 'count': 11},
#  {'production_company': 'Bleiberg Entertainment', 'count': 11},
#  {'production_company': 'ARD Degeto Film', 'count': 11},
#  {'production_company': 'ADR Productions', 'count': 11},
#  {'production_company': 'Agidi', 'count': 11},
#  {'production_company': 'Canal Sur Televisión', 'count': 11},
#  {'production_company': 'The Archers', 'count': 11},
#  {'production_company': 'Blue Rider Pictures', 'count': 11},
#  {'production_company': 'Slovenská filmová tvorba Koliba (SFT)', 'count': 11},
#  {'production_company': 'Producciones Rodríguez Hermanos', 'count': 11},
#  {'production_company': 'Astral Bellevue Pathé', 'count': 11},
#  {'production_company': 'Alquimia Cinema', 'count': 11},
#  {'production_company': 'Sil-Metropole Organisation', 'count': 11},
#  {'production_company': 'The Ladd Company', 'count': 11},
#  {'production_company': 'Film Par Film', 'count': 11},
#  {'production_company': 'Bh5', 'count': 11},
#  {'production_company': 'Aksoy Film', 'count': 11},
#  {'production_company': 'A. Film', 'count': 11},
#  {'production_company': 'Wakamatsu Production', 'count': 11},
#  {'production_company': 'Action Films', 'count': 11},
#  {'production_company': 'FilmTeknik', 'count': 11},
#  {'production_company': 'Unified Pictures', 'count': 11},
#  {'production_company': 'Tornasol Films', 'count': 11},
#  {'production_company': 'Otto Preminger Films', 'count': 11},
#  {'production_company': 'A24', 'count': 11},
#  {'production_company': 'Epo-Film Produktionsgesellschaft', 'count': 11},
#  {'production_company': 'Super Cassettes Industries Limited (T-Series)',
#   'count': 11},
#  {'production_company': 'Filmpartners', 'count': 11},
#  {'production_company': 'Surinder Films', 'count': 11},
#  {'production_company': 'Surrender Cinema', 'count': 11},
#  {'production_company': 'Shapiro-Glickenhaus Entertainment', 'count': 11},
#  {'production_company': 'Filmax', 'count': 11},
#  {'production_company': 'Arizona Films', 'count': 11},
#  {'production_company': 'Svenska Biografteatern AB', 'count': 11},
#  {'production_company': 'Jolly Film', 'count': 11},
#  {'production_company': 'Image Organization', 'count': 11},
#  {'production_company': 'Group Film Productions Limited', 'count': 11},
#  {'production_company': 'Art Port', 'count': 11},
#  {'production_company': 'Geneon Entertainment', 'count': 11},
#  {'production_company': 'Reliance Big Pictures', 'count': 11},
#  {'production_company': 'Artcam International', 'count': 11},
#  {'production_company': 'Anchor Bay Films', 'count': 11},
#  {'production_company': 'Grindstone Entertainment Group', 'count': 11},
#  {'production_company': 'Thirukumaran Entertainment', 'count': 11},
#  {'production_company': 'Charles Chaplin Productions', 'count': 11},
#  {'production_company': 'Les Productions Lazennec', 'count': 11},
#  {'production_company': 'Lorimar Productions', 'count': 11},
#  {'production_company': 'Zip Cinema', 'count': 11},
#  {'production_company': 'Claussen Wöbke Putz Filmproduktion', 'count': 11},
#  {'production_company': 'Yale Productions', 'count': 11},
#  {'production_company': 'Kokuei Company', 'count': 11},
#  {'production_company': 'Conacite Uno', 'count': 11},
#  {'production_company': 'Corsan', 'count': 11},
#  {'production_company': 'Lumière & Company', 'count': 11},
#  {'production_company': 'Cinema Art', 'count': 11},
#  {'production_company': 'Les Films Vision 4', 'count': 11},
#  {'production_company': 'Fridthjof Film', 'count': 11},
#  {'production_company': 'Chubu-nippon Broadcasting Company (CBC)',
#   'count': 11},
#  {'production_company': 'Les Films de la Boétie', 'count': 11},
#  {'production_company': 'Lietuvos Kinostudija', 'count': 11},
#  {'production_company': 'Monolith Films', 'count': 11},
#  {'production_company': 'Fox International Productions (FIP)', 'count': 11},
#  {'production_company': 'Mandarin Films Distribution', 'count': 11},
#  {'production_company': 'Crone Film Produktion A/S', 'count': 11},
#  {'production_company': 'National Theatre', 'count': 11},
#  {'production_company': 'Caramel Film', 'count': 11},
#  {'production_company': 'Creative Commercials', 'count': 11},
#  {'production_company': '24 Frames Factory', 'count': 11},
#  {'production_company': 'Lucasfilm', 'count': 11},
#  {'production_company': 'Kindai Eiga Kyokai', 'count': 11},
#  {'production_company': 'MDP Worldwide', 'count': 11},
#  {'production_company': 'Kino Swiat', 'count': 11},
#  {'production_company': 'Neue Deutsche Filmgesellschaft (NDF)', 'count': 11},
#  {'production_company': 'Les Films du Lendemain', 'count': 11},
#  {'production_company': 'Kyoto Animation', 'count': 10},
#  {'production_company': 'Celluloid Dreams', 'count': 10},
#  {'production_company': 'Dialóg Filmstúdió', 'count': 10},
#  {'production_company': 'New Regency Pictures', 'count': 10},
#  {'production_company': 'Alcor Films', 'count': 10},
#  {'production_company': 'Belladonna Productions', 'count': 10},
#  {'production_company': 'Big Beach Films', 'count': 10},
#  {'production_company': 'In-Cine Compañía Industrial Cinematográfica',
#   'count': 10},
#  {'production_company': 'Independent-International Pictures', 'count': 10},
#  {'production_company': 'Belarusfilm', 'count': 10},
#  {'production_company': 'Revolution Films', 'count': 10},
#  {'production_company': 'Producers-Actors Corporation', 'count': 10},
#  {'production_company': 'Wüste Film', 'count': 10},
#  {'production_company': 'Svensk Talfilm', 'count': 10},
#  {'production_company': 'George King Productions', 'count': 10},
#  {'production_company': 'Warner Brothers-First National Productions',
#   'count': 10},
#  {'production_company': 'Film Science', 'count': 10},
#  {'production_company': 'United States Pictures', 'count': 10},
#  {'production_company': 'IBC Movie', 'count': 10},
#  {'production_company': 'PVPictures', 'count': 10},
#  {'production_company': 'SBS Productions', 'count': 10},
#  {'production_company': 'Warner Bros. Animation', 'count': 10},
#  {'production_company': 'IFC Films', 'count': 10},
#  {'production_company': 'Paco Cinematografica', 'count': 10},
#  {'production_company': 'Anglo-EMI', 'count': 10},
#  {'production_company': 'Toei Video Company', 'count': 10},
#  {'production_company': 'Gramercy Pictures (I)', 'count': 10},
#  {'production_company': 'Continental Films', 'count': 10},
#  {'production_company': 'C&I Entertainment', 'count': 10},
#  {'production_company': 'Robot Communications', 'count': 10},
#  {'production_company': 'Moby Dick Films', 'count': 10},
#  {'production_company': "Xi'an Film Studio", 'count': 10},
#  {'production_company': 'Modernciné', 'count': 10},
#  {'production_company': 'Caviar Films', 'count': 10},
#  {'production_company': 'Cinecittà', 'count': 10},
#  {'production_company': 'Fox Atomic', 'count': 10},
#  {'production_company': 'Rastar Films', 'count': 10},
#  {'production_company': 'Parts and Labor', 'count': 10},
#  {'production_company': 'ElSobky Film', 'count': 10},
#  {'production_company': 'Credofilm', 'count': 10},
#  {'production_company': 'East Japan Marketing & Communications Inc.',
#   'count': 10},
#  {'production_company': 'Item 7', 'count': 10},
#  {'production_company': 'Kinotar', 'count': 10},
#  {'production_company': "Lion's Gate Films", 'count': 10},
#  {'production_company': 'New Artists Alliance', 'count': 10},
#  {'production_company': 'Boll Kino Beteiligungs GmbH & Co. KG', 'count': 10},
#  {'production_company': 'ESX Entertainment', 'count': 10},
#  {'production_company': 'Cranium Entertainment', 'count': 10},
#  {'production_company': 'BondIt Media Capital', 'count': 10},
#  {'production_company': 'Nasir Hussain Films', 'count': 10},
#  {'production_company': 'Tempean Films', 'count': 10},
#  {'production_company': 'ALT Entertainment', 'count': 10},
#  {'production_company': 'Permut Presentations', 'count': 10},
#  {'production_company': 'Vinod Chopra Productions', 'count': 10},
#  {'production_company': 'Bosna Film', 'count': 10},
#  {'production_company': 'Terra-Filmkunst', 'count': 10},
#  {'production_company': 'Windows Production House', 'count': 10},
#  {'production_company': 'Negativ', 'count': 10},
#  {'production_company': 'Cesáreo González Producciones Cinematográficas',
#   'count': 10},
#  {'production_company': 'Brut Productions', 'count': 10},
#  {'production_company': 'Lightning Pictures', 'count': 10},
#  {'production_company': 'Taewon Entertainment', 'count': 10},
#  {'production_company': 'Vyjayanthi Movies', 'count': 10},
#  {'production_company': 'RabbitBandini Productions', 'count': 10},
#  {'production_company': 'Lippert Pictures', 'count': 10},
#  {'production_company': 'Greka Film', 'count': 10},
#  {'production_company': 'GH Pictures', 'count': 10},
#  {'production_company': 'New Horizons Picture', 'count': 10},
#  {'production_company': 'Aleph Producciones S.A.', 'count': 10},
#  {'production_company': 'RAI Radiotelevisione Italiana', 'count': 10},
#  {'production_company': 'International Video 80', 'count': 10},
#  {'production_company': 'Blind Spot Pictures Oy', 'count': 10},
#  {'production_company': 'Pathé Renn Productions', 'count': 10},
#  {'production_company': 'D.M.S. Films', 'count': 10},
#  {'production_company': 'D.D.L.', 'count': 10},
#  {'production_company': 'Dream Warrior Pictures', 'count': 10},
#  {'production_company': 'Island Pictures', 'count': 10},
#  {'production_company': "Jing's Production", 'count': 10},
#  {'production_company': 'Cosmopolitan Film Productions', 'count': 10},
#  {'production_company': 'Peace Arch Entertainment Group', 'count': 10},
#  {'production_company': 'GMM Tai Hub (GTH)', 'count': 10},
#  {'production_company': 'Lyca Productions', 'count': 10},
#  {'production_company': 'Cineproduzioni Daunia 70', 'count': 10},
#  {'production_company': 'Dschoint Ventschr Filmproduktion AG', 'count': 10},
#  {'production_company': 'B.O.M. Film Productions Co.', 'count': 10},
#  {'production_company': 'Cinéa', 'count': 10},
#  {'production_company': 'Anto Joseph Film Company', 'count': 10},
#  {'production_company': 'Column Film', 'count': 10},
#  {'production_company': 'Darryl F. Zanuck Productions', 'count': 10},
#  {'production_company': 'Silver Peak Productions', 'count': 10},
#  {'production_company': 'Schramm Film Koerner & Weber', 'count': 10},
#  {'production_company': 'Güney Film', 'count': 10},
#  {'production_company': 'A&M Films', 'count': 10},
#  {'production_company': 'Aftab Pictures', 'count': 10},
#  {'production_company': 'Exclusive Media Group', 'count': 10},
#  {'production_company': 'Obel Film', 'count': 10},
#  {'production_company': 'Zespol Filmowy "Perspektywa"', 'count': 10},
#  {'production_company': 'Daro Film Distribution', 'count': 10},
#  {'production_company': 'Film Kraft', 'count': 10},
#  {'production_company': 'Soyuzdetfilm', 'count': 10},
#  {'production_company': 'Atlántida Films', 'count': 10},
#  {'production_company': 'Avon Productions (II)', 'count': 10},
#  {'production_company': 'Oriental Light and Magic (OLM)', 'count': 10},
#  {'production_company': 'UK Film Council', 'count': 10},
#  {'production_company': "Les Films d'Ici", 'count': 10},
#  {'production_company': 'Marianne Productions', 'count': 10},
#  {'production_company': 'UGC YM', 'count': 10},
#  {'production_company': 'Opus Film', 'count': 10},
#  {'production_company': 'Cinémadefacto', 'count': 10},
#  {'production_company': 'Triglav Film', 'count': 10},
#  {'production_company': 'Soraya Intercine Film PT', 'count': 10},
#  {'production_company': 'F Comme Film', 'count': 10},
#  {'production_company': 'Canal+ Polska', 'count': 10},
#  {'production_company': 'Artémis Productions', 'count': 10},
#  {'production_company': 'Anzervos', 'count': 10},
#  {'production_company': 'Zoetrope Studios', 'count': 10},
#  {'production_company': 'A-1 Pictures', 'count': 10},
#  {'production_company': 'Metafilms', 'count': 10},
#  {'production_company': 'Audiovisual Aval SGR', 'count': 10},
#  {'production_company': 'O Som e a Fúria', 'count': 10},
#  {'production_company': 'Archipel 35', 'count': 10},
#  {'production_company': 'Cinerenta Medienbeteiligungs KG', 'count': 10},
#  {'production_company': 'Shoreline Entertainment', 'count': 10},
#  {'production_company': 'SamFilm Produktion', 'count': 10},
#  {'production_company': 'Action International Pictures (AIP)', 'count': 10},
#  {'production_company': 'Aeroplano Cine', 'count': 10},
#  {'production_company': 'Olga Film', 'count': 10},
#  {'production_company': 'Campfire', 'count': 10},
#  {'production_company': 'Films & Casting Temple Pvt. Ltd. Sydney',
#   'count': 10},
#  {'production_company': 'Mavi Film', 'count': 10},
#  {'production_company': 'Active Entertainment', 'count': 10},
#  {'production_company': 'David Foster Productions', 'count': 10},
#  {'production_company': 'Argonauts Productions S.A.', 'count': 10},
#  {'production_company': 'Happinet.', 'count': 10},
#  {'production_company': 'Carthago Films S.a.r.l.', 'count': 10},
#  {'production_company': 'Gloria Films', 'count': 10},
#  {'production_company': 'Darius Films', 'count': 10},
#  {'production_company': 'Twisted Pictures', 'count': 10},
#  {'production_company': 'Sathya Jyothi Films', 'count': 10},
#  {'production_company': 'Melenny Productions', 'count': 10},
#  {'production_company': 'Les Films du Poisson', 'count': 10},
#  {'production_company': 'Thelma Films', 'count': 10},
#  {'production_company': 'Associated Talking Pictures (ATP)', 'count': 9},
#  {'production_company': 'Shree Krishna International', 'count': 9},
#  {'production_company': 'Corporación Nacional Cinematográfica (CONACINE)',
#   'count': 9},
#  {'production_company': 'Maruti International', 'count': 9},
#  {'production_company': 'Studio 100', 'count': 9},
#  {'production_company': 'Pure Flix Entertainment', 'count': 9},
#  {'production_company': 'Chartoff-Winkler Productions', 'count': 9},
#  {'production_company': 'ApolloMedia Distribution', 'count': 9},
#  {'production_company': 'Block 2 Pictures', 'count': 9},
#  {'production_company': 'Edward L. Alperson Productions', 'count': 9},
#  {'production_company': 'Società Italiana Cines', 'count': 9},
#  {'production_company': 'Charter Film Productions', 'count': 9},
#  {'production_company': 'Er Film', 'count': 9},
#  {'production_company': 'Les Films Velvet', 'count': 9},
#  {'production_company': 'Trimurti Films Pvt. Ltd.', 'count': 9},
#  {'production_company': 'ArieScope Pictures', 'count': 9},
#  {'production_company': 'Fu Works', 'count': 9},
#  {'production_company': 'Argosy Pictures', 'count': 9},
#  {'production_company': 'Champs-Élysées Productions', 'count': 9},
#  {'production_company': 'Jack Schwarz Productions', 'count': 9},
#  ...]

# %%
budget_csv = "graph4-budget vs profit.csv"

budget_df = pd.read_csv(budget_csv)
budget_df
# Out:
#                                country  \
# 0                                  USA
# 1      Argentina, Netherlands, Germany
# 2             Germany, Sweden, Denmark
# 3                          Germany, UK
# 4                                  USA
# ...                                ...
# 12756                              USA
# 12757                              USA
# 12758   USA, Mexico, Australia, Canada
# 12759                              USA
# 12760                              USA
#
#                                    original_title  year  \
# 0                                     The Heiress  1949
# 1                                 Camino a La Paz  2015
# 2                              Eagle Hunter's Son  2009
# 3                                          Inbred  2011
# 4                                       Zyzzyx Rd  2006
# ...                                           ...   ...
# 12756                      Avengers: Infinity War  2018
# 12757  Star Wars: Episode VII - The Force Awakens  2015
# 12758                                     Titanic  1997
# 12759                                      Avatar  2009
# 12760                           Avengers: Endgame  2019
#
#                             genre  avg_vote    votes       budget  \
# 0                  Drama, Romance       8.1    13301    2600000.0
# 1                           Drama       7.0      625     650000.0
# 2                   Drama, Family       6.4      129    1200000.0
# 3                  Comedy, Horror       5.2     4536    1250000.0
# 4          Crime, Drama, Thriller       4.1      983    2000000.0
# ...                           ...       ...      ...          ...
# 12756   Action, Adventure, Sci-Fi       8.4   796486  321000000.0
# 12757   Action, Adventure, Sci-Fi       7.9   845102  245000000.0
# 12758              Drama, Romance       7.8  1023181  200000000.0
# 12759  Action, Adventure, Fantasy       7.8  1101160  237000000.0
# 12760    Action, Adventure, Drama       8.4   754786  356000000.0
#
#        worlwide_gross_income
# 0               1.600000e+01
# 1               1.700000e+01
# 2               2.300000e+01
# 3               2.400000e+01
# 4               3.000000e+01
# ...                      ...
# 12756           2.048360e+09
# 12757           2.068224e+09
# 12758           2.195170e+09
# 12759           2.790439e+09
# 12760           2.797801e+09
#
# [12761 rows x 8 columns]

# %%
budget_df.to_dict('records')
# Out:
# [{'country': 'USA',
#   'original_title': 'The Heiress',
#   'year': 1949,
#   'genre': 'Drama, Romance',
#   'avg_vote': 8.1,
#   'votes': 13301,
#   'budget': 2600000.0,
#   'worlwide_gross_income': 16.0},
#  {'country': 'Argentina, Netherlands, Germany',
#   'original_title': 'Camino a La Paz',
#   'year': 2015,
#   'genre': 'Drama',
#   'avg_vote': 7.0,
#   'votes': 625,
#   'budget': 650000.0,
#   'worlwide_gross_income': 17.0},
#  {'country': 'Germany, Sweden, Denmark',
#   'original_title': "Eagle Hunter's Son",
#   'year': 2009,
#   'genre': 'Drama, Family',
#   'avg_vote': 6.4,
#   'votes': 129,
#   'budget': 1200000.0,
#   'worlwide_gross_income': 23.0},
#  {'country': 'Germany, UK',
#   'original_title': 'Inbred',
#   'year': 2011,
#   'genre': 'Comedy, Horror',
#   'avg_vote': 5.2,
#   'votes': 4536,
#   'budget': 1250000.0,
#   'worlwide_gross_income': 24.0},
#  {'country': 'USA',
#   'original_title': 'Zyzzyx Rd',
#   'year': 2006,
#   'genre': 'Crime, Drama, Thriller',
#   'avg_vote': 4.1,
#   'votes': 983,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 30.0},
#  {'country': 'USA',
#   'original_title': 'Older Than America',
#   'year': 2008,
#   'genre': 'Drama',
#   'avg_vote': 5.3,
#   'votes': 857,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 32.0},
#  {'country': 'UK',
#   'original_title': 'The Marker',
#   'year': 2017,
#   'genre': 'Crime, Thriller',
#   'avg_vote': 5.4,
#   'votes': 279,
#   'budget': 750000.0,
#   'worlwide_gross_income': 37.0},
#  {'country': 'Brazil',
#   'original_title': 'El bosque negro',
#   'year': 2018,
#   'genre': 'Horror',
#   'avg_vote': 5.7,
#   'votes': 167,
#   'budget': 675000.0,
#   'worlwide_gross_income': 43.0},
#  {'country': 'UK',
#   'original_title': '7 Lives',
#   'year': 2011,
#   'genre': 'Fantasy, Thriller',
#   'avg_vote': 3.5,
#   'votes': 416,
#   'budget': 2500.0,
#   'worlwide_gross_income': 51.0},
#  {'country': 'Finland, Sweden, France',
#   'original_title': 'Små mirakel och stora',
#   'year': 2006,
#   'genre': 'Drama',
#   'avg_vote': 5.8,
#   'votes': 185,
#   'budget': 1983558.0,
#   'worlwide_gross_income': 57.0},
#  {'country': 'France',
#   'original_title': 'Dans ton sommeil',
#   'year': 2010,
#   'genre': 'Horror, Thriller',
#   'avg_vote': 5.6,
#   'votes': 1375,
#   'budget': 1400000.0,
#   'worlwide_gross_income': 73.0},
#  {'country': 'Mexico',
#   'original_title': 'Atroz (Atrocious)',
#   'year': 2015,
#   'genre': 'Horror',
#   'avg_vote': 5.3,
#   'votes': 435,
#   'budget': 7000.0,
#   'worlwide_gross_income': 74.0},
#  {'country': 'Spain, France, Romania',
#   'original_title': 'Història de la meva mort',
#   'year': 2013,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'votes': 657,
#   'budget': 1300000.0,
#   'worlwide_gross_income': 77.0},
#  {'country': 'China',
#   'original_title': 'Yi ge mo sheng nu ren de lai xin',
#   'year': 2004,
#   'genre': 'Drama',
#   'avg_vote': 6.8,
#   'votes': 663,
#   'budget': 20000000.0,
#   'worlwide_gross_income': 78.0},
#  {'country': 'Hungary',
#   'original_title': 'Egyetleneim',
#   'year': 2006,
#   'genre': 'Comedy, Drama, Romance',
#   'avg_vote': 5.8,
#   'votes': 218,
#   'budget': 48000000.0,
#   'worlwide_gross_income': 88.0},
#  {'country': 'Lithuania, France, Belgium',
#   'original_title': 'Aurora',
#   'year': 2012,
#   'genre': 'Romance, Sci-Fi, Thriller',
#   'avg_vote': 6.0,
#   'votes': 2502,
#   'budget': 1175000.0,
#   'worlwide_gross_income': 91.0},
#  {'country': 'Finland, Estonia',
#   'original_title': 'Stiilipidu',
#   'year': 2005,
#   'genre': 'Comedy, Drama',
#   'avg_vote': 6.1,
#   'votes': 244,
#   'budget': 607000.0,
#   'worlwide_gross_income': 95.0},
#  {'country': 'USA, Morocco',
#   'original_title': 'The Objective',
#   'year': 2008,
#   'genre': 'Horror, Sci-Fi, Thriller',
#   'avg_vote': 5.5,
#   'votes': 7744,
#   'budget': 4000000.0,
#   'worlwide_gross_income': 95.0},
#  {'country': 'USA',
#   'original_title': 'Some Guy Who Kills People',
#   'year': 2011,
#   'genre': 'Comedy, Crime, Drama',
#   'avg_vote': 6.4,
#   'votes': 5607,
#   'budget': 300000.0,
#   'worlwide_gross_income': 113.0},
#  {'country': 'Spain',
#   'original_title': 'Dixie y la rebelión zombi',
#   'year': 2014,
#   'genre': 'Animation',
#   'avg_vote': 4.6,
#   'votes': 185,
#   'budget': 1800000.0,
#   'worlwide_gross_income': 120.0},
#  {'country': 'UK',
#   'original_title': 'Darling',
#   'year': 1965,
#   'genre': 'Drama, Romance',
#   'avg_vote': 7.1,
#   'votes': 5876,
#   'budget': 400000.0,
#   'worlwide_gross_income': 137.0},
#  {'country': 'France',
#   'original_title': 'Rendez-vous à Kiruna',
#   'year': 2012,
#   'genre': 'Drama',
#   'avg_vote': 6.4,
#   'votes': 114,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 148.0},
#  {'country': 'South Africa',
#   'original_title': 'Boy Called Twist',
#   'year': 2004,
#   'genre': 'Drama',
#   'avg_vote': 6.6,
#   'votes': 147,
#   'budget': 2400000.0,
#   'worlwide_gross_income': 177.0},
#  {'country': 'UK',
#   'original_title': 'The Angelic Conversation',
#   'year': 1985,
#   'genre': 'Drama',
#   'avg_vote': 6.2,
#   'votes': 708,
#   'budget': 35000.0,
#   'worlwide_gross_income': 205.0},
#  {'country': 'UK, Canada, USA',
#   'original_title': 'Jeremiah Terminator LeRoy',
#   'year': 2018,
#   'genre': 'Biography, Drama',
#   'avg_vote': 5.3,
#   'votes': 1621,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 205.0},
#  {'country': 'UK',
#   'original_title': 'Pandorica',
#   'year': 2016,
#   'genre': 'Sci-Fi',
#   'avg_vote': 3.6,
#   'votes': 470,
#   'budget': 75000.0,
#   'worlwide_gross_income': 228.0},
#  {'country': 'India',
#   'original_title': 'Sarrainodu',
#   'year': 2016,
#   'genre': 'Action, Drama',
#   'avg_vote': 6.4,
#   'votes': 4022,
#   'budget': 750000000.0,
#   'worlwide_gross_income': 239.0},
#  {'country': 'Norway',
#   'original_title': 'Dirk Ohm - Illusjonisten som forsvant',
#   'year': 2015,
#   'genre': 'Drama, Mystery',
#   'avg_vote': 5.5,
#   'votes': 189,
#   'budget': 21600000.0,
#   'worlwide_gross_income': 273.0},
#  {'country': 'USA',
#   'original_title': 'Blood Car',
#   'year': 2007,
#   'genre': 'Comedy, Horror',
#   'avg_vote': 5.3,
#   'votes': 2384,
#   'budget': 25000.0,
#   'worlwide_gross_income': 297.0},
#  {'country': 'USA',
#   'original_title': 'Trojan War',
#   'year': 1997,
#   'genre': 'Comedy',
#   'avg_vote': 5.7,
#   'votes': 5636,
#   'budget': 15000000.0,
#   'worlwide_gross_income': 309.0},
#  {'country': 'UK',
#   'original_title': '100 Streets',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 5.7,
#   'votes': 3645,
#   'budget': 3000000.0,
#   'worlwide_gross_income': 309.0},
#  {'country': 'France',
#   'original_title': 'The Lost Door',
#   'year': 2008,
#   'genre': 'Drama, Thriller',
#   'avg_vote': 4.4,
#   'votes': 173,
#   'budget': 1200000.0,
#   'worlwide_gross_income': 328.0},
#  {'country': 'UK',
#   'original_title': 'Turnout',
#   'year': 2011,
#   'genre': 'Drama',
#   'avg_vote': 5.4,
#   'votes': 271,
#   'budget': 500000.0,
#   'worlwide_gross_income': 333.0},
#  {'country': 'Indonesia',
#   'original_title': 'Babi Buta yang Ingin Terbang',
#   'year': 2008,
#   'genre': 'Drama',
#   'avg_vote': 6.1,
#   'votes': 215,
#   'budget': 250000.0,
#   'worlwide_gross_income': 344.0},
#  {'country': 'UK',
#   'original_title': 'The Reverend',
#   'year': 2011,
#   'genre': 'Horror',
#   'avg_vote': 4.0,
#   'votes': 375,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 366.0},
#  {'country': 'Argentina',
#   'original_title': 'Tiempo muerto',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 6.1,
#   'votes': 172,
#   'budget': 400000.0,
#   'worlwide_gross_income': 369.0},
#  {'country': 'UK',
#   'original_title': 'Saturday Night and Sunday Morning',
#   'year': 1960,
#   'genre': 'Drama, Romance',
#   'avg_vote': 7.6,
#   'votes': 7520,
#   'budget': 100000.0,
#   'worlwide_gross_income': 370.0},
#  {'country': 'UK, USA',
#   'original_title': 'Chitty Chitty Bang Bang',
#   'year': 1968,
#   'genre': 'Adventure, Family, Fantasy',
#   'avg_vote': 6.9,
#   'votes': 40116,
#   'budget': 10000000.0,
#   'worlwide_gross_income': 398.0},
#  {'country': 'Canada',
#   'original_title': 'La vallée des larmes',
#   'year': 2012,
#   'genre': 'Drama',
#   'avg_vote': 7.4,
#   'votes': 566,
#   'budget': 0.0,
#   'worlwide_gross_income': 404.0},
#  {'country': 'Spain',
#   'original_title': 'Asmodexia',
#   'year': 2014,
#   'genre': 'Horror',
#   'avg_vote': 4.6,
#   'votes': 1127,
#   'budget': 500000.0,
#   'worlwide_gross_income': 418.0},
#  {'country': 'USA',
#   'original_title': 'The Wolf Man',
#   'year': 1941,
#   'genre': 'Horror',
#   'avg_vote': 7.3,
#   'votes': 23071,
#   'budget': 180000.0,
#   'worlwide_gross_income': 420.0},
#  {'country': 'Canada',
#   'original_title': 'The Dark Hours',
#   'year': 2005,
#   'genre': 'Horror, Thriller',
#   'avg_vote': 6.0,
#   'votes': 5212,
#   'budget': 500000.0,
#   'worlwide_gross_income': 423.0},
#  {'country': 'Croatia',
#   'original_title': 'Ta divna Splitska noc',
#   'year': 2004,
#   'genre': 'Crime, Drama, Romance',
#   'avg_vote': 7.4,
#   'votes': 1427,
#   'budget': 250000.0,
#   'worlwide_gross_income': 427.0},
#  {'country': 'Russia',
#   'original_title': 'Geroy',
#   'year': 2016,
#   'genre': 'Action, Drama, Romance',
#   'avg_vote': 4.6,
#   'votes': 385,
#   'budget': 7000000.0,
#   'worlwide_gross_income': 434.0},
#  {'country': 'UK',
#   'original_title': 'My Name Is Lenny',
#   'year': 2017,
#   'genre': 'Biography, Drama, Sport',
#   'avg_vote': 6.2,
#   'votes': 2467,
#   'budget': 10000000.0,
#   'worlwide_gross_income': 435.0},
#  {'country': 'Brazil',
#   'original_title': 'Mar Negro',
#   'year': 2013,
#   'genre': 'Horror',
#   'avg_vote': 5.6,
#   'votes': 238,
#   'budget': 300000.0,
#   'worlwide_gross_income': 435.0},
#  {'country': 'China',
#   'original_title': 'Yi shi er niao',
#   'year': 2005,
#   'genre': 'Action, Adventure, Comedy',
#   'avg_vote': 3.5,
#   'votes': 140,
#   'budget': 15000000.0,
#   'worlwide_gross_income': 449.0},
#  {'country': 'UK',
#   'original_title': 'Piggy',
#   'year': 2012,
#   'genre': 'Horror, Thriller',
#   'avg_vote': 5.6,
#   'votes': 1427,
#   'budget': 900000.0,
#   'worlwide_gross_income': 467.0},
#  {'country': 'USA',
#   'original_title': 'Rome & Jewel',
#   'year': 2008,
#   'genre': 'Drama, Musical',
#   'avg_vote': 4.2,
#   'votes': 129,
#   'budget': 1200000.0,
#   'worlwide_gross_income': 470.0},
#  {'country': 'India',
#   'original_title': 'Pushpaka Vimana',
#   'year': 2017,
#   'genre': 'Comedy, Drama, Family',
#   'avg_vote': 7.5,
#   'votes': 257,
#   'budget': 250000000.0,
#   'worlwide_gross_income': 499.0},
#  {'country': 'France',
#   'original_title': 'Baisers volés',
#   'year': 1968,
#   'genre': 'Comedy, Drama, Romance',
#   'avg_vote': 7.7,
#   'votes': 11806,
#   'budget': 350000.0,
#   'worlwide_gross_income': 509.0},
#  {'country': 'UK',
#   'original_title': 'Fahrenheit 451',
#   'year': 1966,
#   'genre': 'Drama, Sci-Fi',
#   'avg_vote': 7.2,
#   'votes': 40524,
#   'budget': 1500000.0,
#   'worlwide_gross_income': 509.0},
#  {'country': 'Norway, United Arab Emirates',
#   'original_title': 'Brev til Kongen',
#   'year': 2014,
#   'genre': 'Drama',
#   'avg_vote': 6.9,
#   'votes': 229,
#   'budget': 6000000.0,
#   'worlwide_gross_income': 529.0},
#  {'country': 'Romania',
#   'original_title': 'Occident',
#   'year': 2002,
#   'genre': 'Comedy',
#   'avg_vote': 7.6,
#   'votes': 2072,
#   'budget': 450000.0,
#   'worlwide_gross_income': 533.0},
#  {'country': 'India',
#   'original_title': 'Brahmotsavam',
#   'year': 2016,
#   'genre': 'Action, Drama, Family',
#   'avg_vote': 4.3,
#   'votes': 2820,
#   'budget': 500000000.0,
#   'worlwide_gross_income': 541.0},
#  {'country': 'Turkey',
#   'original_title': 'Beginner',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 6.3,
#   'votes': 221,
#   'budget': 300000.0,
#   'worlwide_gross_income': 551.0},
#  {'country': 'Canada',
#   'original_title': 'The Pit',
#   'year': 1981,
#   'genre': 'Horror, Mystery',
#   'avg_vote': 5.8,
#   'votes': 2231,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 560.0},
#  {'country': 'USA',
#   'original_title': '12 Angry Men',
#   'year': 1957,
#   'genre': 'Crime, Drama',
#   'avg_vote': 8.9,
#   'votes': 668473,
#   'budget': 350000.0,
#   'worlwide_gross_income': 576.0},
#  {'country': 'Canada',
#   'original_title': 'Shake Hands with the Devil',
#   'year': 2007,
#   'genre': 'Drama, History, War',
#   'avg_vote': 7.6,
#   'votes': 3202,
#   'budget': 11000000.0,
#   'worlwide_gross_income': 594.0},
#  {'country': 'Bulgaria',
#   'original_title': 'Damascena',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 6.0,
#   'votes': 143,
#   'budget': 2600000.0,
#   'worlwide_gross_income': 594.0},
#  {'country': 'USA, Germany, Ethiopia',
#   'original_title': 'Atletu',
#   'year': 2009,
#   'genre': 'Biography, Drama',
#   'avg_vote': 6.7,
#   'votes': 224,
#   'budget': 3450000.0,
#   'worlwide_gross_income': 611.0},
#  {'country': 'Belgium',
#   'original_title': 'Steve + Sky',
#   'year': 2004,
#   'genre': 'Romance, Drama, Comedy',
#   'avg_vote': 6.9,
#   'votes': 1264,
#   'budget': 750000.0,
#   'worlwide_gross_income': 624.0},
#  {'country': 'Canada',
#   'original_title': 'Edwin Boyd',
#   'year': 2011,
#   'genre': 'Crime, Drama',
#   'avg_vote': 6.2,
#   'votes': 4124,
#   'budget': 5000000.0,
#   'worlwide_gross_income': 625.0},
#  {'country': 'UK, West Germany',
#   'original_title': 'The Last of England',
#   'year': 1987,
#   'genre': 'Drama, Fantasy',
#   'avg_vote': 6.7,
#   'votes': 1150,
#   'budget': 276000.0,
#   'worlwide_gross_income': 630.0},
#  {'country': 'Bulgaria, Sweden, Netherlands',
#   'original_title': 'The Prosecutor the Defender the Father and His Son',
#   'year': 2015,
#   'genre': 'Drama, War',
#   'avg_vote': 6.7,
#   'votes': 171,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 635.0},
#  {'country': 'USA',
#   'original_title': 'Gentlemen Prefer Blondes',
#   'year': 1953,
#   'genre': 'Comedy, Musical, Romance',
#   'avg_vote': 7.2,
#   'votes': 30759,
#   'budget': 2260000.0,
#   'worlwide_gross_income': 648.0},
#  {'country': 'USA',
#   'original_title': 'King Kong',
#   'year': 1933,
#   'genre': 'Adventure, Horror, Sci-Fi',
#   'avg_vote': 7.9,
#   'votes': 77507,
#   'budget': 670000.0,
#   'worlwide_gross_income': 651.0},
#  {'country': 'USA',
#   'original_title': 'Syrup',
#   'year': 2013,
#   'genre': 'Comedy, Drama, Romance',
#   'avg_vote': 5.7,
#   'votes': 10565,
#   'budget': 2500000.0,
#   'worlwide_gross_income': 663.0},
#  {'country': 'Luxembourg, Belgium, Austria',
#   'original_title': 'Hot Hot Hot',
#   'year': 2011,
#   'genre': 'Comedy, Drama',
#   'avg_vote': 4.8,
#   'votes': 128,
#   'budget': 3000000.0,
#   'worlwide_gross_income': 669.0},
#  {'country': 'UK, France, Luxembourg, USA',
#   'original_title': 'The Point Men',
#   'year': 2001,
#   'genre': 'Action, Drama',
#   'avg_vote': 4.4,
#   'votes': 1043,
#   'budget': 6100000.0,
#   'worlwide_gross_income': 714.0},
#  {'country': 'UK',
#   'original_title': 'Aux',
#   'year': 2018,
#   'genre': 'Action, Horror, Thriller',
#   'avg_vote': 4.3,
#   'votes': 291,
#   'budget': 20000000.0,
#   'worlwide_gross_income': 725.0},
#  {'country': 'UK',
#   'original_title': 'The Haunting',
#   'year': 1963,
#   'genre': 'Horror',
#   'avg_vote': 7.5,
#   'votes': 33652,
#   'budget': 1400000.0,
#   'worlwide_gross_income': 742.0},
#  {'country': 'USA',
#   'original_title': 'Wings',
#   'year': 1927,
#   'genre': 'Drama, Romance, War',
#   'avg_vote': 7.5,
#   'votes': 11139,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 746.0},
#  {'country': 'UK',
#   'original_title': 'Big Fat Gypsy Gangster',
#   'year': 2011,
#   'genre': 'Action, Comedy, Crime',
#   'avg_vote': 3.5,
#   'votes': 807,
#   'budget': 1300000.0,
#   'worlwide_gross_income': 753.0},
#  {'country': 'Singapore',
#   'original_title': 'Mei man ren sheng',
#   'year': 2006,
#   'genre': 'Drama',
#   'avg_vote': 6.9,
#   'votes': 303,
#   'budget': 800000.0,
#   'worlwide_gross_income': 756.0},
#  {'country': 'Egypt',
#   'original_title': 'Microphone',
#   'year': 2010,
#   'genre': 'Comedy, Drama, Music',
#   'avg_vote': 7.2,
#   'votes': 1497,
#   'budget': 3500000.0,
#   'worlwide_gross_income': 772.0},
#  {'country': 'USA',
#   'original_title': 'Issues',
#   'year': 2005,
#   'genre': 'Comedy',
#   'avg_vote': 5.6,
#   'votes': 103,
#   'budget': 50000.0,
#   'worlwide_gross_income': 783.0},
#  {'country': 'UK',
#   'original_title': 'The Tempest',
#   'year': 1979,
#   'genre': 'Drama, Fantasy',
#   'avg_vote': 6.4,
#   'votes': 955,
#   'budget': 150000.0,
#   'worlwide_gross_income': 813.0},
#  {'country': 'USA',
#   'original_title': 'Disfigured',
#   'year': 2008,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'votes': 310,
#   'budget': 50000.0,
#   'worlwide_gross_income': 829.0},
#  {'country': 'USA',
#   'original_title': 'The Underground Comedy Movie',
#   'year': 1999,
#   'genre': 'Comedy',
#   'avg_vote': 2.2,
#   'votes': 2424,
#   'budget': 170000.0,
#   'worlwide_gross_income': 856.0},
#  {'country': 'UK',
#   'original_title': 'The Tapes',
#   'year': 2011,
#   'genre': 'Horror',
#   'avg_vote': 3.2,
#   'votes': 481,
#   'budget': 100000.0,
#   'worlwide_gross_income': 880.0},
#  {'country': 'Germany, USA',
#   'original_title': 'In Her Line of Fire',
#   'year': 2006,
#   'genre': 'Action, Drama',
#   'avg_vote': 3.8,
#   'votes': 927,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 884.0},
#  {'country': 'Germany, Canada, Poland, USA',
#   'original_title': 'Julie Walking Home',
#   'year': 2002,
#   'genre': 'Drama, Romance',
#   'avg_vote': 6.3,
#   'votes': 932,
#   'budget': 5000000.0,
#   'worlwide_gross_income': 892.0},
#  {'country': 'South Africa, USA',
#   'original_title': 'Beat the Drum',
#   'year': 2003,
#   'genre': 'Drama',
#   'avg_vote': 7.1,
#   'votes': 662,
#   'budget': 1500000.0,
#   'worlwide_gross_income': 895.0},
#  {'country': 'USA',
#   'original_title': 'How to Be a Serial Killer',
#   'year': 2008,
#   'genre': 'Comedy, Crime, Horror',
#   'avg_vote': 5.5,
#   'votes': 1978,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 899.0},
#  {'country': 'USA',
#   'original_title': 'High Strung',
#   'year': 1992,
#   'genre': 'Comedy',
#   'avg_vote': 6.8,
#   'votes': 1922,
#   'budget': 300000.0,
#   'worlwide_gross_income': 904.0},
#  {'country': 'UK',
#   'original_title': 'Jubilee',
#   'year': 1978,
#   'genre': 'Comedy, Drama, Fantasy',
#   'avg_vote': 6.1,
#   'votes': 2821,
#   'budget': 200000.0,
#   'worlwide_gross_income': 923.0},
#  {'country': 'Denmark',
#   'original_title': 'Fuglene over sundet',
#   'year': 2016,
#   'genre': 'Drama, History, War',
#   'avg_vote': 6.2,
#   'votes': 621,
#   'budget': 7045000.0,
#   'worlwide_gross_income': 926.0},
#  {'country': 'Singapore',
#   'original_title': '4:30',
#   'year': 2005,
#   'genre': 'Drama',
#   'avg_vote': 6.7,
#   'votes': 494,
#   'budget': 400000.0,
#   'worlwide_gross_income': 935.0},
#  {'country': 'Netherlands, South Africa, Ireland',
#   'original_title': "The Bird Can't Fly",
#   'year': 2007,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'votes': 188,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 938.0},
#  {'country': 'Germany',
#   'original_title': 'Shanghai Baby',
#   'year': 2007,
#   'genre': 'Drama',
#   'avg_vote': 4.4,
#   'votes': 167,
#   'budget': 7500000.0,
#   'worlwide_gross_income': 954.0},
#  {'country': 'USA',
#   'original_title': 'Midnight Son',
#   'year': 2011,
#   'genre': 'Horror',
#   'avg_vote': 5.9,
#   'votes': 1695,
#   'budget': 3250000.0,
#   'worlwide_gross_income': 973.0},
#  {'country': 'USA',
#   'original_title': 'The Jimmy Show',
#   'year': 2001,
#   'genre': 'Comedy, Drama',
#   'avg_vote': 5.2,
#   'votes': 525,
#   'budget': 1500000.0,
#   'worlwide_gross_income': 1000.0},
#  {'country': 'India',
#   'original_title': 'Nannaku Prematho',
#   'year': 2016,
#   'genre': 'Action, Drama, Thriller',
#   'avg_vote': 7.6,
#   'votes': 8672,
#   'budget': 500000000.0,
#   'worlwide_gross_income': 1003.0},
#  {'country': 'USA',
#   'original_title': 'Madam Satan',
#   'year': 1930,
#   'genre': 'Comedy, Drama, Musical',
#   'avg_vote': 6.5,
#   'votes': 838,
#   'budget': 980000.0,
#   'worlwide_gross_income': 1005.0},
#  {'country': 'Denmark',
#   'original_title': 'En frygtelig kvinde',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 6.6,
#   'votes': 1614,
#   'budget': 3900000.0,
#   'worlwide_gross_income': 1008.0},
#  {'country': 'UK, USA',
#   'original_title': 'The Manson Family Massacre',
#   'year': 2019,
#   'genre': 'Crime, Horror, Thriller',
#   'avg_vote': 3.2,
#   'votes': 245,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 1047.0},
#  {'country': 'Italy, Romania, Bulgaria, Republic of North Macedonia',
#   'original_title': 'Banat - Il viaggio',
#   'year': 2015,
#   'genre': 'Drama',
#   'avg_vote': 5.8,
#   'votes': 126,
#   'budget': 1200000.0,
#   'worlwide_gross_income': 1074.0},
#  {'country': 'USA',
#   'original_title': 'The Transcendents',
#   'year': 2018,
#   'genre': 'Music, Mystery, Thriller',
#   'avg_vote': 9.2,
#   'votes': 1450,
#   'budget': 90000.0,
#   'worlwide_gross_income': 1090.0},
#  {'country': 'Hungary',
#   'original_title': 'Csak szex és más semmi',
#   'year': 2005,
#   'genre': 'Comedy',
#   'avg_vote': 6.3,
#   'votes': 2938,
#   'budget': 1100000.0,
#   'worlwide_gross_income': 1112.0},
#  {'country': 'UK',
#   'original_title': 'Urban Hymn',
#   'year': 2015,
#   'genre': 'Crime, Drama',
#   'avg_vote': 6.5,
#   'votes': 363,
#   'budget': 3000000.0,
#   'worlwide_gross_income': 1115.0},
#  {'country': 'Canada',
#   'original_title': 'Yellowknife',
#   'year': 2002,
#   'genre': 'Drama',
#   'avg_vote': 6.6,
#   'votes': 180,
#   'budget': 3200000.0,
#   'worlwide_gross_income': 1128.0},
#  {'country': 'India',
#   'original_title': 'Half Ticket',
#   'year': 2016,
#   'genre': 'Drama, Family',
#   'avg_vote': 7.8,
#   'votes': 185,
#   'budget': 20000000.0,
#   'worlwide_gross_income': 1135.0},
#  {'country': 'Turkey',
#   'original_title': 'Vicdan Agaci',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 5.4,
#   'votes': 310,
#   'budget': 500000.0,
#   'worlwide_gross_income': 1179.0},
#  {'country': 'UK',
#   'original_title': 'I Love My Mum',
#   'year': 2018,
#   'genre': 'Comedy',
#   'avg_vote': 4.6,
#   'votes': 286,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 1182.0},
#  {'country': 'Switzerland, Hungary',
#   'original_title': 'Pinprick',
#   'year': 2009,
#   'genre': 'Drama, Thriller',
#   'avg_vote': 5.1,
#   'votes': 299,
#   'budget': 130000000.0,
#   'worlwide_gross_income': 1198.0},
#  {'country': 'UK',
#   'original_title': 'Four',
#   'year': 2011,
#   'genre': 'Thriller',
#   'avg_vote': 4.2,
#   'votes': 637,
#   'budget': 500000.0,
#   'worlwide_gross_income': 1198.0},
#  {'country': 'Turkey',
#   'original_title': 'Dead Horse Nebula',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 5.6,
#   'votes': 252,
#   'budget': 100000.0,
#   'worlwide_gross_income': 1233.0},
#  {'country': 'USA',
#   'original_title': 'The Maltese Falcon',
#   'year': 1941,
#   'genre': 'Film-Noir, Mystery',
#   'avg_vote': 8.0,
#   'votes': 146815,
#   'budget': 375000.0,
#   'worlwide_gross_income': 1255.0},
#  {'country': 'USA',
#   'original_title': 'Exorcism',
#   'year': 2003,
#   'genre': 'Horror, Thriller',
#   'avg_vote': 1.8,
#   'votes': 237,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 1303.0},
#  {'country': 'India',
#   'original_title': 'Hind Ka Napak Ko Jawab',
#   'year': 2017,
#   'genre': 'Action, Thriller',
#   'avg_vote': 6.7,
#   'votes': 3977,
#   'budget': 5000000.0,
#   'worlwide_gross_income': 1314.0},
#  {'country': 'Argentina, Germany, Brazil, Spain',
#   'original_title': 'Breve historia del planeta verde',
#   'year': 2019,
#   'genre': 'Adventure, Drama, Fantasy',
#   'avg_vote': 5.7,
#   'votes': 177,
#   'budget': 425406.0,
#   'worlwide_gross_income': 1368.0},
#  {'country': 'China, Taiwan',
#   'original_title': 'Yin shi nan nü - Hao yuan you hao jin',
#   'year': 2012,
#   'genre': 'Comedy, Romance',
#   'avg_vote': 4.5,
#   'votes': 116,
#   'budget': 20000000.0,
#   'worlwide_gross_income': 1377.0},
#  {'country': 'Australia',
#   'original_title': 'The Last Wave',
#   'year': 1977,
#   'genre': 'Drama, Fantasy, Mystery',
#   'avg_vote': 7.0,
#   'votes': 8419,
#   'budget': 810000.0,
#   'worlwide_gross_income': 1382.0},
#  {'country': 'USA',
#   'original_title': 'Drool',
#   'year': 2009,
#   'genre': 'Comedy',
#   'avg_vote': 5.7,
#   'votes': 745,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 1403.0},
#  {'country': 'Serbia',
#   'original_title': 'Zona Zamfirova-drugi deo',
#   'year': 2017,
#   'genre': 'Drama, Romance',
#   'avg_vote': 4.6,
#   'votes': 340,
#   'budget': 4500000.0,
#   'worlwide_gross_income': 1404.0},
#  {'country': 'UK',
#   'original_title': 'Habit',
#   'year': 2017,
#   'genre': 'Horror',
#   'avg_vote': 5.2,
#   'votes': 852,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 1426.0},
#  {'country': 'India',
#   'original_title': 'Kalyug',
#   'year': 2005,
#   'genre': 'Action, Crime, Drama',
#   'avg_vote': 6.5,
#   'votes': 2402,
#   'budget': 40000000.0,
#   'worlwide_gross_income': 1435.0},
#  {'country': 'Argentina, South Korea, Austria',
#   'original_title': 'Los decentes',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 5.9,
#   'votes': 387,
#   'budget': 250000.0,
#   'worlwide_gross_income': 1441.0},
#  {'country': 'UK',
#   'original_title': 'Demon Eye',
#   'year': 2019,
#   'genre': 'Horror',
#   'avg_vote': 3.3,
#   'votes': 428,
#   'budget': 250000.0,
#   'worlwide_gross_income': 1473.0},
#  {'country': 'USA, China',
#   'original_title': 'The Blood Bond',
#   'year': 2010,
#   'genre': 'Action, Thriller',
#   'avg_vote': 3.2,
#   'votes': 227,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 1483.0},
#  {'country': 'Canada, Germany',
#   'original_title': 'Blackwoods',
#   'year': 2001,
#   'genre': 'Drama, Mystery, Thriller',
#   'avg_vote': 2.8,
#   'votes': 2091,
#   'budget': 3000000.0,
#   'worlwide_gross_income': 1500.0},
#  {'country': 'USA',
#   'original_title': 'The Fly',
#   'year': 1958,
#   'genre': 'Drama, Horror, Sci-Fi',
#   'avg_vote': 7.1,
#   'votes': 20329,
#   'budget': 700000.0,
#   'worlwide_gross_income': 1501.0},
#  {'country': 'UK',
#   'original_title': 'Bad Day for the Cut',
#   'year': 2017,
#   'genre': 'Action, Crime, Drama',
#   'avg_vote': 6.5,
#   'votes': 5480,
#   'budget': 250000.0,
#   'worlwide_gross_income': 1510.0},
#  {'country': 'South Korea',
#   'original_title': 'Baramui paiteo',
#   'year': 2004,
#   'genre': 'Action, Biography, Drama',
#   'avg_vote': 7.0,
#   'votes': 3724,
#   'budget': 6000000.0,
#   'worlwide_gross_income': 1518.0},
#  {'country': 'Japan',
#   'original_title': '46-okunen no koi',
#   'year': 2006,
#   'genre': 'Drama, Fantasy',
#   'avg_vote': 6.7,
#   'votes': 1889,
#   'budget': 10000000.0,
#   'worlwide_gross_income': 1520.0},
#  {'country': 'Canada, Ireland',
#   'original_title': 'Unless',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 5.3,
#   'votes': 209,
#   'budget': 20800000.0,
#   'worlwide_gross_income': 1527.0},
#  {'country': 'Canada',
#   'original_title': 'Rhymes for Young Ghouls',
#   'year': 2013,
#   'genre': 'Crime, Drama',
#   'avg_vote': 6.5,
#   'votes': 1097,
#   'budget': 1500000.0,
#   'worlwide_gross_income': 1529.0},
#  {'country': 'Australia',
#   'original_title': 'The Tunnel',
#   'year': 2011,
#   'genre': 'Horror, Mystery, Thriller',
#   'avg_vote': 5.9,
#   'votes': 19103,
#   'budget': 135000.0,
#   'worlwide_gross_income': 1532.0},
#  {'country': 'USA',
#   'original_title': 'Easier with Practice',
#   'year': 2009,
#   'genre': 'Drama, Romance',
#   'avg_vote': 6.4,
#   'votes': 970,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 1558.0},
#  {'country': 'Israel',
#   'original_title': 'Next to Her',
#   'year': 2014,
#   'genre': 'Drama',
#   'avg_vote': 7.1,
#   'votes': 511,
#   'budget': 500000.0,
#   'worlwide_gross_income': 1575.0},
#  {'country': 'Netherlands',
#   'original_title': 'Links',
#   'year': 2008,
#   'genre': 'Drama',
#   'avg_vote': 6.1,
#   'votes': 119,
#   'budget': 200000.0,
#   'worlwide_gross_income': 1588.0},
#  {'country': 'USA',
#   'original_title': '42nd Street',
#   'year': 1933,
#   'genre': 'Comedy, Musical, Romance',
#   'avg_vote': 7.4,
#   'votes': 10490,
#   'budget': 439000.0,
#   'worlwide_gross_income': 1600.0},
#  {'country': 'Denmark',
#   'original_title': 'Pusher',
#   'year': 1996,
#   'genre': 'Crime, Thriller',
#   'avg_vote': 7.4,
#   'votes': 33653,
#   'budget': 6000000.0,
#   'worlwide_gross_income': 1605.0},
#  {'country': 'Canada',
#   'original_title': 'Un dimanche à Kigali',
#   'year': 2006,
#   'genre': 'Drama',
#   'avg_vote': 7.3,
#   'votes': 634,
#   'budget': 7000000.0,
#   'worlwide_gross_income': 1609.0},
#  {'country': 'USA',
#   'original_title': 'The Sticky Fingers of Time',
#   'year': 1997,
#   'genre': 'Sci-Fi',
#   'avg_vote': 6.1,
#   'votes': 424,
#   'budget': 250000.0,
#   'worlwide_gross_income': 1610.0},
#  {'country': 'USA',
#   'original_title': 'Frankenstein',
#   'year': 1931,
#   'genre': 'Drama, Horror, Romance',
#   'avg_vote': 7.8,
#   'votes': 63315,
#   'budget': 291000.0,
#   'worlwide_gross_income': 1626.0},
#  {'country': 'Germany, Iran',
#   'original_title': 'Eine Hand Voll Gras',
#   'year': 2000,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'votes': 218,
#   'budget': 7000000.0,
#   'worlwide_gross_income': 1654.0},
#  {'country': 'USA',
#   'original_title': 'House of Usher',
#   'year': 2008,
#   'genre': 'Horror, Thriller',
#   'avg_vote': 2.9,
#   'votes': 485,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 1677.0},
#  {'country': 'USA',
#   'original_title': 'Dystopia: 2013',
#   'year': 2012,
#   'genre': 'Sci-Fi',
#   'avg_vote': 2.7,
#   'votes': 110,
#   'budget': 150000.0,
#   'worlwide_gross_income': 1708.0},
#  {'country': 'Italy, France',
#   'original_title': 'Fellini - Satyricon',
#   'year': 1969,
#   'genre': 'Drama, Fantasy, History',
#   'avg_vote': 6.9,
#   'votes': 14570,
#   'budget': 3000000.0,
#   'worlwide_gross_income': 1729.0},
#  {'country': 'Canada',
#   'original_title': 'Wilby Wonderful',
#   'year': 2004,
#   'genre': 'Comedy, Drama, Romance',
#   'avg_vote': 6.6,
#   'votes': 1488,
#   'budget': 2500000.0,
#   'worlwide_gross_income': 1749.0},
#  {'country': 'Sweden',
#   'original_title': 'Made in YU',
#   'year': 2005,
#   'genre': 'Drama, Action',
#   'avg_vote': 6.3,
#   'votes': 367,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 1754.0},
#  {'country': 'USA',
#   'original_title': 'Detention of the Dead',
#   'year': 2012,
#   'genre': 'Action, Adventure, Comedy',
#   'avg_vote': 4.5,
#   'votes': 2507,
#   'budget': 500000.0,
#   'worlwide_gross_income': 1777.0},
#  {'country': 'Taiwan, Germany',
#   'original_title': 'Ghosted',
#   'year': 2009,
#   'genre': 'Drama, Mystery',
#   'avg_vote': 4.6,
#   'votes': 353,
#   'budget': 800000.0,
#   'worlwide_gross_income': 1780.0},
#  {'country': 'USA',
#   'original_title': 'The Canyon',
#   'year': 2009,
#   'genre': 'Thriller',
#   'avg_vote': 5.9,
#   'votes': 4046,
#   'budget': 10000000.0,
#   'worlwide_gross_income': 1785.0},
#  {'country': 'USA',
#   'original_title': 'Invasion of the Body Snatchers',
#   'year': 1956,
#   'genre': 'Drama, Horror, Sci-Fi',
#   'avg_vote': 7.7,
#   'votes': 43866,
#   'budget': 417000.0,
#   'worlwide_gross_income': 1861.0},
#  {'country': 'France',
#   'original_title': 'Que le diable nous emporte',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 5.6,
#   'votes': 187,
#   'budget': 600000.0,
#   'worlwide_gross_income': 1869.0},
#  {'country': 'UK',
#   'original_title': 'In the Dark Half',
#   'year': 2012,
#   'genre': 'Drama, Mystery',
#   'avg_vote': 5.4,
#   'votes': 493,
#   'budget': 300000.0,
#   'worlwide_gross_income': 1873.0},
#  {'country': 'Austria',
#   'original_title': 'Crash Test Dummies',
#   'year': 2005,
#   'genre': 'Comedy, Drama',
#   'avg_vote': 6.4,
#   'votes': 169,
#   'budget': 1300000.0,
#   'worlwide_gross_income': 1875.0},
#  {'country': 'Dominican Republic',
#   'original_title': 'Veneno',
#   'year': 2018,
#   'genre': 'Action, Drama, Sport',
#   'avg_vote': 8.1,
#   'votes': 403,
#   'budget': 115126396.0,
#   'worlwide_gross_income': 1897.0},
#  {'country': 'Mexico',
#   'original_title': 'Fando y Lis',
#   'year': 1968,
#   'genre': 'Adventure, Fantasy',
#   'avg_vote': 7.0,
#   'votes': 4873,
#   'budget': 100000.0,
#   'worlwide_gross_income': 1897.0},
#  {'country': 'France, Germany',
#   'original_title': '20 nuits et un jour de pluie',
#   'year': 2006,
#   'genre': 'Drama',
#   'avg_vote': 4.1,
#   'votes': 148,
#   'budget': 2060000.0,
#   'worlwide_gross_income': 1903.0},
#  {'country': 'USA',
#   'original_title': 'Mr. Smith Gets a Hustler',
#   'year': 2002,
#   'genre': 'Crime, Drama, Romance',
#   'avg_vote': 4.7,
#   'votes': 205,
#   'budget': 200000.0,
#   'worlwide_gross_income': 1915.0},
#  {'country': 'USA',
#   'original_title': 'Shuttle',
#   'year': 2008,
#   'genre': 'Crime, Drama, Mystery',
#   'avg_vote': 5.7,
#   'votes': 5325,
#   'budget': 2400000.0,
#   'worlwide_gross_income': 1925.0},
#  {'country': 'USA',
#   'original_title': 'Best Man Down',
#   'year': 2012,
#   'genre': 'Comedy, Drama',
#   'avg_vote': 6.4,
#   'votes': 8985,
#   'budget': 1500000.0,
#   'worlwide_gross_income': 1938.0},
#  {'country': 'Israel, France, USA',
#   'original_title': 'Kirot',
#   'year': 2009,
#   'genre': 'Action, Drama, Thriller',
#   'avg_vote': 5.7,
#   'votes': 2391,
#   'budget': 3000000.0,
#   'worlwide_gross_income': 1948.0},
#  {'country': 'Estonia, Finland, Sweden, France',
#   'original_title': 'Püha Tõnu kiusamine',
#   'year': 2009,
#   'genre': 'Drama, Fantasy, Mystery',
#   'avg_vote': 7.2,
#   'votes': 1184,
#   'budget': 983081.0,
#   'worlwide_gross_income': 1963.0},
#  {'country': 'USA',
#   'original_title': 'FAQs',
#   'year': 2005,
#   'genre': 'Drama',
#   'avg_vote': 5.8,
#   'votes': 488,
#   'budget': 250000.0,
#   'worlwide_gross_income': 1967.0},
#  {'country': 'Hungary',
#   'original_title': 'A vizsga',
#   'year': 2011,
#   'genre': 'Drama, History, Thriller',
#   'avg_vote': 7.4,
#   'votes': 1539,
#   'budget': 380000.0,
#   'worlwide_gross_income': 1968.0},
#  {'country': 'Chile, Germany',
#   'original_title': 'La Casa Lobo',
#   'year': 2018,
#   'genre': 'Animation, Drama, Horror',
#   'avg_vote': 7.5,
#   'votes': 884,
#   'budget': 245000.0,
#   'worlwide_gross_income': 1970.0},
#  {'country': 'Germany, USA',
#   'original_title': 'Errors of the Human Body',
#   'year': 2012,
#   'genre': 'Drama, Horror, Mystery',
#   'avg_vote': 5.3,
#   'votes': 2167,
#   'budget': 1500000.0,
#   'worlwide_gross_income': 1984.0},
#  {'country': 'Australia',
#   'original_title': 'Boxing Day',
#   'year': 2007,
#   'genre': 'Crime, Drama',
#   'avg_vote': 7.1,
#   'votes': 132,
#   'budget': 174000.0,
#   'worlwide_gross_income': 1985.0},
#  {'country': 'USA',
#   'original_title': 'The Watermelon Woman',
#   'year': 1996,
#   'genre': 'Comedy, Drama, Romance',
#   'avg_vote': 7.0,
#   'votes': 1466,
#   'budget': 300000.0,
#   'worlwide_gross_income': 1989.0},
#  {'country': 'USA',
#   'original_title': 'Enemies of Laughter',
#   'year': 2000,
#   'genre': 'Comedy, Romance',
#   'avg_vote': 5.5,
#   'votes': 166,
#   'budget': 2500000.0,
#   'worlwide_gross_income': 2000.0},
#  {'country': 'USA',
#   'original_title': 'The Night of the Hunter',
#   'year': 1955,
#   'genre': 'Crime, Drama, Film-Noir',
#   'avg_vote': 8.0,
#   'votes': 80215,
#   'budget': 795000.0,
#   'worlwide_gross_income': 2001.0},
#  {'country': 'Spain',
#   'original_title': 'Tercer grado',
#   'year': 2015,
#   'genre': 'Action, Drama, Romance',
#   'avg_vote': 5.8,
#   'votes': 230,
#   'budget': 500000.0,
#   'worlwide_gross_income': 2009.0},
#  {'country': 'USA, Germany',
#   'original_title': 'The Tenants',
#   'year': 2005,
#   'genre': 'Crime, Drama, Romance',
#   'avg_vote': 5.2,
#   'votes': 977,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 2010.0},
#  {'country': 'USA',
#   'original_title': 'The Bad and the Beautiful',
#   'year': 1952,
#   'genre': 'Drama, Romance',
#   'avg_vote': 7.8,
#   'votes': 12941,
#   'budget': 1558000.0,
#   'worlwide_gross_income': 2025.0},
#  {'country': 'Poland',
#   'original_title': 'Zacma',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 5.6,
#   'votes': 167,
#   'budget': 4000000.0,
#   'worlwide_gross_income': 2035.0},
#  {'country': 'Italy, Philippines, Japan',
#   'original_title': 'Blanka',
#   'year': 2015,
#   'genre': 'Drama',
#   'avg_vote': 7.0,
#   'votes': 232,
#   'budget': 250000.0,
#   'worlwide_gross_income': 2042.0},
#  {'country': 'France',
#   'original_title': 'Blockbuster',
#   'year': 2018,
#   'genre': 'Comedy',
#   'avg_vote': 5.5,
#   'votes': 409,
#   'budget': 650000.0,
#   'worlwide_gross_income': 2044.0},
#  {'country': 'Bulgaria, UK, France',
#   'original_title': 'Cat in the Wall',
#   'year': 2019,
#   'genre': 'Drama',
#   'avg_vote': 5.5,
#   'votes': 252,
#   'budget': 305000.0,
#   'worlwide_gross_income': 2108.0},
#  {'country': 'USA',
#   'original_title': 'The Velocity of Gary',
#   'year': 1998,
#   'genre': 'Comedy, Drama, Romance',
#   'avg_vote': 5.0,
#   'votes': 1691,
#   'budget': 4000000.0,
#   'worlwide_gross_income': 2143.0},
#  {'country': 'Argentina',
#   'original_title': 'La extranjera',
#   'year': 2008,
#   'genre': 'Drama',
#   'avg_vote': 4.6,
#   'votes': 148,
#   'budget': 800000.0,
#   'worlwide_gross_income': 2161.0},
#  {'country': 'Kazakhstan',
#   'original_title': 'Zhauzhürek myng bala',
#   'year': 2012,
#   'genre': 'Action, Adventure, Drama',
#   'avg_vote': 6.5,
#   'votes': 744,
#   'budget': 12000000.0,
#   'worlwide_gross_income': 2172.0},
#  {'country': 'Italy',
#   'original_title': 'Il bosco fuori',
#   'year': 2006,
#   'genre': 'Horror, Thriller',
#   'avg_vote': 4.5,
#   'votes': 1040,
#   'budget': 45000.0,
#   'worlwide_gross_income': 2186.0},
#  {'country': 'UK',
#   'original_title': 'Last Summer',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 5.8,
#   'votes': 224,
#   'budget': 830000.0,
#   'worlwide_gross_income': 2205.0},
#  {'country': 'France',
#   'original_title': 'Notre paradis',
#   'year': 2011,
#   'genre': 'Crime, Drama, Romance',
#   'avg_vote': 6.0,
#   'votes': 1266,
#   'budget': 600000.0,
#   'worlwide_gross_income': 2206.0},
#  {'country': 'Colombia, Argentina, France',
#   'original_title': 'Alias María',
#   'year': 2015,
#   'genre': 'Drama, War',
#   'avg_vote': 6.1,
#   'votes': 340,
#   'budget': 1356000.0,
#   'worlwide_gross_income': 2208.0},
#  {'country': 'USA',
#   'original_title': 'Side Effects',
#   'year': 2005,
#   'genre': 'Comedy, Drama, Romance',
#   'avg_vote': 4.9,
#   'votes': 1056,
#   'budget': 30000000.0,
#   'worlwide_gross_income': 2216.0},
#  {'country': 'Ireland, UK',
#   'original_title': 'Kissing Candice',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 5.2,
#   'votes': 240,
#   'budget': 300000.0,
#   'worlwide_gross_income': 2238.0},
#  {'country': 'UK',
#   'original_title': 'Treacle Jr.',
#   'year': 2010,
#   'genre': 'Drama',
#   'avg_vote': 6.9,
#   'votes': 592,
#   'budget': 30000.0,
#   'worlwide_gross_income': 2248.0},
#  {'country': 'USA',
#   'original_title': 'The Pool Boys',
#   'year': 2009,
#   'genre': 'Comedy',
#   'avg_vote': 4.7,
#   'votes': 2401,
#   'budget': 15000000.0,
#   'worlwide_gross_income': 2269.0},
#  {'country': 'Germany, Switzerland, Belgium',
#   'original_title': 'Madonnen',
#   'year': 2007,
#   'genre': 'Drama',
#   'avg_vote': 6.2,
#   'votes': 152,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 2271.0},
#  {'country': 'Portugal, France, Brazil, South Africa, Mozambique, Spain',
#   'original_title': 'Comboio de Sal e Açucar',
#   'year': 2016,
#   'genre': 'Adventure',
#   'avg_vote': 6.2,
#   'votes': 104,
#   'budget': 1500000.0,
#   'worlwide_gross_income': 2293.0},
#  {'country': 'UK, USA',
#   'original_title': 'Casino Royale',
#   'year': 1967,
#   'genre': 'Comedy',
#   'avg_vote': 5.2,
#   'votes': 26559,
#   'budget': 12000000.0,
#   'worlwide_gross_income': 2324.0},
#  {'country': 'USA',
#   'original_title': 'The Killing Jar',
#   'year': 2010,
#   'genre': 'Crime, Mystery, Thriller',
#   'avg_vote': 5.8,
#   'votes': 2500,
#   'budget': 400000.0,
#   'worlwide_gross_income': 2339.0},
#  {'country': 'UK',
#   'original_title': 'Break My Fall',
#   'year': 2011,
#   'genre': 'Drama, Romance',
#   'avg_vote': 3.7,
#   'votes': 144,
#   'budget': 50000.0,
#   'worlwide_gross_income': 2372.0},
#  {'country': 'USA',
#   'original_title': 'The Devil Is a Woman',
#   'year': 1935,
#   'genre': 'Comedy, Drama, Romance',
#   'avg_vote': 7.0,
#   'votes': 2942,
#   'budget': 800000.0,
#   'worlwide_gross_income': 2375.0},
#  {'country': 'UK',
#   'original_title': 'The Incident',
#   'year': 2015,
#   'genre': 'Drama, Thriller',
#   'avg_vote': 4.5,
#   'votes': 182,
#   'budget': 750000.0,
#   'worlwide_gross_income': 2401.0},
#  {'country': 'USA, UK',
#   'original_title': 'L.A. Slasher',
#   'year': 2015,
#   'genre': 'Comedy, Crime, Drama',
#   'avg_vote': 3.3,
#   'votes': 742,
#   'budget': 10000.0,
#   'worlwide_gross_income': 2421.0},
#  {'country': 'USA',
#   'original_title': 'The Ghastly Love of Johnny X',
#   'year': 2012,
#   'genre': 'Comedy, Fantasy, Musical',
#   'avg_vote': 5.6,
#   'votes': 406,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 2436.0},
#  {'country': 'USA',
#   'original_title': 'Motocross Kids',
#   'year': 2004,
#   'genre': 'Action, Adventure, Family',
#   'avg_vote': 3.9,
#   'votes': 410,
#   'budget': 3000000.0,
#   'worlwide_gross_income': 2462.0},
#  {'country': 'USA',
#   'original_title': 'Roberta',
#   'year': 1935,
#   'genre': 'Comedy, Musical, Romance',
#   'avg_vote': 7.1,
#   'votes': 2860,
#   'budget': 610000.0,
#   'worlwide_gross_income': 2493.0},
#  {'country': 'USA',
#   'original_title': 'Swing',
#   'year': 2003,
#   'genre': 'Comedy, Fantasy, Romance',
#   'avg_vote': 5.4,
#   'votes': 164,
#   'budget': 2500000.0,
#   'worlwide_gross_income': 2509.0},
#  {'country': 'USA',
#   'original_title': 'New York City Serenade',
#   'year': 2007,
#   'genre': 'Comedy, Drama',
#   'avg_vote': 5.0,
#   'votes': 471,
#   'budget': 1800000.0,
#   'worlwide_gross_income': 2509.0},
#  {'country': 'UK',
#   'original_title': 'Twenty8k',
#   'year': 2012,
#   'genre': 'Thriller',
#   'avg_vote': 4.8,
#   'votes': 567,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 2517.0},
#  {'country': 'USA',
#   'original_title': 'Miles',
#   'year': 2016,
#   'genre': 'Comedy, Drama, Family',
#   'avg_vote': 5.7,
#   'votes': 587,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 2537.0},
#  {'country': 'Australia',
#   'original_title': 'Burke & Wills',
#   'year': 1985,
#   'genre': 'Adventure, Drama, History',
#   'avg_vote': 6.1,
#   'votes': 225,
#   'budget': 8900000.0,
#   'worlwide_gross_income': 2546.0},
#  {'country': 'USA',
#   'original_title': 'Lazarat',
#   'year': 2019,
#   'genre': 'Action, Crime, Thriller',
#   'avg_vote': 5.0,
#   'votes': 576,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 2548.0},
#  {'country': 'Spain',
#   'original_title': 'Finisterrae',
#   'year': 2010,
#   'genre': 'Fantasy',
#   'avg_vote': 6.4,
#   'votes': 619,
#   'budget': 300000.0,
#   'worlwide_gross_income': 2550.0},
#  {'country': 'India',
#   'original_title': 'Jihne Mera Dil Luteya',
#   'year': 2011,
#   'genre': 'Comedy, Drama',
#   'avg_vote': 7.3,
#   'votes': 942,
#   'budget': 30000000.0,
#   'worlwide_gross_income': 2551.0},
#  {'country': 'Canada',
#   'original_title': 'Ginger Snaps',
#   'year': 2000,
#   'genre': 'Drama, Fantasy, Horror',
#   'avg_vote': 6.8,
#   'votes': 40897,
#   'budget': 5000000.0,
#   'worlwide_gross_income': 2554.0},
#  {'country': 'India',
#   'original_title': 'Munthiri Monchan',
#   'year': 2019,
#   'genre': 'Comedy, Romance',
#   'avg_vote': 8.1,
#   'votes': 990,
#   'budget': 30000000.0,
#   'worlwide_gross_income': 2568.0},
#  {'country': 'Romania, France',
#   'original_title': 'Moon Hotel Kabul',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'votes': 106,
#   'budget': 800000.0,
#   'worlwide_gross_income': 2577.0},
#  {'country': 'USA',
#   'original_title': 'The Incredible Shrinking Man',
#   'year': 1957,
#   'genre': 'Horror, Sci-Fi',
#   'avg_vote': 7.6,
#   'votes': 15583,
#   'budget': 750000.0,
#   'worlwide_gross_income': 2580.0},
#  {'country': 'Mexico, Spain, France',
#   'original_title': 'Acorazado',
#   'year': 2010,
#   'genre': 'Comedy',
#   'avg_vote': 6.7,
#   'votes': 143,
#   'budget': 1200000.0,
#   'worlwide_gross_income': 2596.0},
#  {'country': 'UK, USA',
#   'original_title': 'Conspiracy of Silence',
#   'year': 2003,
#   'genre': 'Crime, Drama, Thriller',
#   'avg_vote': 6.4,
#   'votes': 368,
#   'budget': 3000000.0,
#   'worlwide_gross_income': 2598.0},
#  {'country': 'India',
#   'original_title': 'Jayantabhai Ki Luv Story',
#   'year': 2013,
#   'genre': 'Action, Comedy, Romance',
#   'avg_vote': 5.3,
#   'votes': 1207,
#   'budget': 100000000.0,
#   'worlwide_gross_income': 2628.0},
#  {'country': 'USA',
#   'original_title': 'Duck',
#   'year': 2005,
#   'genre': 'Drama',
#   'avg_vote': 6.0,
#   'votes': 287,
#   'budget': 300000.0,
#   'worlwide_gross_income': 2657.0},
#  {'country': 'UK',
#   'original_title': 'Gangsters Gamblers Geezers',
#   'year': 2016,
#   'genre': 'Comedy',
#   'avg_vote': 5.0,
#   'votes': 750,
#   'budget': 1800000.0,
#   'worlwide_gross_income': 2662.0},
#  {'country': 'USA',
#   'original_title': 'Catfight',
#   'year': 2016,
#   'genre': 'Comedy, Drama',
#   'avg_vote': 5.8,
#   'votes': 5188,
#   'budget': 350000.0,
#   'worlwide_gross_income': 2666.0},
#  {'country': 'UK, USA',
#   'original_title': 'Division 19',
#   'year': 2017,
#   'genre': 'Action, Sci-Fi, Thriller',
#   'avg_vote': 4.5,
#   'votes': 829,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 2680.0},
#  {'country': 'USA',
#   'original_title': 'The Boys in the Band',
#   'year': 1970,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'votes': 4030,
#   'budget': 5500000.0,
#   'worlwide_gross_income': 2695.0},
#  {'country': 'UK',
#   'original_title': 'Mum & Dad',
#   'year': 2008,
#   'genre': 'Horror, Thriller',
#   'avg_vote': 5.9,
#   'votes': 5707,
#   'budget': 100000.0,
#   'worlwide_gross_income': 2698.0},
#  {'country': 'UK',
#   'original_title': 'Burning Men',
#   'year': 2019,
#   'genre': 'Drama',
#   'avg_vote': 4.2,
#   'votes': 118,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 2702.0},
#  {'country': 'Hungary, UK',
#   'original_title': 'Eichmann',
#   'year': 2007,
#   'genre': 'Biography, Drama, History',
#   'avg_vote': 5.9,
#   'votes': 2987,
#   'budget': 8000000.0,
#   'worlwide_gross_income': 2706.0},
#  {'country': 'USA',
#   'original_title': 'Johnny Got His Gun',
#   'year': 1971,
#   'genre': 'Drama, War',
#   'avg_vote': 7.9,
#   'votes': 15306,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 2735.0},
#  {'country': 'India',
#   'original_title': 'Abrahaminte Santhathikal',
#   'year': 2018,
#   'genre': 'Action, Crime, Thriller',
#   'avg_vote': 7.5,
#   'votes': 4545,
#   'budget': 60000000.0,
#   'worlwide_gross_income': 2735.0},
#  {'country': 'USA',
#   'original_title': 'Approaching Midnight',
#   'year': 2013,
#   'genre': 'Crime, Drama, Romance',
#   'avg_vote': 4.2,
#   'votes': 244,
#   'budget': 100000.0,
#   'worlwide_gross_income': 2795.0},
#  {'country': 'Bulgaria',
#   'original_title': 'Children of Wax',
#   'year': 2007,
#   'genre': 'Action, Crime, Drama',
#   'avg_vote': 3.8,
#   'votes': 351,
#   'budget': 3000000.0,
#   'worlwide_gross_income': 2797.0},
#  {'country': 'USA',
#   'original_title': 'Lower Learning',
#   'year': 2008,
#   'genre': 'Comedy',
#   'avg_vote': 4.0,
#   'votes': 2427,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 2804.0},
#  {'country': 'Belgium',
#   'original_title': 'Seule à mon mariage',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 6.4,
#   'votes': 149,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 2829.0},
#  {'country': 'Romania, France',
#   'original_title': 'Europolis',
#   'year': 2010,
#   'genre': 'Drama',
#   'avg_vote': 6.1,
#   'votes': 115,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 2839.0},
#  {'country': 'USA',
#   'original_title': 'Three Days of Rain',
#   'year': 2002,
#   'genre': 'Drama',
#   'avg_vote': 5.5,
#   'votes': 245,
#   'budget': 3500000.0,
#   'worlwide_gross_income': 2841.0},
#  {'country': 'Romania, Czech Republic',
#   'original_title': 'Heads and Tails',
#   'year': 2019,
#   'genre': 'Drama',
#   'avg_vote': 3.7,
#   'votes': 100,
#   'budget': 150000.0,
#   'worlwide_gross_income': 2853.0},
#  {'country': 'France, Belgium',
#   'original_title': 'La famille Wolberg',
#   'year': 2009,
#   'genre': 'Drama',
#   'avg_vote': 5.8,
#   'votes': 225,
#   'budget': 2600000.0,
#   'worlwide_gross_income': 2867.0},
#  {'country': 'Romania',
#   'original_title': 'Beyond America',
#   'year': 2008,
#   'genre': 'Drama, History, Romance',
#   'avg_vote': 3.8,
#   'votes': 114,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 2889.0},
#  {'country': 'Turkey',
#   'original_title': 'içerdekiler',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 6.0,
#   'votes': 112,
#   'budget': 150000.0,
#   'worlwide_gross_income': 2910.0},
#  {'country': 'Israel',
#   'original_title': 'Once I Was',
#   'year': 2010,
#   'genre': 'Drama',
#   'avg_vote': 7.2,
#   'votes': 735,
#   'budget': 2150000.0,
#   'worlwide_gross_income': 2920.0},
#  {'country': 'UK, France',
#   'original_title': 'The Comedian',
#   'year': 2012,
#   'genre': 'Drama, Romance',
#   'avg_vote': 5.5,
#   'votes': 329,
#   'budget': 635000.0,
#   'worlwide_gross_income': 2921.0},
#  {'country': 'Bangladesh, India',
#   'original_title': 'Nabab',
#   'year': 2017,
#   'genre': 'Comedy, Romance, Thriller',
#   'avg_vote': 7.5,
#   'votes': 784,
#   'budget': 30000000.0,
#   'worlwide_gross_income': 2945.0},
#  {'country': 'USA',
#   'original_title': 'Mercy',
#   'year': 1995,
#   'genre': 'Crime, Drama, Thriller',
#   'avg_vote': 5.4,
#   'votes': 252,
#   'budget': 52000.0,
#   'worlwide_gross_income': 2967.0},
#  {'country': 'USA',
#   'original_title': "Dog Lover's Symphony",
#   'year': 2006,
#   'genre': 'Comedy, Family',
#   'avg_vote': 2.6,
#   'votes': 115,
#   'budget': 500000.0,
#   'worlwide_gross_income': 2968.0},
#  {'country': 'USA',
#   'original_title': 'Philadelphia Experiment II',
#   'year': 1993,
#   'genre': 'Action, Adventure, Sci-Fi',
#   'avg_vote': 4.5,
#   'votes': 1775,
#   'budget': 5000000.0,
#   'worlwide_gross_income': 2970.0},
#  {'country': 'Germany, Austria',
#   'original_title': 'Fremde Haut',
#   'year': 2005,
#   'genre': 'Drama',
#   'avg_vote': 7.0,
#   'votes': 998,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 3025.0},
#  {'country': 'USA',
#   'original_title': 'Spiral',
#   'year': 2007,
#   'genre': 'Drama, Thriller',
#   'avg_vote': 6.4,
# ...
#   'original_title': 'Xing xing wang',
#   'year': 1977,
#   'genre': 'Action, Adventure, Horror',
#   'avg_vote': 5.3,
#   'votes': 1614,
#   'budget': 6000000.0,
#   'worlwide_gross_income': 17368.0},
#  {'country': 'UK',
#   'original_title': 'Two for the Road',
#   'year': 1967,
#   'genre': 'Comedy, Drama, Romance',
#   'avg_vote': 7.5,
#   'votes': 11933,
#   'budget': 4000000.0,
#   'worlwide_gross_income': 17380.0},
#  {'country': 'Indonesia',
#   'original_title': 'Ghost Writer',
#   'year': 2019,
#   'genre': 'Comedy, Drama, Horror',
#   'avg_vote': 6.8,
#   'votes': 260,
#   'budget': 7900000.0,
#   'worlwide_gross_income': 17395.0},
#  {'country': 'Romania',
#   'original_title': 'Hîrtia va fi albastrã',
#   'year': 2006,
#   'genre': 'Action, Drama',
#   'avg_vote': 7.7,
#   'votes': 1976,
#   'budget': 700000.0,
#   'worlwide_gross_income': 17419.0},
#  {'country': 'USA',
#   'original_title': 'Adventures of Power',
#   'year': 2008,
#   'genre': 'Comedy, Music',
#   'avg_vote': 5.9,
#   'votes': 1844,
#   'budget': 2500000.0,
#   'worlwide_gross_income': 17419.0},
#  {'country': 'Portugal',
#   'original_title': 'Goodnight Irene',
#   'year': 2008,
#   'genre': 'Comedy, Drama',
#   'avg_vote': 6.8,
#   'votes': 169,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 17569.0},
#  {'country': 'Spain, Cuba',
#   'original_title': 'La partida',
#   'year': 2013,
#   'genre': 'Drama, Romance',
#   'avg_vote': 6.6,
#   'votes': 1922,
#   'budget': 183409.0,
#   'worlwide_gross_income': 17647.0},
#  {'country': 'USA',
#   'original_title': 'Molly',
#   'year': 1999,
#   'genre': 'Comedy, Drama, Romance',
#   'avg_vote': 5.8,
#   'votes': 2667,
#   'budget': 21000000.0,
#   'worlwide_gross_income': 17650.0},
#  {'country': 'Slovakia, Czech Republic',
#   'original_title': 'O dve slabiky pozadu',
#   'year': 2005,
#   'genre': 'Romance, Drama',
#   'avg_vote': 6.9,
#   'votes': 101,
#   'budget': 10000000.0,
#   'worlwide_gross_income': 17696.0},
#  {'country': 'India',
#   'original_title': 'Guru',
#   'year': 2017,
#   'genre': 'Action, Drama, Sport',
#   'avg_vote': 7.9,
#   'votes': 589,
#   'budget': 180000000.0,
#   'worlwide_gross_income': 17750.0},
#  {'country': 'India',
#   'original_title': 'David',
#   'year': 2013,
#   'genre': 'Action, Crime, Drama',
#   'avg_vote': 6.2,
#   'votes': 2508,
#   'budget': 500000000.0,
#   'worlwide_gross_income': 17828.0},
#  {'country': 'USA',
#   'original_title': 'Cook County',
#   'year': 2008,
#   'genre': 'Drama',
#   'avg_vote': 6.7,
#   'votes': 488,
#   'budget': 700000.0,
#   'worlwide_gross_income': 17977.0},
#  {'country': 'USA',
#   'original_title': 'Cruel World',
#   'year': 2005,
#   'genre': 'Comedy, Horror, Thriller',
#   'avg_vote': 3.9,
#   'votes': 1287,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 17986.0},
#  {'country': 'India',
#   'original_title': 'Nanu Ki Jaanu',
#   'year': 2018,
#   'genre': 'Comedy, Drama, Horror',
#   'avg_vote': 5.9,
#   'votes': 917,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 18065.0},
#  {'country': 'USA',
#   'original_title': 'A Bit of Bad Luck',
#   'year': 2014,
#   'genre': 'Comedy, Drama, Thriller',
#   'avg_vote': 4.7,
#   'votes': 245,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 18089.0},
#  {'country': 'UK, USA',
#   'original_title': 'The Lion in Winter',
#   'year': 1968,
#   'genre': 'Biography, Drama, History',
#   'avg_vote': 7.9,
#   'votes': 28450,
#   'budget': 4000000.0,
#   'worlwide_gross_income': 18177.0},
#  {'country': 'Pakistan, USA',
#   'original_title': 'Torn',
#   'year': 2013,
#   'genre': 'Drama',
#   'avg_vote': 5.8,
#   'votes': 536,
#   'budget': 450000.0,
#   'worlwide_gross_income': 18202.0},
#  {'country': 'India',
#   'original_title': 'Rendu',
#   'year': 2006,
#   'genre': 'Comedy',
#   'avg_vote': 4.8,
#   'votes': 166,
#   'budget': 3000000.0,
#   'worlwide_gross_income': 18241.0},
#  {'country': 'USA',
#   'original_title': 'Deadfall',
#   'year': 1993,
#   'genre': 'Crime, Drama',
#   'avg_vote': 4.0,
#   'votes': 2848,
#   'budget': 10000000.0,
#   'worlwide_gross_income': 18369.0},
#  {'country': 'Russia',
#   'original_title': 'Chelovek s bulvara Kaputsinok',
#   'year': 2010,
#   'genre': 'Comedy',
#   'avg_vote': 1.4,
#   'votes': 241,
#   'budget': 108000000.0,
#   'worlwide_gross_income': 18378.0},
#  {'country': 'USA',
#   'original_title': 'The Reception',
#   'year': 2005,
#   'genre': 'Comedy, Drama, Romance',
#   'avg_vote': 5.8,
#   'votes': 183,
#   'budget': 5000.0,
#   'worlwide_gross_income': 18389.0},
#  {'country': 'France, Denmark',
#   'original_title': 'Chacun sa nuit',
#   'year': 2006,
#   'genre': 'Drama',
#   'avg_vote': 5.8,
#   'votes': 1215,
#   'budget': 1400000.0,
#   'worlwide_gross_income': 18435.0},
#  {'country': 'Hungary',
#   'original_title': 'Tesó',
#   'year': 2003,
#   'genre': 'Comedy',
#   'avg_vote': 6.8,
#   'votes': 436,
#   'budget': 80000.0,
#   'worlwide_gross_income': 18501.0},
#  {'country': 'USA',
#   'original_title': 'Clubland',
#   'year': 1999,
#   'genre': 'Music',
#   'avg_vote': 5.0,
#   'votes': 207,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 18529.0},
#  {'country': 'USA',
#   'original_title': 'Finding Steve McQueen',
#   'year': 2019,
#   'genre': 'Crime, Romance',
#   'avg_vote': 6.2,
#   'votes': 3605,
#   'budget': 7000000.0,
#   'worlwide_gross_income': 18566.0},
#  {'country': 'USA',
#   'original_title': 'Proximity',
#   'year': 2001,
#   'genre': 'Action, Crime, Mystery',
#   'avg_vote': 4.8,
#   'votes': 576,
#   'budget': 6000000.0,
#   'worlwide_gross_income': 18569.0},
#  {'country': 'Spain',
#   'original_title': 'Clandestinos',
#   'year': 2007,
#   'genre': 'Crime, Drama, Romance',
#   'avg_vote': 5.6,
#   'votes': 526,
#   'budget': 768000.0,
#   'worlwide_gross_income': 18575.0},
#  {'country': 'UK, Latvia',
#   'original_title': 'Nameja gredzens',
#   'year': 2018,
#   'genre': 'Action, Drama, History',
#   'avg_vote': 6.2,
#   'votes': 1803,
#   'budget': 28000000.0,
#   'worlwide_gross_income': 18598.0},
#  {'country': 'South Korea, China, USA',
#   'original_title': 'Seoul Searching',
#   'year': 2015,
#   'genre': 'Comedy, Drama, Music',
#   'avg_vote': 7.0,
#   'votes': 1146,
#   'budget': 2100000.0,
#   'worlwide_gross_income': 18654.0},
#  {'country': 'Mexico, USA',
#   'original_title': 'Bring Me the Head of Alfredo Garcia',
#   'year': 1974,
#   'genre': 'Action, Crime, Drama',
#   'avg_vote': 7.5,
#   'votes': 17781,
#   'budget': 1500000.0,
#   'worlwide_gross_income': 18698.0},
#  {'country': 'USA',
#   'original_title': 'Dial M for Murder',
#   'year': 1954,
#   'genre': 'Crime, Thriller',
#   'avg_vote': 8.2,
#   'votes': 153300,
#   'budget': 1400000.0,
#   'worlwide_gross_income': 18816.0},
#  {'country': 'USA',
#   'original_title': 'Test',
#   'year': 2013,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'votes': 1431,
#   'budget': 250000.0,
#   'worlwide_gross_income': 18823.0},
#  {'country': 'Romania, Poland, France',
#   'original_title': 'Ilegitim',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 6.9,
#   'votes': 1218,
#   'budget': 57000.0,
#   'worlwide_gross_income': 18840.0},
#  {'country': 'USA',
#   'original_title': 'Door in the Woods',
#   'year': 2019,
#   'genre': 'Thriller',
#   'avg_vote': 3.8,
#   'votes': 457,
#   'budget': 175000.0,
#   'worlwide_gross_income': 18861.0},
#  {'country': 'Spain',
#   'original_title': 'Como la espuma',
#   'year': 2017,
#   'genre': 'Comedy, Drama, Romance',
#   'avg_vote': 4.8,
#   'votes': 300,
#   'budget': 500000.0,
#   'worlwide_gross_income': 18892.0},
#  {'country': 'USA',
#   'original_title': 'What Love Is',
#   'year': 2007,
#   'genre': 'Comedy, Romance',
#   'avg_vote': 5.4,
#   'votes': 1227,
#   'budget': 8500000.0,
#   'worlwide_gross_income': 18901.0},
#  {'country': 'Japan',
#   'original_title': 'Momoiro sora o',
#   'year': 2011,
#   'genre': 'Drama',
#   'avg_vote': 6.7,
#   'votes': 167,
#   'budget': 50000000.0,
#   'worlwide_gross_income': 18993.0},
#  {'country': 'USA',
#   'original_title': 'Spellbound',
#   'year': 1945,
#   'genre': 'Film-Noir, Mystery, Romance',
#   'avg_vote': 7.6,
#   'votes': 42377,
#   'budget': 1696377.0,
#   'worlwide_gross_income': 19000.0},
#  {'country': 'Estonia',
#   'original_title': 'November',
#   'year': 2017,
#   'genre': 'Drama, Fantasy, Horror',
#   'avg_vote': 7.2,
#   'votes': 3752,
#   'budget': 1450000.0,
#   'worlwide_gross_income': 19084.0},
#  {'country': 'USA',
#   'original_title': "The People I've Slept With",
#   'year': 2012,
#   'genre': 'Comedy',
#   'avg_vote': 4.8,
#   'votes': 671,
#   'budget': 3000000.0,
#   'worlwide_gross_income': 19137.0},
#  {'country': 'Turkey',
#   'original_title': 'Öldür beni',
#   'year': 2009,
#   'genre': 'Comedy, Drama, Mystery',
#   'avg_vote': 5.0,
#   'votes': 249,
#   'budget': 55000.0,
#   'worlwide_gross_income': 19142.0},
#  {'country': 'USA',
#   'original_title': 'The Mule',
#   'year': 2012,
#   'genre': 'Crime, Drama, Mystery',
#   'avg_vote': 4.2,
#   'votes': 1684,
#   'budget': 5000000.0,
#   'worlwide_gross_income': 19152.0},
#  {'country': 'USA',
#   'original_title': 'Cops and Robbers',
#   'year': 2017,
#   'genre': 'Action, Thriller',
#   'avg_vote': 3.8,
#   'votes': 362,
#   'budget': 5500000.0,
#   'worlwide_gross_income': 19224.0},
#  {'country': 'Germany',
#   'original_title': 'Solo für Klarinette',
#   'year': 1998,
#   'genre': 'Crime, Romance, Thriller',
#   'avg_vote': 6.0,
#   'votes': 372,
#   'budget': 6800000.0,
#   'worlwide_gross_income': 19278.0},
#  {'country': 'UK',
#   'original_title': 'Reuniting the Rubins',
#   'year': 2010,
#   'genre': 'Comedy, Drama, Family',
#   'avg_vote': 5.1,
#   'votes': 383,
#   'budget': 7500000.0,
#   'worlwide_gross_income': 19288.0},
#  {'country': 'UK',
#   'original_title': 'Great Expectations',
#   'year': 1946,
#   'genre': 'Adventure, Drama, Mystery',
#   'avg_vote': 7.8,
#   'votes': 21540,
#   'budget': 350000.0,
#   'worlwide_gross_income': 19329.0},
#  {'country': 'Canada',
#   'original_title': "Everything's Gone Green",
#   'year': 2006,
#   'genre': 'Comedy, Crime',
#   'avg_vote': 6.1,
#   'votes': 1967,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 19373.0},
#  {'country': 'USA',
#   'original_title': 'Curse of the Nun',
#   'year': 2019,
#   'genre': 'Horror, Mystery, Thriller',
#   'avg_vote': 2.8,
#   'votes': 770,
#   'budget': 18000000.0,
#   'worlwide_gross_income': 19396.0},
#  {'country': 'Russia, Lithuania, Republic of North Macedonia',
#   'original_title': 'Kharms',
#   'year': 2017,
#   'genre': 'Biography',
#   'avg_vote': 6.0,
#   'votes': 122,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 19431.0},
#  {'country': 'USA',
#   'original_title': 'The Super',
#   'year': 2017,
#   'genre': 'Horror, Mystery, Thriller',
#   'avg_vote': 5.9,
#   'votes': 11393,
#   'budget': 2300000.0,
#   'worlwide_gross_income': 19513.0},
#  {'country': 'USA',
#   'original_title': 'Time Lapse',
#   'year': 2014,
#   'genre': 'Horror, Sci-Fi, Thriller',
#   'avg_vote': 6.5,
#   'votes': 40494,
#   'budget': 5000000.0,
#   'worlwide_gross_income': 19572.0},
#  {'country': 'Russia, France, Germany',
#   'original_title': 'Zoologiya',
#   'year': 2016,
#   'genre': 'Comedy, Drama',
#   'avg_vote': 6.4,
#   'votes': 1052,
#   'budget': 3000000.0,
#   'worlwide_gross_income': 19572.0},
#  {'country': 'France, Italy',
#   'original_title': 'Piégé',
#   'year': 2014,
#   'genre': 'Thriller',
#   'avg_vote': 5.1,
#   'votes': 284,
#   'budget': 3000000.0,
#   'worlwide_gross_income': 19585.0},
#  {'country': 'Australia',
#   'original_title': 'Stone Bros.',
#   'year': 2009,
#   'genre': 'Comedy',
#   'avg_vote': 5.2,
#   'votes': 240,
#   'budget': 3400000.0,
#   'worlwide_gross_income': 19694.0},
#  {'country': 'India',
#   'original_title': 'Monster',
#   'year': 2019,
#   'genre': 'Comedy, Drama, Family',
#   'avg_vote': 6.8,
#   'votes': 444,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 19705.0},
#  {'country': 'USA',
#   'original_title': 'The Open Road',
#   'year': 2009,
#   'genre': 'Comedy, Drama',
#   'avg_vote': 5.4,
#   'votes': 3358,
#   'budget': 10000000.0,
#   'worlwide_gross_income': 19716.0},
#  {'country': 'Lebanon',
#   'original_title': 'Lahon W Habs',
#   'year': 2019,
#   'genre': 'Comedy',
#   'avg_vote': 4.4,
#   'votes': 545,
#   'budget': 400000.0,
#   'worlwide_gross_income': 19722.0},
#  {'country': 'UK, USA',
#   'original_title': 'The Private Life of Sherlock Holmes',
#   'year': 1970,
#   'genre': 'Adventure, Comedy, Crime',
#   'avg_vote': 7.1,
#   'votes': 10337,
#   'budget': 10000000.0,
#   'worlwide_gross_income': 19773.0},
#  {'country': 'USA',
#   'original_title': 'The Simian Line',
#   'year': 2000,
#   'genre': 'Drama, Romance',
#   'avg_vote': 5.4,
#   'votes': 365,
#   'budget': 2000000.0,
#   'worlwide_gross_income': 19823.0},
#  {'country': 'Finland, Latvia',
#   'original_title': 'Koirat eivät käytä housuja',
#   'year': 2019,
#   'genre': 'Drama, Romance',
#   'avg_vote': 7.0,
#   'votes': 2174,
#   'budget': 1420000.0,
#   'worlwide_gross_income': 19855.0},
#  {'country': 'Argentina, Germany',
#   'original_title': 'Las vidas posibles',
#   'year': 2007,
#   'genre': 'Mystery, Romance',
#   'avg_vote': 6.0,
#   'votes': 128,
#   'budget': 570000.0,
#   'worlwide_gross_income': 19868.0},
#  {'country': 'India',
#   'original_title': 'Idhu Namma Aalu',
#   'year': 2016,
#   'genre': 'Comedy, Romance',
#   'avg_vote': 5.3,
#   'votes': 533,
#   'budget': 200000000.0,
#   'worlwide_gross_income': 19873.0},
#  {'country': 'UK',
#   'original_title': 'Seachd: The Inaccessible Pinnacle',
#   'year': 2007,
#   'genre': 'Drama, Family',
#   'avg_vote': 6.5,
#   'votes': 257,
#   'budget': 650000.0,
#   'worlwide_gross_income': 19978.0},
#  {'country': 'UK',
#   'original_title': 'The Bromley Boys',
#   'year': 2018,
#   'genre': 'Comedy',
#   'avg_vote': 6.8,
#   'votes': 2681,
#   'budget': 1500000.0,
#   'worlwide_gross_income': 19996.0},
#  {'country': 'Brazil',
#   'original_title': 'FilmeFobia',
#   'year': 2008,
#   'genre': 'Drama, Fantasy, Horror',
#   'avg_vote': 5.2,
#   'votes': 118,
#   'budget': 1600400.0,
#   'worlwide_gross_income': 20061.0},
#  {'country': 'USA',
#   'original_title': 'The Other Side',
#   'year': 2018,
#   'genre': 'Comedy, Drama, Romance',
#   'avg_vote': 4.1,
#   'votes': 109,
#   'budget': 400000.0,
#   'worlwide_gross_income': 20062.0},
#  {'country': 'Ukraine',
#   'original_title': 'Moya babusya Fani Kaplan',
#   'year': 2016,
#   'genre': 'Biography, Drama, History',
#   'avg_vote': 6.3,
#   'votes': 106,
#   'budget': 22000000.0,
#   'worlwide_gross_income': 20116.0},
#  {'country': 'Romania, France',
#   'original_title': 'Charleston',
#   'year': 2017,
#   'genre': 'Comedy, Drama',
#   'avg_vote': 7.0,
#   'votes': 704,
#   'budget': 800000.0,
#   'worlwide_gross_income': 20270.0},
#  {'country': 'Latvia',
#   'original_title': 'Rudolfa mantojums',
#   'year': 2010,
#   'genre': 'Comedy, Drama',
#   'avg_vote': 7.0,
#   'votes': 326,
#   'budget': 1500000.0,
#   'worlwide_gross_income': 20317.0},
#  {'country': 'UK, USA',
#   'original_title': 'Alcatraz',
#   'year': 2018,
#   'genre': 'Action, Adventure, Crime',
#   'avg_vote': 3.3,
#   'votes': 365,
#   'budget': 250000.0,
#   'worlwide_gross_income': 20342.0},
#  {'country': 'UK, USA',
#   'original_title': 'London',
#   'year': 2005,
#   'genre': 'Drama, Romance',
#   'avg_vote': 6.5,
#   'votes': 21913,
#   'budget': 14000.0,
#   'worlwide_gross_income': 20361.0},
#  {'country': 'USA',
#   'original_title': 'Terror Tract',
#   'year': 2000,
#   'genre': 'Comedy, Horror, Romance',
#   'avg_vote': 6.1,
#   'votes': 1638,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 20400.0},
#  {'country': 'Argentina, New Zealand',
#   'original_title': 'Los olvidados',
#   'year': 2017,
#   'genre': 'Horror',
#   'avg_vote': 4.8,
#   'votes': 2323,
#   'budget': 1100000.0,
#   'worlwide_gross_income': 20418.0},
#  {'country': 'UK',
#   'original_title': 'Heartless',
#   'year': 2009,
#   'genre': 'Drama, Fantasy, Horror',
#   'avg_vote': 6.0,
#   'votes': 9797,
#   'budget': 5000000.0,
#   'worlwide_gross_income': 20435.0},
#  {'country': 'Brazil',
#   'original_title': 'Para Minha Amada Morta',
#   'year': 2015,
#   'genre': 'Drama, Thriller',
#   'avg_vote': 6.9,
#   'votes': 255,
#   'budget': 1000000.0,
#   'worlwide_gross_income': 20584.0},
#  {'country': 'USA',
#   'original_title': 'Douchebag',
#   'year': 2010,
#   'genre': 'Comedy, Drama',
#   'avg_vote': 6.1,
#   'votes': 144,
#   'budget': 500000.0,
#   'worlwide_gross_income': 20615.0},
#  {'country': 'Russia, Egypt, France, Morocco, Switzerland, UK',
#   'original_title': 'Dusha shpiona',
#   'year': 2015,
#   'genre': 'Drama, Thriller',
#   'avg_vote': 4.9,
#   'votes': 294,
#   'budget': 10000000.0,
#   'worlwide_gross_income': 20670.0},
#  {'country': 'USA',
#   'original_title': 'The Duel',
#   'year': 2016,
#   'genre': 'Drama, Western',
#   'avg_vote': 5.8,
#   'votes': 9617,
#   'budget': 10000000.0,
#   'worlwide_gross_income': 20672.0},
#  ...]

# %%
unfiltered_votes_csv = "votes_unfiltered(profit vs rating).csv"

unfiltered_votes_df = pd.read_csv(unfiltered_votes_csv)
unfiltered_votes_df
# Out:
#          country   original_title  year      genre  avg_vote  votes  \
# 0        Hungary          Bizalom  1980      Drama       7.6    607
# 1            USA      The Heiress  1949      Drama       8.1  13301
# 2      Argentina  Camino a La Paz  2015      Drama       7.0    625
# 3             UK    Zombie Undead  2010     Horror       2.3    436
# 4          China      Wo he ba ba  2003      Drama       6.8    157
# ...          ...              ...   ...        ...       ...    ...
# 30996      India           Temper  2015     Action       7.4   5600
# 30997      India     Chandramukhi  2005     Action       7.1   4947
# 30998      India          Thegidi  2014      Crime       7.7   2295
# 30999      Nepal       Seto Surya  2016  Adventure       7.1    475
# 31000   Pakistan        Wrong No.  2015     Comedy       6.7   1752
#
#        worlwide_gross_income
# 0                        1.0
# 1                       16.0
# 2                       17.0
# 3                       17.0
# 4                       20.0
# ...                      ...
# 30996            740300000.0
# 30997            750000000.0
# 30998             76000000.0
# 30999             20000000.0
# 31000            157500000.0
#
# [31001 rows x 7 columns]

# %%
unfiltered_votes_df.to_dict('records')
# Out:
# [{'country': 'Hungary',
#   'original_title': 'Bizalom',
#   'year': 1980,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'votes': 607,
#   'worlwide_gross_income': 1.0},
#  {'country': 'USA',
#   'original_title': 'The Heiress',
#   'year': 1949,
#   'genre': 'Drama',
#   'avg_vote': 8.1,
#   'votes': 13301,
#   'worlwide_gross_income': 16.0},
#  {'country': 'Argentina',
#   'original_title': 'Camino a La Paz',
#   'year': 2015,
#   'genre': 'Drama',
#   'avg_vote': 7.0,
#   'votes': 625,
#   'worlwide_gross_income': 17.0},
#  {'country': 'UK',
#   'original_title': 'Zombie Undead',
#   'year': 2010,
#   'genre': 'Horror',
#   'avg_vote': 2.3,
#   'votes': 436,
#   'worlwide_gross_income': 17.0},
#  {'country': 'China',
#   'original_title': 'Wo he ba ba',
#   'year': 2003,
#   'genre': 'Drama',
#   'avg_vote': 6.8,
#   'votes': 157,
#   'worlwide_gross_income': 20.0},
#  {'country': 'Germany',
#   'original_title': "Eagle Hunter's Son",
#   'year': 2009,
#   'genre': 'Drama',
#   'avg_vote': 6.4,
#   'votes': 129,
#   'worlwide_gross_income': 23.0},
#  {'country': 'Germany',
#   'original_title': 'Inbred',
#   'year': 2011,
#   'genre': 'Comedy',
#   'avg_vote': 5.2,
#   'votes': 4536,
#   'worlwide_gross_income': 24.0},
#  {'country': 'Hong Kong',
#   'original_title': 'Shao Lin jiang shi',
#   'year': 2004,
#   'genre': 'Action',
#   'avg_vote': 4.2,
#   'votes': 328,
#   'worlwide_gross_income': 25.0},
#  {'country': 'USA',
#   'original_title': 'Zyzzyx Rd',
#   'year': 2006,
#   'genre': 'Crime',
#   'avg_vote': 4.1,
#   'votes': 983,
#   'worlwide_gross_income': 30.0},
#  {'country': 'USA',
#   'original_title': 'Older Than America',
#   'year': 2008,
#   'genre': 'Drama',
#   'avg_vote': 5.3,
#   'votes': 857,
#   'worlwide_gross_income': 32.0},
#  {'country': 'Taiwan',
#   'original_title': 'Hei an zhi guang',
#   'year': 1999,
#   'genre': 'Drama',
#   'avg_vote': 7.2,
#   'votes': 217,
#   'worlwide_gross_income': 37.0},
#  {'country': 'UK',
#   'original_title': 'The Marker',
#   'year': 2017,
#   'genre': 'Crime',
#   'avg_vote': 5.4,
#   'votes': 279,
#   'worlwide_gross_income': 37.0},
#  {'country': 'Sweden',
#   'original_title': 'ABBA: The Movie',
#   'year': 1977,
#   'genre': 'Comedy',
#   'avg_vote': 6.5,
#   'votes': 2963,
#   'worlwide_gross_income': 38.0},
#  {'country': 'China',
#   'original_title': 'Wo ai ni',
#   'year': 2002,
#   'genre': 'Drama',
#   'avg_vote': 6.8,
#   'votes': 208,
#   'worlwide_gross_income': 39.0},
#  {'country': 'Canada',
#   'original_title': 'Allure',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 4.9,
#   'votes': 1399,
#   'worlwide_gross_income': 39.0},
#  {'country': 'India',
#   'original_title': 'Urvi',
#   'year': 2017,
#   'genre': 'Crime',
#   'avg_vote': 7.0,
#   'votes': 210,
#   'worlwide_gross_income': 42.0},
#  {'country': 'Brazil',
#   'original_title': 'El bosque negro',
#   'year': 2018,
#   'genre': 'Horror',
#   'avg_vote': 5.7,
#   'votes': 167,
#   'worlwide_gross_income': 43.0},
#  {'country': 'UK',
#   'original_title': 'Dangerous Game',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 4.5,
#   'votes': 528,
#   'worlwide_gross_income': 50.0},
#  {'country': 'UK',
#   'original_title': 'My Days of Mercy',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 6.4,
#   'votes': 2754,
#   'worlwide_gross_income': 51.0},
#  {'country': 'UK',
#   'original_title': '7 Lives',
#   'year': 2011,
#   'genre': 'Fantasy',
#   'avg_vote': 3.5,
#   'votes': 416,
#   'worlwide_gross_income': 51.0},
#  {'country': 'USA',
#   'original_title': 'A Walk in the Spring Rain',
#   'year': 1970,
#   'genre': 'Drama',
#   'avg_vote': 6.1,
#   'votes': 647,
#   'worlwide_gross_income': 52.0},
#  {'country': 'China',
#   'original_title': 'Kong que',
#   'year': 2005,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'votes': 955,
#   'worlwide_gross_income': 55.0},
#  {'country': 'Japan',
#   'original_title': 'Yaku san-jû no uso',
#   'year': 2004,
#   'genre': 'Comedy',
#   'avg_vote': 5.7,
#   'votes': 131,
#   'worlwide_gross_income': 55.0},
#  {'country': 'Japan',
#   'original_title': 'Ningen no shômei',
#   'year': 1977,
#   'genre': 'Crime',
#   'avg_vote': 6.7,
#   'votes': 284,
#   'worlwide_gross_income': 57.0},
#  {'country': 'Finland',
#   'original_title': 'Små mirakel och stora',
#   'year': 2006,
#   'genre': 'Drama',
#   'avg_vote': 5.8,
#   'votes': 185,
#   'worlwide_gross_income': 57.0},
#  {'country': 'USA',
#   'original_title': '400 Days',
#   'year': 2015,
#   'genre': 'Mystery',
#   'avg_vote': 4.4,
#   'votes': 10018,
#   'worlwide_gross_income': 58.0},
#  {'country': 'Canada',
#   'original_title': 'Capture Kill Release',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 5.2,
#   'votes': 640,
#   'worlwide_gross_income': 72.0},
#  {'country': 'France',
#   'original_title': 'Dans ton sommeil',
#   'year': 2010,
#   'genre': 'Horror',
#   'avg_vote': 5.6,
#   'votes': 1375,
#   'worlwide_gross_income': 73.0},
#  {'country': 'Mexico',
#   'original_title': 'Atroz (Atrocious)',
#   'year': 2015,
#   'genre': 'Horror',
#   'avg_vote': 5.3,
#   'votes': 435,
#   'worlwide_gross_income': 74.0},
#  {'country': 'India',
#   'original_title': 'Malaal',
#   'year': 2019,
#   'genre': 'Action',
#   'avg_vote': 5.9,
#   'votes': 718,
#   'worlwide_gross_income': 76.0},
#  {'country': 'Spain',
#   'original_title': 'Història de la meva mort',
#   'year': 2013,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'votes': 657,
#   'worlwide_gross_income': 77.0},
#  {'country': 'Spain',
#   'original_title': 'Chicas paranoicas',
#   'year': 2015,
#   'genre': 'Comedy',
#   'avg_vote': 7.2,
#   'votes': 146,
#   'worlwide_gross_income': 78.0},
#  {'country': 'China',
#   'original_title': 'Yi ge mo sheng nu ren de lai xin',
#   'year': 2004,
#   'genre': 'Drama',
#   'avg_vote': 6.8,
#   'votes': 663,
#   'worlwide_gross_income': 78.0},
#  {'country': 'Colombia',
#   'original_title': 'Perro come perro',
#   'year': 2008,
#   'genre': 'Thriller',
#   'avg_vote': 6.7,
#   'votes': 1601,
#   'worlwide_gross_income': 80.0},
#  {'country': 'Hungary',
#   'original_title': 'Egyetleneim',
#   'year': 2006,
#   'genre': 'Comedy',
#   'avg_vote': 5.8,
#   'votes': 218,
#   'worlwide_gross_income': 88.0},
#  {'country': 'Lithuania',
#   'original_title': 'Aurora',
#   'year': 2012,
#   'genre': 'Romance',
#   'avg_vote': 6.0,
#   'votes': 2502,
#   'worlwide_gross_income': 91.0},
#  {'country': 'Finland',
#   'original_title': 'Stiilipidu',
#   'year': 2005,
#   'genre': 'Comedy',
#   'avg_vote': 6.1,
#   'votes': 244,
#   'worlwide_gross_income': 95.0},
#  {'country': 'USA',
#   'original_title': 'The Objective',
#   'year': 2008,
#   'genre': 'Horror',
#   'avg_vote': 5.5,
#   'votes': 7744,
#   'worlwide_gross_income': 95.0},
#  {'country': 'UK',
#   'original_title': "The Comedian's Guide to Survival",
#   'year': 2016,
#   'genre': 'Comedy',
#   'avg_vote': 4.7,
#   'votes': 292,
#   'worlwide_gross_income': 95.0},
#  {'country': 'France',
#   'original_title': "L'étoile du soldat",
#   'year': 2006,
#   'genre': 'Drama',
#   'avg_vote': 6.7,
#   'votes': 122,
#   'worlwide_gross_income': 98.0},
#  {'country': 'Argentina',
#   'original_title': 'El patrón, radiografía de un crimen',
#   'year': 2014,
#   'genre': 'Crime',
#   'avg_vote': 7.4,
#   'votes': 1233,
#   'worlwide_gross_income': 102.0},
#  {'country': 'Turkey',
#   'original_title': 'Genç pehlivanlar',
#   'year': 2016,
#   'genre': 'Family',
#   'avg_vote': 6.6,
#   'votes': 144,
#   'worlwide_gross_income': 105.0},
#  {'country': 'USA',
#   'original_title': 'Some Guy Who Kills People',
#   'year': 2011,
#   'genre': 'Comedy',
#   'avg_vote': 6.4,
#   'votes': 5607,
#   'worlwide_gross_income': 113.0},
#  {'country': 'Argentina',
#   'original_title': 'El futuro perfecto',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 6.7,
#   'votes': 325,
#   'worlwide_gross_income': 115.0},
#  {'country': 'Singapore',
#   'original_title': 'Robotropolis',
#   'year': 2011,
#   'genre': 'Action',
#   'avg_vote': 2.9,
#   'votes': 1178,
#   'worlwide_gross_income': 118.0},
#  {'country': 'Spain',
#   'original_title': 'Dixie y la rebelión zombi',
#   'year': 2014,
#   'genre': 'Animation',
#   'avg_vote': 4.6,
#   'votes': 185,
#   'worlwide_gross_income': 120.0},
#  {'country': 'Brazil',
#   'original_title': 'Tinta Bruta',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 6.8,
#   'votes': 817,
#   'worlwide_gross_income': 122.0},
#  {'country': 'UK',
#   'original_title': 'Reverb',
#   'year': 2008,
#   'genre': 'Horror',
#   'avg_vote': 3.9,
#   'votes': 744,
#   'worlwide_gross_income': 124.0},
#  {'country': 'Sweden',
#   'original_title': 'Miss Kicki',
#   'year': 2009,
#   'genre': 'Drama',
#   'avg_vote': 6.6,
#   'votes': 645,
#   'worlwide_gross_income': 129.0},
#  {'country': 'Germany',
#   'original_title': "Molly's Way",
#   'year': 2005,
#   'genre': 'Drama',
#   'avg_vote': 6.4,
#   'votes': 100,
#   'worlwide_gross_income': 130.0},
#  {'country': 'Philippines',
#   'original_title': 'Kid Kulafu',
#   'year': 2015,
#   'genre': 'Biography',
#   'avg_vote': 6.8,
#   'votes': 265,
#   'worlwide_gross_income': 131.0},
#  {'country': 'UK',
#   'original_title': 'Darling',
#   'year': 1965,
#   'genre': 'Drama',
#   'avg_vote': 7.1,
#   'votes': 5876,
#   'worlwide_gross_income': 137.0},
#  {'country': 'UK',
#   'original_title': 'Deviation',
#   'year': 2012,
#   'genre': 'Thriller',
#   'avg_vote': 3.9,
#   'votes': 523,
#   'worlwide_gross_income': 140.0},
#  {'country': 'West Germany',
#   'original_title': 'Die Patriotin',
#   'year': 1979,
#   'genre': 'Drama',
#   'avg_vote': 6.8,
#   'votes': 154,
#   'worlwide_gross_income': 144.0},
#  {'country': 'France',
#   'original_title': 'Rendez-vous à Kiruna',
#   'year': 2012,
#   'genre': 'Drama',
#   'avg_vote': 6.4,
#   'votes': 114,
#   'worlwide_gross_income': 148.0},
#  {'country': 'Switzerland',
#   'original_title': "Le milieu de l'horizon",
#   'year': 2019,
#   'genre': 'Drama',
#   'avg_vote': 6.8,
#   'votes': 119,
#   'worlwide_gross_income': 152.0},
#  {'country': 'France',
#   'original_title': 'Pauline à la plage',
#   'year': 1983,
#   'genre': 'Comedy',
#   'avg_vote': 7.4,
#   'votes': 6644,
#   'worlwide_gross_income': 159.0},
#  {'country': 'Turkey',
#   'original_title': 'Sükut Evi',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 6.8,
#   'votes': 469,
#   'worlwide_gross_income': 159.0},
#  {'country': 'USA',
#   'original_title': 'All That Heaven Allows',
#   'year': 1955,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'votes': 12957,
#   'worlwide_gross_income': 170.0},
#  {'country': 'South Africa',
#   'original_title': 'Boy Called Twist',
#   'year': 2004,
#   'genre': 'Drama',
#   'avg_vote': 6.6,
#   'votes': 147,
#   'worlwide_gross_income': 177.0},
#  {'country': 'UK',
#   'original_title': 'Red White & Blue',
#   'year': 2010,
#   'genre': 'Drama',
#   'avg_vote': 6.4,
#   'votes': 5444,
#   'worlwide_gross_income': 177.0},
#  {'country': 'Netherlands',
#   'original_title': 'Crepuscule',
#   'year': 2009,
#   'genre': 'Drama',
#   'avg_vote': 5.7,
#   'votes': 122,
#   'worlwide_gross_income': 178.0},
#  {'country': 'UK',
#   'original_title': 'Outcast',
#   'year': 2010,
#   'genre': 'Horror',
#   'avg_vote': 5.3,
#   'votes': 2314,
#   'worlwide_gross_income': 179.0},
#  {'country': 'Turkey',
#   'original_title': 'Laz Kit',
#   'year': 2020,
#   'genre': 'Comedy',
#   'avg_vote': 1.1,
#   'votes': 521,
#   'worlwide_gross_income': 180.0},
#  {'country': 'UK',
#   'original_title': 'Songbird',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 4.2,
#   'votes': 441,
#   'worlwide_gross_income': 184.0},
#  {'country': 'Argentina',
#   'original_title': 'La película infinita',
#   'year': 2018,
#   'genre': 'Fantasy',
#   'avg_vote': 6.2,
#   'votes': 143,
#   'worlwide_gross_income': 190.0},
#  {'country': 'USA',
#   'original_title': 'The Color of Time',
#   'year': 2012,
#   'genre': 'Biography',
#   'avg_vote': 4.3,
#   'votes': 1286,
#   'worlwide_gross_income': 199.0},
#  {'country': 'USA',
#   'original_title': 'Everything Is Wonderful',
#   'year': 2018,
#   'genre': 'Comedy',
#   'avg_vote': 3.5,
#   'votes': 122,
#   'worlwide_gross_income': 202.0},
#  {'country': 'UK',
#   'original_title': 'Strawberry Fields',
#   'year': 2012,
#   'genre': 'Drama',
#   'avg_vote': 4.6,
#   'votes': 289,
#   'worlwide_gross_income': 203.0},
#  {'country': 'USA',
#   'original_title': "Dr. Ehrlich's Magic Bullet",
#   'year': 1940,
#   'genre': 'Biography',
#   'avg_vote': 7.4,
#   'votes': 1445,
#   'worlwide_gross_income': 205.0},
#  {'country': 'UK',
#   'original_title': 'The Angelic Conversation',
#   'year': 1985,
#   'genre': 'Drama',
#   'avg_vote': 6.2,
#   'votes': 708,
#   'worlwide_gross_income': 205.0},
#  {'country': 'UK',
#   'original_title': 'Jeremiah Terminator LeRoy',
#   'year': 2018,
#   'genre': 'Biography',
#   'avg_vote': 5.3,
#   'votes': 1621,
#   'worlwide_gross_income': 205.0},
#  {'country': 'Italy',
#   'original_title': 'Leoni',
#   'year': 2015,
#   'genre': 'Comedy',
#   'avg_vote': 5.2,
#   'votes': 111,
#   'worlwide_gross_income': 206.0},
#  {'country': 'Federal Republic of Yugoslavia',
#   'original_title': 'Lepa sela lepo gore',
#   'year': 1996,
#   'genre': 'Comedy',
#   'avg_vote': 8.7,
#   'votes': 14304,
#   'worlwide_gross_income': 211.0},
#  {'country': 'India',
#   'original_title': 'Rajaratha',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 5.2,
#   'votes': 166,
#   'worlwide_gross_income': 214.0},
#  {'country': 'Japan',
#   'original_title': 'Ranpo jigoku',
#   'year': 2005,
#   'genre': 'Fantasy',
#   'avg_vote': 6.3,
#   'votes': 1020,
#   'worlwide_gross_income': 217.0},
#  {'country': 'India',
#   'original_title': 'Sardaar Gabbar Singh',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 4.8,
#   'votes': 2195,
#   'worlwide_gross_income': 218.0},
#  {'country': 'UK',
#   'original_title': 'Pandorica',
#   'year': 2016,
#   'genre': 'Sci-Fi',
#   'avg_vote': 3.6,
#   'votes': 470,
#   'worlwide_gross_income': 228.0},
#  {'country': 'India',
#   'original_title': 'Sarrainodu',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 6.4,
#   'votes': 4022,
#   'worlwide_gross_income': 239.0},
#  {'country': 'West Germany',
#   'original_title': 'Der Angriff der Gegenwart auf die übrige Zeit',
#   'year': 1985,
#   'genre': 'Comedy',
#   'avg_vote': 6.8,
#   'votes': 130,
#   'worlwide_gross_income': 242.0},
#  {'country': 'UK',
#   'original_title': 'Native',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 4.2,
#   'votes': 361,
#   'worlwide_gross_income': 243.0},
#  {'country': 'Tajikistan',
#   'original_title': 'Bihisht faqat baroi murdagon',
#   'year': 2006,
#   'genre': 'Crime',
#   'avg_vote': 6.5,
#   'votes': 246,
#   'worlwide_gross_income': 246.0},
#  {'country': 'Turkey',
#   'original_title': 'Arada',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 5.4,
#   'votes': 408,
#   'worlwide_gross_income': 254.0},
#  {'country': 'Italy',
#   'original_title': 'Luce dei miei occhi',
#   'year': 2001,
#   'genre': 'Drama',
#   'avg_vote': 7.0,
#   'votes': 824,
#   'worlwide_gross_income': 257.0},
#  {'country': 'Japan',
#   'original_title': 'Koibito-tachi wa nureta',
#   'year': 1973,
#   'genre': 'Drama',
#   'avg_vote': 6.1,
#   'votes': 142,
#   'worlwide_gross_income': 259.0},
#  {'country': 'India',
#   'original_title': 'Aaha Kalyanam',
#   'year': 2014,
#   'genre': 'Comedy',
#   'avg_vote': 6.0,
#   'votes': 328,
#   'worlwide_gross_income': 260.0},
#  {'country': 'Japan',
#   'original_title': 'Kaze ni nureta onna',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 5.9,
#   'votes': 842,
#   'worlwide_gross_income': 268.0},
#  {'country': 'Greece',
#   'original_title': 'A Blast',
#   'year': 2014,
#   'genre': 'Drama',
#   'avg_vote': 5.7,
#   'votes': 769,
#   'worlwide_gross_income': 270.0},
#  {'country': 'Norway',
#   'original_title': 'Dirk Ohm - Illusjonisten som forsvant',
#   'year': 2015,
#   'genre': 'Drama',
#   'avg_vote': 5.5,
#   'votes': 189,
#   'worlwide_gross_income': 273.0},
#  {'country': 'USA',
#   'original_title': 'Creature from the Black Lagoon',
#   'year': 1954,
#   'genre': 'Horror',
#   'avg_vote': 7.0,
#   'votes': 25643,
#   'worlwide_gross_income': 275.0},
#  {'country': 'Canada',
#   'original_title': 'The Hexecutioners',
#   'year': 2015,
#   'genre': 'Horror',
#   'avg_vote': 4.0,
#   'votes': 514,
#   'worlwide_gross_income': 276.0},
#  {'country': 'India',
#   'original_title': 'Rekka',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 4.9,
#   'votes': 662,
#   'worlwide_gross_income': 282.0},
#  {'country': 'Bangladesh',
#   'original_title': 'Bengali Beauty',
#   'year': 2018,
#   'genre': 'Comedy',
#   'avg_vote': 7.0,
#   'votes': 121,
#   'worlwide_gross_income': 284.0},
#  {'country': 'Japan',
#   'original_title': 'Anchiporuno',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'votes': 2598,
#   'worlwide_gross_income': 294.0},
#  {'country': 'USA',
#   'original_title': 'Blood Car',
#   'year': 2007,
#   'genre': 'Comedy',
#   'avg_vote': 5.3,
#   'votes': 2384,
#   'worlwide_gross_income': 297.0},
#  {'country': 'Japan',
#   'original_title': 'Gunjô: Ai ga shizunda umi no iro',
#   'year': 2009,
#   'genre': 'Drama',
#   'avg_vote': 5.7,
#   'votes': 116,
#   'worlwide_gross_income': 301.0},
#  {'country': 'India',
#   'original_title': 'Naina',
#   'year': 2005,
#   'genre': 'Drama',
#   'avg_vote': 4.3,
#   'votes': 744,
#   'worlwide_gross_income': 304.0},
#  {'country': 'UK',
#   'original_title': 'Dummy',
#   'year': 2008,
#   'genre': 'Drama',
#   'avg_vote': 6.9,
#   'votes': 255,
#   'worlwide_gross_income': 307.0},
#  {'country': 'USA',
#   'original_title': 'Trojan War',
#   'year': 1997,
#   'genre': 'Comedy',
#   'avg_vote': 5.7,
#   'votes': 5636,
#   'worlwide_gross_income': 309.0},
#  {'country': 'UK',
#   'original_title': '100 Streets',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 5.7,
#   'votes': 3645,
#   'worlwide_gross_income': 309.0},
#  {'country': 'Japan',
#   'original_title': 'Howaito rirî',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 4.5,
#   'votes': 320,
#   'worlwide_gross_income': 319.0},
#  {'country': 'Austria',
#   'original_title': 'Die Geträumten',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 6.6,
#   'votes': 202,
#   'worlwide_gross_income': 327.0},
#  {'country': 'France',
#   'original_title': 'The Lost Door',
#   'year': 2008,
#   'genre': 'Drama',
#   'avg_vote': 4.4,
#   'votes': 173,
#   'worlwide_gross_income': 328.0},
#  {'country': 'UK',
#   'original_title': 'Turnout',
#   'year': 2011,
#   'genre': 'Drama',
#   'avg_vote': 5.4,
#   'votes': 271,
#   'worlwide_gross_income': 333.0},
#  {'country': 'Indonesia',
#   'original_title': 'Babi Buta yang Ingin Terbang',
#   'year': 2008,
#   'genre': 'Drama',
#   'avg_vote': 6.1,
#   'votes': 215,
#   'worlwide_gross_income': 344.0},
#  {'country': 'Bulgaria',
#   'original_title': 'Pazachyt na myrtvite',
#   'year': 2006,
#   'genre': 'Drama',
#   'avg_vote': 6.9,
#   'votes': 181,
#   'worlwide_gross_income': 348.0},
#  {'country': 'India',
#   'original_title': 'Marubhoomiyile Aana',
#   'year': 2016,
#   'genre': 'Comedy',
#   'avg_vote': 5.0,
#   'votes': 317,
#   'worlwide_gross_income': 348.0},
#  {'country': 'USA',
#   'original_title': "All God's Children Can Dance",
#   'year': 2008,
#   'genre': 'Drama',
#   'avg_vote': 5.2,
#   'votes': 250,
#   'worlwide_gross_income': 355.0},
#  {'country': 'UK',
#   'original_title': 'A Night in the Woods',
#   'year': 2011,
#   'genre': 'Horror',
#   'avg_vote': 3.7,
#   'votes': 820,
#   'worlwide_gross_income': 357.0},
#  {'country': 'Portugal',
#   'original_title': 'Mal',
#   'year': 1999,
#   'genre': 'Drama',
#   'avg_vote': 6.1,
#   'votes': 111,
#   'worlwide_gross_income': 359.0},
#  {'country': 'UK',
#   'original_title': 'Travellers',
#   'year': 2011,
#   'genre': 'Action',
#   'avg_vote': 4.3,
#   'votes': 512,
#   'worlwide_gross_income': 360.0},
#  {'country': 'USA',
#   'original_title': 'Dark Night',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 4.4,
#   'votes': 840,
#   'worlwide_gross_income': 363.0},
#  {'country': 'UK',
#   'original_title': 'The Reverend',
#   'year': 2011,
#   'genre': 'Horror',
#   'avg_vote': 4.0,
#   'votes': 375,
#   'worlwide_gross_income': 366.0},
#  {'country': 'Canada',
#   'original_title': '2 secondes',
#   'year': 1998,
#   'genre': 'Comedy',
#   'avg_vote': 6.5,
#   'votes': 511,
#   'worlwide_gross_income': 369.0},
#  {'country': 'Argentina',
#   'original_title': 'Tiempo muerto',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 6.1,
#   'votes': 172,
#   'worlwide_gross_income': 369.0},
#  {'country': 'UK',
#   'original_title': 'Saturday Night and Sunday Morning',
#   'year': 1960,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'votes': 7520,
#   'worlwide_gross_income': 370.0},
#  {'country': 'India',
#   'original_title': 'Gethu',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 3.6,
#   'votes': 373,
#   'worlwide_gross_income': 373.0},
#  {'country': 'France',
#   'original_title': 'La mort en ce jardin',
#   'year': 1956,
#   'genre': 'Adventure',
#   'avg_vote': 6.8,
#   'votes': 1850,
#   'worlwide_gross_income': 384.0},
#  {'country': 'UK',
#   'original_title': 'Viking Siege',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 3.1,
#   'votes': 127,
#   'worlwide_gross_income': 393.0},
#  {'country': 'UK',
#   'original_title': 'Chitty Chitty Bang Bang',
#   'year': 1968,
#   'genre': 'Adventure',
#   'avg_vote': 6.9,
#   'votes': 40116,
#   'worlwide_gross_income': 398.0},
#  {'country': 'Spain',
#   'original_title': 'La distancia',
#   'year': 2006,
#   'genre': 'Thriller',
#   'avg_vote': 5.9,
#   'votes': 307,
#   'worlwide_gross_income': 398.0},
#  {'country': 'Canada',
#   'original_title': 'Cinemanovels',
#   'year': 2013,
#   'genre': 'Comedy',
#   'avg_vote': 5.1,
#   'votes': 202,
#   'worlwide_gross_income': 398.0},
#  {'country': 'Finland',
#   'original_title': 'Kyrsyä - Tuftland',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 5.2,
#   'votes': 308,
#   'worlwide_gross_income': 399.0},
#  {'country': 'Spain',
#   'original_title': 'Con el viento',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 6.7,
#   'votes': 229,
#   'worlwide_gross_income': 403.0},
#  {'country': 'Canada',
#   'original_title': 'La vallée des larmes',
#   'year': 2012,
#   'genre': 'Drama',
#   'avg_vote': 7.4,
#   'votes': 566,
#   'worlwide_gross_income': 404.0},
#  {'country': 'France',
#   'original_title': 'Hôtel des Amériques',
#   'year': 1981,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'votes': 823,
#   'worlwide_gross_income': 406.0},
#  {'country': 'Japan',
#   'original_title': 'Tenshi no harawata: Akai inga',
#   'year': 1981,
#   'genre': 'Drama',
#   'avg_vote': 5.6,
#   'votes': 208,
#   'worlwide_gross_income': 407.0},
#  {'country': 'Spain',
#   'original_title': 'Asmodexia',
#   'year': 2014,
#   'genre': 'Horror',
#   'avg_vote': 4.6,
#   'votes': 1127,
#   'worlwide_gross_income': 418.0},
#  {'country': 'USA',
#   'original_title': 'The Wolf Man',
#   'year': 1941,
#   'genre': 'Horror',
#   'avg_vote': 7.3,
#   'votes': 23071,
#   'worlwide_gross_income': 420.0},
#  {'country': 'USA',
#   'original_title': 'State Park',
#   'year': 1988,
#   'genre': 'Comedy',
#   'avg_vote': 4.7,
#   'votes': 294,
#   'worlwide_gross_income': 421.0},
#  {'country': 'Canada',
#   'original_title': 'The Dark Hours',
#   'year': 2005,
#   'genre': 'Horror',
#   'avg_vote': 6.0,
#   'votes': 5212,
#   'worlwide_gross_income': 423.0},
#  {'country': 'Croatia',
#   'original_title': 'Ta divna Splitska noc',
#   'year': 2004,
#   'genre': 'Crime',
#   'avg_vote': 7.4,
#   'votes': 1427,
#   'worlwide_gross_income': 427.0},
#  {'country': 'Albania',
#   'original_title': 'Daybreak',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 6.7,
#   'votes': 136,
#   'worlwide_gross_income': 432.0},
#  {'country': 'Russia',
#   'original_title': 'Geroy',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 4.6,
#   'votes': 385,
#   'worlwide_gross_income': 434.0},
#  {'country': 'UK',
#   'original_title': 'My Name Is Lenny',
#   'year': 2017,
#   'genre': 'Biography',
#   'avg_vote': 6.2,
#   'votes': 2467,
#   'worlwide_gross_income': 435.0},
#  {'country': 'Brazil',
#   'original_title': 'Mar Negro',
#   'year': 2013,
#   'genre': 'Horror',
#   'avg_vote': 5.6,
#   'votes': 238,
#   'worlwide_gross_income': 435.0},
#  {'country': 'USA',
#   'original_title': 'The Quarry',
#   'year': 2020,
#   'genre': 'Crime',
#   'avg_vote': 5.2,
#   'votes': 1446,
#   'worlwide_gross_income': 439.0},
#  {'country': 'USA',
#   'original_title': 'Serum',
#   'year': 2006,
#   'genre': 'Horror',
#   'avg_vote': 3.0,
#   'votes': 382,
#   'worlwide_gross_income': 440.0},
#  {'country': 'West Germany',
#   'original_title': 'Abschied von gestern - (Anita G.)',
#   'year': 1966,
#   'genre': 'Drama',
#   'avg_vote': 7.0,
#   'votes': 855,
#   'worlwide_gross_income': 446.0},
#  {'country': 'China',
#   'original_title': 'Yi shi er niao',
#   'year': 2005,
#   'genre': 'Action',
#   'avg_vote': 3.5,
#   'votes': 140,
#   'worlwide_gross_income': 449.0},
#  {'country': 'USA',
#   'original_title': 'Green is Gold',
#   'year': 2016,
#   'genre': 'Crime',
#   'avg_vote': 6.0,
#   'votes': 902,
#   'worlwide_gross_income': 455.0},
#  {'country': 'Austria',
#   'original_title': 'Angelo',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 5.9,
#   'votes': 294,
#   'worlwide_gross_income': 464.0},
#  {'country': 'UK',
#   'original_title': 'Piggy',
#   'year': 2012,
#   'genre': 'Horror',
#   'avg_vote': 5.6,
#   'votes': 1427,
#   'worlwide_gross_income': 467.0},
#  {'country': 'USA',
#   'original_title': 'Rome & Jewel',
#   'year': 2008,
#   'genre': 'Drama',
#   'avg_vote': 4.2,
#   'votes': 129,
#   'worlwide_gross_income': 470.0},
#  {'country': 'France',
#   'original_title': 'Le dernier des fous',
#   'year': 2006,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'votes': 277,
#   'worlwide_gross_income': 481.0},
#  {'country': 'Italy',
#   'original_title': "L'oro di Napoli",
#   'year': 1954,
#   'genre': 'Comedy',
#   'avg_vote': 7.3,
#   'votes': 1474,
#   'worlwide_gross_income': 483.0},
#  {'country': 'Netherlands',
#   'original_title': 'Winterstilte',
#   'year': 2008,
#   'genre': 'Drama',
#   'avg_vote': 6.2,
#   'votes': 122,
#   'worlwide_gross_income': 486.0},
#  {'country': 'Canada',
#   'original_title': 'Chloe & Theo',
#   'year': 2015,
#   'genre': 'Comedy',
#   'avg_vote': 5.8,
#   'votes': 1485,
#   'worlwide_gross_income': 490.0},
#  {'country': 'China',
#   'original_title': 'Qin Mi Di Ren',
#   'year': 2011,
#   'genre': 'Comedy',
#   'avg_vote': 4.6,
#   'votes': 143,
#   'worlwide_gross_income': 491.0},
#  {'country': 'India',
#   'original_title': 'Pushpaka Vimana',
#   'year': 2017,
#   'genre': 'Comedy',
#   'avg_vote': 7.5,
#   'votes': 257,
#   'worlwide_gross_income': 499.0},
#  {'country': 'Chile',
#   'original_title': 'Princesita',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 6.0,
#   'votes': 128,
#   'worlwide_gross_income': 499.0},
#  {'country': 'Japan',
#   'original_title': 'Kanaria',
#   'year': 2004,
#   'genre': 'Drama',
#   'avg_vote': 6.9,
#   'votes': 301,
#   'worlwide_gross_income': 504.0},
#  {'country': 'France',
#   'original_title': "Indigène d'Eurasie",
#   'year': 2010,
#   'genre': 'Drama',
#   'avg_vote': 6.4,
#   'votes': 358,
#   'worlwide_gross_income': 504.0},
#  {'country': 'Brazil',
#   'original_title': 'Em Teu Nome',
#   'year': 2009,
#   'genre': 'Drama',
#   'avg_vote': 6.2,
#   'votes': 148,
#   'worlwide_gross_income': 504.0},
#  {'country': 'India',
#   'original_title': 'Devi(L)',
#   'year': 2016,
#   'genre': 'Comedy',
#   'avg_vote': 6.2,
#   'votes': 893,
#   'worlwide_gross_income': 508.0},
#  {'country': 'France',
#   'original_title': 'La nuit américaine',
#   'year': 1973,
#   'genre': 'Comedy',
#   'avg_vote': 8.0,
#   'votes': 19790,
#   'worlwide_gross_income': 509.0},
#  {'country': 'France',
#   'original_title': 'Baisers volés',
#   'year': 1968,
#   'genre': 'Comedy',
#   'avg_vote': 7.7,
#   'votes': 11806,
#   'worlwide_gross_income': 509.0},
#  {'country': 'France',
#   'original_title': 'Domicile conjugal',
#   'year': 1970,
#   'genre': 'Comedy',
#   'avg_vote': 7.5,
#   'votes': 8003,
#   'worlwide_gross_income': 509.0},
#  {'country': 'France',
#   'original_title': 'Les deux Anglaises et le continent',
#   'year': 1971,
#   'genre': 'Romance',
#   'avg_vote': 7.4,
#   'votes': 4721,
#   'worlwide_gross_income': 509.0},
#  {'country': 'France',
#   'original_title': "La femme d'à côté",
#   'year': 1981,
#   'genre': 'Drama',
#   'avg_vote': 7.3,
#   'votes': 6993,
#   'worlwide_gross_income': 509.0},
#  {'country': 'France',
#   'original_title': 'Vivement dimanche!',
#   'year': 1983,
#   'genre': 'Comedy',
#   'avg_vote': 7.3,
#   'votes': 5613,
#   'worlwide_gross_income': 509.0},
#  {'country': 'UK',
#   'original_title': 'Fahrenheit 451',
#   'year': 1966,
#   'genre': 'Drama',
#   'avg_vote': 7.2,
#   'votes': 40524,
#   'worlwide_gross_income': 509.0},
#  {'country': 'France',
#   'original_title': "L'amour en fuite",
#   'year': 1979,
#   'genre': 'Comedy',
#   'avg_vote': 7.1,
#   'votes': 5927,
#   'worlwide_gross_income': 509.0},
#  {'country': 'France',
#   'original_title': 'La chambre verte',
#   'year': 1978,
#   'genre': 'Drama',
#   'avg_vote': 7.0,
#   'votes': 2615,
#   'worlwide_gross_income': 509.0},
#  {'country': 'USA',
#   'original_title': 'Looking for Jimmy',
#   'year': 2002,
#   'genre': 'Drama',
#   'avg_vote': 5.6,
#   'votes': 159,
#   'worlwide_gross_income': 510.0},
#  {'country': 'Germany',
#   'original_title': 'I Am Here',
#   'year': 2014,
#   'genre': 'Drama',
#   'avg_vote': 5.0,
#   'votes': 1610,
#   'worlwide_gross_income': 510.0},
#  {'country': 'India',
#   'original_title': 'Iruttu Araiyil Murattu Kuthu',
#   'year': 2018,
#   'genre': 'Horror',
#   'avg_vote': 4.2,
#   'votes': 714,
#   'worlwide_gross_income': 512.0},
#  {'country': 'Japan',
#   'original_title': 'Enjo-kôsai monogatari: shitagaru onna-tachi',
#   'year': 2005,
#   'genre': 'Drama',
#   'avg_vote': 5.3,
#   'votes': 107,
#   'worlwide_gross_income': 513.0},
#  {'country': 'Argentina',
#   'original_title': 'Jess & James',
#   'year': 2015,
#   'genre': 'Drama',
#   'avg_vote': 5.3,
#   'votes': 487,
#   'worlwide_gross_income': 514.0},
#  {'country': 'USA',
#   'original_title': '68 Kill',
#   'year': 2017,
#   'genre': 'Comedy',
#   'avg_vote': 6.0,
#   'votes': 4694,
#   'worlwide_gross_income': 522.0},
#  {'country': 'Portugal',
#   'original_title': 'Inner Ghosts',
#   'year': 2018,
#   'genre': 'Horror',
#   'avg_vote': 3.8,
#   'votes': 243,
#   'worlwide_gross_income': 522.0},
#  {'country': 'Switzerland',
#   'original_title': 'Aloys',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 6.3,
#   'votes': 1803,
#   'worlwide_gross_income': 523.0},
#  {'country': 'USA',
#   'original_title': 'Meeting Evil',
#   'year': 2012,
#   'genre': 'Crime',
#   'avg_vote': 5.3,
#   'votes': 11599,
#   'worlwide_gross_income': 525.0},
#  {'country': 'USA',
#   'original_title': 'Higher Power',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 4.8,
#   'votes': 2138,
#   'worlwide_gross_income': 528.0},
#  {'country': 'Norway',
#   'original_title': 'Brev til Kongen',
#   'year': 2014,
#   'genre': 'Drama',
#   'avg_vote': 6.9,
#   'votes': 229,
#   'worlwide_gross_income': 529.0},
#  {'country': 'Turkey',
#   'original_title': 'Murtaza',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 6.0,
#   'votes': 112,
#   'worlwide_gross_income': 532.0},
#  {'country': 'Romania',
#   'original_title': 'Occident',
#   'year': 2002,
#   'genre': 'Comedy',
#   'avg_vote': 7.6,
#   'votes': 2072,
#   'worlwide_gross_income': 533.0},
#  {'country': 'India',
#   'original_title': 'Brahmotsavam',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 4.3,
#   'votes': 2820,
#   'worlwide_gross_income': 541.0},
#  {'country': 'Japan',
#   'original_title': 'Funshutsu kigan - 15-sai no baishunfu',
#   'year': 1971,
#   'genre': 'Drama',
#   'avg_vote': 5.6,
#   'votes': 169,
#   'worlwide_gross_income': 544.0},
#  {'country': 'Turkey',
#   'original_title': 'Beginner',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 6.3,
#   'votes': 221,
#   'worlwide_gross_income': 551.0},
#  {'country': 'Brazil',
#   'original_title': 'António Um Dois Três',
#   'year': 2017,
#   'genre': 'Comedy',
#   'avg_vote': 6.6,
#   'votes': 109,
#   'worlwide_gross_income': 552.0},
#  {'country': 'Iran',
#   'original_title': 'Chaharshanbeh, 19 Ordibehesht',
#   'year': 2015,
#   'genre': 'Drama',
#   'avg_vote': 6.6,
#   'votes': 591,
#   'worlwide_gross_income': 557.0},
#  {'country': 'Canada',
#   'original_title': 'The Pit',
#   'year': 1981,
#   'genre': 'Horror',
#   'avg_vote': 5.8,
#   'votes': 2231,
#   'worlwide_gross_income': 560.0},
#  {'country': 'UK',
#   'original_title': 'Best Laid Plans',
#   'year': 2012,
#   'genre': 'Drama',
#   'avg_vote': 6.3,
#   'votes': 1491,
#   'worlwide_gross_income': 573.0},
#  {'country': 'USA',
#   'original_title': '12 Angry Men',
#   'year': 1957,
#   'genre': 'Crime',
#   'avg_vote': 8.9,
#   'votes': 668473,
#   'worlwide_gross_income': 576.0},
#  {'country': 'UK',
#   'original_title': 'The Last Thakur',
#   'year': 2008,
#   'genre': 'Action',
#   'avg_vote': 6.3,
#   'votes': 174,
#   'worlwide_gross_income': 578.0},
#  {'country': 'Japan',
#   'original_title': 'Tenshi no kôkotsu',
#   'year': 1972,
#   'genre': 'Action',
#   'avg_vote': 6.7,
#   'votes': 888,
#   'worlwide_gross_income': 585.0},
#  {'country': 'India',
#   'original_title': 'Mayurakshi',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 7.1,
#   'votes': 328,
#   'worlwide_gross_income': 590.0},
#  {'country': 'Canada',
#   'original_title': 'Shake Hands with the Devil',
#   'year': 2007,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'votes': 3202,
#   'worlwide_gross_income': 594.0},
#  {'country': 'Bulgaria',
#   'original_title': 'Damascena',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 6.0,
#   'votes': 143,
#   'worlwide_gross_income': 594.0},
#  {'country': 'USA',
#   'original_title': 'In Memory of My Father',
#   'year': 2005,
#   'genre': 'Comedy',
#   'avg_vote': 6.0,
#   'votes': 609,
#   'worlwide_gross_income': 603.0},
#  {'country': 'USA',
#   'original_title': 'Atletu',
#   'year': 2009,
#   'genre': 'Biography',
#   'avg_vote': 6.7,
#   'votes': 224,
#   'worlwide_gross_income': 611.0},
#  {'country': 'India',
#   'original_title': 'Enakkul Oruvan',
#   'year': 2015,
#   'genre': 'Thriller',
#   'avg_vote': 7.8,
#   'votes': 1472,
#   'worlwide_gross_income': 621.0},
#  {'country': 'Colombia',
#   'original_title': 'Pariente',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 6.6,
#   'votes': 213,
#   'worlwide_gross_income': 622.0},
#  {'country': 'Belgium',
#   'original_title': 'Steve + Sky',
#   'year': 2004,
#   'genre': 'Romance',
#   'avg_vote': 6.9,
#   'votes': 1264,
#   'worlwide_gross_income': 624.0},
#  {'country': 'India',
#   'original_title': 'Oozham',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 6.0,
#   'votes': 1113,
#   'worlwide_gross_income': 624.0},
#  {'country': 'Canada',
#   'original_title': 'Edwin Boyd',
#   'year': 2011,
#   'genre': 'Crime',
#   'avg_vote': 6.2,
#   'votes': 4124,
#   'worlwide_gross_income': 625.0},
#  {'country': 'Soviet Union',
#   'original_title': 'Devyat dney odnogo goda',
#   'year': 1962,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'votes': 958,
#   'worlwide_gross_income': 630.0},
#  {'country': 'UK',
#   'original_title': 'The Last of England',
#   'year': 1987,
#   'genre': 'Drama',
#   'avg_vote': 6.7,
#   'votes': 1150,
#   'worlwide_gross_income': 630.0},
#  {'country': 'India',
#   'original_title': 'Natsamrat',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 9.1,
#   'votes': 4880,
#   'worlwide_gross_income': 633.0},
#  {'country': 'Serbia',
#   'original_title': 'Beli, beli svet',
#   'year': 2010,
#   'genre': 'Drama',
#   'avg_vote': 6.8,
#   'votes': 499,
#   'worlwide_gross_income': 633.0},
#  {'country': 'Bulgaria',
#   'original_title': 'The Prosecutor the Defender the Father and His Son',
#   'year': 2015,
#   'genre': 'Drama',
#   'avg_vote': 6.7,
#   'votes': 171,
#   'worlwide_gross_income': 635.0},
#  {'country': 'Turkey',
#   'original_title': 'Kizim Gibi Kokuyorsun',
#   'year': 2019,
#   'genre': 'Drama',
#   'avg_vote': 6.0,
#   'votes': 113,
#   'worlwide_gross_income': 635.0},
#  {'country': 'Turkey',
#   'original_title': 'Kumun Tadi',
#   'year': 2014,
#   'genre': 'Drama',
#   'avg_vote': 4.4,
#   'votes': 180,
#   'worlwide_gross_income': 640.0},
#  {'country': 'India',
#   'original_title': 'Kavi Uddheshichathu..?',
#   'year': 2016,
#   'genre': 'Comedy',
#   'avg_vote': 5.5,
#   'votes': 275,
#   'worlwide_gross_income': 646.0},
#  {'country': 'USA',
#   'original_title': 'Nature Calls',
#   'year': 2012,
#   'genre': 'Comedy',
#   'avg_vote': 4.0,
#   'votes': 2197,
#   'worlwide_gross_income': 646.0},
#  {'country': 'USA',
#   'original_title': 'Gentlemen Prefer Blondes',
#   'year': 1953,
#   'genre': 'Comedy',
#   'avg_vote': 7.2,
#   'votes': 30759,
#   'worlwide_gross_income': 648.0},
#  {'country': 'USA',
#   'original_title': 'King Kong',
#   'year': 1933,
#   'genre': 'Adventure',
#   'avg_vote': 7.9,
#   'votes': 77507,
#   'worlwide_gross_income': 651.0},
#  {'country': 'France',
#   'original_title': 'Le petit prince a dit',
#   'year': 1992,
#   'genre': 'Drama',
#   'avg_vote': 7.1,
#   'votes': 399,
#   'worlwide_gross_income': 655.0},
#  {'country': 'Japan',
#   'original_title': 'Yuke yuke nidome no shojo',
#   'year': 1969,
#   'genre': 'Drama',
#   'avg_vote': 7.5,
#   'votes': 2309,
#   'worlwide_gross_income': 659.0},
#  {'country': 'Japan',
#   'original_title': 'Appurushido: Ekusu makina',
#   'year': 2007,
#   'genre': 'Animation',
#   'avg_vote': 7.1,
#   'votes': 9283,
#   'worlwide_gross_income': 662.0},
#  {'country': 'Chile',
#   'original_title': 'El Príncipe',
#   'year': 2019,
#   'genre': 'Drama',
#   'avg_vote': 6.4,
#   'votes': 507,
#   'worlwide_gross_income': 663.0},
#  {'country': 'USA',
#   'original_title': 'Syrup',
#   'year': 2013,
#   'genre': 'Comedy',
#   'avg_vote': 5.7,
#   'votes': 10565,
#   'worlwide_gross_income': 663.0},
#  {'country': 'Japan',
#   'original_title': 'Mizu no nai puuru',
#   'year': 1982,
#   'genre': 'Crime',
#   'avg_vote': 7.0,
#   'votes': 473,
#   'worlwide_gross_income': 668.0},
#  {'country': 'Luxembourg',
#   'original_title': 'Hot Hot Hot',
#   'year': 2011,
#   'genre': 'Comedy',
#   'avg_vote': 4.8,
#   'votes': 128,
#   'worlwide_gross_income': 669.0},
#  {'country': 'USA',
#   'original_title': 'Family Games',
#   'year': 2018,
#   'genre': 'Comedy',
#   'avg_vote': 4.1,
#   'votes': 129,
#   'worlwide_gross_income': 671.0},
#  {'country': 'Serbia',
#   'original_title': 'Daca bobul nu moare',
#   'year': 2010,
#   'genre': 'Comedy',
#   'avg_vote': 6.5,
#   'votes': 171,
#   'worlwide_gross_income': 681.0},
#  {'country': 'West Germany',
#   'original_title': 'Die Artisten in der Zirkuskuppel: Ratlos',
#   'year': 1968,
#   'genre': 'Drama',
#   'avg_vote': 6.7,
#   'votes': 355,
#   'worlwide_gross_income': 684.0},
#  {'country': 'USA',
#   'original_title': 'Bitch',
#   'year': 2017,
#   'genre': 'Comedy',
#   'avg_vote': 5.1,
#   'votes': 1715,
#   'worlwide_gross_income': 688.0},
#  {'country': 'India',
#   'original_title': 'I Am Kalam',
#   'year': 2010,
#   'genre': 'Comedy',
#   'avg_vote': 8.0,
#   'votes': 3511,
#   'worlwide_gross_income': 691.0},
#  {'country': 'USA',
#   'original_title': '2 Minutes Later',
#   'year': 2007,
#   'genre': 'Adventure',
#   'avg_vote': 4.2,
#   'votes': 404,
#   'worlwide_gross_income': 693.0},
#  {'country': 'Germany',
#   'original_title': 'Blindgänger',
#   'year': 2004,
#   'genre': 'Family',
#   'avg_vote': 6.6,
#   'votes': 119,
#   'worlwide_gross_income': 702.0},
#  {'country': 'Costa Rica',
#   'original_title': 'Viaje',
#   'year': 2015,
#   'genre': 'Romance',
#   'avg_vote': 6.4,
#   'votes': 226,
#   'worlwide_gross_income': 712.0},
#  {'country': 'Japan',
#   'original_title': 'Funuke domo, kanashimi no ai wo misero',
#   'year': 2007,
#   'genre': 'Drama',
#   'avg_vote': 7.2,
#   'votes': 686,
#   'worlwide_gross_income': 713.0},
#  {'country': 'USA',
#   'original_title': 'A Girl Like Grace',
#   'year': 2015,
#   'genre': 'Drama',
#   'avg_vote': 5.9,
#   'votes': 494,
#   'worlwide_gross_income': 713.0},
#  {'country': 'UK',
#   'original_title': 'Breakdown',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 5.2,
#   'votes': 734,
#   'worlwide_gross_income': 713.0},
#  {'country': 'UK',
#   'original_title': 'The Point Men',
#   'year': 2001,
#   'genre': 'Action',
#   'avg_vote': 4.4,
#   'votes': 1043,
#   'worlwide_gross_income': 714.0},
#  {'country': 'UK',
#   'original_title': 'Aux',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 4.3,
#   'votes': 291,
#   'worlwide_gross_income': 725.0},
#  {'country': 'UK',
#   'original_title': "A New Day in Old Sana'a",
#   'year': 2005,
#   'genre': 'Drama',
#   'avg_vote': 6.2,
#   'votes': 160,
#   'worlwide_gross_income': 737.0},
#  {'country': 'Mexico',
#   'original_title': 'Abrakadabra',
#   'year': 2018,
#   'genre': 'Horror',
#   'avg_vote': 5.6,
#   'votes': 232,
#   'worlwide_gross_income': 737.0},
#  {'country': 'UK',
#   'original_title': 'The Haunting',
#   'year': 1963,
#   'genre': 'Horror',
#   'avg_vote': 7.5,
#   'votes': 33652,
#   'worlwide_gross_income': 742.0},
#  {'country': 'USA',
#   'original_title': 'Wings',
#   'year': 1927,
#   'genre': 'Drama',
#   'avg_vote': 7.5,
#   'votes': 11139,
#   'worlwide_gross_income': 746.0},
#  {'country': 'Kazakhstan',
#   'original_title': 'Ozen',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 6.4,
#   'votes': 138,
#   'worlwide_gross_income': 748.0},
#  {'country': 'Canada',
#   'original_title': 'The Steam Engines of Oz',
#   'year': 2018,
#   'genre': 'Animation',
#   'avg_vote': 7.1,
#   'votes': 592,
#   'worlwide_gross_income': 751.0},
#  {'country': 'Japan',
#   'original_title': 'Majokko shimai no Yoyo to Nene',
#   'year': 2013,
#   'genre': 'Animation',
#   'avg_vote': 6.8,
#   'votes': 154,
#   'worlwide_gross_income': 751.0},
#  {'country': 'UK',
#   'original_title': 'Big Fat Gypsy Gangster',
#   'year': 2011,
#   'genre': 'Action',
#   'avg_vote': 3.5,
#   'votes': 807,
#   'worlwide_gross_income': 753.0},
#  {'country': 'Singapore',
#   'original_title': 'Mei man ren sheng',
#   'year': 2006,
#   'genre': 'Drama',
#   'avg_vote': 6.9,
#   'votes': 303,
#   'worlwide_gross_income': 756.0},
#  {'country': 'Argentina',
#   'original_title': 'El auge del humano',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 5.8,
#   'votes': 282,
#   'worlwide_gross_income': 758.0},
#  {'country': 'Japan',
#   'original_title': 'Scrap Heaven',
#   'year': 2005,
#   'genre': 'Drama',
#   'avg_vote': 6.9,
#   'votes': 429,
#   'worlwide_gross_income': 760.0},
#  {'country': 'Italy',
#   'original_title': 'Uncut',
#   'year': 2003,
#   'genre': 'Comedy',
#   'avg_vote': 4.7,
#   'votes': 145,
#   'worlwide_gross_income': 762.0},
#  {'country': 'Japan',
#   'original_title': 'Hatsukoi: Jigoku-hen',
#   'year': 1968,
#   'genre': 'Drama',
#   'avg_vote': 7.4,
#   'votes': 716,
#   'worlwide_gross_income': 769.0},
#  {'country': 'Egypt',
#   'original_title': 'Microphone',
#   'year': 2010,
#   'genre': 'Comedy',
#   'avg_vote': 7.2,
#   'votes': 1497,
#   'worlwide_gross_income': 772.0},
#  {'country': 'USA',
#   'original_title': 'Flakes',
#   'year': 2007,
#   'genre': 'Comedy',
#   'avg_vote': 6.0,
#   'votes': 3331,
#   'worlwide_gross_income': 778.0},
#  {'country': 'Slovakia',
#   'original_title': 'Vsetko co mam rad',
#   'year': 1993,
#   'genre': 'Drama',
#   'avg_vote': 6.8,
#   'votes': 167,
#   'worlwide_gross_income': 779.0},
#  {'country': 'USA',
#   'original_title': 'Issues',
#   'year': 2005,
#   'genre': 'Comedy',
#   'avg_vote': 5.6,
#   'votes': 103,
#   'worlwide_gross_income': 783.0},
#  {'country': 'Spain',
#   'original_title': 'El callejón',
#   'year': 2011,
#   'genre': 'Horror',
#   'avg_vote': 4.4,
#   'votes': 806,
#   'worlwide_gross_income': 786.0},
#  {'country': 'USA',
#   'original_title': 'The Untold Story',
#   'year': 2019,
#   'genre': 'Comedy',
#   'avg_vote': 5.4,
#   'votes': 275,
#   'worlwide_gross_income': 790.0},
#  {'country': 'Japan',
#   'original_title': 'Kannô byôtô: nureta akai kuchibiru',
#   'year': 2005,
#   'genre': 'Drama',
#   'avg_vote': 4.8,
#   'votes': 112,
#   'worlwide_gross_income': 790.0},
#  {'country': 'UK',
#   'original_title': 'K-Shop',
#   'year': 2016,
#   'genre': 'Crime',
#   'avg_vote': 5.9,
#   'votes': 1218,
#   'worlwide_gross_income': 793.0},
#  {'country': 'Sweden',
#   'original_title': 'Gud, lukt och henne',
#   'year': 2008,
#   'genre': 'Drama',
#   'avg_vote': 6.3,
#   'votes': 113,
#   'worlwide_gross_income': 794.0},
#  {'country': 'UK',
#   'original_title': 'This Sporting Life',
#   'year': 1963,
#   'genre': 'Drama',
#   'avg_vote': 7.7,
#   'votes': 5752,
#   'worlwide_gross_income': 813.0},
#  {'country': 'UK',
#   'original_title': 'The Tempest',
#   'year': 1979,
#   'genre': 'Drama',
#   'avg_vote': 6.4,
#   'votes': 955,
#   'worlwide_gross_income': 813.0},
#  {'country': 'India',
#   'original_title': 'Shikkari Shambhu',
#   'year': 2018,
#   'genre': 'Comedy',
#   'avg_vote': 5.7,
#   'votes': 429,
#   'worlwide_gross_income': 816.0},
#  {'country': 'Brazil',
#   'original_title': 'Vermelho Russo',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 6.3,
#   'votes': 147,
#   'worlwide_gross_income': 817.0},
#  {'country': 'Netherlands',
#   'original_title': 'R U There',
#   'year': 2010,
#   'genre': 'Drama',
#   'avg_vote': 5.5,
#   'votes': 303,
#   'worlwide_gross_income': 821.0},
#  {'country': 'Belgium',
#   'original_title': 'Puppylove',
#   'year': 2013,
#   'genre': 'Romance',
#   'avg_vote': 5.7,
#   'votes': 566,
#   'worlwide_gross_income': 824.0},
#  {'country': 'USA',
#   'original_title': 'Disfigured',
#   'year': 2008,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'votes': 310,
#   'worlwide_gross_income': 829.0},
#  {'country': 'Australia',
#   'original_title': 'Doing Time for Patsy Cline',
#   'year': 1997,
#   'genre': 'Comedy',
#   'avg_vote': 6.2,
#   'votes': 297,
#   'worlwide_gross_income': 831.0},
#  {'country': 'UK',
#   'original_title': 'Taking Stock',
#   'year': 2015,
#   'genre': 'Comedy',
#   'avg_vote': 3.8,
#   'votes': 188,
#   'worlwide_gross_income': 837.0},
#  {'country': 'France',
#   'original_title': "Ensemble, nous allons vivre une très, très grande histoire d'amour...",
#   'year': 2010,
#   'genre': 'Comedy',
#   'avg_vote': 4.7,
#   'votes': 163,
#   'worlwide_gross_income': 848.0},
#  {'country': 'Hong Kong',
#   'original_title': 'PTU',
#   'year': 2003,
#   'genre': 'Crime',
#   'avg_vote': 6.9,
#   'votes': 3924,
#   'worlwide_gross_income': 849.0},
#  {'country': 'USA',
#   'original_title': 'Officer Downe',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 4.2,
#   'votes': 1834,
#   'worlwide_gross_income': 850.0},
#  {'country': 'USA',
#   'original_title': 'Letter from an Unknown Woman',
#   'year': 1948,
#   'genre': 'Drama',
#   'avg_vote': 8.0,
#   'votes': 10756,
#   'worlwide_gross_income': 852.0},
#  {'country': 'France',
#   'original_title': 'La ronde',
#   'year': 1950,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'votes': 4733,
#   'worlwide_gross_income': 852.0},
#  {'country': 'Germany',
#   'original_title': 'Liebelei',
#   'year': 1933,
#   'genre': 'Drama',
#   'avg_vote': 7.5,
#   'votes': 1281,
#   'worlwide_gross_income': 852.0},
#  {'country': 'USA',
#   'original_title': 'The Underground Comedy Movie',
#   'year': 1999,
#   'genre': 'Comedy',
#   'avg_vote': 2.2,
#   'votes': 2424,
#   'worlwide_gross_income': 856.0},
#  {'country': 'UK',
#   'original_title': 'Trick or Treat',
#   'year': 2019,
#   'genre': 'Thriller',
#   'avg_vote': 5.7,
#   'votes': 379,
#   'worlwide_gross_income': 859.0},
#  {'country': 'Australia',
#   'original_title': 'Acolytes',
#   'year': 2008,
#   'genre': 'Crime',
#   'avg_vote': 5.5,
#   'votes': 2207,
#   'worlwide_gross_income': 860.0},
#  {'country': 'Germany',
#   'original_title': 'Die Frau meiner Träume',
#   'year': 1944,
#   'genre': 'Comedy',
#   'avg_vote': 6.7,
#   'votes': 189,
#   'worlwide_gross_income': 864.0},
#  {'country': 'UK',
#   'original_title': 'The Tapes',
#   'year': 2011,
#   'genre': 'Horror',
#   'avg_vote': 3.2,
#   'votes': 481,
#   'worlwide_gross_income': 880.0},
#  {'country': 'Canada',
#   'original_title': 'Big Muddy',
#   'year': 2014,
#   'genre': 'Crime',
#   'avg_vote': 4.9,
#   'votes': 145,
#   'worlwide_gross_income': 881.0},
#  {'country': 'Germany',
#   'original_title': 'In Her Line of Fire',
#   'year': 2006,
#   'genre': 'Action',
#   'avg_vote': 3.8,
#   'votes': 927,
#   'worlwide_gross_income': 884.0},
#  {'country': 'Germany',
#   'original_title': 'Julie Walking Home',
#   'year': 2002,
#   'genre': 'Drama',
#   'avg_vote': 6.3,
#   'votes': 932,
#   'worlwide_gross_income': 892.0},
#  {'country': 'South Africa',
#   'original_title': 'Beat the Drum',
#   'year': 2003,
#   'genre': 'Drama',
#   'avg_vote': 7.1,
#   'votes': 662,
#   'worlwide_gross_income': 895.0},
#  {'country': 'USA',
#   'original_title': 'How to Be a Serial Killer',
#   'year': 2008,
#   'genre': 'Comedy',
#   'avg_vote': 5.5,
#   'votes': 1978,
#   'worlwide_gross_income': 899.0},
#  {'country': 'USA',
#   'original_title': 'High Strung',
#   'year': 1992,
#   'genre': 'Comedy',
#   'avg_vote': 6.8,
#   'votes': 1922,
#   'worlwide_gross_income': 904.0},
#  {'country': 'USA',
#   'original_title': 'The Girl from Monday',
#   'year': 2005,
#   'genre': 'Action',
#   'avg_vote': 5.2,
#   'votes': 983,
#   'worlwide_gross_income': 921.0},
#  {'country': 'UK',
#   'original_title': 'Jubilee',
#   'year': 1978,
#   'genre': 'Comedy',
#   'avg_vote': 6.1,
#   'votes': 2821,
#   'worlwide_gross_income': 923.0},
#  {'country': 'Denmark',
#   'original_title': 'Fuglene over sundet',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 6.2,
#   'votes': 621,
#   'worlwide_gross_income': 926.0},
#  {'country': 'Japan',
#   'original_title': 'Hana to hebi 2: Pari/Shizuko',
#   'year': 2005,
#   'genre': 'Drama',
#   'avg_vote': 5.6,
#   'votes': 410,
#   'worlwide_gross_income': 927.0},
#  {'country': 'UK',
#   'original_title': 'City Rats',
#   'year': 2009,
#   'genre': 'Action',
#   'avg_vote': 4.9,
#   'votes': 1202,
#   'worlwide_gross_income': 932.0},
#  {'country': 'Singapore',
#   'original_title': '4:30',
#   'year': 2005,
#   'genre': 'Drama',
#   'avg_vote': 6.7,
#   'votes': 494,
#   'worlwide_gross_income': 935.0},
#  {'country': 'Netherlands',
#   'original_title': "The Bird Can't Fly",
#   'year': 2007,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'votes': 188,
#   'worlwide_gross_income': 938.0},
#  {'country': 'Denmark',
#   'original_title': 'Epidemic',
#   'year': 1987,
#   'genre': 'Drama',
#   'avg_vote': 6.2,
#   'votes': 4798,
#   'worlwide_gross_income': 938.0},
#  {'country': 'Germany',
#   'original_title': 'Shanghai Baby',
#   'year': 2007,
#   'genre': 'Drama',
#   'avg_vote': 4.4,
# ...
#   'year': 1936,
#   'genre': 'Comedy',
#   'avg_vote': 6.6,
#   'votes': 256,
#   'worlwide_gross_income': 3337.0},
#  {'country': 'Australia',
#   'original_title': 'Swerve',
#   'year': 2011,
#   'genre': 'Crime',
#   'avg_vote': 5.3,
#   'votes': 1743,
#   'worlwide_gross_income': 3338.0},
#  {'country': 'India',
#   'original_title': 'One Day: Justice Delivered',
#   'year': 2019,
#   'genre': 'Action',
#   'avg_vote': 5.5,
#   'votes': 1325,
#   'worlwide_gross_income': 3340.0},
#  {'country': 'USA',
#   'original_title': 'Fashion Victim',
#   'year': 2008,
#   'genre': 'Thriller',
#   'avg_vote': 3.1,
#   'votes': 222,
#   'worlwide_gross_income': 3346.0},
#  {'country': 'Slovenia',
#   'original_title': 'Kruh in mleko',
#   'year': 2001,
#   'genre': 'Drama',
#   'avg_vote': 7.1,
#   'votes': 420,
#   'worlwide_gross_income': 3349.0},
#  {'country': 'USA',
#   'original_title': 'Followers',
#   'year': 2017,
#   'genre': 'Thriller',
#   'avg_vote': 3.7,
#   'votes': 245,
#   'worlwide_gross_income': 3350.0},
#  {'country': 'Singapore',
#   'original_title': 'Bad Match',
#   'year': 2017,
#   'genre': 'Thriller',
#   'avg_vote': 5.5,
#   'votes': 3593,
#   'worlwide_gross_income': 3351.0},
#  {'country': 'USA',
#   'original_title': 'Amanda & Jack Go Glamping',
#   'year': 2017,
#   'genre': 'Comedy',
#   'avg_vote': 4.5,
#   'votes': 605,
#   'worlwide_gross_income': 3352.0},
#  {'country': 'USA',
#   'original_title': 'American Fork',
#   'year': 2007,
#   'genre': 'Comedy',
#   'avg_vote': 6.2,
#   'votes': 599,
#   'worlwide_gross_income': 3359.0},
#  {'country': 'Portugal',
#   'original_title': 'A Vingança de Uma Mulher',
#   'year': 2012,
#   'genre': 'Biography',
#   'avg_vote': 6.1,
#   'votes': 214,
#   'worlwide_gross_income': 3361.0},
#  {'country': 'Japan',
#   'original_title': 'Tenshi',
#   'year': 2005,
#   'genre': 'Fantasy',
#   'avg_vote': 6.2,
#   'votes': 144,
#   'worlwide_gross_income': 3365.0},
#  {'country': 'USA',
#   'original_title': 'Prince Valiant',
#   'year': 1954,
#   'genre': 'Action',
#   'avg_vote': 6.2,
#   'votes': 2363,
#   'worlwide_gross_income': 3373.0},
#  {'country': 'Japan',
#   'original_title': 'Koi no mon',
#   'year': 2004,
#   'genre': 'Romance',
#   'avg_vote': 6.8,
#   'votes': 496,
#   'worlwide_gross_income': 3374.0},
#  {'country': 'India',
#   'original_title': "Karingunnam 6's",
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 5.5,
#   'votes': 333,
#   'worlwide_gross_income': 3375.0},
#  {'country': 'Colombia',
#   'original_title': 'Porfirio',
#   'year': 2011,
#   'genre': 'Comedy',
#   'avg_vote': 6.4,
#   'votes': 259,
#   'worlwide_gross_income': 3376.0},
#  {'country': 'Argentina',
#   'original_title': 'Próxima Salida',
#   'year': 2004,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'votes': 142,
#   'worlwide_gross_income': 3380.0},
#  {'country': 'Brazil',
#   'original_title': 'Educação Sentimental',
#   'year': 2013,
#   'genre': 'Drama',
#   'avg_vote': 6.1,
#   'votes': 131,
#   'worlwide_gross_income': 3381.0},
#  {'country': 'USA',
#   'original_title': 'Rottentail',
#   'year': 2018,
#   'genre': 'Comedy',
#   'avg_vote': 3.5,
#   'votes': 150,
#   'worlwide_gross_income': 3383.0},
#  {'country': 'Japan',
#   'original_title': 'Tamala 2010: A Punk Cat in Space',
#   'year': 2002,
#   'genre': 'Animation',
#   'avg_vote': 6.5,
#   'votes': 476,
#   'worlwide_gross_income': 3386.0},
#  {'country': 'Switzerland',
#   'original_title': 'Mario',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 7.4,
#   'votes': 3042,
#   'worlwide_gross_income': 3394.0},
#  {'country': 'USA',
#   'original_title': 'The Happy Poet',
#   'year': 2010,
#   'genre': 'Comedy',
#   'avg_vote': 6.1,
#   'votes': 236,
#   'worlwide_gross_income': 3400.0},
#  {'country': 'India',
#   'original_title': 'Amazon Obhijaan',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 4.7,
#   'votes': 1076,
#   'worlwide_gross_income': 3403.0},
#  {'country': 'Panama',
#   'original_title': 'Más que hermanos',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 7.9,
#   'votes': 1213,
#   'worlwide_gross_income': 3410.0},
#  {'country': 'India',
#   'original_title': 'Peranbu',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 9.0,
#   'votes': 11752,
#   'worlwide_gross_income': 3417.0},
#  {'country': 'USA',
#   'original_title': 'The Mark of Zorro',
#   'year': 1940,
#   'genre': 'Action',
#   'avg_vote': 7.5,
#   'votes': 9067,
#   'worlwide_gross_income': 3424.0},
#  {'country': 'USA',
#   'original_title': 'Mahogany Sunrise',
#   'year': 2014,
#   'genre': 'Crime',
#   'avg_vote': 7.8,
#   'votes': 508,
#   'worlwide_gross_income': 3432.0},
#  {'country': 'USA',
#   'original_title': 'Scenic Route',
#   'year': 2013,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'votes': 10191,
#   'worlwide_gross_income': 3434.0},
#  {'country': 'India',
#   'original_title': 'Mental Madhilo',
#   'year': 2017,
#   'genre': 'Comedy',
#   'avg_vote': 7.4,
#   'votes': 466,
#   'worlwide_gross_income': 3435.0},
#  {'country': 'Argentina',
#   'original_title': 'Glue',
#   'year': 2006,
#   'genre': 'Drama',
#   'avg_vote': 6.4,
#   'votes': 1454,
#   'worlwide_gross_income': 3439.0},
#  {'country': 'USA',
#   'original_title': 'Jesse James',
#   'year': 1939,
#   'genre': 'Biography',
#   'avg_vote': 7.0,
#   'votes': 3887,
#   'worlwide_gross_income': 3444.0},
#  {'country': 'Canada',
#   'original_title': 'Clifton Hill',
#   'year': 2019,
#   'genre': 'Drama',
#   'avg_vote': 5.7,
#   'votes': 825,
#   'worlwide_gross_income': 3449.0},
#  {'country': 'USA',
#   'original_title': 'Aftermath',
#   'year': 2013,
#   'genre': 'Crime',
#   'avg_vote': 5.1,
#   'votes': 316,
#   'worlwide_gross_income': 3451.0},
#  {'country': 'USA',
#   'original_title': 'Short Eyes',
#   'year': 1977,
#   'genre': 'Drama',
#   'avg_vote': 7.0,
#   'votes': 1074,
#   'worlwide_gross_income': 3456.0},
#  {'country': 'South Africa',
#   'original_title': 'Bunny Chow: Know Thyself',
#   'year': 2006,
#   'genre': 'Comedy',
#   'avg_vote': 4.8,
#   'votes': 139,
#   'worlwide_gross_income': 3458.0},
#  {'country': 'Georgia',
#   'original_title': 'Quchis dgeebi',
#   'year': 2010,
#   'genre': 'Drama',
#   'avg_vote': 7.7,
#   'votes': 1097,
#   'worlwide_gross_income': 3463.0},
#  {'country': 'Indonesia',
#   'original_title': 'Kebun Binatang',
#   'year': 2012,
#   'genre': 'Drama',
#   'avg_vote': 6.2,
#   'votes': 273,
#   'worlwide_gross_income': 3471.0},
#  {'country': 'UK',
#   'original_title': 'Strangeways Here We Come',
#   'year': 2018,
#   'genre': 'Comedy',
#   'avg_vote': 4.5,
#   'votes': 125,
#   'worlwide_gross_income': 3473.0},
#  {'country': 'USA',
#   'original_title': 'Death of a Ghost Hunter',
#   'year': 2007,
#   'genre': 'Horror',
#   'avg_vote': 4.5,
#   'votes': 1939,
#   'worlwide_gross_income': 3490.0},
#  {'country': 'USA',
#   'original_title': 'Blood and Bone',
#   'year': 2009,
#   'genre': 'Action',
#   'avg_vote': 6.7,
#   'votes': 30815,
#   'worlwide_gross_income': 3492.0},
#  {'country': 'USA',
#   'original_title': 'Locker 13',
#   'year': 2014,
#   'genre': 'Thriller',
#   'avg_vote': 4.8,
#   'votes': 290,
#   'worlwide_gross_income': 3496.0},
#  {'country': 'Estonia',
#   'original_title': 'Teesklejad',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 5.6,
#   'votes': 385,
#   'worlwide_gross_income': 3509.0},
#  {'country': 'USA',
#   'original_title': "When the Party's Over",
#   'year': 1992,
#   'genre': 'Comedy',
#   'avg_vote': 4.9,
#   'votes': 936,
#   'worlwide_gross_income': 3514.0},
#  {'country': 'UK',
#   'original_title': 'The Roads Not Taken',
#   'year': 2020,
#   'genre': 'Drama',
#   'avg_vote': 4.9,
#   'votes': 753,
#   'worlwide_gross_income': 3518.0},
#  {'country': 'France',
#   'original_title': 'Notre jour viendra',
#   'year': 2010,
#   'genre': 'Drama',
#   'avg_vote': 6.2,
#   'votes': 3736,
#   'worlwide_gross_income': 3528.0},
#  {'country': 'USA',
#   'original_title': 'Macao',
#   'year': 1952,
#   'genre': 'Adventure',
#   'avg_vote': 6.7,
#   'votes': 2741,
#   'worlwide_gross_income': 3530.0},
#  {'country': 'Netherlands',
#   'original_title': 'Steekspel',
#   'year': 2012,
#   'genre': 'Comedy',
#   'avg_vote': 6.1,
#   'votes': 1093,
#   'worlwide_gross_income': 3533.0},
#  {'country': 'Iran',
#   'original_title': 'Shabhaye Zayendeh-Rood',
#   'year': 1990,
#   'genre': 'Drama',
#   'avg_vote': 6.6,
#   'votes': 233,
#   'worlwide_gross_income': 3536.0},
#  {'country': 'Turkey',
#   'original_title': 'Kümes',
#   'year': 2015,
#   'genre': 'Drama',
#   'avg_vote': 6.0,
#   'votes': 287,
#   'worlwide_gross_income': 3541.0},
#  {'country': 'Turkey',
#   'original_title': 'Genco',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 4.4,
#   'votes': 124,
#   'worlwide_gross_income': 3541.0},
#  {'country': 'India',
#   'original_title': 'Jada',
#   'year': 2019,
#   'genre': 'Drama',
#   'avg_vote': 5.6,
#   'votes': 111,
#   'worlwide_gross_income': 3542.0},
#  {'country': 'Brazil',
#   'original_title': 'Antônia',
#   'year': 2006,
#   'genre': 'Drama',
#   'avg_vote': 6.4,
#   'votes': 390,
#   'worlwide_gross_income': 3550.0},
#  {'country': 'USA',
#   'original_title': 'Fourplay',
#   'year': 2018,
#   'genre': 'Comedy',
#   'avg_vote': 4.6,
#   'votes': 135,
#   'worlwide_gross_income': 3550.0},
#  {'country': 'Turkey',
#   'original_title': 'Devir',
#   'year': 2013,
#   'genre': 'Drama',
#   'avg_vote': 6.0,
#   'votes': 177,
#   'worlwide_gross_income': 3555.0},
#  {'country': 'USA',
#   'original_title': 'The Last Film Festival',
#   'year': 2016,
#   'genre': 'Comedy',
#   'avg_vote': 4.0,
#   'votes': 272,
#   'worlwide_gross_income': 3558.0},
#  {'country': 'Sweden',
#   'original_title': 'Pojkarna',
#   'year': 2015,
#   'genre': 'Crime',
#   'avg_vote': 6.1,
#   'votes': 1039,
#   'worlwide_gross_income': 3561.0},
#  {'country': 'Poland',
#   'original_title': 'Wilkolak',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 6.0,
#   'votes': 949,
#   'worlwide_gross_income': 3564.0},
#  {'country': 'USA',
#   'original_title': "I'm Reed Fish",
#   'year': 2006,
#   'genre': 'Comedy',
#   'avg_vote': 5.7,
#   'votes': 4184,
#   'worlwide_gross_income': 3567.0},
#  {'country': 'USA',
#   'original_title': 'Happy Here and Now',
#   'year': 2002,
#   'genre': 'Drama',
#   'avg_vote': 5.0,
#   'votes': 307,
#   'worlwide_gross_income': 3574.0},
#  {'country': 'USA',
#   'original_title': 'Hide Your Smiling Faces',
#   'year': 2013,
#   'genre': 'Drama',
#   'avg_vote': 6.0,
#   'votes': 1595,
#   'worlwide_gross_income': 3576.0},
#  {'country': 'Germany',
#   'original_title': 'Hirngespinster',
#   'year': 2014,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'votes': 160,
#   'worlwide_gross_income': 3577.0},
#  {'country': 'UK',
#   'original_title': 'Hyena',
#   'year': 2014,
#   'genre': 'Crime',
#   'avg_vote': 6.1,
#   'votes': 2772,
#   'worlwide_gross_income': 3586.0},
#  {'country': 'UK',
#   'original_title': 'Cuckoo',
#   'year': 2009,
#   'genre': 'Drama',
#   'avg_vote': 3.7,
#   'votes': 116,
#   'worlwide_gross_income': 3587.0},
#  {'country': 'Austria',
#   'original_title': 'Struggle',
#   'year': 2003,
#   'genre': 'Drama',
#   'avg_vote': 5.7,
#   'votes': 152,
#   'worlwide_gross_income': 3590.0},
#  {'country': 'France',
#   'original_title': "Jeannette, l'enfance de Jeanne d'Arc",
#   'year': 2017,
#   'genre': 'History',
#   'avg_vote': 5.7,
#   'votes': 819,
#   'worlwide_gross_income': 3592.0},
#  {'country': 'USA',
#   'original_title': 'It Stains the Sands Red',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 5.5,
#   'votes': 4276,
#   'worlwide_gross_income': 3599.0},
#  {'country': 'India',
#   'original_title': 'Naa Nuvve',
#   'year': 2018,
#   'genre': 'Romance',
#   'avg_vote': 4.2,
#   'votes': 136,
#   'worlwide_gross_income': 3606.0},
#  {'country': 'India',
#   'original_title': 'Theevandi',
#   'year': 2018,
#   'genre': 'Comedy',
#   'avg_vote': 6.6,
#   'votes': 1184,
#   'worlwide_gross_income': 3614.0},
#  {'country': 'Romania',
#   'original_title': 'Aniversarea',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 6.8,
#   'votes': 110,
#   'worlwide_gross_income': 3616.0},
#  {'country': 'UK',
#   'original_title': 'Moon Dogs',
#   'year': 2016,
#   'genre': 'Comedy',
#   'avg_vote': 6.6,
#   'votes': 165,
#   'worlwide_gross_income': 3616.0},
#  {'country': 'France',
#   'original_title': "Vincent n'a pas d'écailles",
#   'year': 2014,
#   'genre': 'Comedy',
#   'avg_vote': 6.2,
#   'votes': 677,
#   'worlwide_gross_income': 3623.0},
#  {'country': 'Chile',
#   'original_title': 'La Telenovela Errante',
#   'year': 2017,
#   'genre': 'Comedy',
#   'avg_vote': 6.6,
#   'votes': 260,
#   'worlwide_gross_income': 3624.0},
#  {'country': 'India',
#   'original_title': 'Abhiyude Katha Anuvinteyum',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'votes': 548,
#   'worlwide_gross_income': 3631.0},
#  {'country': 'UK',
#   'original_title': 'The Last Minute',
#   'year': 2001,
#   'genre': 'Drama',
#   'avg_vote': 5.7,
#   'votes': 826,
#   'worlwide_gross_income': 3639.0},
#  {'country': 'Argentina',
#   'original_title': 'Respira: Transgenesis',
#   'year': 2019,
#   'genre': 'Thriller',
#   'avg_vote': 7.2,
#   'votes': 344,
#   'worlwide_gross_income': 3640.0},
#  {'country': 'USA',
#   'original_title': 'Bird of Prey',
#   'year': 1995,
#   'genre': 'Crime',
#   'avg_vote': 4.8,
#   'votes': 180,
#   'worlwide_gross_income': 3652.0},
#  {'country': 'Germany',
#   'original_title': 'Die Mitte der Welt',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 7.2,
#   'votes': 4658,
#   'worlwide_gross_income': 3656.0},
#  {'country': 'Japan',
#   'original_title': 'Gimî hebun',
#   'year': 2005,
#   'genre': 'Thriller',
#   'avg_vote': 5.7,
#   'votes': 288,
#   'worlwide_gross_income': 3661.0},
#  {'country': 'Mexico',
#   'original_title': 'Espacio interior',
#   'year': 2012,
#   'genre': 'Drama',
#   'avg_vote': 6.6,
#   'votes': 238,
#   'worlwide_gross_income': 3664.0},
#  {'country': 'Hungary',
#   'original_title': 'Örök tél',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 7.4,
#   'votes': 1187,
#   'worlwide_gross_income': 3671.0},
#  {'country': 'China',
#   'original_title': 'Ji quan bu ning',
#   'year': 2006,
#   'genre': 'Comedy',
#   'avg_vote': 6.2,
#   'votes': 164,
#   'worlwide_gross_income': 3671.0},
#  {'country': 'Argentina',
#   'original_title': 'Marilyn',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 6.6,
#   'votes': 259,
#   'worlwide_gross_income': 3676.0},
#  {'country': 'USA',
#   'original_title': 'Suits',
#   'year': 1999,
#   'genre': 'Comedy',
#   'avg_vote': 4.1,
#   'votes': 158,
#   'worlwide_gross_income': 3676.0},
#  {'country': 'Ireland',
#   'original_title': 'The Front Line',
#   'year': 2006,
#   'genre': 'Action',
#   'avg_vote': 6.5,
#   'votes': 962,
#   'worlwide_gross_income': 3681.0},
#  {'country': 'USA',
#   'original_title': 'Catch Me If You Can',
#   'year': 1989,
#   'genre': 'Action',
#   'avg_vote': 6.1,
#   'votes': 543,
#   'worlwide_gross_income': 3686.0},
#  {'country': 'Hong Kong',
#   'original_title': 'Gong hei bat poh',
#   'year': 2019,
#   'genre': 'Comedy',
#   'avg_vote': 5.3,
#   'votes': 193,
#   'worlwide_gross_income': 3692.0},
#  {'country': 'Denmark',
#   'original_title': 'De forbandede år',
#   'year': 2020,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'votes': 487,
#   'worlwide_gross_income': 3693.0},
#  {'country': 'Argentina',
#   'original_title': 'UPA! Una película argentina',
#   'year': 2007,
#   'genre': 'Comedy',
#   'avg_vote': 6.2,
#   'votes': 126,
#   'worlwide_gross_income': 3695.0},
#  {'country': 'Venezuela',
#   'original_title': 'La familia',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 6.7,
#   'votes': 388,
#   'worlwide_gross_income': 3696.0},
#  {'country': 'USA',
#   'original_title': 'Collaborator',
#   'year': 2011,
#   'genre': 'Comedy',
#   'avg_vote': 5.9,
#   'votes': 783,
#   'worlwide_gross_income': 3696.0},
#  {'country': 'Argentina',
#   'original_title': 'Claudia',
#   'year': 2019,
#   'genre': 'Comedy',
#   'avg_vote': 5.1,
#   'votes': 104,
#   'worlwide_gross_income': 3697.0},
#  {'country': 'France',
#   'original_title': 'La fiancée de Dracula',
#   'year': 2002,
#   'genre': 'Horror',
#   'avg_vote': 4.9,
#   'votes': 453,
#   'worlwide_gross_income': 3697.0},
#  {'country': 'USA',
#   'original_title': 'The Men Next Door',
#   'year': 2012,
#   'genre': 'Comedy',
#   'avg_vote': 5.6,
#   'votes': 710,
#   'worlwide_gross_income': 3699.0},
#  {'country': 'Netherlands',
#   'original_title': 'Der Stand der Dinge',
#   'year': 1982,
#   'genre': 'Drama',
#   'avg_vote': 7.0,
#   'votes': 2823,
#   'worlwide_gross_income': 3700.0},
#  {'country': 'France',
#   'original_title': 'Si tu voyais son coeur',
#   'year': 2017,
#   'genre': 'Crime',
#   'avg_vote': 4.8,
#   'votes': 340,
#   'worlwide_gross_income': 3700.0},
#  {'country': 'USA',
#   'original_title': 'The Helix... Loaded',
#   'year': 2005,
#   'genre': 'Action',
#   'avg_vote': 2.1,
#   'votes': 565,
#   'worlwide_gross_income': 3700.0},
#  ...]

# %%
filtered_votes_csv = "votes_filtered(votes vs rating).csv"

filtered_votes_df = pd.read_csv(filtered_votes_csv)
filtered_votes_df
# Out:
#        country    original_title  year    genre  avg_vote  votes  \
# 0          USA       The Heiress  1949    Drama       8.1  13301
# 1      Germany            Inbred  2011   Comedy       5.2   4536
# 2       Sweden   ABBA: The Movie  1977   Comedy       6.5   2963
# 3           UK  My Days of Mercy  2017    Drama       6.4   2754
# 4          USA          400 Days  2015  Mystery       4.4  10018
# ...        ...               ...   ...      ...       ...    ...
# 14401    India            Premam  2015   Comedy       8.3  16224
# 14402    India     Gopala Gopala  2015   Comedy       7.3   3456
# 14403    India            Temper  2015   Action       7.4   5600
# 14404    India      Chandramukhi  2005   Action       7.1   4947
# 14405    India           Thegidi  2014    Crime       7.7   2295
#
#        worlwide_gross_income
# 0                       16.0
# 1                       24.0
# 2                       38.0
# 3                       51.0
# 4                       58.0
# ...                      ...
# 14401            600000000.0
# 14402            660100000.0
# 14403            740300000.0
# 14404            750000000.0
# 14405             76000000.0
#
# [14406 rows x 7 columns]

# %%
filtered_votes_df.to_dict('records')
# Out:
# [{'country': 'USA',
#   'original_title': 'The Heiress',
#   'year': 1949,
#   'genre': 'Drama',
#   'avg_vote': 8.1,
#   'votes': 13301,
#   'worlwide_gross_income': 16.0},
#  {'country': 'Germany',
#   'original_title': 'Inbred',
#   'year': 2011,
#   'genre': 'Comedy',
#   'avg_vote': 5.2,
#   'votes': 4536,
#   'worlwide_gross_income': 24.0},
#  {'country': 'Sweden',
#   'original_title': 'ABBA: The Movie',
#   'year': 1977,
#   'genre': 'Comedy',
#   'avg_vote': 6.5,
#   'votes': 2963,
#   'worlwide_gross_income': 38.0},
#  {'country': 'UK',
#   'original_title': 'My Days of Mercy',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 6.4,
#   'votes': 2754,
#   'worlwide_gross_income': 51.0},
#  {'country': 'USA',
#   'original_title': '400 Days',
#   'year': 2015,
#   'genre': 'Mystery',
#   'avg_vote': 4.4,
#   'votes': 10018,
#   'worlwide_gross_income': 58.0},
#  {'country': 'Lithuania',
#   'original_title': 'Aurora',
#   'year': 2012,
#   'genre': 'Romance',
#   'avg_vote': 6.0,
#   'votes': 2502,
#   'worlwide_gross_income': 91.0},
#  {'country': 'USA',
#   'original_title': 'The Objective',
#   'year': 2008,
#   'genre': 'Horror',
#   'avg_vote': 5.5,
#   'votes': 7744,
#   'worlwide_gross_income': 95.0},
#  {'country': 'USA',
#   'original_title': 'Some Guy Who Kills People',
#   'year': 2011,
#   'genre': 'Comedy',
#   'avg_vote': 6.4,
#   'votes': 5607,
#   'worlwide_gross_income': 113.0},
#  {'country': 'UK',
#   'original_title': 'Darling',
#   'year': 1965,
#   'genre': 'Drama',
#   'avg_vote': 7.1,
#   'votes': 5876,
#   'worlwide_gross_income': 137.0},
#  {'country': 'France',
#   'original_title': 'Pauline à la plage',
#   'year': 1983,
#   'genre': 'Comedy',
#   'avg_vote': 7.4,
#   'votes': 6644,
#   'worlwide_gross_income': 159.0},
#  {'country': 'USA',
#   'original_title': 'All That Heaven Allows',
#   'year': 1955,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'votes': 12957,
#   'worlwide_gross_income': 170.0},
#  {'country': 'UK',
#   'original_title': 'Red White & Blue',
#   'year': 2010,
#   'genre': 'Drama',
#   'avg_vote': 6.4,
#   'votes': 5444,
#   'worlwide_gross_income': 177.0},
#  {'country': 'UK',
#   'original_title': 'Outcast',
#   'year': 2010,
#   'genre': 'Horror',
#   'avg_vote': 5.3,
#   'votes': 2314,
#   'worlwide_gross_income': 179.0},
#  {'country': 'Federal Republic of Yugoslavia',
#   'original_title': 'Lepa sela lepo gore',
#   'year': 1996,
#   'genre': 'Comedy',
#   'avg_vote': 8.7,
#   'votes': 14304,
#   'worlwide_gross_income': 211.0},
#  {'country': 'India',
#   'original_title': 'Sardaar Gabbar Singh',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 4.8,
#   'votes': 2195,
#   'worlwide_gross_income': 218.0},
#  {'country': 'India',
#   'original_title': 'Sarrainodu',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 6.4,
#   'votes': 4022,
#   'worlwide_gross_income': 239.0},
#  {'country': 'USA',
#   'original_title': 'Creature from the Black Lagoon',
#   'year': 1954,
#   'genre': 'Horror',
#   'avg_vote': 7.0,
#   'votes': 25643,
#   'worlwide_gross_income': 275.0},
#  {'country': 'Japan',
#   'original_title': 'Anchiporuno',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'votes': 2598,
#   'worlwide_gross_income': 294.0},
#  {'country': 'USA',
#   'original_title': 'Blood Car',
#   'year': 2007,
#   'genre': 'Comedy',
#   'avg_vote': 5.3,
#   'votes': 2384,
#   'worlwide_gross_income': 297.0},
#  {'country': 'USA',
#   'original_title': 'Trojan War',
#   'year': 1997,
#   'genre': 'Comedy',
#   'avg_vote': 5.7,
#   'votes': 5636,
#   'worlwide_gross_income': 309.0},
#  {'country': 'UK',
#   'original_title': '100 Streets',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 5.7,
#   'votes': 3645,
#   'worlwide_gross_income': 309.0},
#  {'country': 'UK',
#   'original_title': 'Saturday Night and Sunday Morning',
#   'year': 1960,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'votes': 7520,
#   'worlwide_gross_income': 370.0},
#  {'country': 'UK',
#   'original_title': 'Chitty Chitty Bang Bang',
#   'year': 1968,
#   'genre': 'Adventure',
#   'avg_vote': 6.9,
#   'votes': 40116,
#   'worlwide_gross_income': 398.0},
#  {'country': 'USA',
#   'original_title': 'The Wolf Man',
#   'year': 1941,
#   'genre': 'Horror',
#   'avg_vote': 7.3,
#   'votes': 23071,
#   'worlwide_gross_income': 420.0},
#  {'country': 'Canada',
#   'original_title': 'The Dark Hours',
#   'year': 2005,
#   'genre': 'Horror',
#   'avg_vote': 6.0,
#   'votes': 5212,
#   'worlwide_gross_income': 423.0},
#  {'country': 'UK',
#   'original_title': 'My Name Is Lenny',
#   'year': 2017,
#   'genre': 'Biography',
#   'avg_vote': 6.2,
#   'votes': 2467,
#   'worlwide_gross_income': 435.0},
#  {'country': 'France',
#   'original_title': 'La nuit américaine',
#   'year': 1973,
#   'genre': 'Comedy',
#   'avg_vote': 8.0,
#   'votes': 19790,
#   'worlwide_gross_income': 509.0},
#  {'country': 'France',
#   'original_title': 'Baisers volés',
#   'year': 1968,
#   'genre': 'Comedy',
#   'avg_vote': 7.7,
#   'votes': 11806,
#   'worlwide_gross_income': 509.0},
#  {'country': 'France',
#   'original_title': 'Domicile conjugal',
#   'year': 1970,
#   'genre': 'Comedy',
#   'avg_vote': 7.5,
#   'votes': 8003,
#   'worlwide_gross_income': 509.0},
#  {'country': 'France',
#   'original_title': 'Les deux Anglaises et le continent',
#   'year': 1971,
#   'genre': 'Romance',
#   'avg_vote': 7.4,
#   'votes': 4721,
#   'worlwide_gross_income': 509.0},
#  {'country': 'France',
#   'original_title': "La femme d'à côté",
#   'year': 1981,
#   'genre': 'Drama',
#   'avg_vote': 7.3,
#   'votes': 6993,
#   'worlwide_gross_income': 509.0},
#  {'country': 'France',
#   'original_title': 'Vivement dimanche!',
#   'year': 1983,
#   'genre': 'Comedy',
#   'avg_vote': 7.3,
#   'votes': 5613,
#   'worlwide_gross_income': 509.0},
#  {'country': 'UK',
#   'original_title': 'Fahrenheit 451',
#   'year': 1966,
#   'genre': 'Drama',
#   'avg_vote': 7.2,
#   'votes': 40524,
#   'worlwide_gross_income': 509.0},
#  {'country': 'France',
#   'original_title': "L'amour en fuite",
#   'year': 1979,
#   'genre': 'Comedy',
#   'avg_vote': 7.1,
#   'votes': 5927,
#   'worlwide_gross_income': 509.0},
#  {'country': 'France',
#   'original_title': 'La chambre verte',
#   'year': 1978,
#   'genre': 'Drama',
#   'avg_vote': 7.0,
#   'votes': 2615,
#   'worlwide_gross_income': 509.0},
#  {'country': 'USA',
#   'original_title': '68 Kill',
#   'year': 2017,
#   'genre': 'Comedy',
#   'avg_vote': 6.0,
#   'votes': 4694,
#   'worlwide_gross_income': 522.0},
#  {'country': 'USA',
#   'original_title': 'Meeting Evil',
#   'year': 2012,
#   'genre': 'Crime',
#   'avg_vote': 5.3,
#   'votes': 11599,
#   'worlwide_gross_income': 525.0},
#  {'country': 'USA',
#   'original_title': 'Higher Power',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 4.8,
#   'votes': 2138,
#   'worlwide_gross_income': 528.0},
#  {'country': 'Romania',
#   'original_title': 'Occident',
#   'year': 2002,
#   'genre': 'Comedy',
#   'avg_vote': 7.6,
#   'votes': 2072,
#   'worlwide_gross_income': 533.0},
#  {'country': 'India',
#   'original_title': 'Brahmotsavam',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 4.3,
#   'votes': 2820,
#   'worlwide_gross_income': 541.0},
#  {'country': 'Canada',
#   'original_title': 'The Pit',
#   'year': 1981,
#   'genre': 'Horror',
#   'avg_vote': 5.8,
#   'votes': 2231,
#   'worlwide_gross_income': 560.0},
#  {'country': 'USA',
#   'original_title': '12 Angry Men',
#   'year': 1957,
#   'genre': 'Crime',
#   'avg_vote': 8.9,
#   'votes': 668473,
#   'worlwide_gross_income': 576.0},
#  {'country': 'Canada',
#   'original_title': 'Shake Hands with the Devil',
#   'year': 2007,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'votes': 3202,
#   'worlwide_gross_income': 594.0},
#  {'country': 'Canada',
#   'original_title': 'Edwin Boyd',
#   'year': 2011,
#   'genre': 'Crime',
#   'avg_vote': 6.2,
#   'votes': 4124,
#   'worlwide_gross_income': 625.0},
#  {'country': 'India',
#   'original_title': 'Natsamrat',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 9.1,
#   'votes': 4880,
#   'worlwide_gross_income': 633.0},
#  {'country': 'USA',
#   'original_title': 'Nature Calls',
#   'year': 2012,
#   'genre': 'Comedy',
#   'avg_vote': 4.0,
#   'votes': 2197,
#   'worlwide_gross_income': 646.0},
#  {'country': 'USA',
#   'original_title': 'Gentlemen Prefer Blondes',
#   'year': 1953,
#   'genre': 'Comedy',
#   'avg_vote': 7.2,
#   'votes': 30759,
#   'worlwide_gross_income': 648.0},
#  {'country': 'USA',
#   'original_title': 'King Kong',
#   'year': 1933,
#   'genre': 'Adventure',
#   'avg_vote': 7.9,
#   'votes': 77507,
#   'worlwide_gross_income': 651.0},
#  {'country': 'Japan',
#   'original_title': 'Yuke yuke nidome no shojo',
#   'year': 1969,
#   'genre': 'Drama',
#   'avg_vote': 7.5,
#   'votes': 2309,
#   'worlwide_gross_income': 659.0},
#  {'country': 'Japan',
#   'original_title': 'Appurushido: Ekusu makina',
#   'year': 2007,
#   'genre': 'Animation',
#   'avg_vote': 7.1,
#   'votes': 9283,
#   'worlwide_gross_income': 662.0},
#  {'country': 'USA',
#   'original_title': 'Syrup',
#   'year': 2013,
#   'genre': 'Comedy',
#   'avg_vote': 5.7,
#   'votes': 10565,
#   'worlwide_gross_income': 663.0},
#  {'country': 'India',
#   'original_title': 'I Am Kalam',
#   'year': 2010,
#   'genre': 'Comedy',
#   'avg_vote': 8.0,
#   'votes': 3511,
#   'worlwide_gross_income': 691.0},
#  {'country': 'UK',
#   'original_title': 'The Haunting',
#   'year': 1963,
#   'genre': 'Horror',
#   'avg_vote': 7.5,
#   'votes': 33652,
#   'worlwide_gross_income': 742.0},
#  {'country': 'USA',
#   'original_title': 'Wings',
#   'year': 1927,
#   'genre': 'Drama',
#   'avg_vote': 7.5,
#   'votes': 11139,
#   'worlwide_gross_income': 746.0},
#  {'country': 'USA',
#   'original_title': 'Flakes',
#   'year': 2007,
#   'genre': 'Comedy',
#   'avg_vote': 6.0,
#   'votes': 3331,
#   'worlwide_gross_income': 778.0},
#  {'country': 'UK',
#   'original_title': 'This Sporting Life',
#   'year': 1963,
#   'genre': 'Drama',
#   'avg_vote': 7.7,
#   'votes': 5752,
#   'worlwide_gross_income': 813.0},
#  {'country': 'Hong Kong',
#   'original_title': 'PTU',
#   'year': 2003,
#   'genre': 'Crime',
#   'avg_vote': 6.9,
#   'votes': 3924,
#   'worlwide_gross_income': 849.0},
#  {'country': 'USA',
#   'original_title': 'Letter from an Unknown Woman',
#   'year': 1948,
#   'genre': 'Drama',
#   'avg_vote': 8.0,
#   'votes': 10756,
#   'worlwide_gross_income': 852.0},
#  {'country': 'France',
#   'original_title': 'La ronde',
#   'year': 1950,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'votes': 4733,
#   'worlwide_gross_income': 852.0},
#  {'country': 'USA',
#   'original_title': 'The Underground Comedy Movie',
#   'year': 1999,
#   'genre': 'Comedy',
#   'avg_vote': 2.2,
#   'votes': 2424,
#   'worlwide_gross_income': 856.0},
#  {'country': 'Australia',
#   'original_title': 'Acolytes',
#   'year': 2008,
#   'genre': 'Crime',
#   'avg_vote': 5.5,
#   'votes': 2207,
#   'worlwide_gross_income': 860.0},
#  {'country': 'UK',
#   'original_title': 'Jubilee',
#   'year': 1978,
#   'genre': 'Comedy',
#   'avg_vote': 6.1,
#   'votes': 2821,
#   'worlwide_gross_income': 923.0},
#  {'country': 'Denmark',
#   'original_title': 'Epidemic',
#   'year': 1987,
#   'genre': 'Drama',
#   'avg_vote': 6.2,
#   'votes': 4798,
#   'worlwide_gross_income': 938.0},
#  {'country': 'India',
#   'original_title': 'Pranchiyettan and the Saint',
#   'year': 2010,
#   'genre': 'Comedy',
#   'avg_vote': 8.3,
#   'votes': 4584,
#   'worlwide_gross_income': 957.0},
#  {'country': 'Italy',
#   'original_title': 'Giù la testa',
#   'year': 1971,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'votes': 29314,
#   'worlwide_gross_income': 980.0},
#  {'country': 'India',
#   'original_title': 'Nannaku Prematho',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 7.6,
#   'votes': 8672,
#   'worlwide_gross_income': 1003.0},
#  {'country': 'Denmark',
#   'original_title': 'Forbrydelsens element',
#   'year': 1984,
#   'genre': 'Crime',
#   'avg_vote': 6.8,
#   'votes': 9066,
#   'worlwide_gross_income': 1003.0},
#  {'country': 'USA',
#   'original_title': 'How to Rob a Bank (and 10 Tips to Actually Get Away with It)',
#   'year': 2007,
#   'genre': 'Comedy',
#   'avg_vote': 6.1,
#   'votes': 5874,
#   'worlwide_gross_income': 1006.0},
#  {'country': 'Japan',
#   'original_title': 'Gin-iro no kami no Agito',
#   'year': 2006,
#   'genre': 'Animation',
#   'avg_vote': 6.5,
#   'votes': 4424,
#   'worlwide_gross_income': 1052.0},
#  {'country': 'Japan',
#   'original_title': 'Jûbê ninpûchô',
#   'year': 1993,
#   'genre': 'Animation',
#   'avg_vote': 7.9,
#   'votes': 33843,
#   'worlwide_gross_income': 1073.0},
#  {'country': 'France',
#   'original_title': 'Le salaire de la peur',
#   'year': 1953,
#   'genre': 'Adventure',
#   'avg_vote': 8.1,
#   'votes': 52952,
#   'worlwide_gross_income': 1098.0},
#  {'country': 'Hungary',
#   'original_title': 'Csak szex és más semmi',
#   'year': 2005,
#   'genre': 'Comedy',
#   'avg_vote': 6.3,
#   'votes': 2938,
#   'worlwide_gross_income': 1112.0},
#  {'country': 'Japan',
#   'original_title': 'Bara no sôretsu',
#   'year': 1969,
#   'genre': 'Drama',
#   'avg_vote': 7.9,
#   'votes': 4430,
#   'worlwide_gross_income': 1114.0},
#  {'country': 'USA',
#   'original_title': 'Seconds Apart',
#   'year': 2011,
#   'genre': 'Horror',
#   'avg_vote': 5.7,
#   'votes': 5986,
#   'worlwide_gross_income': 1137.0},
#  {'country': 'USA',
#   'original_title': 'Jack & Diane',
#   'year': 2012,
#   'genre': 'Drama',
#   'avg_vote': 4.4,
#   'votes': 2661,
#   'worlwide_gross_income': 1142.0},
#  {'country': 'India',
#   'original_title': 'Rann',
#   'year': 2010,
#   'genre': 'Drama',
#   'avg_vote': 6.9,
#   'votes': 2341,
#   'worlwide_gross_income': 1146.0},
#  {'country': 'Taiwan',
#   'original_title': 'Kong bu fen zi',
#   'year': 1986,
#   'genre': 'Crime',
#   'avg_vote': 7.8,
#   'votes': 2589,
#   'worlwide_gross_income': 1185.0},
#  {'country': 'USA',
#   'original_title': 'The Maltese Falcon',
#   'year': 1941,
#   'genre': 'Film-Noir',
#   'avg_vote': 8.0,
#   'votes': 146815,
#   'worlwide_gross_income': 1255.0},
#  {'country': 'India',
#   'original_title': 'Hind Ka Napak Ko Jawab',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 6.7,
#   'votes': 3977,
#   'worlwide_gross_income': 1314.0},
#  {'country': 'USA',
#   'original_title': 'The Dog Problem',
#   'year': 2006,
#   'genre': 'Comedy',
#   'avg_vote': 6.3,
#   'votes': 3213,
#   'worlwide_gross_income': 1344.0},
#  {'country': 'Australia',
#   'original_title': 'The Last Wave',
#   'year': 1977,
#   'genre': 'Drama',
#   'avg_vote': 7.0,
#   'votes': 8419,
#   'worlwide_gross_income': 1382.0},
#  {'country': 'UK',
#   'original_title': 'Love, Honour and Obey',
#   'year': 2000,
#   'genre': 'Comedy',
#   'avg_vote': 6.5,
#   'votes': 5029,
#   'worlwide_gross_income': 1400.0},
#  {'country': 'India',
#   'original_title': 'Kalyug',
#   'year': 2005,
#   'genre': 'Action',
#   'avg_vote': 6.5,
#   'votes': 2402,
#   'worlwide_gross_income': 1435.0},
#  {'country': 'USA',
#   'original_title': 'The Woman',
#   'year': 2011,
#   'genre': 'Drama',
#   'avg_vote': 6.0,
#   'votes': 21521,
#   'worlwide_gross_income': 1449.0},
#  {'country': 'Mexico',
#   'original_title': 'The Young One',
#   'year': 1960,
#   'genre': 'Drama',
#   'avg_vote': 7.4,
#   'votes': 2439,
#   'worlwide_gross_income': 1463.0},
#  {'country': 'USA',
#   'original_title': 'The Package',
#   'year': 2013,
#   'genre': 'Action',
#   'avg_vote': 5.0,
#   'votes': 3841,
#   'worlwide_gross_income': 1469.0},
#  {'country': 'UK',
#   'original_title': 'Cul-de-sac',
#   'year': 1966,
#   'genre': 'Comedy',
#   'avg_vote': 7.1,
#   'votes': 11520,
#   'worlwide_gross_income': 1500.0},
#  {'country': 'Canada',
#   'original_title': 'Blackwoods',
#   'year': 2001,
#   'genre': 'Drama',
#   'avg_vote': 2.8,
#   'votes': 2091,
#   'worlwide_gross_income': 1500.0},
#  {'country': 'USA',
#   'original_title': 'The Fly',
#   'year': 1958,
#   'genre': 'Drama',
#   'avg_vote': 7.1,
#   'votes': 20329,
#   'worlwide_gross_income': 1501.0},
#  {'country': 'UK',
#   'original_title': 'Bad Day for the Cut',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 6.5,
#   'votes': 5480,
#   'worlwide_gross_income': 1510.0},
#  {'country': 'South Korea',
#   'original_title': 'Baramui paiteo',
#   'year': 2004,
#   'genre': 'Action',
#   'avg_vote': 7.0,
#   'votes': 3724,
#   'worlwide_gross_income': 1518.0},
#  {'country': 'Australia',
#   'original_title': 'The Tunnel',
#   'year': 2011,
#   'genre': 'Horror',
#   'avg_vote': 5.9,
#   'votes': 19103,
#   'worlwide_gross_income': 1532.0},
#  {'country': 'Serbia',
#   'original_title': 'Srpski film',
#   'year': 2010,
#   'genre': 'Horror',
#   'avg_vote': 5.1,
#   'votes': 55866,
#   'worlwide_gross_income': 1541.0},
#  {'country': 'UK',
#   'original_title': 'Once Upon a Time in London',
#   'year': 2019,
#   'genre': 'Crime',
#   'avg_vote': 5.9,
#   'votes': 4587,
#   'worlwide_gross_income': 1567.0},
#  {'country': 'France',
#   'original_title': 'La Pointe-Courte',
#   'year': 1955,
#   'genre': 'Drama',
#   'avg_vote': 7.1,
#   'votes': 2598,
#   'worlwide_gross_income': 1596.0},
#  {'country': 'USA',
#   'original_title': '42nd Street',
#   'year': 1933,
#   'genre': 'Comedy',
#   'avg_vote': 7.4,
#   'votes': 10490,
#   'worlwide_gross_income': 1600.0},
#  {'country': 'Denmark',
#   'original_title': 'Pusher',
#   'year': 1996,
#   'genre': 'Crime',
#   'avg_vote': 7.4,
#   'votes': 33653,
#   'worlwide_gross_income': 1605.0},
#  {'country': 'Denmark',
#   'original_title': 'Pusher III',
#   'year': 2005,
#   'genre': 'Crime',
#   'avg_vote': 7.3,
#   'votes': 13364,
#   'worlwide_gross_income': 1605.0},
#  {'country': 'USA',
#   'original_title': 'The Task',
#   'year': 2011,
#   'genre': 'Horror',
#   'avg_vote': 4.3,
#   'votes': 3249,
#   'worlwide_gross_income': 1619.0},
#  {'country': 'USA',
#   'original_title': 'Frankenstein',
#   'year': 1931,
#   'genre': 'Drama',
#   'avg_vote': 7.8,
#   'votes': 63315,
#   'worlwide_gross_income': 1626.0},
#  {'country': 'Soviet Union',
#   'original_title': 'Ivan Groznyy. Skaz vtoroy: Boyarskiy zagovor',
#   'year': 1958,
#   'genre': 'Biography',
#   'avg_vote': 7.9,
#   'votes': 6567,
#   'worlwide_gross_income': 1655.0},
#  {'country': 'UK',
#   'original_title': 'I Want You',
#   'year': 1998,
#   'genre': 'Crime',
#   'avg_vote': 6.1,
#   'votes': 2806,
#   'worlwide_gross_income': 1672.0},
#  {'country': 'Italy',
#   'original_title': 'Fellini - Satyricon',
#   'year': 1969,
#   'genre': 'Drama',
#   'avg_vote': 6.9,
#   'votes': 14570,
#   'worlwide_gross_income': 1729.0},
#  {'country': 'UK',
#   'original_title': 'Late Night Shopping',
#   'year': 2001,
#   'genre': 'Comedy',
#   'avg_vote': 6.9,
#   'votes': 2069,
#   'worlwide_gross_income': 1743.0},
#  {'country': 'USA',
#   'original_title': 'Detention of the Dead',
#   'year': 2012,
#   'genre': 'Action',
#   'avg_vote': 4.5,
#   'votes': 2507,
#   'worlwide_gross_income': 1777.0},
#  {'country': 'USA',
#   'original_title': 'The Canyon',
#   'year': 2009,
#   'genre': 'Thriller',
#   'avg_vote': 5.9,
#   'votes': 4046,
#   'worlwide_gross_income': 1785.0},
#  {'country': 'UK',
#   'original_title': 'Detour',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 6.2,
#   'votes': 5216,
#   'worlwide_gross_income': 1788.0},
#  {'country': 'USA',
#   'original_title': 'Abominable',
#   'year': 2006,
#   'genre': 'Horror',
#   'avg_vote': 5.1,
#   'votes': 4073,
#   'worlwide_gross_income': 1810.0},
#  {'country': 'Federal Republic of Yugoslavia',
#   'original_title': 'Munje!',
#   'year': 2001,
#   'genre': 'Comedy',
#   'avg_vote': 7.9,
#   'votes': 6507,
#   'worlwide_gross_income': 1833.0},
#  {'country': 'Spain',
#   'original_title': 'Viridiana',
#   'year': 1961,
#   'genre': 'Drama',
#   'avg_vote': 8.2,
#   'votes': 21674,
#   'worlwide_gross_income': 1843.0},
#  {'country': 'Mexico',
#   'original_title': 'El ángel exterminador',
#   'year': 1962,
#   'genre': 'Drama',
#   'avg_vote': 8.1,
#   'votes': 28767,
#   'worlwide_gross_income': 1843.0},
#  {'country': 'Spain',
#   'original_title': 'Hogar',
#   'year': 2020,
#   'genre': 'Adventure',
#   'avg_vote': 6.3,
#   'votes': 11175,
#   'worlwide_gross_income': 1845.0},
#  {'country': 'Sweden',
#   'original_title': 'Såsom i en spegel',
#   'year': 1961,
#   'genre': 'Drama',
#   'avg_vote': 8.1,
#   'votes': 22179,
#   'worlwide_gross_income': 1848.0},
#  {'country': 'France',
#   'original_title': "Le testament d'Orphée ou ne me demandez pas pourquoi",
#   'year': 1960,
#   'genre': 'Biography',
#   'avg_vote': 7.3,
#   'votes': 2832,
#   'worlwide_gross_income': 1850.0},
#  {'country': 'USA',
#   'original_title': 'An Affair to Remember',
#   'year': 1957,
#   'genre': 'Drama',
#   'avg_vote': 7.5,
#   'votes': 27148,
#   'worlwide_gross_income': 1854.0},
#  {'country': 'USA',
#   'original_title': 'Invasion of the Body Snatchers',
#   'year': 1956,
#   'genre': 'Drama',
#   'avg_vote': 7.7,
#   'votes': 43866,
#   'worlwide_gross_income': 1861.0},
#  {'country': 'USA',
#   'original_title': 'The Outsider',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 6.3,
#   'votes': 19548,
#   'worlwide_gross_income': 1869.0},
#  {'country': 'France',
#   'original_title': 'Cléo de 5 à 7',
#   'year': 1962,
#   'genre': 'Comedy',
#   'avg_vote': 7.9,
#   'votes': 15797,
#   'worlwide_gross_income': 1886.0},
#  {'country': 'Russia',
#   'original_title': 'Voyna',
#   'year': 2002,
#   'genre': 'Action',
#   'avg_vote': 7.7,
#   'votes': 3934,
#   'worlwide_gross_income': 1887.0},
#  {'country': 'Mexico',
#   'original_title': 'Fando y Lis',
#   'year': 1968,
#   'genre': 'Adventure',
#   'avg_vote': 7.0,
#   'votes': 4873,
#   'worlwide_gross_income': 1897.0},
#  {'country': 'UK',
#   'original_title': 'Dead of Night',
#   'year': 1945,
#   'genre': 'Drama',
#   'avg_vote': 7.7,
#   'votes': 10520,
#   'worlwide_gross_income': 1919.0},
#  {'country': 'USA',
#   'original_title': 'Shuttle',
#   'year': 2008,
#   'genre': 'Crime',
#   'avg_vote': 5.7,
#   'votes': 5325,
#   'worlwide_gross_income': 1925.0},
#  {'country': 'USA',
#   'original_title': 'Best Man Down',
#   'year': 2012,
#   'genre': 'Comedy',
#   'avg_vote': 6.4,
#   'votes': 8985,
#   'worlwide_gross_income': 1938.0},
#  {'country': 'India',
#   'original_title': 'Visaaranai',
#   'year': 2015,
#   'genre': 'Crime',
#   'avg_vote': 8.5,
#   'votes': 6711,
#   'worlwide_gross_income': 1943.0},
#  {'country': 'Israel',
#   'original_title': 'Kirot',
#   'year': 2009,
#   'genre': 'Action',
#   'avg_vote': 5.7,
#   'votes': 2391,
#   'worlwide_gross_income': 1948.0},
#  {'country': 'Germany',
#   'original_title': 'Errors of the Human Body',
#   'year': 2012,
#   'genre': 'Drama',
#   'avg_vote': 5.3,
#   'votes': 2167,
#   'worlwide_gross_income': 1984.0},
#  {'country': 'Australia',
#   'original_title': 'The Horseman',
#   'year': 2008,
#   'genre': 'Crime',
#   'avg_vote': 6.5,
#   'votes': 4726,
#   'worlwide_gross_income': 1993.0},
#  {'country': 'USA',
#   'original_title': 'The Night of the Hunter',
#   'year': 1955,
#   'genre': 'Crime',
#   'avg_vote': 8.0,
#   'votes': 80215,
#   'worlwide_gross_income': 2001.0},
#  {'country': 'USA',
#   'original_title': 'Beautiful Joe',
#   'year': 2000,
#   'genre': 'Comedy',
#   'avg_vote': 5.8,
#   'votes': 2164,
#   'worlwide_gross_income': 2009.0},
#  {'country': 'USA',
#   'original_title': 'The Bad and the Beautiful',
#   'year': 1952,
#   'genre': 'Drama',
#   'avg_vote': 7.8,
#   'votes': 12941,
#   'worlwide_gross_income': 2025.0},
#  {'country': 'Soviet Union',
#   'original_title': 'Neokonchennaya pyesa dlya mekhanicheskogo pianino',
#   'year': 1977,
#   'genre': 'Drama',
#   'avg_vote': 7.9,
#   'votes': 2938,
#   'worlwide_gross_income': 2047.0},
#  {'country': 'France',
#   'original_title': 'Le plaisir',
#   'year': 1952,
#   'genre': 'Comedy',
#   'avg_vote': 7.7,
#   'votes': 4160,
#   'worlwide_gross_income': 2097.0},
#  {'country': 'India',
#   'original_title': 'Ustad Hotel',
#   'year': 2012,
#   'genre': 'Comedy',
#   'avg_vote': 8.3,
#   'votes': 11118,
#   'worlwide_gross_income': 2178.0},
#  {'country': 'USA',
#   'original_title': 'Road to Paloma',
#   'year': 2014,
#   'genre': 'Drama',
#   'avg_vote': 6.1,
#   'votes': 4595,
#   'worlwide_gross_income': 2191.0},
#  {'country': 'France',
#   'original_title': 'Le vieux fusil',
#   'year': 1975,
#   'genre': 'Drama',
#   'avg_vote': 7.7,
#   'votes': 3598,
#   'worlwide_gross_income': 2225.0},
#  {'country': 'Soviet Union',
#   'original_title': 'Aleksandr Nevskiy',
#   'year': 1938,
#   'genre': 'Action',
#   'avg_vote': 7.6,
#   'votes': 10279,
#   'worlwide_gross_income': 2226.0},
#  {'country': 'Italy',
#   'original_title': 'Mamma Roma',
#   'year': 1962,
#   'genre': 'Drama',
#   'avg_vote': 7.8,
#   'votes': 8077,
#   'worlwide_gross_income': 2248.0},
#  {'country': 'Italy',
#   'original_title': 'Edipo Re',
#   'year': 1967,
#   'genre': 'Drama',
#   'avg_vote': 7.4,
#   'votes': 4996,
#   'worlwide_gross_income': 2248.0},
#  {'country': 'Italy',
#   'original_title': 'Uccellacci e uccellini',
#   'year': 1966,
#   'genre': 'Comedy',
#   'avg_vote': 7.3,
#   'votes': 4127,
#   'worlwide_gross_income': 2248.0},
#  {'country': 'USA',
#   'original_title': 'The Pool Boys',
#   'year': 2009,
#   'genre': 'Comedy',
#   'avg_vote': 4.7,
#   'votes': 2401,
#   'worlwide_gross_income': 2269.0},
#  {'country': 'UK',
#   'original_title': 'The Hide',
#   'year': 2008,
#   'genre': 'Thriller',
#   'avg_vote': 7.0,
#   'votes': 2145,
#   'worlwide_gross_income': 2313.0},
#  {'country': 'UK',
#   'original_title': 'Casino Royale',
#   'year': 1967,
#   'genre': 'Comedy',
#   'avg_vote': 5.2,
#   'votes': 26559,
#   'worlwide_gross_income': 2324.0},
#  {'country': 'USA',
#   'original_title': 'The Killing Jar',
#   'year': 2010,
#   'genre': 'Crime',
#   'avg_vote': 5.8,
#   'votes': 2500,
#   'worlwide_gross_income': 2339.0},
#  {'country': 'France',
#   'original_title': 'Une femme douce',
#   'year': 1969,
#   'genre': 'Drama',
#   'avg_vote': 7.5,
#   'votes': 2298,
#   'worlwide_gross_income': 2356.0},
#  {'country': 'Yugoslavia',
#   'original_title': 'Oberst Redl',
#   'year': 1985,
#   'genre': 'Biography',
#   'avg_vote': 7.6,
#   'votes': 2640,
#   'worlwide_gross_income': 2357.0},
#  {'country': 'USA',
#   'original_title': 'Scissors',
#   'year': 1991,
#   'genre': 'Horror',
#   'avg_vote': 5.2,
#   'votes': 2404,
#   'worlwide_gross_income': 2368.0},
#  {'country': 'USA',
#   'original_title': 'The Devil Is a Woman',
#   'year': 1935,
#   'genre': 'Comedy',
#   'avg_vote': 7.0,
#   'votes': 2942,
#   'worlwide_gross_income': 2375.0},
#  {'country': 'India',
#   'original_title': 'Aandavan Kattalai',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 8.1,
#   'votes': 2124,
#   'worlwide_gross_income': 2476.0},
#  {'country': 'UK',
#   'original_title': 'Gun Shy',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 4.1,
#   'votes': 2555,
#   'worlwide_gross_income': 2480.0},
#  {'country': 'USA',
#   'original_title': 'Roberta',
#   'year': 1935,
#   'genre': 'Comedy',
#   'avg_vote': 7.1,
#   'votes': 2860,
#   'worlwide_gross_income': 2493.0},
#  {'country': 'USA',
#   'original_title': 'Cassadaga',
#   'year': 2011,
#   'genre': 'Horror',
#   'avg_vote': 5.3,
#   'votes': 3289,
#   'worlwide_gross_income': 2544.0},
#  {'country': 'Canada',
#   'original_title': 'Ginger Snaps',
#   'year': 2000,
#   'genre': 'Drama',
#   'avg_vote': 6.8,
#   'votes': 40897,
#   'worlwide_gross_income': 2554.0},
#  {'country': 'USA',
#   'original_title': 'The Incredible Shrinking Man',
#   'year': 1957,
#   'genre': 'Horror',
#   'avg_vote': 7.6,
#   'votes': 15583,
#   'worlwide_gross_income': 2580.0},
#  {'country': 'USA',
#   'original_title': 'Take Me',
#   'year': 2017,
#   'genre': 'Comedy',
#   'avg_vote': 6.1,
#   'votes': 4108,
#   'worlwide_gross_income': 2583.0},
#  {'country': 'UK',
#   'original_title': 'Hammer of the Gods',
#   'year': 2013,
#   'genre': 'Action',
#   'avg_vote': 4.5,
#   'votes': 7709,
#   'worlwide_gross_income': 2590.0},
#  {'country': 'Japan',
#   'original_title': 'Dead or Alive: Final',
#   'year': 2002,
#   'genre': 'Action',
#   'avg_vote': 5.7,
#   'votes': 2306,
#   'worlwide_gross_income': 2591.0},
#  {'country': 'USA',
#   'original_title': 'Catfight',
#   'year': 2016,
#   'genre': 'Comedy',
#   'avg_vote': 5.8,
#   'votes': 5188,
#   'worlwide_gross_income': 2666.0},
#  {'country': 'Denmark',
#   'original_title': 'Holiday',
#   'year': 2018,
#   'genre': 'Crime',
#   'avg_vote': 5.7,
#   'votes': 3224,
#   'worlwide_gross_income': 2678.0},
#  {'country': 'USA',
#   'original_title': 'The Boys in the Band',
#   'year': 1970,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'votes': 4030,
#   'worlwide_gross_income': 2695.0},
#  {'country': 'UK',
#   'original_title': 'Mum & Dad',
#   'year': 2008,
#   'genre': 'Horror',
#   'avg_vote': 5.9,
#   'votes': 5707,
#   'worlwide_gross_income': 2698.0},
#  {'country': 'Hungary',
#   'original_title': 'Eichmann',
#   'year': 2007,
#   'genre': 'Biography',
#   'avg_vote': 5.9,
#   'votes': 2987,
#   'worlwide_gross_income': 2706.0},
#  {'country': 'USA',
#   'original_title': 'Johnny Got His Gun',
#   'year': 1971,
#   'genre': 'Drama',
#   'avg_vote': 7.9,
#   'votes': 15306,
#   'worlwide_gross_income': 2735.0},
#  {'country': 'India',
#   'original_title': 'Abrahaminte Santhathikal',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 7.5,
#   'votes': 4545,
#   'worlwide_gross_income': 2735.0},
#  {'country': 'Hong Kong',
#   'original_title': 'Beiqíng chéngshì',
#   'year': 1989,
#   'genre': 'Drama',
#   'avg_vote': 7.9,
#   'votes': 4058,
#   'worlwide_gross_income': 2737.0},
#  {'country': 'USA',
#   'original_title': 'Excision',
#   'year': 2012,
#   'genre': 'Comedy',
#   'avg_vote': 6.1,
#   'votes': 20368,
#   'worlwide_gross_income': 2757.0},
#  {'country': 'Canada',
#   'original_title': 'Zoom',
#   'year': 2015,
#   'genre': 'Animation',
#   'avg_vote': 6.1,
#   'votes': 2580,
#   'worlwide_gross_income': 2784.0},
#  {'country': 'Belgium',
#   'original_title': 'De Premier',
#   'year': 2016,
#   'genre': 'Thriller',
#   'avg_vote': 6.2,
#   'votes': 2325,
#   'worlwide_gross_income': 2793.0},
#  {'country': 'USA',
#   'original_title': 'Lower Learning',
#   'year': 2008,
#   'genre': 'Comedy',
#   'avg_vote': 4.0,
#   'votes': 2427,
#   'worlwide_gross_income': 2804.0},
#  {'country': 'France',
#   'original_title': 'Boudu sauvé des eaux',
#   'year': 1932,
#   'genre': 'Comedy',
#   'avg_vote': 7.4,
#   'votes': 5046,
#   'worlwide_gross_income': 2805.0},
#  {'country': 'Italy',
#   'original_title': 'Caro diario',
#   'year': 1993,
#   'genre': 'Biography',
#   'avg_vote': 7.3,
#   'votes': 6931,
#   'worlwide_gross_income': 2856.0},
#  {'country': 'France',
#   'original_title': 'Cet obscur objet du désir',
#   'year': 1977,
#   'genre': 'Comedy',
#   'avg_vote': 7.9,
#   'votes': 20182,
#   'worlwide_gross_income': 2864.0},
#  {'country': 'West Germany',
#   'original_title': 'Fitzcarraldo',
#   'year': 1982,
#   'genre': 'Adventure',
#   'avg_vote': 8.1,
#   'votes': 30563,
#   'worlwide_gross_income': 2874.0},
#  {'country': 'West Germany',
#   'original_title': 'Stroszek',
#   'year': 1977,
#   'genre': 'Comedy',
#   'avg_vote': 7.9,
#   'votes': 12723,
#   'worlwide_gross_income': 2874.0},
#  {'country': 'West Germany',
#   'original_title': 'Jeder für sich und Gott gegen alle',
#   'year': 1974,
#   'genre': 'Biography',
#   'avg_vote': 7.8,
#   'votes': 16032,
#   'worlwide_gross_income': 2874.0},
#  {'country': 'West Germany',
#   'original_title': 'Nosferatu: Phantom der Nacht',
#   'year': 1979,
#   'genre': 'Drama',
#   'avg_vote': 7.5,
#   'votes': 31417,
#   'worlwide_gross_income': 2874.0},
#  {'country': 'West Germany',
#   'original_title': 'Herz aus Glas',
#   'year': 1976,
#   'genre': 'Drama',
#   'avg_vote': 7.1,
#   'votes': 5320,
#   'worlwide_gross_income': 2874.0},
#  {'country': 'France',
#   'original_title': 'La voie lactée',
#   'year': 1969,
#   'genre': 'Drama',
#   'avg_vote': 7.5,
#   'votes': 6728,
#   'worlwide_gross_income': 2893.0},
#  {'country': 'USA',
#   'original_title': 'The Parallax View',
#   'year': 1974,
#   'genre': 'Drama',
#   'avg_vote': 7.1,
#   'votes': 14892,
#   'worlwide_gross_income': 2942.0},
#  {'country': 'USA',
#   'original_title': 'Money',
#   'year': 2016,
#   'genre': 'Crime',
#   'avg_vote': 5.5,
#   'votes': 2498,
#   'worlwide_gross_income': 3041.0},
#  {'country': 'UK',
#   'original_title': 'Shopping',
#   'year': 1994,
#   'genre': 'Action',
#   'avg_vote': 5.4,
#   'votes': 2498,
#   'worlwide_gross_income': 3061.0},
#  {'country': 'India',
#   'original_title': 'Dum Laga Ke Haisha',
#   'year': 2015,
#   'genre': 'Comedy',
#   'avg_vote': 7.5,
#   'votes': 17508,
#   'worlwide_gross_income': 3064.0},
#  {'country': 'USA',
#   'original_title': 'Spiral',
#   'year': 2007,
#   'genre': 'Drama',
#   'avg_vote': 6.4,
#   'votes': 3543,
#   'worlwide_gross_income': 3072.0},
#  {'country': 'USA',
#   'original_title': 'Oxygen',
#   'year': 1999,
#   'genre': 'Crime',
#   'avg_vote': 6.1,
#   'votes': 4259,
#   'worlwide_gross_income': 3088.0},
#  {'country': 'USA',
#   'original_title': 'Thursday',
#   'year': 1998,
#   'genre': 'Action',
#   'avg_vote': 7.2,
#   'votes': 16895,
#   'worlwide_gross_income': 3121.0},
#  {'country': 'UK',
#   'original_title': 'Moulin Rouge',
#   'year': 1952,
#   'genre': 'Biography',
#   'avg_vote': 7.1,
#   'votes': 4833,
#   'worlwide_gross_income': 3188.0},
#  {'country': 'France',
#   'original_title': 'Le roi danse',
#   'year': 2000,
#   'genre': 'Drama',
#   'avg_vote': 6.9,
#   'votes': 2112,
#   'worlwide_gross_income': 3203.0},
#  {'country': 'France',
#   'original_title': 'Lacombe Lucien',
#   'year': 1974,
#   'genre': 'Drama',
#   'avg_vote': 7.7,
#   'votes': 6368,
#   'worlwide_gross_income': 3228.0},
#  {'country': 'USA',
#   'original_title': 'As Cool as I Am',
#   'year': 2013,
#   'genre': 'Comedy',
#   'avg_vote': 5.8,
#   'votes': 5076,
#   'worlwide_gross_income': 3234.0},
#  {'country': 'Hungary',
#   'original_title': 'Viharsarok',
#   'year': 2014,
#   'genre': 'Drama',
#   'avg_vote': 6.9,
#   'votes': 3393,
#   'worlwide_gross_income': 3241.0},
#  {'country': 'Belgium',
#   'original_title': 'Calvaire',
#   'year': 2004,
#   'genre': 'Horror',
#   'avg_vote': 6.2,
#   'votes': 11427,
#   'worlwide_gross_income': 3260.0},
#  {'country': 'USA',
#   'original_title': 'Burning Palms',
#   'year': 2010,
#   'genre': 'Comedy',
#   'avg_vote': 5.3,
#   'votes': 2641,
#   'worlwide_gross_income': 3271.0},
#  {'country': 'USA',
#   'original_title': 'The Scarlet Empress',
#   'year': 1934,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'votes': 5688,
#   'worlwide_gross_income': 3299.0},
#  {'country': 'UK',
#   'original_title': 'Overlord',
#   'year': 1975,
#   'genre': 'Drama',
#   'avg_vote': 7.1,
#   'votes': 2564,
#   'worlwide_gross_income': 3333.0},
#  {'country': 'Singapore',
#   'original_title': 'Bad Match',
#   'year': 2017,
#   'genre': 'Thriller',
#   'avg_vote': 5.5,
#   'votes': 3593,
#   'worlwide_gross_income': 3351.0},
#  {'country': 'USA',
#   'original_title': 'Prince Valiant',
#   'year': 1954,
#   'genre': 'Action',
#   'avg_vote': 6.2,
#   'votes': 2363,
#   'worlwide_gross_income': 3373.0},
#  {'country': 'Switzerland',
#   'original_title': 'Mario',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 7.4,
#   'votes': 3042,
#   'worlwide_gross_income': 3394.0},
#  {'country': 'India',
#   'original_title': 'Peranbu',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 9.0,
#   'votes': 11752,
#   'worlwide_gross_income': 3417.0},
#  {'country': 'USA',
#   'original_title': 'The Mark of Zorro',
#   'year': 1940,
#   'genre': 'Action',
#   'avg_vote': 7.5,
#   'votes': 9067,
#   'worlwide_gross_income': 3424.0},
#  {'country': 'USA',
#   'original_title': 'Scenic Route',
#   'year': 2013,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'votes': 10191,
#   'worlwide_gross_income': 3434.0},
#  {'country': 'USA',
#   'original_title': 'Jesse James',
#   'year': 1939,
#   'genre': 'Biography',
#   'avg_vote': 7.0,
#   'votes': 3887,
#   'worlwide_gross_income': 3444.0},
#  {'country': 'USA',
#   'original_title': 'Blood and Bone',
#   'year': 2009,
#   'genre': 'Action',
#   'avg_vote': 6.7,
#   'votes': 30815,
#   'worlwide_gross_income': 3492.0},
#  {'country': 'France',
#   'original_title': 'Notre jour viendra',
#   'year': 2010,
#   'genre': 'Drama',
#   'avg_vote': 6.2,
#   'votes': 3736,
#   'worlwide_gross_income': 3528.0},
#  {'country': 'USA',
#   'original_title': 'Macao',
#   'year': 1952,
#   'genre': 'Adventure',
#   'avg_vote': 6.7,
#   'votes': 2741,
#   'worlwide_gross_income': 3530.0},
#  {'country': 'USA',
#   'original_title': "I'm Reed Fish",
#   'year': 2006,
#   'genre': 'Comedy',
#   'avg_vote': 5.7,
#   'votes': 4184,
#   'worlwide_gross_income': 3567.0},
#  {'country': 'UK',
#   'original_title': 'Hyena',
#   'year': 2014,
#   'genre': 'Crime',
#   'avg_vote': 6.1,
#   'votes': 2772,
#   'worlwide_gross_income': 3586.0},
#  {'country': 'USA',
#   'original_title': 'It Stains the Sands Red',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 5.5,
#   'votes': 4276,
#   'worlwide_gross_income': 3599.0},
#  {'country': 'Germany',
#   'original_title': 'Die Mitte der Welt',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 7.2,
#   'votes': 4658,
#   'worlwide_gross_income': 3656.0},
#  {'country': 'Netherlands',
#   'original_title': 'Der Stand der Dinge',
#   'year': 1982,
#   'genre': 'Drama',
#   'avg_vote': 7.0,
#   'votes': 2823,
#   'worlwide_gross_income': 3700.0},
#  {'country': 'USA',
#   'original_title': 'Dumbo',
#   'year': 1941,
#   'genre': 'Animation',
#   'avg_vote': 7.2,
#   'votes': 116855,
#   'worlwide_gross_income': 3731.0},
#  {'country': 'UK',
#   'original_title': 'Fever Pitch',
#   'year': 1997,
#   'genre': 'Comedy',
#   'avg_vote': 6.7,
#   'votes': 10030,
#   'worlwide_gross_income': 3736.0},
#  {'country': 'USA',
#   'original_title': 'Nothing Sacred',
#   'year': 1937,
#   'genre': 'Comedy',
#   'avg_vote': 6.9,
#   'votes': 5841,
#   'worlwide_gross_income': 3765.0},
#  {'country': 'Denmark',
#   'original_title': 'De grønne slagtere',
#   'year': 2003,
#   'genre': 'Comedy',
#   'avg_vote': 7.3,
#   'votes': 19008,
#   'worlwide_gross_income': 3783.0},
#  {'country': 'Sweden',
#   'original_title': 'Ett hål i mitt hjärta',
#   'year': 2004,
#   'genre': 'Drama',
#   'avg_vote': 4.5,
#   'votes': 4652,
#   'worlwide_gross_income': 3784.0},
#  {'country': 'France',
#   'original_title': 'Trafic',
#   'year': 1971,
#   'genre': 'Comedy',
#   'avg_vote': 7.1,
#   'votes': 5690,
#   'worlwide_gross_income': 3800.0},
#  {'country': 'USA',
#   'original_title': 'The Man Who Killed Hitler and Then the Bigfoot',
#   'year': 2018,
#   'genre': 'Adventure',
#   'avg_vote': 5.7,
#   'votes': 9564,
#   'worlwide_gross_income': 3822.0},
#  {'country': 'UK',
#   'original_title': 'Await Further Instructions',
#   'year': 2018,
#   'genre': 'Horror',
#   'avg_vote': 4.8,
#   'votes': 6858,
#   'worlwide_gross_income': 3823.0},
#  {'country': 'USA',
#   'original_title': 'Crown Vic',
#   'year': 2019,
#   'genre': 'Action',
#   'avg_vote': 6.4,
#   'votes': 3025,
#   'worlwide_gross_income': 3868.0},
#  {'country': 'India',
#   'original_title': 'Kammatti Paadam',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 8.1,
#   'votes': 3535,
#   'worlwide_gross_income': 3891.0},
#  {'country': 'USA',
#   'original_title': 'The Night of the Iguana',
#   'year': 1964,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'votes': 10499,
#   'worlwide_gross_income': 3942.0},
#  {'country': 'West Germany',
#   'original_title': 'Der amerikanische Freund',
#   'year': 1977,
#   'genre': 'Crime',
#   'avg_vote': 7.4,
#   'votes': 13462,
#   'worlwide_gross_income': 3978.0},
#  {'country': 'USA',
#   'original_title': 'I Am Michael',
#   'year': 2015,
#   'genre': 'Biography',
#   'avg_vote': 5.6,
#   'votes': 4849,
#   'worlwide_gross_income': 3995.0},
#  {'country': 'Canada',
#   'original_title': 'Come and Find Me',
#   'year': 2016,
#   'genre': 'Thriller',
#   'avg_vote': 5.7,
#   'votes': 7835,
#   'worlwide_gross_income': 4052.0},
#  {'country': 'USA',
#   'original_title': 'Freaks',
#   'year': 1932,
#   'genre': 'Drama',
#   'avg_vote': 7.9,
#   'votes': 41173,
#   'worlwide_gross_income': 4072.0},
#  {'country': 'UK',
#   'original_title': 'Sebastiane',
#   'year': 1976,
#   'genre': 'Drama',
#   'avg_vote': 6.1,
#   'votes': 2475,
#   'worlwide_gross_income': 4091.0},
#  {'country': 'UK',
#   'original_title': 'Frenzy',
#   'year': 1972,
#   'genre': 'Thriller',
#   'avg_vote': 7.4,
#   'votes': 40353,
#   'worlwide_gross_income': 4121.0},
#  {'country': 'USA',
#   'original_title': 'The Miracle Worker',
#   'year': 1962,
#   'genre': 'Biography',
#   'avg_vote': 8.1,
#   'votes': 15609,
#   'worlwide_gross_income': 4139.0},
#  {'country': 'USA',
#   'original_title': 'Pawn',
#   'year': 2013,
#   'genre': 'Action',
#   'avg_vote': 5.7,
#   'votes': 6808,
#   'worlwide_gross_income': 4141.0},
#  {'country': 'USA',
#   'original_title': 'Bachelor Mother',
#   'year': 1939,
#   'genre': 'Comedy',
#   'avg_vote': 7.6,
#   'votes': 3566,
#   'worlwide_gross_income': 4149.0},
#  {'country': 'USA',
#   'original_title': 'Melvin Goes to Dinner',
#   'year': 2003,
#   'genre': 'Comedy',
#   'avg_vote': 6.8,
#   'votes': 2616,
#   'worlwide_gross_income': 4168.0},
#  {'country': 'USA',
#   'original_title': 'Maximum Ride',
#   'year': 2016,
#   'genre': 'Action',
#   'avg_vote': 3.6,
#   'votes': 4119,
#   'worlwide_gross_income': 4218.0},
#  {'country': 'Italy',
#   'original_title': 'Francesco, giullare di Dio',
#   'year': 1950,
#   'genre': 'Biography',
#   'avg_vote': 7.4,
#   'votes': 3138,
#   'worlwide_gross_income': 4223.0},
#  {'country': 'USA',
#   'original_title': 'Reign of the Supermen',
#   'year': 2019,
#   'genre': 'Animation',
#   'avg_vote': 6.8,
#   'votes': 10615,
#   'worlwide_gross_income': 4223.0},
#  {'country': 'USA',
#   'original_title': 'The Basement',
#   'year': 2018,
#   'genre': 'Horror',
#   'avg_vote': 4.4,
#   'votes': 2431,
#   'worlwide_gross_income': 4286.0},
#  {'country': 'USA',
#   'original_title': 'The Man Who Laughs',
#   'year': 1928,
#   'genre': 'Drama',
#   'avg_vote': 7.7,
#   'votes': 5711,
#   'worlwide_gross_income': 4347.0},
#  {'country': 'USA',
#   'original_title': 'A Cool, Dry Place',
#   'year': 1998,
#   'genre': 'Drama',
#   'avg_vote': 6.2,
#   'votes': 2831,
#   'worlwide_gross_income': 4390.0},
#  {'country': 'USA',
#   'original_title': 'The Truth About Emanuel',
#   'year': 2013,
#   'genre': 'Drama',
#   'avg_vote': 6.0,
#   'votes': 8605,
#   'worlwide_gross_income': 4404.0},
#  {'country': 'Germany',
#   'original_title': 'Der blaue Engel',
#   'year': 1930,
#   'genre': 'Drama',
#   'avg_vote': 7.7,
#   'votes': 13311,
#   'worlwide_gross_income': 4410.0},
#  {'country': 'India',
#   'original_title': 'Agent Sai Srinivasa Athreya',
#   'year': 2019,
#   'genre': 'Action',
#   'avg_vote': 8.5,
#   'votes': 5585,
#   'worlwide_gross_income': 4454.0},
#  {'country': 'USA',
#   'original_title': 'Road House',
#   'year': 1948,
#   'genre': 'Action',
#   'avg_vote': 7.3,
#   'votes': 2293,
#   'worlwide_gross_income': 4467.0},
#  {'country': 'Spain',
#   'original_title': 'Atrocious',
#   'year': 2010,
#   'genre': 'Horror',
#   'avg_vote': 5.0,
#   'votes': 4735,
#   'worlwide_gross_income': 4472.0},
#  {'country': 'UK',
#   'original_title': 'Retreat',
#   'year': 2011,
#   'genre': 'Drama',
#   'avg_vote': 5.8,
#   'votes': 10914,
#   'worlwide_gross_income': 4498.0},
#  {'country': 'USA',
#   'original_title': 'Synchronicity',
#   'year': 2015,
#   'genre': 'Drama',
#   'avg_vote': 5.5,
#   'votes': 10085,
#   'worlwide_gross_income': 4505.0},
#  {'country': 'USA',
#   'original_title': 'Deliverance',
#   'year': 1972,
#   'genre': 'Adventure',
#   'avg_vote': 7.7,
#   'votes': 96769,
#   'worlwide_gross_income': 4534.0},
#  {'country': 'Mexico',
#   'original_title': 'Ahí va el diablo',
#   'year': 2012,
#   'genre': 'Horror',
#   'avg_vote': 5.6,
#   'votes': 3788,
#   'worlwide_gross_income': 4534.0},
#  {'country': 'UK',
#   'original_title': 'Blue Juice',
#   'year': 1995,
#   'genre': 'Comedy',
#   'avg_vote': 5.3,
#   'votes': 2491,
#   'worlwide_gross_income': 4535.0},
#  {'country': 'Iran',
#   'original_title': 'Khane-ye doust kodjast?',
#   'year': 1987,
#   'genre': 'Drama',
#   'avg_vote': 8.1,
#   'votes': 9947,
#   'worlwide_gross_income': 4546.0},
#  {'country': 'USA',
#   'original_title': 'All Is Bright',
#   'year': 2013,
#   'genre': 'Comedy',
#   'avg_vote': 5.6,
#   'votes': 5660,
#   'worlwide_gross_income': 4556.0},
#  {'country': 'UK',
#   'original_title': 'A Taste of Honey',
#   'year': 1961,
#   'genre': 'Drama',
#   'avg_vote': 7.5,
#   'votes': 4744,
#   'worlwide_gross_income': 4597.0},
#  {'country': 'USA',
#   'original_title': 'Johnny Guitar',
#   'year': 1954,
#   'genre': 'Drama',
#   'avg_vote': 7.7,
#   'votes': 15198,
#   'worlwide_gross_income': 4604.0},
#  {'country': 'UK',
#   'original_title': 'Lolita',
#   'year': 1962,
#   'genre': 'Crime',
#   'avg_vote': 7.6,
#   'votes': 90641,
#   'worlwide_gross_income': 4631.0},
#  {'country': 'India',
#   'original_title': 'Pudhu Pettai',
#   'year': 2006,
#   'genre': 'Action',
#   'avg_vote': 8.5,
#   'votes': 4161,
#   'worlwide_gross_income': 4652.0},
#  {'country': 'USA',
#   'original_title': 'The Long Dumb Road',
#   'year': 2018,
#   'genre': 'Comedy',
#   'avg_vote': 6.1,
#   'votes': 2339,
#   'worlwide_gross_income': 4667.0},
#  {'country': 'West Germany',
#   'original_title': 'Der Tiger von Eschnapur',
#   'year': 1959,
#   'genre': 'Adventure',
#   'avg_vote': 6.7,
#   'votes': 2302,
#   'worlwide_gross_income': 4673.0},
#  {'country': 'West Germany',
#   'original_title': 'Das indische Grabmal',
#   'year': 1959,
#   'genre': 'Adventure',
#   'avg_vote': 6.7,
#   'votes': 2109,
#   'worlwide_gross_income': 4673.0},
#  {'country': 'USA',
#   'original_title': 'Against the Sun',
#   'year': 2014,
#   'genre': 'Biography',
#   'avg_vote': 6.5,
#   'votes': 5200,
#   'worlwide_gross_income': 4698.0},
#  {'country': 'USA',
#   'original_title': 'Colorado Territory',
#   'year': 1949,
#   'genre': 'Western',
#   'avg_vote': 7.2,
#   'votes': 2287,
#   'worlwide_gross_income': 4755.0},
#  {'country': 'USA',
#   'original_title': 'Stretch',
#   'year': 2014,
#   'genre': 'Comedy',
#   'avg_vote': 6.5,
#   'votes': 28501,
#   'worlwide_gross_income': 4833.0},
#  {'country': 'USA',
#   'original_title': 'The Unknown',
#   'year': 1927,
#   'genre': 'Drama',
#   'avg_vote': 7.8,
#   'votes': 6992,
#   'worlwide_gross_income': 4841.0},
#  {'country': 'UK',
#   'original_title': 'The Dead',
#   'year': 2010,
#   'genre': 'Action',
#   'avg_vote': 5.7,
#   'votes': 8712,
#   'worlwide_gross_income': 4891.0},
#  {'country': 'USA',
#   'original_title': 'Wild Style',
#   'year': 1982,
#   'genre': 'Drama',
#   'avg_vote': 7.1,
#   'votes': 2328,
#   'worlwide_gross_income': 4948.0},
#  {'country': 'USA',
#   'original_title': 'Swing Time',
#   'year': 1936,
#   'genre': 'Comedy',
#   'avg_vote': 7.6,
#   'votes': 11998,
#   'worlwide_gross_income': 4961.0},
#  {'country': 'USA',
#   'original_title': 'Elizabeth Harvest',
#   'year': 2018,
#   'genre': 'Horror',
#   'avg_vote': 5.8,
#   'votes': 6228,
#   'worlwide_gross_income': 4973.0},
#  {'country': 'USA',
#   'original_title': "Hellzapoppin'",
#   'year': 1941,
#   'genre': 'Comedy',
#   'avg_vote': 7.5,
#   'votes': 2685,
#   'worlwide_gross_income': 4982.0},
#  {'country': 'India',
#   'original_title': 'Aadukalam',
#   'year': 2011,
#   'genre': 'Action',
#   'avg_vote': 8.1,
#   'votes': 4540,
#   'worlwide_gross_income': 4997.0},
#  {'country': 'Switzerland',
#   'original_title': 'Les choses de la vie',
#   'year': 1970,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'votes': 3787,
#   'worlwide_gross_income': 5063.0},
#  {'country': 'USA',
#   'original_title': 'The Left Handed Gun',
#   'year': 1958,
#   'genre': 'Western',
#   'avg_vote': 6.5,
#   'votes': 3743,
#   'worlwide_gross_income': 5066.0},
#  {'country': 'USA',
#   'original_title': 'My Dinner with Andre',
#   'year': 1981,
#   'genre': 'Biography',
#   'avg_vote': 7.8,
#   'votes': 17709,
#   'worlwide_gross_income': 5073.0},
#  {'country': 'USA',
#   'original_title': 'Tanner Hall',
#   'year': 2009,
#   'genre': 'Drama',
#   'avg_vote': 5.8,
#   'votes': 3299,
#   'worlwide_gross_income': 5073.0},
#  {'country': 'USA',
#   'original_title': 'Crimewave',
#   'year': 1985,
#   'genre': 'Comedy',
#   'avg_vote': 5.7,
#   'votes': 5036,
#   'worlwide_gross_income': 5101.0},
#  {'country': 'USA',
#   'original_title': 'Body at Brighton Rock',
#   'year': 2019,
#   'genre': 'Horror',
#   'avg_vote': 5.2,
#   'votes': 2272,
#   'worlwide_gross_income': 5123.0},
#  {'country': 'Denmark',
#   'original_title': 'Den eneste ene',
#   'year': 1999,
#   'genre': 'Comedy',
#   'avg_vote': 6.9,
#   'votes': 4197,
#   'worlwide_gross_income': 5129.0},
#  {'country': 'Sweden',
#   'original_title': 'Till glädje',
#   'year': 1950,
#   'genre': 'Drama',
#   'avg_vote': 7.2,
#   'votes': 2410,
#   'worlwide_gross_income': 5135.0},
#  {'country': 'India',
#   'original_title': 'Aakrosh',
#   'year': 2010,
#   'genre': 'Action',
#   'avg_vote': 7.0,
#   'votes': 3245,
#   'worlwide_gross_income': 5148.0},
#  {'country': 'USA',
#   'original_title': 'Home Room',
#   'year': 2002,
#   'genre': 'Crime',
#   'avg_vote': 7.2,
#   'votes': 3165,
#   'worlwide_gross_income': 5216.0},
#  {'country': 'USA',
#   'original_title': 'Deadline - U.S.A.',
#   'year': 1952,
#   'genre': 'Crime',
#   'avg_vote': 7.2,
#   'votes': 2998,
#   'worlwide_gross_income': 5228.0},
#  {'country': 'Indonesia',
#   'original_title': 'Killers',
#   'year': 2014,
#   'genre': 'Action',
#   'avg_vote': 6.4,
#   'votes': 4709,
#   'worlwide_gross_income': 5248.0},
#  {'country': 'USA',
#   'original_title': 'Paths of Glory',
#   'year': 1957,
#   'genre': 'Drama',
#   'avg_vote': 8.4,
#   'votes': 172671,
#   'worlwide_gross_income': 5252.0},
#  {'country': 'Japan',
#   'original_title': 'Sanshô dayû',
#   'year': 1954,
#   'genre': 'Drama',
#   'avg_vote': 8.4,
#   'votes': 14034,
#   'worlwide_gross_income': 5267.0},
#  {'country': 'South Korea',
#   'original_title': 'Maljukgeori janhoksa',
#   'year': 2004,
#   'genre': 'Action',
#   'avg_vote': 7.4,
#   'votes': 2401,
#   'worlwide_gross_income': 5271.0},
#  {'country': 'UK',
#   'original_title': 'When the Wind Blows',
#   'year': 1986,
#   'genre': 'Animation',
#   'avg_vote': 7.7,
#   'votes': 9633,
#   'worlwide_gross_income': 5274.0},
#  {'country': 'USA',
#   'original_title': 'Sunlight Jr.',
#   'year': 2013,
#   'genre': 'Drama',
#   'avg_vote': 5.6,
#   'votes': 2909,
#   'worlwide_gross_income': 5346.0},
#  {'country': 'USA',
#   'original_title': 'Dragonwyck',
#   'year': 1946,
#   'genre': 'Drama',
#   'avg_vote': 7.0,
#   'votes': 3653,
#   'worlwide_gross_income': 5434.0},
#  {'country': 'USA',
#   'original_title': 'The Man from Earth: Holocene',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 5.3,
#   'votes': 7670,
#   'worlwide_gross_income': 5472.0},
#  {'country': 'UK',
# ...
#   'worlwide_gross_income': 26055.0},
#  {'country': 'UK',
#   'original_title': 'Endgame',
#   'year': 2009,
#   'genre': 'Drama',
#   'avg_vote': 6.2,
#   'votes': 2608,
#   'worlwide_gross_income': 26260.0},
#  {'country': 'USA',
#   'original_title': 'Two Bits',
#   'year': 1995,
#   'genre': 'Drama',
#   'avg_vote': 6.2,
#   'votes': 3207,
#   'worlwide_gross_income': 26282.0},
#  {'country': 'Iran',
#   'original_title': 'Shirin',
#   'year': 2008,
#   'genre': 'Drama',
#   'avg_vote': 6.7,
#   'votes': 2216,
#   'worlwide_gross_income': 26302.0},
#  {'country': 'Germany',
#   'original_title': 'Romeos',
#   'year': 2011,
#   'genre': 'Drama',
#   'avg_vote': 7.0,
#   'votes': 3157,
#   'worlwide_gross_income': 26324.0},
#  {'country': 'Indonesia',
#   'original_title': 'Marlina si pembunuh dalam empat babak',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 7.0,
#   'votes': 2350,
#   'worlwide_gross_income': 26331.0},
#  {'country': 'Canada',
#   'original_title': 'First Light',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 5.5,
#   'votes': 2958,
#   'worlwide_gross_income': 26338.0},
#  {'country': 'USA',
#   'original_title': 'Clean, Shaven',
#   'year': 1993,
#   'genre': 'Crime',
#   'avg_vote': 7.1,
#   'votes': 5130,
#   'worlwide_gross_income': 26351.0},
#  {'country': 'UK',
#   'original_title': 'All the Little Animals',
#   'year': 1998,
#   'genre': 'Adventure',
#   'avg_vote': 6.9,
#   'votes': 2604,
#   'worlwide_gross_income': 26558.0},
#  {'country': 'Indonesia',
#   'original_title': 'Dead Mine',
#   'year': 2012,
#   'genre': 'Action',
#   'avg_vote': 4.5,
#   'votes': 2887,
#   'worlwide_gross_income': 26597.0},
#  {'country': 'USA',
#   'original_title': 'Arlen Faber',
#   'year': 2009,
#   'genre': 'Comedy',
#   'avg_vote': 6.4,
#   'votes': 6219,
#   'worlwide_gross_income': 26676.0},
#  {'country': 'Spain',
#   'original_title': 'Metroland',
#   'year': 1997,
#   'genre': 'Comedy',
#   'avg_vote': 6.4,
#   'votes': 3122,
#   'worlwide_gross_income': 26682.0},
#  {'country': 'France',
#   'original_title': 'Le diable probablement',
#   'year': 1977,
#   'genre': 'Drama',
#   'avg_vote': 7.3,
#   'votes': 3375,
#   'worlwide_gross_income': 26816.0},
#  {'country': 'India',
#   'original_title': 'Tholi Prema',
#   'year': 2018,
#   'genre': 'Romance',
#   'avg_vote': 7.3,
#   'votes': 2132,
#   'worlwide_gross_income': 26878.0},
#  {'country': 'USA',
#   'original_title': 'The Kid',
#   'year': 1921,
#   'genre': 'Comedy',
#   'avg_vote': 8.3,
#   'votes': 109038,
#   'worlwide_gross_income': 26916.0},
#  {'country': 'USA',
#   'original_title': 'The Gold Rush',
#   'year': 1925,
#   'genre': 'Adventure',
#   'avg_vote': 8.2,
#   'votes': 97480,
#   'worlwide_gross_income': 26916.0},
#  {'country': 'USA',
#   'original_title': 'The Circus',
#   'year': 1928,
#   'genre': 'Comedy',
#   'avg_vote': 8.1,
#   'votes': 27414,
#   'worlwide_gross_income': 26916.0},
#  {'country': 'USA',
#   'original_title': 'The Invisible Man',
#   'year': 1933,
#   'genre': 'Horror',
#   'avg_vote': 7.7,
#   'votes': 29291,
#   'worlwide_gross_income': 27105.0},
#  {'country': 'India',
#   'original_title': 'Kill Dil',
#   'year': 2014,
#   'genre': 'Action',
#   'avg_vote': 4.3,
#   'votes': 3796,
#   'worlwide_gross_income': 27256.0},
#  {'country': 'USA',
#   'original_title': 'Bad Johnson',
#   'year': 2014,
#   'genre': 'Comedy',
#   'avg_vote': 4.5,
#   'votes': 4785,
#   'worlwide_gross_income': 27650.0},
#  {'country': 'USA',
#   'original_title': 'In the Heat of the Night',
#   'year': 1967,
#   'genre': 'Crime',
#   'avg_vote': 7.9,
#   'votes': 65862,
#   'worlwide_gross_income': 27669.0},
#  {'country': 'Germany',
#   'original_title': 'Das Testament des Dr. Mabuse',
#   'year': 1933,
#   'genre': 'Crime',
#   'avg_vote': 8.0,
#   'votes': 11162,
#   'worlwide_gross_income': 27690.0},
#  {'country': 'Italy',
#   'original_title': 'Senso',
#   'year': 1954,
#   'genre': 'Drama',
#   'avg_vote': 7.5,
#   'votes': 5967,
#   'worlwide_gross_income': 27723.0},
#  {'country': 'Austria',
#   'original_title': 'The Dark',
#   'year': 2018,
#   'genre': 'Drama',
#   'avg_vote': 5.6,
#   'votes': 4170,
#   'worlwide_gross_income': 27738.0},
#  {'country': 'USA',
#   'original_title': 'Simon Killer',
#   'year': 2012,
#   'genre': 'Drama',
#   'avg_vote': 6.3,
#   'votes': 4112,
#   'worlwide_gross_income': 27740.0},
#  {'country': 'USA',
#   'original_title': 'Slipstream',
#   'year': 2007,
#   'genre': 'Comedy',
#   'avg_vote': 4.9,
#   'votes': 4576,
#   'worlwide_gross_income': 27769.0},
#  {'country': 'USA',
#   'original_title': 'Teen Witch',
#   'year': 1989,
#   'genre': 'Comedy',
#   'avg_vote': 6.1,
#   'votes': 8057,
#   'worlwide_gross_income': 27843.0},
#  {'country': 'UK',
#   'original_title': 'El Norte',
#   'year': 1983,
#   'genre': 'Drama',
#   'avg_vote': 7.7,
#   'votes': 4690,
#   'worlwide_gross_income': 27920.0},
#  {'country': 'USA',
#   'original_title': 'Like Sunday, Like Rain',
#   'year': 2014,
#   'genre': 'Drama',
#   'avg_vote': 6.9,
#   'votes': 4154,
#   'worlwide_gross_income': 28208.0},
#  {'country': 'USA',
#   'original_title': 'Date and Switch',
#   'year': 2014,
#   'genre': 'Comedy',
#   'avg_vote': 5.7,
#   'votes': 7621,
#   'worlwide_gross_income': 28222.0},
#  {'country': 'India',
#   'original_title': 'Manam',
#   'year': 2014,
#   'genre': 'Comedy',
#   'avg_vote': 8.0,
#   'votes': 9715,
#   'worlwide_gross_income': 28369.0},
#  {'country': 'USA',
#   'original_title': 'The Strange Ones',
#   'year': 2017,
#   'genre': 'Drama',
#   'avg_vote': 5.0,
#   'votes': 2304,
#   'worlwide_gross_income': 28374.0},
#  {'country': 'USA',
#   'original_title': 'Struck by Lightning',
#   'year': 2012,
#   'genre': 'Comedy',
#   'avg_vote': 6.3,
#   'votes': 14374,
#   'worlwide_gross_income': 28378.0},
#  {'country': 'Romania',
#   'original_title': 'Katalin Varga',
#   'year': 2009,
#   'genre': 'Crime',
#   'avg_vote': 7.0,
#   'votes': 2485,
#   'worlwide_gross_income': 28399.0},
#  {'country': 'USA',
#   'original_title': 'Carrie Pilby',
#   'year': 2016,
#   'genre': 'Comedy',
#   'avg_vote': 6.6,
#   'votes': 7567,
#   'worlwide_gross_income': 28430.0},
#  {'country': 'Japan',
#   'original_title': 'Akarui mirai',
#   'year': 2002,
#   'genre': 'Drama',
#   'avg_vote': 6.8,
#   'votes': 2506,
#   'worlwide_gross_income': 28463.0},
#  {'country': 'USA',
#   'original_title': 'The Final',
#   'year': 2010,
#   'genre': 'Drama',
#   'avg_vote': 5.4,
#   'votes': 10309,
#   'worlwide_gross_income': 28491.0},
#  {'country': 'Japan',
#   'original_title': 'Sanma no aji',
#   'year': 1962,
#   'genre': 'Drama',
#   'avg_vote': 8.1,
#   'votes': 7629,
#   'worlwide_gross_income': 28538.0},
#  {'country': 'USA',
#   'original_title': 'Some Came Running',
#   'year': 1958,
#   'genre': 'Drama',
#   'avg_vote': 7.4,
#   'votes': 5541,
#   'worlwide_gross_income': 28594.0},
#  {'country': 'USA',
#   'original_title': 'The Transfiguration',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 6.1,
#   'votes': 3395,
#   'worlwide_gross_income': 28631.0},
#  {'country': 'UK',
#   'original_title': 'The Debt Collector',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 5.7,
#   'votes': 4770,
#   'worlwide_gross_income': 28645.0},
#  {'country': 'Taiwan',
#   'original_title': 'Qing shao nian nuo zha',
#   'year': 1992,
#   'genre': 'Crime',
#   'avg_vote': 7.6,
#   'votes': 3398,
#   'worlwide_gross_income': 28791.0},
#  {'country': 'USA',
#   'original_title': 'Plush',
#   'year': 2013,
#   'genre': 'Drama',
#   'avg_vote': 5.3,
#   'votes': 3654,
#   'worlwide_gross_income': 28864.0},
#  {'country': 'India',
#   'original_title': 'Freaky Ali',
#   'year': 2016,
#   'genre': 'Comedy',
#   'avg_vote': 4.9,
#   'votes': 2523,
#   'worlwide_gross_income': 28940.0},
#  {'country': 'Canada',
#   'original_title': 'Distorted',
#   'year': 2018,
#   'genre': 'Crime',
#   'avg_vote': 4.8,
#   'votes': 4507,
#   'worlwide_gross_income': 28951.0},
#  {'country': 'India',
#   'original_title': 'Khaidi No. 150',
#   'year': 2017,
#   'genre': 'Action',
#   'avg_vote': 6.0,
#   'votes': 3148,
#   'worlwide_gross_income': 28995.0},
#  {'country': 'India',
#   'original_title': 'Pyaar Impossible!',
#   'year': 2010,
#   'genre': 'Comedy',
#   'avg_vote': 4.6,
#   'votes': 2910,
#   'worlwide_gross_income': 29117.0},
#  {'country': 'USA',
#   'original_title': 'Buffaloed',
#   'year': 2019,
#   'genre': 'Comedy',
#   'avg_vote': 6.2,
#   'votes': 2561,
#   'worlwide_gross_income': 29118.0},
#  {'country': 'UK',
#   'original_title': 'Billy Liar',
#   'year': 1963,
#   'genre': 'Comedy',
#   'avg_vote': 7.3,
#   'votes': 5750,
#   'worlwide_gross_income': 29153.0},
#  {'country': 'USA',
#   'original_title': 'Freaked',
#   'year': 1993,
#   'genre': 'Comedy',
#   'avg_vote': 6.4,
#   'votes': 6238,
#   'worlwide_gross_income': 29296.0},
#  {'country': 'USA',
#   'original_title': 'The Eyes of My Mother',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 6.2,
#   'votes': 11061,
#   'worlwide_gross_income': 29539.0},
#  {'country': 'USA',
#   'original_title': 'The Ghost and Mrs. Muir',
#   'year': 1947,
#   'genre': 'Comedy',
#   'avg_vote': 7.9,
#   'votes': 15297,
#   'worlwide_gross_income': 29545.0},
#  {'country': 'France',
#   'original_title': 'Les amants du Pont-Neuf',
#   'year': 1991,
#   'genre': 'Drama',
#   'avg_vote': 7.6,
#   'votes': 12084,
#   'worlwide_gross_income': 29679.0},
#  {'country': 'USA',
#   'original_title': 'The Asphalt Jungle',
#   'year': 1950,
#   'genre': 'Crime',
#   'avg_vote': 7.9,
#   'votes': 23441,
#   'worlwide_gross_income': 29868.0},
#  {'country': 'Japan',
#   'original_title': 'Otoshiana',
#   'year': 1962,
#   'genre': 'Crime',
#   'avg_vote': 7.6,
#   'votes': 3413,
#   'worlwide_gross_income': 30078.0},
#  {'country': 'UK',
#   'original_title': 'The Innocents',
#   'year': 1961,
#   'genre': 'Horror',
#   'avg_vote': 7.8,
#   'votes': 25893,
#   'worlwide_gross_income': 30103.0},
#  {'country': 'UK',
#   'original_title': 'The Life and Death of Colonel Blimp',
#   'year': 1943,
#   'genre': 'Drama',
#   'avg_vote': 8.1,
#   'votes': 12813,
#   'worlwide_gross_income': 30129.0},
#  {'country': 'USA',
#   'original_title': 'Standing Still',
#   'year': 2005,
#   'genre': 'Comedy',
#   'avg_vote': 5.7,
#   'votes': 2217,
#   'worlwide_gross_income': 30142.0},
#  {'country': 'UK',
#   'original_title': 'The Red Shoes',
#   'year': 1948,
#   'genre': 'Drama',
#   'avg_vote': 8.1,
#   'votes': 29901,
#   'worlwide_gross_income': 30165.0},
#  {'country': 'UK',
#   'original_title': 'The Rezort',
#   'year': 2015,
#   'genre': 'Horror',
#   'avg_vote': 5.3,
#   'votes': 8663,
#   'worlwide_gross_income': 30194.0},
#  {'country': 'USA',
#   'original_title': 'Free Enterprise',
#   'year': 1998,
#   'genre': 'Comedy',
#   'avg_vote': 6.7,
#   'votes': 3103,
#   'worlwide_gross_income': 30229.0},
#  {'country': 'USA',
#   'original_title': 'Down to the Bone',
#   'year': 2004,
#   'genre': 'Drama',
#   'avg_vote': 6.7,
#   'votes': 2113,
#   'worlwide_gross_income': 30241.0},
#  {'country': 'USA',
#   'original_title': 'Happy Christmas',
#   'year': 2014,
#   'genre': 'Comedy',
#   'avg_vote': 5.4,
#   'votes': 7549,
#   'worlwide_gross_income': 30312.0},
#  {'country': 'USA',
#   'original_title': 'Love Is a Many-Splendored Thing',
#   'year': 1955,
#   'genre': 'Biography',
#   'avg_vote': 6.5,
#   'votes': 4363,
#   'worlwide_gross_income': 30330.0},
#  {'country': 'Canada',
#   'original_title': 'Rock & Rule',
#   'year': 1983,
#   'genre': 'Animation',
#   'avg_vote': 6.6,
#   'votes': 3140,
#   'worlwide_gross_income': 30379.0},
#  {'country': 'USA',
#   'original_title': 'The Boondock Saints',
#   'year': 1999,
#   'genre': 'Action',
#   'avg_vote': 7.8,
#   'votes': 224749,
#   'worlwide_gross_income': 30471.0},
#  {'country': 'Italy',
#   'original_title': 'Fanfan la Tulipe',
#   'year': 1952,
#   'genre': 'Adventure',
#   'avg_vote': 7.2,
#   'votes': 2510,
#   'worlwide_gross_income': 30590.0},
#  {'country': 'France',
#   'original_title': 'The Factory',
#   'year': 2012,
#   'genre': 'Crime',
#   'avg_vote': 5.8,
#   'votes': 10430,
#   'worlwide_gross_income': 30640.0},
#  {'country': 'India',
#   'original_title': 'Aladin',
#   'year': 2009,
#   'genre': 'Action',
#   'avg_vote': 4.6,
#   'votes': 2713,
#   'worlwide_gross_income': 30879.0},
#  {'country': 'UK',
#   'original_title': 'Gangster No. 1',
#   'year': 2000,
#   'genre': 'Crime',
#   'avg_vote': 6.8,
#   'votes': 12968,
#   'worlwide_gross_income': 30915.0},
#  {'country': 'UK',
#   'original_title': 'How to Be',
#   'year': 2008,
#   'genre': 'Comedy',
#   'avg_vote': 5.5,
#   'votes': 3709,
#   'worlwide_gross_income': 30945.0},
#  {'country': 'USA',
#   'original_title': 'Waterloo Bridge',
#   'year': 1940,
#   'genre': 'Drama',
#   'avg_vote': 7.8,
#   'votes': 8727,
#   'worlwide_gross_income': 31111.0},
#  {'country': 'Canada',
#   'original_title': 'Small Town Murder Songs',
#   'year': 2010,
#   'genre': 'Crime',
#   'avg_vote': 5.9,
#   'votes': 2799,
#   'worlwide_gross_income': 31133.0},
#  {'country': 'Canada',
#   'original_title': 'Rupture',
#   'year': 2016,
#   'genre': 'Horror',
#   'avg_vote': 4.8,
#   'votes': 6180,
#   'worlwide_gross_income': 31238.0},
#  {'country': 'USA',
#   'original_title': 'Bootmen',
#   'year': 2000,
#   'genre': 'Comedy',
#   'avg_vote': 6.2,
#   'votes': 2221,
#   'worlwide_gross_income': 31288.0},
#  {'country': 'Germany',
#   'original_title': 'Funny Money',
#   'year': 2006,
#   'genre': 'Comedy',
#   'avg_vote': 5.3,
#   'votes': 2858,
#   'worlwide_gross_income': 31290.0},
#  {'country': 'USA',
#   'original_title': 'Don Verdean',
#   'year': 2015,
#   'genre': 'Adventure',
#   'avg_vote': 5.4,
#   'votes': 4779,
#   'worlwide_gross_income': 31309.0},
#  {'country': 'Serbia',
#   'original_title': 'Zone of the Dead',
#   'year': 2009,
#   'genre': 'Action',
#   'avg_vote': 3.9,
#   'votes': 3039,
#   'worlwide_gross_income': 31401.0},
#  {'country': 'France',
#   'original_title': 'Céline et Julie vont en bateau: Phantom Ladies Over Paris',
#   'year': 1974,
#   'genre': 'Comedy',
#   'avg_vote': 7.5,
#   'votes': 4622,
#   'worlwide_gross_income': 31452.0},
#  {'country': 'USA',
#   'original_title': 'McCabe & Mrs. Miller',
#   'year': 1971,
#   'genre': 'Drama',
#   'avg_vote': 7.7,
#   'votes': 21506,
#   'worlwide_gross_income': 31558.0},
#  {'country': 'Canada',
#   'original_title': 'Operation Avalanche',
#   'year': 2016,
#   'genre': 'Drama',
#   'avg_vote': 6.1,
#   'votes': 6551,
#   'worlwide_gross_income': 31585.0},
#  {'country': 'USA',
#   'original_title': 'The Institute',
#   'year': 2017,
#   'genre': 'Thriller',
#   'avg_vote': 4.1,
#   'votes': 2584,
#   'worlwide_gross_income': 31634.0},
#  {'country': 'France',
#   'original_title': 'Al di là delle nuvole',
#   'year': 1995,
#   'genre': 'Drama',
#   'avg_vote': 6.5,
#   'votes': 5374,
#   'worlwide_gross_income': 31738.0},
#  {'country': 'UK',
#   'original_title': 'Pandora and the Flying Dutchman',
#   'year': 1951,
#   'genre': 'Drama',
#   'avg_vote': 7.0,
#   'votes': 3240,
#   'worlwide_gross_income': 31805.0},
#  {'country': 'USA',
#   'original_title': 'Amira & Sam',
#   'year': 2014,
#   'genre': 'Comedy',
#   'avg_vote': 6.1,
#   'votes': 2496,
#   'worlwide_gross_income': 31849.0},
#  {'country': 'Canada',
#   'original_title': 'Pontypool',
#   'year': 2008,
#   'genre': 'Fantasy',
#   'avg_vote': 6.6,
#   'votes': 28597,
#   'worlwide_gross_income': 32118.0},
#  {'country': 'USA',
#   'original_title': 'Brotherhood',
#   'year': 2010,
#   'genre': 'Crime',
#   'avg_vote': 6.4,
#   'votes': 3861,
#   'worlwide_gross_income': 32416.0},
#  {'country': 'USA',
#   'original_title': 'The Atticus Institute',
#   'year': 2015,
#   'genre': 'Horror',
#   'avg_vote': 5.5,
#   'votes': 8099,
#   'worlwide_gross_income': 32521.0},
#  {'country': 'UK',
#   'original_title': 'The Cry of the Owl',
#   'year': 2009,
#   'genre': 'Drama',
#   'avg_vote': 5.9,
#   'votes': 4332,
#   'worlwide_gross_income': 32572.0},
#  {'country': 'USA',
#   'original_title': 'The Birds',
#   'year': 1963,
#   'genre': 'Drama',
#   'avg_vote': 7.7,
#   'votes': 167317,
#   'worlwide_gross_income': 32655.0},
#  {'country': 'France',
#   'original_title': 'La religieuse',
#   'year': 1966,
#   'genre': 'Drama',
#   'avg_vote': 7.5,
#   'votes': 2277,
#   'worlwide_gross_income': 32659.0},
#  {'country': 'France',
#   'original_title': "L'âge d'or",
#   'year': 1930,
#   'genre': 'Comedy',
#   'avg_vote': 7.3,
#   'votes': 12551,
#   'worlwide_gross_income': 32712.0},
#  {'country': 'Serbia',
#   'original_title': 'Neprijatelj',
#   'year': 2011,
#   'genre': 'Drama',
#   'avg_vote': 7.4,
#   'votes': 2343,
#   'worlwide_gross_income': 32764.0},
#  {'country': 'USA',
#   'original_title': 'The Intervention',
#   'year': 2016,
#   'genre': 'Comedy',
#   'avg_vote': 6.0,
#   'votes': 5652,
#   'worlwide_gross_income': 32919.0},
#  {'country': 'India',
#   'original_title': 'Pataakha',
#   'year': 2018,
#   'genre': 'Action',
#   'avg_vote': 7.2,
#   'votes': 3500,
#   'worlwide_gross_income': 32929.0},
#  ...]

# %%
country_csv = "movies per country.csv"
country_df = pd.read_csv(country_csv)
country_df = country_df.rename(columns={"0":"count"})
country_df
# Out:
#      country  count
# 0        USA  30908
# 1      India   6189
# 2         UK   5889
# 3     France   5202
# 4      Italy   3785
# ..       ...    ...
# 156   Zambia      1
# 157  Lesotho      1
# 158     Laos      1
# 159    Korea      1
# 160    Libya      1
#
# [161 rows x 2 columns]

# %%
country_df.to_dict('records')
# Out:
# [{'country': 'USA', 'count': 30908},
#  {'country': 'India', 'count': 6189},
#  {'country': 'UK', 'count': 5889},
#  {'country': 'France', 'count': 5202},
#  {'country': 'Italy', 'count': 3785},
#  {'country': 'Japan', 'count': 3275},
#  {'country': 'Canada', 'count': 2508},
#  {'country': 'Germany', 'count': 2039},
#  {'country': 'Spain', 'count': 1788},
#  {'country': 'Hong Kong', 'count': 1527},
#  {'country': 'Turkey', 'count': 1468},
#  {'country': 'South Korea', 'count': 1184},
#  {'country': 'Australia', 'count': 961},
#  {'country': 'Russia', 'count': 940},
#  {'country': 'Sweden', 'count': 855},
#  {'country': 'Brazil', 'count': 846},
#  {'country': 'Mexico', 'count': 830},
#  {'country': 'Soviet Union', 'count': 816},
#  {'country': 'China', 'count': 802},
#  {'country': 'Denmark', 'count': 756},
#  {'country': 'Poland', 'count': 731},
#  {'country': 'Iran', 'count': 701},
#  {'country': 'Netherlands', 'count': 663},
#  {'country': 'Greece', 'count': 640},
#  {'country': 'Argentina', 'count': 633},
#  {'country': 'West Germany', 'count': 602},
#  {'country': 'Finland', 'count': 574},
#  {'country': 'Belgium', 'count': 459},
#  {'country': 'Hungary', 'count': 455},
#  {'country': 'Egypt', 'count': 448},
#  {'country': 'Norway', 'count': 440},
#  {'country': 'Romania', 'count': 353},
#  {'country': 'Philippines', 'count': 325},
#  {'country': 'Taiwan', 'count': 308},
#  {'country': 'Yugoslavia', 'count': 306},
#  {'country': 'Thailand', 'count': 298},
#  {'country': 'Czech Republic', 'count': 296},
#  {'country': 'Czechoslovakia', 'count': 291},
#  {'country': 'Ireland', 'count': 282},
#  {'country': 'Indonesia', 'count': 267},
#  {'country': 'Israel', 'count': 264},
#  {'country': 'Portugal', 'count': 257},
#  {'country': 'Switzerland', 'count': 248},
#  {'country': 'Austria', 'count': 237},
#  {'country': 'South Africa', 'count': 203},
#  {'country': 'Chile', 'count': 180},
#  {'country': 'New Zealand', 'count': 176},
#  {'country': 'Bulgaria', 'count': 167},
#  {'country': 'Serbia', 'count': 156},
#  {'country': 'Croatia', 'count': 135},
#  {'country': 'Colombia', 'count': 133},
#  {'country': 'Iceland', 'count': 109},
#  {'country': 'Bangladesh', 'count': 106},
#  {'country': 'Estonia', 'count': 84},
#  {'country': 'Pakistan', 'count': 78},
#  {'country': 'Malaysia', 'count': 77},
#  {'country': 'Ukraine', 'count': 77},
#  {'country': 'Lithuania', 'count': 75},
#  {'country': 'Federal Republic of Yugoslavia', 'count': 70},
#  {'country': 'Singapore', 'count': 67},
#  {'country': 'Slovenia', 'count': 64},
#  {'country': 'East Germany', 'count': 60},
#  {'country': 'Peru', 'count': 58},
#  {'country': 'Vietnam', 'count': 57},
#  {'country': 'Dominican Republic', 'count': 44},
#  {'country': 'Georgia', 'count': 44},
#  {'country': 'Venezuela', 'count': 44},
#  {'country': 'Latvia', 'count': 43},
#  {'country': 'Sri Lanka', 'count': 38},
#  {'country': 'Slovakia', 'count': 36},
#  {'country': 'Cuba', 'count': 35},
#  {'country': 'Lebanon', 'count': 33},
#  {'country': 'Republic of North Macedonia', 'count': 32},
#  {'country': 'Bosnia and Herzegovina', 'count': 30},
#  {'country': 'Kazakhstan', 'count': 30},
#  {'country': 'Luxembourg', 'count': 30},
#  {'country': 'Uruguay', 'count': 28},
#  {'country': 'Nigeria', 'count': 28},
#  {'country': 'Nepal', 'count': 25},
#  {'country': 'Puerto Rico', 'count': 25},
#  {'country': 'Tunisia', 'count': 24},
#  {'country': 'United Arab Emirates', 'count': 23},
#  {'country': 'Algeria', 'count': 19},
#  {'country': 'Albania', 'count': 19},
#  {'country': 'Bolivia', 'count': 19},
#  {'country': 'Azerbaijan', 'count': 19},
#  {'country': 'Costa Rica', 'count': 18},
#  {'country': 'Palestine', 'count': 15},
#  {'country': 'Senegal', 'count': 14},
#  {'country': 'Morocco', 'count': 14},
#  {'country': 'Armenia', 'count': 14},
#  {'country': 'Ecuador', 'count': 13},
#  {'country': 'Kosovo', 'count': 12},
#  {'country': 'Jamaica', 'count': 12},
#  {'country': 'Iraq', 'count': 12},
#  {'country': 'Kyrgyzstan', 'count': 9},
#  {'country': 'Guatemala', 'count': 9},
#  {'country': 'Malta', 'count': 9},
#  {'country': 'Mongolia', 'count': 9},
#  {'country': 'Panama', 'count': 8},
#  {'country': 'Cyprus', 'count': 8},
#  {'country': 'Afghanistan', 'count': 7},
#  {'country': 'Burkina Faso', 'count': 7},
#  {'country': 'Saudi Arabia', 'count': 7},
#  {'country': 'Bahamas', 'count': 7},
#  {'country': 'Jordan', 'count': 6},
#  {'country': 'Cambodia', 'count': 6},
#  {'country': 'Bhutan', 'count': 6},
#  {'country': 'Syria', 'count': 5},
#  {'country': 'Angola', 'count': 5},
#  {'country': 'Mali', 'count': 5},
#  {'country': 'North Korea', 'count': 5},
#  {'country': 'Montenegro', 'count': 5},
#  {'country': 'Uganda', 'count': 4},
#  {'country': 'Trinidad and Tobago', 'count': 4},
#  {'country': 'Tajikistan', 'count': 4},
#  {'country': 'Aruba', 'count': 4},
#  {'country': 'Paraguay', 'count': 4},
#  {'country': 'Myanmar', 'count': 4},
#  {'country': 'Kenya', 'count': 4},
#  {'country': 'Ghana', 'count': 4},
#  {'country': 'Ethiopia', 'count': 4},
#  {'country': 'Greenland', 'count': 4},
#  {'country': 'Moldova', 'count': 3},
#  {'country': 'Belarus', 'count': 3},
#  {'country': 'Liechtenstein', 'count': 3},
#  {'country': 'Yemen', 'count': 3},
#  {'country': 'Honduras', 'count': 3},
#  {'country': 'Mozambique', 'count': 2},
#  {'country': 'Haiti', 'count': 2},
#  {'country': 'Chad', 'count': 2},
#  {'country': 'Isle Of Man', 'count': 2},
#  {'country': 'Kuwait', 'count': 2},
#  {'country': 'Serbia and Montenegro', 'count': 2},
#  {'country': "Côte d'Ivoire", 'count': 2},
#  {'country': 'Nicaragua', 'count': 2},
#  {'country': 'Andorra', 'count': 1},
#  {'country': 'Brunei', 'count': 1},
#  {'country': 'Bermuda', 'count': 1},
#  {'country': 'Zimbabwe', 'count': 1},
#  {'country': 'Gibraltar', 'count': 1},
#  {'country': 'Papua New Guinea', 'count': 1},
#  {'country': 'Uzbekistan', 'count': 1},
#  {'country': 'The Democratic Republic Of Congo', 'count': 1},
#  {'country': 'Tanzania', 'count': 1},
#  {'country': 'Suriname', 'count': 1},
#  {'country': 'Sudan', 'count': 1},
#  {'country': 'Somalia', 'count': 1},
#  {'country': 'Rwanda', 'count': 1},
#  {'country': 'Qatar', 'count': 1},
#  {'country': 'Oman', 'count': 1},
#  {'country': 'Guinea', 'count': 1},
#  {'country': 'North Vietnam', 'count': 1},
#  {'country': 'Netherlands Antilles', 'count': 1},
#  {'country': 'Mauritius', 'count': 1},
#  {'country': 'Mauritania', 'count': 1},
#  {'country': 'Zambia', 'count': 1},
#  {'country': 'Lesotho', 'count': 1},
#  {'country': 'Laos', 'count': 1},
#  {'country': 'Korea', 'count': 1},
#  {'country': 'Libya', 'count': 1}]
