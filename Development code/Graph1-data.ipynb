# %% [markdown]
# This file is transforming the main file into different csv to be used during the analysis.

# %%
import pandas as pd
import numpy as np

# %%
movie_data = "IMDB movies.csv"

movie_df = pd.read_csv(movie_data)
movie_df
# Out:
# C:\Users\leann\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       imdb_title_id                    title           original_title  year  \
# 0         tt4635548                Wrong No.                Wrong No.  2015
# 1         tt3638644               Seto Surya               Seto Surya  2016
# 2         tt3565264                  Thegidi                  Thegidi  2014
# 3         tt0449869             Chandramukhi             Chandramukhi  2005
# 4         tt4442758                   Temper                   Temper  2015
# ...             ...                      ...                      ...   ...
# 85848     tt6021902           Death Forest 4           Death Forest 4  2016
# 85849     tt3262718          Bai bai, marâno          Bai bai, marâno  2013
# 85850     tt5874352    Utsuroi no hyôhonbako    Utsuroi no hyôhonbako  2016
# 85851     tt4837074  Ritoru Kyouta no bouken  Ritoru Kyouta no bouken  2017
# 85852     tt1244614           Prema Panjaram           Prema Panjaram  1991
#
#       date_published                     genre  duration  \
# 0         18/07/2015           Comedy, Romance       133
# 1          9/12/2016          Adventure, Drama        89
# 2         28/02/2014  Crime, Mystery, Thriller       126
# 3         13/04/2005   Action, Comedy, Fantasy       166
# 4         13/02/2015             Action, Drama       147
# ...              ...                       ...       ...
# 85848      3/05/2016                    Horror        70
# 85849      8/07/2013                     Drama       114
# 85850     29/10/2016                    Comedy        95
# 85851      1/04/2017                 Adventure        82
# 85852           1991             Drama, Family       138
#
#                                   country  language           director  ...  \
# 0                                Pakistan      Urdu        Yasir Nawaz  ...
# 1      Nepal, Netherlands, Qatar, USA, UK    Nepali    Deepak Rauniyar  ...
# 2                                   India     Tamil          P. Ramesh  ...
# 3                                   India     Tamil            P. Vasu  ...
# 4                                   India    Telugu     Puri Jagannadh  ...
# ...                                   ...       ...                ...  ...
# 85848                               Japan  Japanese     Yasutake Torii  ...
# 85849                               Japan  Japanese          Yunsu Kim  ...
# 85850                               Japan  Japanese     Keiko Tsuruoka  ...
# 85851                               Japan  Japanese      Satsuki Okawa  ...
# 85852                               India    Telugu  Ramana Reddy B.V.  ...
#
#       avg_vote votes budget usa_gross_income  worlwide_gross_income  \
# 0          6.7  1752    NaN              NaN          PKR 157500000
# 1          7.1   475    NaN              NaN           NPR 20000000
# 2          7.7  2295    NaN              NaN           INR 76000000
# 3          7.1  4947    NaN              NaN          INR 750000000
# 4          7.4  5600    NaN              NaN          INR 740300000
# ...        ...   ...    ...              ...                    ...
# 85848      1.0   204    NaN              NaN                    NaN
# 85849      1.0   193    NaN              NaN                    NaN
# 85850      1.0   176    NaN              NaN                    NaN
# 85851      1.0   144    NaN              NaN                    NaN
# 85852      1.0   107    NaN              NaN                    NaN
#
#        metascore reviews_from_users reviews_from_critics Unnamed: 22  \
# 0            NaN               12.0                  5.0         NaN
# 1           81.0                4.0                 30.0         NaN
# 2            NaN               17.0                  4.0         NaN
# 3            NaN               36.0                 20.0         NaN
# 4            NaN               23.0                  4.0         NaN
# ...          ...                ...                  ...         ...
# 85848        NaN                NaN                  NaN         NaN
# 85849        NaN                NaN                  NaN         NaN
# 85850        NaN                NaN                  NaN         NaN
# 85851        NaN                NaN                  NaN         NaN
# 85852        NaN                NaN                  NaN         NaN
#
#        Over budget
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 85848          NaN
# 85849          NaN
# 85850          NaN
# 85851          NaN
# 85852          NaN
#
# [85853 rows x 24 columns]

# %%
del movie_df["title"]
del movie_df["Unnamed: 22"]
del movie_df["Over budget"]
movie_df.head()
# Out:
#   imdb_title_id original_title  year date_published                     genre  \
# 0     tt4635548      Wrong No.  2015     18/07/2015           Comedy, Romance
# 1     tt3638644     Seto Surya  2016      9/12/2016          Adventure, Drama
# 2     tt3565264        Thegidi  2014     28/02/2014  Crime, Mystery, Thriller
# 3     tt0449869   Chandramukhi  2005     13/04/2005   Action, Comedy, Fantasy
# 4     tt4442758         Temper  2015     13/02/2015             Action, Drama
#
#    duration                             country language         director  \
# 0       133                            Pakistan     Urdu      Yasir Nawaz
# 1        89  Nepal, Netherlands, Qatar, USA, UK   Nepali  Deepak Rauniyar
# 2       126                               India    Tamil        P. Ramesh
# 3       166                               India    Tamil          P. Vasu
# 4       147                               India   Telugu   Puri Jagannadh
#
#                              writer  ...  \
# 0                       Yasir Nawaz  ...
# 1     Deepak Rauniyar, David Barker  ...
# 2                         P. Ramesh  ...
# 3                           P. Vasu  ...
# 4  Puri Jagannadh, Vakkantham Vamsi  ...
#
#                                               actors  \
# 0  Javed Sheikh, Danish Taimoor, Janita Asma, Nay...
# 1  Dayahang Rai, Asha Magrati, Rabindra Singh Ban...
# 2  Ashok Selvan, Janani Iyer, V. Jayaprakash, Jay...
# 3  Rajinikanth, Jyotika, Prabhu, Nayanthara, Vadi...
# 4  N.T. Rama Rao Jr., Kajal Aggarwal, Prakash Raj...
#
#                                          description avg_vote  votes  budget  \
# 0  A story of a middle class guy, passionate abou...      6.7   1752     NaN
# 1  Anti-regime partisan Chandra confronts physica...      7.1    475     NaN
# 2  A plainclothe officer falls in the hands of ph...      7.7   2295     NaN
# 3  Creepy happenings in an abandoned mansion are ...      7.1   4947     NaN
# 4  Daya, a corrupt police officer, finds his life...      7.4   5600     NaN
#
#   usa_gross_income worlwide_gross_income metascore  reviews_from_users  \
# 0              NaN         PKR 157500000       NaN                12.0
# 1              NaN          NPR 20000000      81.0                 4.0
# 2              NaN          INR 76000000       NaN                17.0
# 3              NaN         INR 750000000       NaN                36.0
# 4              NaN         INR 740300000       NaN                23.0
#
#    reviews_from_critics
# 0                   5.0
# 1                  30.0
# 2                   4.0
# 3                  20.0
# 4                   4.0
#
# [5 rows x 21 columns]

# %%
movie_df['country'] = movie_df['country'].str.split(',').str[0]
movie_df.tail()
# Out:
#       imdb_title_id           original_title  year date_published  \
# 85848     tt6021902           Death Forest 4  2016      3/05/2016
# 85849     tt3262718          Bai bai, marâno  2013      8/07/2013
# 85850     tt5874352    Utsuroi no hyôhonbako  2016     29/10/2016
# 85851     tt4837074  Ritoru Kyouta no bouken  2017      1/04/2017
# 85852     tt1244614           Prema Panjaram  1991           1991
#
#                genre  duration country  language           director  \
# 85848         Horror        70   Japan  Japanese     Yasutake Torii
# 85849          Drama       114   Japan  Japanese          Yunsu Kim
# 85850         Comedy        95   Japan  Japanese     Keiko Tsuruoka
# 85851      Adventure        82   Japan  Japanese      Satsuki Okawa
# 85852  Drama, Family       138   India    Telugu  Ramana Reddy B.V.
#
#                                            writer  ...  \
# 85848                       Kazz, Satoshi Okonogi  ...
# 85849                                   Yunsu Kim  ...
# 85850                              Keiko Tsuruoka  ...
# 85851                               Satsuki Okawa  ...
# 85852  Ramana Reddy B.V., Gopalakrishna Paruchuri  ...
#
#                                                   actors  \
# 85848                      Cyborg Kaori, Daijiro Kawaoka
# 85849  Yumiko Hara, Sujin Lee, Gyô Miyamoto, Shû Naka...
# 85850  Mone Sakuragi, Gen Ogawa, Moeru Akazome, Kôsuk...
# 85851  Tao Tsuchiya, Misa Shimizu, Hidekazu Mashima, ...
# 85852  Mohan Babu, Brahmanandam, Harish, Madhubala, G...
#
#                                              description avg_vote  votes  \
# 85848  They took a bad turn when they took the short ...      1.0    204
# 85849                                                NaN      1.0    193
# 85850  A women challenges herself to do more and over...      1.0    176
# 85851                                                NaN      1.0    144
# 85852                                                NaN      1.0    107
#
#        budget usa_gross_income worlwide_gross_income metascore  \
# 85848     NaN              NaN                   NaN       NaN
# 85849     NaN              NaN                   NaN       NaN
# 85850     NaN              NaN                   NaN       NaN
# 85851     NaN              NaN                   NaN       NaN
# 85852     NaN              NaN                   NaN       NaN
#
#        reviews_from_users  reviews_from_critics
# 85848                 NaN                   NaN
# 85849                 NaN                   NaN
# 85850                 NaN                   NaN
# 85851                 NaN                   NaN
# 85852                 NaN                   NaN
#
# [5 rows x 21 columns]

# %%
movie_df['genre'] = movie_df['genre'].str.split(',').str[0]
movie_df.tail()
# Out:
#       imdb_title_id           original_title  year date_published      genre  \
# 85848     tt6021902           Death Forest 4  2016      3/05/2016     Horror
# 85849     tt3262718          Bai bai, marâno  2013      8/07/2013      Drama
# 85850     tt5874352    Utsuroi no hyôhonbako  2016     29/10/2016     Comedy
# 85851     tt4837074  Ritoru Kyouta no bouken  2017      1/04/2017  Adventure
# 85852     tt1244614           Prema Panjaram  1991           1991      Drama
#
#        duration country  language           director  \
# 85848        70   Japan  Japanese     Yasutake Torii
# 85849       114   Japan  Japanese          Yunsu Kim
# 85850        95   Japan  Japanese     Keiko Tsuruoka
# 85851        82   Japan  Japanese      Satsuki Okawa
# 85852       138   India    Telugu  Ramana Reddy B.V.
#
#                                            writer  ...  \
# 85848                       Kazz, Satoshi Okonogi  ...
# 85849                                   Yunsu Kim  ...
# 85850                              Keiko Tsuruoka  ...
# 85851                               Satsuki Okawa  ...
# 85852  Ramana Reddy B.V., Gopalakrishna Paruchuri  ...
#
#                                                   actors  \
# 85848                      Cyborg Kaori, Daijiro Kawaoka
# 85849  Yumiko Hara, Sujin Lee, Gyô Miyamoto, Shû Naka...
# 85850  Mone Sakuragi, Gen Ogawa, Moeru Akazome, Kôsuk...
# 85851  Tao Tsuchiya, Misa Shimizu, Hidekazu Mashima, ...
# 85852  Mohan Babu, Brahmanandam, Harish, Madhubala, G...
#
#                                              description avg_vote  votes  \
# 85848  They took a bad turn when they took the short ...      1.0    204
# 85849                                                NaN      1.0    193
# 85850  A women challenges herself to do more and over...      1.0    176
# 85851                                                NaN      1.0    144
# 85852                                                NaN      1.0    107
#
#        budget usa_gross_income worlwide_gross_income metascore  \
# 85848     NaN              NaN                   NaN       NaN
# 85849     NaN              NaN                   NaN       NaN
# 85850     NaN              NaN                   NaN       NaN
# 85851     NaN              NaN                   NaN       NaN
# 85852     NaN              NaN                   NaN       NaN
#
#        reviews_from_users  reviews_from_critics
# 85848                 NaN                   NaN
# 85849                 NaN                   NaN
# 85850                 NaN                   NaN
# 85851                 NaN                   NaN
# 85852                 NaN                   NaN
#
# [5 rows x 21 columns]

# %%
first_movie_df = movie_df[["country", "original_title", "year", "genre","votes","avg_vote"]]
first_movie_df
# Out:
#         country           original_title  year      genre  votes  avg_vote
# 0      Pakistan                Wrong No.  2015     Comedy   1752       6.7
# 1         Nepal               Seto Surya  2016  Adventure    475       7.1
# 2         India                  Thegidi  2014      Crime   2295       7.7
# 3         India             Chandramukhi  2005     Action   4947       7.1
# 4         India                   Temper  2015     Action   5600       7.4
# ...         ...                      ...   ...        ...    ...       ...
# 85848     Japan           Death Forest 4  2016     Horror    204       1.0
# 85849     Japan          Bai bai, marâno  2013      Drama    193       1.0
# 85850     Japan    Utsuroi no hyôhonbako  2016     Comedy    176       1.0
# 85851     Japan  Ritoru Kyouta no bouken  2017  Adventure    144       1.0
# 85852     India           Prema Panjaram  1991      Drama    107       1.0
#
# [85853 rows x 6 columns]

# %%
filtered_df = first_movie_df.loc[first_movie_df["votes"] >= 2000]
filtered_df
# Out:
#          country                    original_title  year   genre  votes  \
# 2          India                           Thegidi  2014   Crime   2295
# 3          India                      Chandramukhi  2005  Action   4947
# 4          India                            Temper  2015  Action   5600
# 7          India                     Gopala Gopala  2015  Comedy   3456
# 8          India                            Premam  2015  Comedy  16224
# ...          ...                               ...   ...     ...    ...
# 85743     Canada                    Jurassic Shark  2012  Action   3922
# 85744      India                        Desh Drohi  2008  Action   2270
# 85786         UK                The Butterfly Ball  1977   Music   2951
# 85805  Indonesia  Hanum & Rangga: Faith & The City  2018   Drama   3490
# 85839      India                           Sadak 2  2020  Action  53162
#
#        avg_vote
# 2           7.7
# 3           7.1
# 4           7.4
# 7           7.3
# 8           8.3
# ...         ...
# 85743       1.5
# 85744       1.5
# 85786       1.3
# 85805       1.2
# 85839       1.0
#
# [20012 rows x 6 columns]

# %%
filtered_df.to_csv("graph1-highest_rated.csv", encoding="utf-8", index=False, header=True)
